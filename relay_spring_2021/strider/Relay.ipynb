# %% [markdown]
# # Setup

# %%
import json
import requests
from datetime import datetime as dt
from collections import defaultdict
import pandas as pd
import copy

# %%
#https://pypi.org/project/gamma-viewer/
from gamma_viewer import GammaViewer
from IPython.display import display, Markdown

# %%
def printjson(j):
    print(json.dumps(j,indent=4))
def print_json(j):
    printjson(j)

# %%
def post(name,url,message,params=None):
    if params is None:
        response = requests.post(url,json=message)
    else:
        response = requests.post(url,json=message,params=params)
    if not response.status_code == 200:
        print(name, 'error:',response.status_code)
        print(response.json())
        return {}
    return response.json()

def automat(db,message):
    automat_url = f'https://automat.renci.org/{db}/query'
    response = requests.post(automat_url,json=message)
    print(response.status_code)
    return response.json()

def strider(message):
    url = 'https://strider.renci.org/query?log_level=DEBUG'
    strider_answer = post(strider,url,message)
    return strider_answer

def aragorn(message, coalesce_type='xnone'):
    if coalesce_type == 'xnone':
        answer = post('aragorn','https://aragorn.renci.org/query',message)
    else:
        answer = post('aragorn','https://aragorn.renci.org/query',message, params={'answer_coalesce_type':coalesce_type})
    return answer

##

def bte(message):
    url = 'https://api.bte.ncats.io/v1/query'
    return post(strider,url,message)

def coalesce(message,method='all'):
    url = 'https://answercoalesce.renci.org/coalesce/graph'
    return post('AC'+method,url,message)

def striderandfriends(message):
    strider_answer = strider(message)    
    coalesced_answer = post('coalesce','https://answercoalesce.renci.org/coalesce/all',strider_answer)
    omni_answer = post('omnicorp','https://aragorn-ranker.renci.org/omnicorp_overlay',coalesced_answer)
    weighted_answer = post('weight','https://aragorn-ranker.renci.org/weight_correctness',omni_answer)
    scored_answer = post('score','https://aragorn-ranker.renci.org/score',weighted_answer)
    return strider_answer,coalesced_answer,omni_answer,weighted_answer,scored_answer

def name_lookup(text):
    url= f'https://name-resolution-sri.renci.org/lookup?string={text}&offset=0&limit=10'
    response = requests.post(url)
    printjson(response.json())

# %%
def print_errors(strider_result):
    errorcounts = defaultdict(int)
    for logmessage in strider_result['logs']:
        if logmessage['level'] == 'ERROR':
            jm = json.loads(logmessage['message'])
            words = jm['error'].split()
            e = " ".join(words[:-5])
            errorcounts[e] += 1
    for error,count in errorcounts.items():
        print(f'{error} ({count} times)')
        
def print_queried_sources(strider_result):
    querycounts = defaultdict(int)
    for logmessage in strider_result['logs']:
        j = json.loads(logmessage['message'])
        if 'url' in j:
            querycounts[j['url']] += 1
    for url,count in querycounts.items():
        print(f'{url} ({count} times)')
        
def print_query_for_source(strider_result,url):
    for logmessage in strider_result['logs']:
        j = json.loads(logmessage['message'])
        if 'url' in j and j['url'] == url:
            print(j)
            return j

# %%
def retrieve_ars_results(mid):
    message_url = f'https://ars.transltr.io/ars/api/messages/{mid}?trace=y'
    response = requests.get(message_url)
    j = response.json()
    results = {}
    for child in j['children']:
        if child['actor']['agent'] in ['ara-aragorn', 'ara-aragorn-exp']:
            childmessage_id = child['message']
            child_url = f'https://ars.transltr.io/ars/api/messages/{childmessage_id}'
            child_response = requests.get(child_url).json()
            try:
                nresults = len(child_response['fields']['data']['message']['results'])
                if nresults > 0:
                    results[child['actor']['agent']] = {'message':child_response['fields']['data']['message']}
            except:
                nresults=0
            print( child['status'], child['actor']['agent'],nresults )
    return results

# %%
def get_provenance(message):
    """Given a message with results, find the source of the edges"""
    prov = defaultdict(lambda: defaultdict(int)) # {qedge->{source->count}}
    results = message['message']['results']
    kg = message['message']['knowledge_graph']['edges']
    edge_bindings = [ r['edge_bindings'] for r in results ]
    for bindings in edge_bindings:
        for qg_e, kg_l in bindings.items():
            for kg_e in kg_l:
                for att in kg[kg_e['id']]['attributes']:
                    if att['name'] == 'provenance':
                        source = att['value']
                        prov[qg_e][source]+=1
    qg_edges = []
    sources = []
    counts = []
    for qg_e in prov:
        for source in prov[qg_e]:
            qg_edges.append(qg_e)
            sources.append(source)
            counts.append(prov[qg_e][source])
    prov_table = pd.DataFrame({"QG Edge":qg_edges, "Source":sources, "Count":counts})
    return prov_table

# %%
def ac_to_table(aragorn_result,mnode):
    scores = []
    answer_node_count = []
    merged_count = []
    method = []
    extra = []
    for res_i, result in enumerate(aragorn_result['message']['results']):
        scores.append(result['score'])
        answer_node_count.append(len(result['node_bindings']))
        merged_count.append(len(result['node_bindings'][mnode]))
        try:
            method.append(result['node_bindings'][mnode][0]['coalescence_method'])
        except:
            method.append('Original')
    df = pd.DataFrame({'N_Answer_Nodes':answer_node_count, 'N_Merged_Nodes':merged_count, 'Method':method, 'Score':scores})
    return df

def filter_to_simple(aragorn_result,mnode):
    simple_result = copy.deepcopy(aragorn_result)
    simple_result['message']['results'] = list(
    filter( lambda x: 'coalescence_method' not in x['node_bindings'][mnode][0], 
           aragorn_result['message']['results'])
    )
    print(len(simple_result['message']['results']))
    return simple_result

def print_nodenames(simple_result,qnode):
    #Print the names of the answers
    for result in simple_result['message']['results']:
        #Each answer has an identifier:
        n1_id = result['node_bindings'][qnode][0]['id']
        #The information for that identifier is in the KG:
        node = simple_result['message']['knowledge_graph']['nodes'][n1_id]
        #Each node has a name
        print(node['name'])

def filter_to_coal(aragorn_result,mnode,method):
    #The results that have been coalesced:
    coalesced_results = list(
        filter( lambda x: 'coalescence_method'  in x['node_bindings'][mnode][0], 
               aragorn_result['message']['results'])
    )
    #Those that have been coalesced via a new node (graph coalescence)
    graph_coalesced_results = list(
        filter( lambda x: x['node_bindings'][mnode][0]['coalescence_method'] == method, coalesced_results)
    )
    print(len(graph_coalesced_results))
    simple_result = copy.deepcopy(aragorn_result)
    simple_result['message']['results'] = graph_coalesced_results
    return simple_result

def filter_to_gc(aragorn_result,mnode):
    return filter_to_coal(aragorn_result,mnode,'graph_enrichment')

def filter_to_pc(aragorn_result,mnode):
    return filter_to_coal(aragorn_result,mnode,'property_enrichment')

# %%
def submit_to_ars(m):
    submit_url = 'https://ars.transltr.io/ars/api/submit'
    response = requests.post(submit_url,json=m)
    try:
        message_id = response.json()['pk']
    except:
        print('fail')
        message_id = None
    print(f'https://arax.ncats.io/?source=ARS&id={message_id}')
    return message_id

def retrieve_ars_results(mid):
    message_url = f'https://ars.transltr.io/ars/api/messages/{mid}?trace=y'
    response = requests.get(message_url)
    j = response.json()
    print( j['status'] )
    results = {}
    for child in j['children']:
        if child['status'] == 'Done':
            childmessage_id = child['message']
            child_url = f'https://ars.transltr.io/ars/api/messages/{childmessage_id}'
            child_response = requests.get(child_url).json()
            try:
                nresults = len(child_response['fields']['data']['message']['results'])
                if nresults > 0:
                    results[child['actor']['agent']] = {'message':child_response['fields']['data']['message']}
            except:
                nresults=0
        else:
            nresults = 0
        print( child['status'], child['actor']['agent'],nresults )
    return results

# %%
def make_message(qg):
    return {"message": {"query_graph": qg}}

# %% [markdown]
# # DILI

# %%
dili_qg = {
  "nodes": {
    "n0": {
      "category": [
        "biolink:DiseaseOrPhenotypicFeature"
      ]
    },
    "n1": {
      "name": "DILI",
      "id": "MONDO:0005359"
    }
  },
  "edges": {
    "e0": {
      "subject": "n0",
      "object": "n1",
      "predicate": [
        "biolink:related_to"
      ]
    }
  }
}

# %%
dili_m = make_message(dili_qg)

# %% [markdown]
# ## Strider Direct

# %%
start = dt.now()
strider_result = strider(dili_m)
end = dt.now()
print(f"Strider produced {len(strider_result['message']['results'])} results in {end-start}.")
# Out:
# Strider produced 18 results in 0:00:20.726106.

# %% [markdown]
# ### Provenance

# %%
prov = get_provenance(strider_result)
display(prov)
# Out:
#   QG Edge                                       Source  Count
# 0      e0  https://stars-app.renci.org/sparql-kp/query     18

# %% [markdown]
# ### Queried sources

# %%
print_queried_sources(strider_result)
# Out:
# https://trapi.monarchinitiative.org/query (13 times)
# https://automat.renci.org/ontological-hierarchy/reasonerapi (8 times)
# https://automat.renci.org/uberongraph/reasonerapi (40 times)
# https://automat.renci.org/covidkopkg/reasonerapi (23 times)
# https://automat.renci.org/cord19-scigraph/reasonerapi (4 times)
# https://automat.renci.org/covid-phenotypes/reasonerapi (3 times)
# https://automat.renci.org/cord19-scibite/reasonerapi (4 times)
# https://automat.renci.org/robokopkg/reasonerapi (19 times)
# https://automat.renci.org/biolink/reasonerapi (3 times)
# https://automat.renci.org/hetio/reasonerapi (3 times)
# https://automat.renci.org/ctd/reasonerapi (2 times)
# https://stars-app.renci.org/sparql-kp/query (10 times)

# %% [markdown]
# ### Errors

# %%
print_errors(strider_result)

# %% [markdown]
# ### Results

# %%
view = GammaViewer(props={"data":strider_result})
display(view)

# %% [markdown]
# ### Strider Assessment

# %% [markdown]
# We are only getting "Affected by" results a la Molepro, which are not specific enough to make this work.  According to ROBOKOP there should be edges from ctd, pharos, and mychem with 'increases activity of'.  The logs look oddly truncated?

# %% [markdown]
# ## ARAGORN

# %%
start = dt.now()
aragorn_result = aragorn(egfr_m)
end = dt.now()
if 'results' in aragorn_result['message']:
    print(f"ARAGORN produced {len(aragorn_result['message']['results'])} results in {end-start}.")
else:
    print('Error, no result field')
# Out:
# Error, no result field

# %% [markdown]
# # KCNMA1

# %%
kcnma1_q={
  "nodes": {
    "n0": {
      "category": [
        "biolink:ChemicalSubstance"
      ],
      "name": "Chemical Substance"
    },
    "n1": {
      "name": "KCNMA1",
      "id": "NCBIGene:3778"
    }
  },
  "edges": {
    "e0": {
      "subject": "n0",
      "object": "n1",
      "predicate": [
        "biolink:related_to"
      ]
    }
  }
}

# %%
kcnma1_m = {'message': {'query_graph':kcnma1_q}}

# %%
strider_result_k = strider(kcnma1_m)

# %%
print(len(strider_result_k['message']['results']))
# Out:
# 90

# %%
strider_result_k['logs']
# Out:
# [{'timestamp': '2021-05-10T18:19:53.906474',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Received response from KP", "url": "https://translator.broadinstitute.org/molepro/trapi/v1.0/query", "request": {"message": {"query_graph": {"nodes": {"n1": {"category": "biolink:Gene", "is_set": false, "name": "KCNMA1", "id": "NCBIGene:3778"}, "n0": {"category": "biolink:ChemicalSubstance", "is_set": false, "name": "Chemical Substance"}}, "edges": {"e0": {"subject": "n1", "object": "n0", "predicate": "biolink:correlated_with"}}}}}, "response": {"message": {"knowledge_graph": {"edges": {"e0-bwXzl8nE4U": {"attributes": [], "object": "CHEMBL.COMPOUND:CHEMBL279157", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e1-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:95017", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e10-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:4911", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e11-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:93630", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e12-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:29022", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e13-bwXzl8nE4U": {"attributes": [], "object": "CHEMBL.COMPOUND:CHEMBL1983350", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e14-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:5855", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e15-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:93748", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e16-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:16619", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e17-bwXzl8nE4U": {"attributes": [], "object": "PUBCHEM.COMPOUND:16404350", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e18-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:31459", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e19-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:140628", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e2-bwXzl8nE4U": {"attributes": [], "object": "PUBCHEM.COMPOUND:6710776", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e20-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:91758", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e21-bwXzl8nE4U": {"attributes": [], "object": "PUBCHEM.COMPOUND:57448257", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e22-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:91615", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e23-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:6117", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e24-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:92103", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e25-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:88249", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e26-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:92537", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e27-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:50173", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e28-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:73731", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e29-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:63627", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e3-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:93432", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e30-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:91805", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e31-bwXzl8nE4U": {"attributes": [], "object": "CHEBI:91958", "predicate": "biolink:correlated_with", "subject": "NCBIGene:3778"}, "e32- ...
#  {'timestamp': '2021-05-10T18:19:53.640938',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "can\'t handle event type ConnectionClosed when role=SERVER and state=SEND_RESPONSE", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:53.553990',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "[Errno 32] Broken pipe", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:53.468152',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "[Errno 32] Broken pipe", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:53.392014',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "[Errno 32] Broken pipe", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:53.286175',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "[Errno 32] Broken pipe", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:53.210170',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=CHEBI%3A5615&curie=CHEBI%3A5784&curie=CHEBI%3A82892&curie=NCBIGene%3A3778&curie=CHEBI%3A41872&curie=CHEBI%3A59773&curie=CHEBI%3A3013&curie=CHEBI%3A5778&curie=CHEBI%3A4495", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=CHEBI%3A5615&curie=CHEBI%3A5784&curie=CHEBI%3A82892&curie=NCBIGene%3A3778&curie=CHEBI%3A41872&curie=CHEBI%3A59773&curie=CHEBI%3A3013&curie=CHEBI%3A5778&curie=CHEBI%3A4495", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "[Errno 32] Broken pipe", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:53.127346',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=PUBCHEM.COMPOUND%3A977&curie=NCIT%3AC2317&curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=PUBCHEM.COMPOUND%3A977&curie=NCIT%3AC2317&curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "[Errno 32] Broken pipe", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:53.010626',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "[Errno 32] Broken pipe", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:52.887956',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "[Errno 32] Broken pipe", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:52.446128',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Received response from KP", "url": "https://translator.broadinstitute.org/molepro/trapi/v1.0/query", "request": {"message": {"query_graph": {"nodes": {"n1": {"category": "biolink:Gene", "is_set": false, "name": "KCNMA1", "id": "NCBIGene:3778"}, "n0": {"category": "biolink:ChemicalSubstance", "is_set": false, "name": "Chemical Substance"}}, "edges": {"e0": {"subject": "n1", "object": "n0", "predicate": "biolink:affected_by"}}}}}, "response": {"message": {"knowledge_graph": {"edges": {"e0-3Mz4lJQRvB": {"attributes": [], "object": "CHEBI:3655", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e1-3Mz4lJQRvB": {"attributes": [], "object": "CHEBI:3013", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e10-8egG3V5wkW": {"attributes": [], "object": "CHEMBL.COMPOUND:CHEMBL1514181", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e11-8egG3V5wkW": {"attributes": [], "object": "CHEBI:16469", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e12-8egG3V5wkW": {"attributes": [], "object": "CHEMBL.COMPOUND:CHEMBL266510", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e13-8egG3V5wkW": {"attributes": [], "object": "CHEMBL.COMPOUND:CHEMBL375448", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e14-8egG3V5wkW": {"attributes": [], "object": "CHEBI:34879", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e15-8egG3V5wkW": {"attributes": [], "object": "PUBCHEM.COMPOUND:16133816", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e16-8egG3V5wkW": {"attributes": [], "object": "PUBCHEM.COMPOUND:56842037", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e17-8egG3V5wkW": {"attributes": [], "object": "PUBCHEM.COMPOUND:16132435", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e18-8egG3V5wkW": {"attributes": [], "object": "CHEBI:44296", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e19-8egG3V5wkW": {"attributes": [], "object": "GTOPDB:2306", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e2-3Mz4lJQRvB": {"attributes": [], "object": "CHEBI:5784", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e20-8egG3V5wkW": {"attributes": [], "object": "PUBCHEM.COMPOUND:4697", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e21-b2aAZPlaMN": {"attributes": [], "object": "CHEMBL.COMPOUND:CHEMBL1290115", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e22-b2aAZPlaMN": {"attributes": [], "object": "CHEBI:9683", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e23-b2aAZPlaMN": {"attributes": [], "object": "CHEBI:4792", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e24-b2aAZPlaMN": {"attributes": [], "object": "CHEBI:3640", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e25-b2aAZPlaMN": {"attributes": [], "object": "CHEMBL.COMPOUND:CHEMBL222460", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e26-b2aAZPlaMN": {"attributes": [], "object": "CHEMBL.COMPOUND:CHEMBL119549", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e3-3Mz4lJQRvB": {"attributes": [], "object": "CHEBI:5778", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e4-3Mz4lJQRvB": {"attributes": [], "object": "CHEBI:4495", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e5-3Mz4lJQRvB": {"attributes": [], "object": "CHEBI:5615", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e6-3Mz4lJQRvB": {"attributes": [], "object": "CHEBI:41872", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e7-3Mz4lJQRvB": {"attributes": [], "object": "CHEBI:8430", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e8-3Mz4lJQRvB": {"attributes": [], "object": "CHEBI:82892", "predicate": "biolink:affected_by", "subject": "NCBIGene:3778"}, "e9-3Mz4lJQRvB": {"attributes": [], "object":  ...
#  {'timestamp': '2021-05-10T18:19:52.382426',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Received response from KP", "url": "https://stars-app.renci.org/cam-kp/query", "request": {"message": {"query_graph": {"nodes": {"n1": {"category": "biolink:Gene", "is_set": false, "name": "KCNMA1", "id": "UniProtKB:Q12791"}, "n0": {"category": "biolink:ChemicalSubstance", "is_set": false, "name": "Chemical Substance"}}, "edges": {"e0": {"subject": "n1", "object": "n0", "predicate": "biolink:related_to"}}}}}, "response": {"message": {"query_graph": {"nodes": {"n1": {"id": "UniProtKB:Q12791", "category": "biolink:Gene", "is_set": false}, "n0": {"category": "biolink:ChemicalSubstance", "is_set": false}}, "edges": {"e0": {"predicate": ["biolink:related_to"], "subject": "n1", "object": "n0"}}}, "knowledge_graph": {"nodes": {}, "edges": {}}, "results": []}, "status": "Success"}, "line_number": 67}'},
#  {'timestamp': '2021-05-10T18:19:52.315813',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Received response from KP", "url": "https://stars-app.renci.org/cam-kp/query", "request": {"message": {"query_graph": {"nodes": {"n1": {"category": "biolink:Gene", "is_set": false, "name": "KCNMA1", "id": "UniProtKB:Q12791"}, "n0": {"category": "biolink:ChemicalSubstance", "is_set": false, "name": "Chemical Substance"}}, "edges": {"e0": {"subject": "n0", "object": "n1", "predicate": "biolink:related_to"}}}}}, "response": {"message": {"query_graph": {"nodes": {"n1": {"id": "UniProtKB:Q12791", "category": "biolink:Gene", "is_set": false}, "n0": {"category": "biolink:ChemicalSubstance", "is_set": false}}, "edges": {"e0": {"predicate": ["biolink:related_to"], "subject": "n0", "object": "n1"}}}, "knowledge_graph": {"nodes": {}, "edges": {}}, "results": []}, "status": "Success"}, "line_number": 67}'},
#  {'timestamp': '2021-05-10T18:19:52.154745',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "can\'t handle event type ConnectionClosed when role=SERVER and state=SEND_RESPONSE", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:52.040679',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:51.966844',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:51.892569',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:51.809510',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:51.717241',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:51.623412',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:51.537021',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=CHEBI%3A5784&curie=CHEBI%3A17245&curie=NCBIGene%3A3778&curie=CHEBI%3A4792&curie=CHEBI%3A3655&curie=CHEBI%3A29108&curie=CHEBI%3A29103&curie=CHEBI%3A59773&curie=CHEBI%3A3013&curie=CHEBI%3A5778&curie=CHEBI%3A4495", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=CHEBI%3A5784&curie=CHEBI%3A17245&curie=NCBIGene%3A3778&curie=CHEBI%3A4792&curie=CHEBI%3A3655&curie=CHEBI%3A29108&curie=CHEBI%3A29103&curie=CHEBI%3A59773&curie=CHEBI%3A3013&curie=CHEBI%3A5778&curie=CHEBI%3A4495", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:51.461912',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:51.387294',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:51.312635',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:51.226527',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:51.151537',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:51.074574',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:50.972641',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:50.893905',
#   'level': 'WARNING',
#   'code': None,
#   'message': '{"message": "RequestError contacting normalizer. Results may be incomplete", "request": {"py/object": "httpx.Request", "method": "GET", "url": {"py/object": "httpx.URL", "_uri_reference": {"py/object": "rfc3986.uri.URIReference", "py/newargs": {"py/tuple": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}, "encoding": "utf-8", "py/seq": ["https", "nodenormalization-sri.renci.org", "/get_normalized_nodes", "curie=NCBIGene%3A3778", null]}}, "headers": {"py/object": "httpx.Headers", "_list": [{"py/tuple": [{"py/b64": "SG9zdA=="}, {"py/b64": "aG9zdA=="}, {"py/b64": "bm9kZW5vcm1hbGl6YXRpb24tc3JpLnJlbmNpLm9yZw=="}]}, {"py/tuple": [{"py/b64": "QWNjZXB0"}, {"py/b64": "YWNjZXB0"}, {"py/b64": "Ki8q"}]}, {"py/tuple": [{"py/b64": "QWNjZXB0LUVuY29kaW5n"}, {"py/b64": "YWNjZXB0LWVuY29kaW5n"}, {"py/b64": "Z3ppcCwgZGVmbGF0ZQ=="}]}, {"py/tuple": [{"py/b64": "Q29ubmVjdGlvbg=="}, {"py/b64": "Y29ubmVjdGlvbg=="}, {"py/b64": "a2VlcC1hbGl2ZQ=="}]}, {"py/tuple": [{"py/b64": "VXNlci1BZ2VudA=="}, {"py/b64": "dXNlci1hZ2VudA=="}, {"py/b64": "cHl0aG9uLWh0dHB4LzAuMTYuMQ=="}]}], "_encoding": "ascii"}, "stream": {"py/object": "httpx._content.PlainByteStream", "_body": {"py/b64": ""}}}, "error": "", "line_number": 145}'},
#  {'timestamp': '2021-05-10T18:19:50.811303',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Received response from KP", "url": "https://automat.renci.org/ctd/reasonerapi", "request": {"message": {"query_graph": {"nodes": {"n1": {"category": "biolink:Gene", "is_set": false, "name": "KCNMA1", "id": "NCBIGene:3778"}, "n0": {"category": "biolink:ChemicalSubstance", "is_set": false, "name": "Chemical Substance"}}, "edges": {"e0": {"subject": "n0", "object": "n1", "predicate": "biolink:affects_molecular_modification_of"}}}}}, "response": {"message": {"query_graph": {"nodes": {"n1": {"id": ["NCBIGene:3778"], "category": ["biolink:Gene"], "is_set": false, "constraints": null, "name": "KCNMA1"}, "n0": {"id": null, "category": ["biolink:ChemicalSubstance"], "is_set": false, "constraints": null, "name": "Chemical Substance"}}, "edges": {"e0": {"subject": "n0", "object": "n1", "predicate": ["biolink:affects_molecular_modification_of"], "relation": null, "constraints": null}}}, "knowledge_graph": {"nodes": {}, "edges": {}}, "results": []}, "log_level": null}, "line_number": 67}'},
#  {'timestamp': '2021-05-10T18:19:50.744142',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Received response from KP", "url": "https://automat.renci.org/ctd/reasonerapi", "request": {"message": {"query_graph": {"nodes": {"n1": {"category": "biolink:Gene", "is_set": false, "name": "KCNMA1", "id": "NCBIGene:3778"}, "n0": {"category": "biolink:ChemicalSubstance", "is_set": false, "name": "Chemical Substance"}}, "edges": {"e0": {"subject": "n1", "object": "n0", "predicate": "biolink:increases_molecular_modification_of"}}}}}, "response": {"message": {"query_graph": {"nodes": {"n1": {"id": ["NCBIGene:3778"], "category": ["biolink:Gene"], "is_set": false, "constraints": null, "name": "KCNMA1"}, "n0": {"id": null, "category": ["biolink:ChemicalSubstance"], "is_set": false, "constraints": null, "name": "Chemical Substance"}}, "edges": {"e0": {"subject": "n1", "object": "n0", "predicate": ["biolink:increases_molecular_modification_of"], "relation": null, "constraints": null}}}, "knowledge_graph": {"nodes": {}, "edges": {}}, "results": []}, "log_level": null}, "line_number": 67}'},
#  {'timestamp': '2021-05-10T18:19:50.642552',
#   'level': 'DEBUG',
#   'code': None,
# ...
#  {'timestamp': '2021-05-10T18:18:42.782280',
#   'level': 'INFO',
#   'code': None,
#   'message': '{"message": "Found 300 plans, collapsed down to 1 plans", "line_number": 562}'},
#  {'timestamp': '2021-05-10T18:18:42.698476',
#   'level': 'INFO',
#   'code': None,
#   'message': '{"message": "Searching query graph permutations for plans", "line_number": 480}'},
#  {'timestamp': '2021-05-10T18:18:42.648977',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Pinned nodes to search from", "pinned": ["n1"], "line_number": 473}'},
#  {'timestamp': '2021-05-10T18:18:42.613912',
#   'level': 'INFO',
#   'code': None,
#   'message': '{"message": "Number of permutations to evaluate for planning", "permutations": 601, "line_number": 459}'},
#  {'timestamp': '2021-05-10T18:18:39.960793',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Annotated query graph with KPs", "filtered_qgraph": {"nodes": {"n0": {"id": null, "category": ["biolink:ChemicalSubstance"], "is_set": false, "name": "Chemical Substance"}, "n1": {"id": ["NCBIGene:3778"], "category": ["biolink:Gene"], "is_set": false, "name": "KCNMA1"}}, "edges": {"e0": {"subject": "n0", "object": "n1", "predicate": ["biolink:related_to"], "relation": null, "kps": [{"name": "cam", "url": "https://stars-app.renci.org/cam-kp/query", "preferred_prefixes": {"biolink:Gene": "UniProtKB", "biolink:BiologicalProcess": "GO"}, "in_transformers": {}, "out_transformers": {}, "edge_predicate": "-biolink:affects->", "source_category": "biolink:ChemicalSubstance", "target_category": "biolink:Gene", "reverse": false}, {"name": "cam", "url": "https://stars-app.renci.org/cam-kp/query", "preferred_prefixes": {"biolink:Gene": "UniProtKB", "biolink:BiologicalProcess": "GO"}, "in_transformers": {}, "out_transformers": {}, "edge_predicate": "-biolink:affects_activity_of->", "source_category": "biolink:ChemicalSubstance", "target_category": "biolink:Gene", "reverse": false}, {"name": "cam", "url": "https://stars-app.renci.org/cam-kp/query", "preferred_prefixes": {"biolink:Gene": "UniProtKB", "biolink:BiologicalProcess": "GO"}, "in_transformers": {}, "out_transformers": {}, "edge_predicate": "-biolink:related_to->", "source_category": "biolink:ChemicalSubstance", "target_category": "biolink:Gene", "reverse": false}, {"name": "cam", "url": "https://stars-app.renci.org/cam-kp/query", "preferred_prefixes": {"biolink:Gene": "UniProtKB", "biolink:BiologicalProcess": "GO"}, "in_transformers": {}, "out_transformers": {}, "edge_predicate": "-biolink:interacts_with->", "source_category": "biolink:ChemicalSubstance", "target_category": "biolink:Gene", "reverse": false}, {"name": "cam", "url": "https://stars-app.renci.org/cam-kp/query", "preferred_prefixes": {"biolink:Gene": "UniProtKB", "biolink:BiologicalProcess": "GO"}, "in_transformers": {}, "out_transformers": {}, "edge_predicate": "-biolink:molecularly_interacts_with->", "source_category": "biolink:ChemicalSubstance", "target_category": "biolink:Gene", "reverse": false}, {"name": "cam", "url": "https://stars-app.renci.org/cam-kp/query", "preferred_prefixes": {"biolink:Gene": "UniProtKB", "biolink:BiologicalProcess": "GO"}, "in_transformers": {}, "out_transformers": {}, "edge_predicate": "-biolink:physically_interacts_with->", "source_category": "biolink:ChemicalSubstance", "target_category": "biolink:Gene", "reverse": false}, {"name": "cam", "url": "https://stars-app.renci.org/cam-kp/query", "preferred_prefixes": {"biolink:Gene": "UniProtKB", "biolink:BiologicalProcess": "GO"}, "in_transformers": {}, "out_transformers": {}, "edge_predicate": "-biolink:has_part->", "source_category": "biolink:ChemicalSubstance", "target_category": "biolink:Gene", "reverse": false}, {"name": "cam", "url": "https://stars-app.renci.org/cam-kp/query", "preferred_prefixes": {"biolink:Gene": "UniProtKB", "biolink:BiologicalProcess": "GO"}, "in_transformers": {}, "out_transformers": {}, "edge_predicate": "-biolink:overlaps->", "source_category": "biolink:ChemicalSubstance", "target_category": "biolink:Gene", "reverse": false}, {"name": "cam", "url": "https://stars-app.renci.org/cam-kp/query", "preferred_prefixes": {"biolink:Gene": "UniProtKB", "biolink:BiologicalProcess": "GO"}, "in_transformers": {}, "out_transformers": {}, "edge_predicate": "-biolink:part_of->", "source_category": "biolink:ChemicalSubstance", "target_category": "biolink:Gene", "reverse": false}, {"name": "molepro", "url": "https://translator.broadinstitute.org/molepro/trapi/v1.0/query", "preferred_prefixes": {"biolink:Disease": "MONDO", "biolink:Gene": "NCBIGene", "biolink:ChemicalSubstance": "CHEMBL.COMPOUND"}, "in_transformers": {}, "out_transformers": {}, "edge_predicate": "-biolink:correlated_with->", "source_category": "biolink:ChemicalSubstance", "target_category": "biolink:Gene", "reverse": false}, {"name": "mol ...
#  {'timestamp': '2021-05-10T18:18:37.193536',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Annotated operation graph with KPs", "operation_graph": {"nodes": {"n0": {"id": null, "category": ["biolink:ChemicalSubstance", "biolink:FoodComponent", "biolink:Carbohydrate", "biolink:Nutrient", "biolink:Micronutrient", "biolink:Vitamin", "biolink:Macronutrient", "biolink:EnvironmentalFoodContaminant", "biolink:ProcessedMaterial", "biolink:FoodAdditive", "biolink:Metabolite", "biolink:ChemicalExposure", "biolink:ComplexChemicalExposure"], "is_set": false, "name": "Chemical Substance"}, "n1": {"id": ["NCBIGene:3778"], "category": ["biolink:Gene"], "is_set": false, "name": "KCNMA1"}}, "edges": {"e0": {"qg_edge_id": "e0", "edge_reverse": false, "source": "n0", "target": "n1", "predicate": ["-biolink:related_to->", "-biolink:derives_into->", "-biolink:has_metabolite->", "-biolink:expressed_in->", "-biolink:located_in->", "-biolink:temporally_related_to->", "-biolink:precedes->", "-biolink:preceded_by->", "-biolink:close_match->", "-biolink:exact_match->", "-biolink:same_as->", "-biolink:contraindicated_for->", "-biolink:prevented_by->", "-biolink:superclass_of->", "-biolink:derives_from->", "-biolink:is_metabolite_of->", "-biolink:in_taxon->", "-biolink:in_linkage_disequilibrium_with->", "-biolink:overlaps->", "-biolink:part_of->", "-biolink:is_active_ingredient_of->", "-biolink:food_component_of->", "-biolink:nutrient_of->", "-biolink:is_excipient_of->", "-biolink:has_part->", "-biolink:has_variant_part->", "-biolink:has_food_component->", "-biolink:has_nutrient->", "-biolink:has_active_ingredient->", "-biolink:has_excipient->", "-biolink:narrow_match->", "-biolink:genetic_association->", "-biolink:gene_associated_with_condition->", "-biolink:condition_associated_with_gene->", "-biolink:translation_of->", "-biolink:develops_from->", "-biolink:disease_has_basis_in->", "-biolink:phenotype_of->", "-biolink:transcribed_to->", "-biolink:affects_risk_for->", "-biolink:predisposes->", "-biolink:prevents->", "-biolink:has_completed->", "-biolink:affects->", "-biolink:affects_metabolic_processing_of->", "-biolink:decreases_metabolic_processing_of->", "-biolink:increases_metabolic_processing_of->", "-biolink:affects_response_to->", "-biolink:increases_response_to->", "-biolink:decreases_response_to->", "-biolink:entity_regulates_entity->", "-biolink:entity_negatively_regulates_entity->", "-biolink:entity_positively_regulates_entity->", "-biolink:affects_expression_in->", "-biolink:affects_stability_of->", "-biolink:increases_stability_of->", "-biolink:decreases_stability_of->", "-biolink:affects_synthesis_of->", "-biolink:decreases_synthesis_of->", "-biolink:increases_synthesis_of->", "-biolink:disrupts->", "-biolink:exacerbates->", "-biolink:affects_folding_of->", "-biolink:decreases_folding_of->", "-biolink:increases_folding_of->", "-biolink:affects_transport_of->", "-biolink:increases_transport_of->", "-biolink:decreases_transport_of->", "-biolink:affects_expression_of->", "-biolink:increases_expression_of->", "-biolink:decreases_expression_of->", "-biolink:affects_mutation_rate_of->", "-biolink:increases_mutation_rate_of->", "-biolink:decreases_mutation_rate_of->", "-biolink:affects_activity_of->", "-biolink:increases_activity_of->", "-biolink:decreases_activity_of->", "-biolink:affects_degradation_of->", "-biolink:increases_degradation_of->", "-biolink:decreases_degradation_of->", "-biolink:affects_molecular_modification_of->", "-biolink:decreases_molecular_modification_of->", "-biolink:increases_molecular_modification_of->", "-biolink:affects_uptake_of->", "-biolink:increases_uptake_of->", "-biolink:decreases_uptake_of->", "-biolink:affects_abundance_of->", "-biolink:decreases_abundance_of->", "-biolink:increases_abundance_of->", "-biolink:process_regulates_process->", "-biolink:process_negatively_regulates_process->", "-biolink:process_positively_regulates_process->", "-biolink:affects_splicing_of->", "-biolink:increases_splicing_of->", "-biolink:decreases_splicing_of->", "-biolink:affects_localization_o ...
#  {'timestamp': '2021-05-10T18:18:36.829236',
#   'level': 'INFO',
#   'code': None,
#   'message': '{"message": "Contacting KP registry to ask for KPs to solve this query graph", "line_number": 441}'},
#  {'timestamp': '2021-05-10T18:18:36.588540',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"description": "Expanded query graph with descendants", "qg": {"nodes": {"n0": {"id": null, "category": ["biolink:ChemicalSubstance", "biolink:FoodComponent", "biolink:Carbohydrate", "biolink:Nutrient", "biolink:Micronutrient", "biolink:Vitamin", "biolink:Macronutrient", "biolink:EnvironmentalFoodContaminant", "biolink:ProcessedMaterial", "biolink:FoodAdditive", "biolink:Metabolite", "biolink:ChemicalExposure", "biolink:ComplexChemicalExposure"], "is_set": false, "name": "Chemical Substance"}, "n1": {"id": ["NCBIGene:3778"], "category": ["biolink:Gene"], "is_set": false, "name": "KCNMA1"}}, "edges": {"e0": {"qg_edge_id": "e0", "edge_reverse": false, "source": "n0", "target": "n1", "predicate": ["-biolink:related_to->", "-biolink:derives_into->", "-biolink:has_metabolite->", "-biolink:expressed_in->", "-biolink:located_in->", "-biolink:temporally_related_to->", "-biolink:precedes->", "-biolink:preceded_by->", "-biolink:close_match->", "-biolink:exact_match->", "-biolink:same_as->", "-biolink:contraindicated_for->", "-biolink:prevented_by->", "-biolink:superclass_of->", "-biolink:derives_from->", "-biolink:is_metabolite_of->", "-biolink:in_taxon->", "-biolink:in_linkage_disequilibrium_with->", "-biolink:overlaps->", "-biolink:part_of->", "-biolink:is_active_ingredient_of->", "-biolink:food_component_of->", "-biolink:nutrient_of->", "-biolink:is_excipient_of->", "-biolink:has_part->", "-biolink:has_variant_part->", "-biolink:has_food_component->", "-biolink:has_nutrient->", "-biolink:has_active_ingredient->", "-biolink:has_excipient->", "-biolink:narrow_match->", "-biolink:genetic_association->", "-biolink:gene_associated_with_condition->", "-biolink:condition_associated_with_gene->", "-biolink:translation_of->", "-biolink:develops_from->", "-biolink:disease_has_basis_in->", "-biolink:phenotype_of->", "-biolink:transcribed_to->", "-biolink:affects_risk_for->", "-biolink:predisposes->", "-biolink:prevents->", "-biolink:has_completed->", "-biolink:affects->", "-biolink:affects_metabolic_processing_of->", "-biolink:decreases_metabolic_processing_of->", "-biolink:increases_metabolic_processing_of->", "-biolink:affects_response_to->", "-biolink:increases_response_to->", "-biolink:decreases_response_to->", "-biolink:entity_regulates_entity->", "-biolink:entity_negatively_regulates_entity->", "-biolink:entity_positively_regulates_entity->", "-biolink:affects_expression_in->", "-biolink:affects_stability_of->", "-biolink:increases_stability_of->", "-biolink:decreases_stability_of->", "-biolink:affects_synthesis_of->", "-biolink:decreases_synthesis_of->", "-biolink:increases_synthesis_of->", "-biolink:disrupts->", "-biolink:exacerbates->", "-biolink:affects_folding_of->", "-biolink:decreases_folding_of->", "-biolink:increases_folding_of->", "-biolink:affects_transport_of->", "-biolink:increases_transport_of->", "-biolink:decreases_transport_of->", "-biolink:affects_expression_of->", "-biolink:increases_expression_of->", "-biolink:decreases_expression_of->", "-biolink:affects_mutation_rate_of->", "-biolink:increases_mutation_rate_of->", "-biolink:decreases_mutation_rate_of->", "-biolink:affects_activity_of->", "-biolink:increases_activity_of->", "-biolink:decreases_activity_of->", "-biolink:affects_degradation_of->", "-biolink:increases_degradation_of->", "-biolink:decreases_degradation_of->", "-biolink:affects_molecular_modification_of->", "-biolink:decreases_molecular_modification_of->", "-biolink:increases_molecular_modification_of->", "-biolink:affects_uptake_of->", "-biolink:increases_uptake_of->", "-biolink:decreases_uptake_of->", "-biolink:affects_abundance_of->", "-biolink:decreases_abundance_of->", "-biolink:increases_abundance_of->", "-biolink:process_regulates_process->", "-biolink:process_negatively_regulates_process->", "-biolink:process_positively_regulates_process->", "-biolink:affects_splicing_of->", "-biolink:increases_splicing_of->", "-biolink:decreases_splicing_of->", "-biolink:affects_localization_of->",  ...
#  {'timestamp': '2021-05-10T18:18:36.558120',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Using BMT to get descendants of node and edge types", "line_number": 337}'},
#  {'timestamp': '2021-05-10T18:18:36.531368',
#   'level': 'INFO',
#   'code': None,
#   'message': '{"message": "Generating plan for query graph", "line_number": 435}'},
#  {'timestamp': '2021-05-10T18:18:36.494523',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Generating plan", "line_number": 149}'},
#  {'timestamp': '2021-05-10T18:18:36.426035',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Contacting node normalizer to get categorys for curies", "line_number": 307}'},
#  {'timestamp': '2021-05-10T18:18:36.348265',
#   'level': 'DEBUG',
#   'code': None,
#   'message': '{"message": "Initialized strider worker", "line_number": 110}'}]

# %%
view = GammaViewer(props={"data":strider_result_k})
display(view)

# %%
for edge_id, edge in strider_result_k['message']['knowledge_graph']['edges'].items():
    print(edge['predicate'])
# Out:
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:affected_by
# biolink:affected_by
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:affected_by
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:correlated_with
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:correlated_with
# biolink:affected_by
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:affected_by
# biolink:affected_by
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:correlated_with
# biolink:affected_by
# biolink:affected_by
# biolink:affected_by
# biolink:correlated_with
# biolink:affected_by

# %%
tq={
    "message": {
        "query_graph": {
            "nodes": {
                "n1": {
                    "id": "HP:0033127",
                    "category": "biolink:PhenotypicFeature"
                },
                "n2": {
                    "category": "biolink:Disease"
                }
            },
            "edges": {
                "e02": {
                    "subject": "n1",
                    "object": "n2",
                    "predicate": "biolink:affected_by"
                }
            }
        }
    }
}

# %% [markdown]
# ### ARAGORN Assessment

# %% [markdown]
# How did we do?
