# %% [markdown]
# # Setup

# %%
import json
import requests
import copy
from datetime import datetime as dt
from collections import defaultdict
import pandas as pd

# %%
#https://pypi.org/project/gamma-viewer/
from gamma_viewer import GammaViewer
from IPython.display import display, Markdown

# %%
def printjson(j):
    print(json.dumps(j,indent=4))
def print_json(j):
    printjson(j)

# %%
def post(name,url,message,params=None):
    """A simple function for posting to a URL and returning the json response"""
    if params is None:
        response = requests.post(url,json=message)
    else:
        response = requests.post(url,json=message,params=params)
    if not response.status_code == 200:
        print(name, 'error:',response.status_code)
        print(response)
        print(response.json())
        return {}
    return response.json()

# %%
def coalesce(em):
    return post('coalesce','https://answercoalesce.renci.org/coalesce/all',em)

# %%
def normalize(ids):
    j = {'curies':ids}
    result = post('nn','https://nodenormalization-sri.renci.org/get_normalized_nodes',j)
    new_ids = [ v['id']['identifier'] for k,v in result.items() if v is not None ]
    return new_ids

# %%
def enrich(biolink_category, identifiers):
    identifiers = normalize(identifiers)
    em={'message': 
         {
             'query_graph':
                  {
                    "nodes": {
                        "n1": {
                            "category": [ biolink_category ]
                            }
                    },
                    "edges":{}  
                  },
              'knowledge_graph': {
                  'nodes': {},
                  'edges': {}
                  },
              'results': []
        }
    }
    for n in identifiers:
        if n.startswith('NCBIGene'):
            n = f"NCBIGENE:{n.split(':')[1]}"
        em['message']['knowledge_graph']['nodes'][n]= {'category':[biolink_category]}
        em['message']['results'].append( {'node_bindings': {'n1':[{"id": n}]}, 'edge_bindings': {} })
    return coalesce(em)

# %%
def ac_to_table(aragorn_result,mnode):
    #scores = []
    answer_node_count = []
    merged_count = []
    method = []
    extra = []
    for res_i, result in enumerate(aragorn_result['message']['results']):
        #scores.append(result['score'])
        answer_node_count.append(len(result['node_bindings']))
        merged_count.append(len(result['node_bindings'][mnode]))
        try:
            method.append(result['node_bindings'][mnode][0]['coalescence_method'])
        except:
            method.append('Original')
    df = pd.DataFrame({'N_Answer_Nodes':answer_node_count, 'N_Merged_Nodes':merged_count, 'Method':method})
    return df

def filter_to_simple(aragorn_result,mnode):
    simple_result = copy.deepcopy(aragorn_result)
    simple_result['message']['results'] = list(
    filter( lambda x: 'coalescence_method' not in x['node_bindings'][mnode][0], 
           aragorn_result['message']['results'])
    )
    print(len(simple_result['message']['results']))
    return simple_result

def print_nodenames(simple_result,qnode):
    #Print the names of the answers
    for result in simple_result['message']['results']:
        #Each answer has an identifier:
        n1_id = result['node_bindings'][qnode][0]['id']
        #The information for that identifier is in the KG:
        node = simple_result['message']['knowledge_graph']['nodes'][n1_id]
        #Each node has a name
        print(node['name'])

def filter_to_coal(aragorn_result,mnode,method):
    #The results that have been coalesced:
    coalesced_results = list(
        filter( lambda x: 'coalescence_method'  in x['node_bindings'][mnode][0], 
               aragorn_result['message']['results'])
    )
    #Those that have been coalesced via a new node (graph coalescence)
    graph_coalesced_results = list(
        filter( lambda x: x['node_bindings'][mnode][0]['coalescence_method'] == method, coalesced_results)
    )
    print(len(graph_coalesced_results))
    simple_result = copy.deepcopy(aragorn_result)
    simple_result['message']['results'] = graph_coalesced_results
    return simple_result

def filter_to_gc(aragorn_result,mnode):
    return filter_to_coal(aragorn_result,mnode,'graph_enrichment')

def filter_to_pc(aragorn_result,mnode):
    return filter_to_coal(aragorn_result,mnode,'property_enrichment')

# %%
def print_gc_result(graph,gc_result):
    print('p_value:', gc_result['node_bindings']['n1'][0]['p_value'])
    for extra_edge in gc_result['edge_bindings']:
        for eb in gc_result['edge_bindings'][extra_edge]:        
            kge = graph['edges'][eb['id']]
            subject_node = kge['subject']
            object_node = kge['object']
            pred = kge['predicate']
            print( f"{graph['nodes'][subject_node]['name']} -[{pred}]-> {graph['nodes'][object_node]['name']}")
    
def print_pc_result(knowledge_graph,pc_result):
    print('p_value:', pc_result['node_bindings']['n1'][0]['p_values'])
    print('properties:', pc_result['node_bindings']['n1'][0]['properties'])
    for node in pc_result['node_bindings']['n1']:
        kgn = knowledge_graph['nodes'][node['id']]
        print( f"  {kgn['name']}")

# %%
#not a valid json file
#with open('Step3a_ConnectionsKP_Output_DILI.json','r') as inf:
#    j =json.load(inf)

import ast
with open('Step3a_ConnectionsKP_Output_DILI.json','r') as inf:
    s = inf.read()

result = ast.literal_eval(s)

# %%
chemicals = [x['subject'] for x in result[0]]
#reformat prefix
chemical_cc = [ f"CHEMBL.COMPOUND:{xid.split(':')[1]}" for xid in chemicals ]

# %%
chemical_cc
# Out:
# ['CHEMBL.COMPOUND:CHEMBL88',
#  'CHEMBL.COMPOUND:CHEMBL428647',
#  'CHEMBL.COMPOUND:CHEMBL53463',
#  'CHEMBL.COMPOUND:CHEMBL3545252',
#  'CHEMBL.COMPOUND:CHEMBL83',
#  'CHEMBL.COMPOUND:CHEMBL1200796',
#  'CHEMBL.COMPOUND:CHEMBL92',
#  'CHEMBL.COMPOUND:CHEMBL1201585',
#  'CHEMBL.COMPOUND:CHEMBL1399',
#  'CHEMBL.COMPOUND:CHEMBL185']

# %%
answer = enrich('biolink:ChemicalSubstance',chemical_cc)

# %%
ac_to_table(answer,'n1')
# Out:
#     N_Answer_Nodes  N_Merged_Nodes               Method
# 0                1               7  property_enrichment
# 1                1               9  property_enrichment
# 2                1               8  property_enrichment
# 3                1               7  property_enrichment
# 4                1               5  property_enrichment
# 5                1               5  property_enrichment
# 6                1               6  property_enrichment
# 7                1               5  property_enrichment
# 8                1               4  property_enrichment
# 9                1               5  property_enrichment
# 10               1               4  property_enrichment
# 11               1               4  property_enrichment
# 12               1               3  property_enrichment
# 13               1               3  property_enrichment
# 14               1               2  property_enrichment
# 15               1               3  property_enrichment
# 16               1               3  property_enrichment
# 17               1               3  property_enrichment
# 18               1               8  property_enrichment
# 19               1               4  property_enrichment
# 20               1               3  property_enrichment
# 21               1               4  property_enrichment
# 22               1               2  property_enrichment
# 23               1               2  property_enrichment
# 24               1               2  property_enrichment
# 25               1               2  property_enrichment
# 26               1               2  property_enrichment
# 27               1               2  property_enrichment
# 28               1               2  property_enrichment
# 29               1               2  property_enrichment
# 30               1               2  property_enrichment
# 31               1               2  property_enrichment
# 32               1               5  property_enrichment
# 33               2               5     graph_enrichment
# 34               2               5     graph_enrichment
# 35               2               5     graph_enrichment
# 36               2               5     graph_enrichment
# 37               2               5     graph_enrichment
# 38               2               5     graph_enrichment
# 39               2               5     graph_enrichment
# 40               2               5     graph_enrichment
# 41               2               5     graph_enrichment
# 42               2               5     graph_enrichment
# 43               1               1             Original
# 44               1               1             Original
# 45               1               1             Original
# 46               1               1             Original
# 47               1               1             Original
# 48               1               1             Original
# 49               1               1             Original
# 50               1               1             Original
# 51               1               1             Original

# %%
x = filter_to_gc(answer,'n1')
# Out:
# 10

# %%
for i,result in enumerate(x['message']['results']):
    print('Result',i)
    print_gc_result(x['message']['knowledge_graph'],result)
# Out:
# Result 0
# p_value: 3.5916218505919564e-20
# Docetaxel trihydrate -[biolink:causes_adverse_event]-> Krukenberg carcinoma
# Anastrozole -[biolink:causes_adverse_event]-> Krukenberg carcinoma
# Paclitaxel -[biolink:causes_adverse_event]-> Krukenberg carcinoma
# Doxorubicin -[biolink:causes_adverse_event]-> Krukenberg carcinoma
# Tamoxifen -[biolink:causes_adverse_event]-> Krukenberg carcinoma
# Result 1
# p_value: 2.7129466315054048e-18
# Tamoxifen -[biolink:treats]-> adenoid cystic breast carcinoma
# Docetaxel trihydrate -[biolink:treats]-> adenoid cystic breast carcinoma
# Anastrozole -[biolink:treats]-> adenoid cystic breast carcinoma
# Doxorubicin -[biolink:treats]-> adenoid cystic breast carcinoma
# Paclitaxel -[biolink:treats]-> adenoid cystic breast carcinoma
# Result 2
# p_value: 1.3014678485860711e-17
# Paclitaxel -[biolink:causes_adverse_event]-> radiation injury
# Anastrozole -[biolink:causes_adverse_event]-> radiation injury
# Tamoxifen -[biolink:causes_adverse_event]-> radiation injury
# Docetaxel trihydrate -[biolink:causes_adverse_event]-> radiation injury
# Doxorubicin -[biolink:causes_adverse_event]-> radiation injury
# Result 3
# p_value: 6.621052118169682e-17
# Doxorubicin -[biolink:causes_adverse_event]-> periodontitis
# Docetaxel trihydrate -[biolink:causes_adverse_event]-> periodontitis
# Anastrozole -[biolink:causes_adverse_event]-> periodontitis
# Paclitaxel -[biolink:causes_adverse_event]-> periodontitis
# Tamoxifen -[biolink:causes_adverse_event]-> periodontitis
# Result 4
# p_value: 8.67565045173062e-17
# Docetaxel trihydrate -[biolink:causes_adverse_event]-> nail anomaly
# Anastrozole -[biolink:causes_adverse_event]-> nail anomaly
# Doxorubicin -[biolink:causes_adverse_event]-> nail anomaly
# Tamoxifen -[biolink:causes_adverse_event]-> nail anomaly
# Paclitaxel -[biolink:causes_adverse_event]-> nail anomaly
# Result 5
# p_value: 9.878519868804491e-17
# Doxorubicin -[biolink:causes_adverse_event]-> actinomycosis
# Paclitaxel -[biolink:causes_adverse_event]-> actinomycosis
# Anastrozole -[biolink:causes_adverse_event]-> actinomycosis
# Docetaxel trihydrate -[biolink:causes_adverse_event]-> actinomycosis
# Tamoxifen -[biolink:causes_adverse_event]-> actinomycosis
# Result 6
# p_value: 1.268404243102419e-16
# Doxorubicin -[biolink:causes_adverse_event]-> periodontal disease
# Paclitaxel -[biolink:causes_adverse_event]-> periodontal disease
# Anastrozole -[biolink:causes_adverse_event]-> periodontal disease
# Tamoxifen -[biolink:causes_adverse_event]-> periodontal disease
# Docetaxel trihydrate -[biolink:causes_adverse_event]-> periodontal disease
# Result 7
# p_value: 1.6093490224559185e-16
# Anastrozole -[biolink:causes_adverse_event]-> bone inflammation disease
# Tamoxifen -[biolink:causes_adverse_event]-> bone inflammation disease
# Paclitaxel -[biolink:causes_adverse_event]-> bone inflammation disease
# Doxorubicin -[biolink:causes_adverse_event]-> bone inflammation disease
# Docetaxel trihydrate -[biolink:causes_adverse_event]-> bone inflammation disease
# Result 8
# p_value: 1.8053280298721135e-16
# Anastrozole -[biolink:causes_adverse_event]-> chronic gingivitis
# Docetaxel trihydrate -[biolink:causes_adverse_event]-> chronic gingivitis
# Tamoxifen -[biolink:causes_adverse_event]-> chronic gingivitis
# Doxorubicin -[biolink:causes_adverse_event]-> chronic gingivitis
# Paclitaxel -[biolink:causes_adverse_event]-> chronic gingivitis
# Result 9
# p_value: 2.2545063418059034e-16
# Docetaxel trihydrate -[biolink:causes_adverse_event]-> dental abscess
# Anastrozole -[biolink:causes_adverse_event]-> dental abscess
# Doxorubicin -[biolink:causes_adverse_event]-> dental abscess
# Paclitaxel -[biolink:causes_adverse_event]-> dental abscess
# Tamoxifen -[biolink:causes_adverse_event]-> dental abscess

# %%
p = filter_to_pc(answer,'n1')
for i,result in enumerate(p['message']['results']):
    print('Result',i)
    print_pc_result(p['message']['knowledge_graph'],result)
# Out:
# 33
# Result 0
# p_value: [3.4740732760049123e-28, 3.0150907252934714e-22, 9.19237936641059e-21, 1.4453940155679862e-17, 5.531687174713188e-15]
# properties: ['Cardiotoxic antineoplastic agents', 'Antineoplastic and Immunomodulating Agents', 'Antineoplastic Agents', 'Cytochrome P-450 Substrates', 'drugbank.approved']
#   Paclitaxel
#   5-Fluorouracil
#   Anastrozole
#   Cyclophosphamide
#   Docetaxel
#   Tamoxifen
#   Doxorubicin
# Result 1
# p_value: [5.66296300312727e-20]
# properties: ['therapeutic_flag']
#   5-Fluorouracil
#   Cyclophosphamide
#   Docetaxel
#   Docetaxel trihydrate
#   Cyclophosphamide monohydrate
#   Paclitaxel
#   Anastrozole
#   Tamoxifen
#   Doxorubicin
# Result 2
# p_value: [7.281244810173953e-19, 1.6899535519547302e-14, 1.893942766744108e-14, 4.072011963732734e-13]
# properties: ['antineoplastic_agent', 'drug', 'pharmaceutical', 'application']
#   Cyclophosphamide monohydrate
#   Paclitaxel
#   5-Fluorouracil
#   Anastrozole
#   Cyclophosphamide
#   Docetaxel
#   Tamoxifen
#   Docetaxel trihydrate
# Result 3
# p_value: [6.400974480668064e-18]
# properties: ['parenteral']
#   Cyclophosphamide monohydrate
#   Paclitaxel
#   5-Fluorouracil
#   Cyclophosphamide
#   Docetaxel
#   Docetaxel trihydrate
#   Doxorubicin
# Result 4
# p_value: [6.94766733910858e-17, 3.1864300002236365e-15]
# properties: ['Myelosuppressive Agents', 'Immunosuppressive Agents']
#   Paclitaxel
#   5-Fluorouracil
#   Cyclophosphamide
#   Docetaxel
#   Doxorubicin
# Result 5
# p_value: [1.9787504817644795e-15]
# properties: ['Cytochrome P-450 CYP3A5 Substrates']
#   Paclitaxel
#   Anastrozole
#   Cyclophosphamide
#   Docetaxel
#   Tamoxifen
# Result 6
# p_value: [2.1583451529461077e-15, 2.7113213598724374e-15]
# properties: ['Cytochrome P-450 CYP3A4 Substrates', 'Cytochrome P-450 CYP3A Substrates']
#   Paclitaxel
#   Anastrozole
#   Cyclophosphamide
#   Docetaxel
#   Tamoxifen
#   Doxorubicin
# Result 7
# p_value: [1.8199827242539138e-14]
# properties: ['P-glycoprotein substrates']
#   Paclitaxel
#   Anastrozole
#   Docetaxel
#   Tamoxifen
#   Doxorubicin
# Result 8
# p_value: [2.0649473116922528e-13]
# properties: ['BCRP/ABCG2 Substrates']
#   5-Fluorouracil
#   Docetaxel
#   Tamoxifen
#   Doxorubicin
# Result 9
# p_value: [6.558854029735969e-13]
# properties: ['Cytochrome P-450 Enzyme Inhibitors']
#   5-Fluorouracil
#   Anastrozole
#   Docetaxel
#   Tamoxifen
#   Doxorubicin
# Result 10
# p_value: [1.3061979823781924e-12]
# properties: ['Cytochrome P-450 CYP2C8 Substrates']
#   Cyclophosphamide
#   Paclitaxel
#   5-Fluorouracil
#   Anastrozole
# Result 11
# p_value: [1.832528308973643e-12, 2.0376835426589385e-11, 2.9499273104993656e-11]
# properties: ['Cytochrome P-450 CYP3A4 Inhibitors (strength unknown)', 'Cytochrome P-450 CYP3A4 Inhibitors', 'Cytochrome P-450 CYP3A Inhibitors']
#   Docetaxel
#   Tamoxifen
#   Anastrozole
#   Doxorubicin
# Result 12
# p_value: [1.0477548872319811e-10]
# properties: ['Cytochrome P-450 CYP2A6 Substrates']
#   Cyclophosphamide
#   Tamoxifen
#   5-Fluorouracil
# Result 13
# p_value: [3.8840079134265395e-10, 1.8309027845207233e-09]
# properties: ['immunosuppressive_agent', 'immunomodulator']
#   Cyclophosphamide
#   Cyclophosphamide monohydrate
#   5-Fluorouracil
# Result 14
# p_value: [1.4198210156773799e-09, 1.4198210156773799e-09, 1.4198210156773799e-09, 4.732623461216679e-09, 7.09885026042084e-09, 4.3062236206905315e-08, 4.3062236206905315e-08, 4.3062236206905315e-08, 4.968660113955705e-08, 2.3466230377575603e-07, 1.8934889942799815e-06, 2.0224856839377383e-06, 2.5317923490806487e-06]
# properties: ['Cyclodecanes', 'Taxane Derivatives', 'Taxoids', 'Microtubule Inhibitors', 'Microtubule Inhibition', 'Antimitotic Agents', 'Mitosis Modulators', 'Tubulin Modulators', 'Diterpenes', 'OATP1B3 substrates', 'Cycloparaffins', 'Agents Causing Muscle Toxicity', 'Terpenes']
#   Docetaxel
#   Paclitaxel
# Result 15
# p_value: [1.5004315799165821e-09]
# properties: ['Cytochrome P-450 CYP3A7 Substrates']
#   Docetaxel
#   Paclitaxel
#   Tamoxifen
# Result 16
# p_value: [1.5449810283757269e-09, 4.046694913203749e-09]
# properties: ['Cytochrome P-450 CYP2C9 Inhibitors (strength unknown)', 'Cytochrome P-450 CYP2C9 Inhibitors']
#   Tamoxifen
#   Anastrozole
#   5-Fluorouracil
# Result 17
# p_value: [4.489146896737723e-09, 8.657485862230892e-09, 1.0154572375339623e-08, 1.855726912122408e-08]
# properties: ['Cytochrome P-450 CYP3A4 Inducers (strength unknown)', 'Cytochrome P-450 CYP3A4 Inducers', 'Cytochrome P-450 CYP3A Inducers', 'Cytochrome P-450 Enzyme Inducers']
#   Cyclophosphamide
#   Paclitaxel
#   Tamoxifen
# Result 18
# p_value: [6.287778749017425e-09]
# properties: ['biological_role']
#   Cyclophosphamide monohydrate
#   Paclitaxel
#   5-Fluorouracil
#   Anastrozole
#   Cyclophosphamide
#   Docetaxel
#   Tamoxifen
#   Doxorubicin
# Result 19
# p_value: [2.0941683244972167e-08]
# properties: ['oral']
#   Cyclophosphamide
#   Cyclophosphamide monohydrate
#   Tamoxifen
#   Anastrozole
# Result 20
# p_value: [2.567506139488886e-08]
# properties: ['P-glycoprotein inhibitors']
#   Paclitaxel
#   Tamoxifen
#   Doxorubicin
# Result 21
# p_value: [3.2923373483764616e-08]
# properties: ['drugbank.investigational']
#   Cyclophosphamide
#   Docetaxel
#   Anastrozole
#   Doxorubicin
# Result 22
# p_value: [4.968660113955705e-08, 5.678400761703749e-08, 1.4194473293419356e-07, 1.7884394392412884e-07, 4.6830554090456026e-07, 8.654899915244284e-07, 3.4311191172166234e-06, 1.2429855143737327e-05]
# properties: ['Estrogen Antagonists', 'Hormone Antagonists and Related Agents', 'Endocrine Therapy', 'Antineoplastic Agents, Hormonal', 'UGT2B7 substrates', 'Hormone Antagonists', 'Cytochrome P-450 CYP2C8 Inhibitors', 'Hormones, Hormone Substitutes, and Hormone Antagonists']
#   Tamoxifen
#   Anastrozole
# Result 23
# p_value: [8.990370911048236e-08, 7.356379181410367e-06, 2.748534462432182e-05]
# properties: ['Thyroxine-binding globulin inducers', 'Cytochrome P-450 CYP1A2 Substrates', 'QTc Prolonging Agents']
#   Tamoxifen
#   5-Fluorouracil
# Result 24
# p_value: [1.6607136353264094e-07]
# properties: ['BSEP/ABCB11 Inhibitors']
#   Paclitaxel
#   Tamoxifen
# Result 25
# p_value: [5.56263595099112e-07, 7.023742678399597e-07, 2.0224856839377383e-06, 9.39597217385949e-06]
# properties: ['P-glycoprotein inducers', 'Cytochrome P-450 CYP2B6 Inhibitors', 'Cytochrome P-450 CYP2D6 Inhibitors (strength unknown)', 'Cytochrome P-450 CYP2D6 Inhibitors']
#   Tamoxifen
#   Doxorubicin
# Result 26
# p_value: [9.534236026358997e-07, 4.797105146242557e-06, 8.212601631999598e-06, 4.5470380110297476e-05, 8.755756610645222e-05]
# properties: ['Immunologic Factors', 'Noxae', 'Toxic Actions', 'environmental_contaminant', 'xenobiotic']
#   Cyclophosphamide
#   5-Fluorouracil
# Result 27
# p_value: [1.2427219371137593e-06, 8.389488183941335e-06, 1.2000918687709104e-05, 1.5400959521753568e-05]
# properties: ['alkylating_agent', 'mutagen', 'genotoxin', 'carcinogenic_agent']
#   Cyclophosphamide
#   Cyclophosphamide monohydrate
# Result 28
# p_value: [1.2772267100302373e-06]
# properties: ['BSEP/ABCB11 Substrates']
#   Paclitaxel
#   Doxorubicin
# Result 29
# p_value: [1.8934889942799815e-06, 6.625988757053208e-06, 1.0558801030387494e-05]
# properties: ['Cytochrome P-450 CYP2B6 Substrates', 'Cytochrome P-450 CYP2C19 Substrates', 'Cytochrome P-450 CYP2C9 Substrates']
#   Cyclophosphamide
#   Tamoxifen
# Result 30
# p_value: [3.545877504251254e-06]
# properties: ['Neurotoxic agents']
#   Cyclophosphamide
#   Paclitaxel
# Result 31
# p_value: [6.493957895347241e-05]
# properties: ['Enzyme Inhibitors']
#   Anastrozole
#   Doxorubicin
# Result 32
# p_value: [7.599207752970565e-05]
# properties: ['biochemical_role']
#   Paclitaxel
#   5-Fluorouracil
#   Anastrozole
#   Tamoxifen
#   Doxorubicin
