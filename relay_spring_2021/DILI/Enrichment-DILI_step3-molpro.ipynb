# %% [markdown]
# # Setup

# %%
import json
import requests
import copy
from datetime import datetime as dt
from collections import defaultdict
import pandas as pd

# %%
#https://pypi.org/project/gamma-viewer/
from gamma_viewer import GammaViewer
from IPython.display import display, Markdown

# %%
def printjson(j):
    print(json.dumps(j,indent=4))
def print_json(j):
    printjson(j)

# %%
def post(name,url,message,params=None):
    """A simple function for posting to a URL and returning the json response"""
    if params is None:
        response = requests.post(url,json=message)
    else:
        response = requests.post(url,json=message,params=params)
    if not response.status_code == 200:
        print(name, 'error:',response.status_code)
        print(response)
        print(response.json())
        return {}
    return response.json()

# %%
def coalesce(em):
    return post('coalesce','https://answercoalesce.renci.org/coalesce/all',em)

# %%
def normalize(ids):
    j = {'curies':ids}
    result = post('nn','https://nodenormalization-sri.renci.org/get_normalized_nodes',j)
    new_ids = [ v['id']['identifier'] for k,v in result.items() if v is not None ]
    return new_ids

# %%
def enrich(biolink_category, identifiers):
    identifiers = normalize(identifiers)
    em={'message': 
         {
             'query_graph':
                  {
                    "nodes": {
                        "n1": {
                            "category": [ biolink_category ]
                            }
                    },
                    "edges":{}  
                  },
              'knowledge_graph': {
                  'nodes': {},
                  'edges': {}
                  },
              'results': []
        }
    }
    for n in identifiers:
        if n.startswith('NCBIGene'):
            n = f"NCBIGENE:{n.split(':')[1]}"
        em['message']['knowledge_graph']['nodes'][n]= {'category':[biolink_category]}
        em['message']['results'].append( {'node_bindings': {'n1':[{"id": n}]}, 'edge_bindings': {} })
    return coalesce(em)

# %%
def ac_to_table(aragorn_result,mnode):
    #scores = []
    answer_node_count = []
    merged_count = []
    method = []
    extra = []
    for res_i, result in enumerate(aragorn_result['message']['results']):
        #scores.append(result['score'])
        answer_node_count.append(len(result['node_bindings']))
        merged_count.append(len(result['node_bindings'][mnode]))
        try:
            method.append(result['node_bindings'][mnode][0]['coalescence_method'])
        except:
            method.append('Original')
    df = pd.DataFrame({'N_Answer_Nodes':answer_node_count, 'N_Merged_Nodes':merged_count, 'Method':method})
    return df

def filter_to_simple(aragorn_result,mnode):
    simple_result = copy.deepcopy(aragorn_result)
    simple_result['message']['results'] = list(
    filter( lambda x: 'coalescence_method' not in x['node_bindings'][mnode][0], 
           aragorn_result['message']['results'])
    )
    print(len(simple_result['message']['results']))
    return simple_result

def print_nodenames(simple_result,qnode):
    #Print the names of the answers
    for result in simple_result['message']['results']:
        #Each answer has an identifier:
        n1_id = result['node_bindings'][qnode][0]['id']
        #The information for that identifier is in the KG:
        node = simple_result['message']['knowledge_graph']['nodes'][n1_id]
        #Each node has a name
        print(node['name'])

def filter_to_coal(aragorn_result,mnode,method):
    #The results that have been coalesced:
    coalesced_results = list(
        filter( lambda x: 'coalescence_method'  in x['node_bindings'][mnode][0], 
               aragorn_result['message']['results'])
    )
    #Those that have been coalesced via a new node (graph coalescence)
    graph_coalesced_results = list(
        filter( lambda x: x['node_bindings'][mnode][0]['coalescence_method'] == method, coalesced_results)
    )
    print(len(graph_coalesced_results))
    simple_result = copy.deepcopy(aragorn_result)
    simple_result['message']['results'] = graph_coalesced_results
    return simple_result

def filter_to_gc(aragorn_result,mnode):
    return filter_to_coal(aragorn_result,mnode,'graph_enrichment')

def filter_to_pc(aragorn_result,mnode):
    return filter_to_coal(aragorn_result,mnode,'property_enrichment')

# %%
def print_gc_result(graph,gc_result):
    print('p_value:', gc_result['node_bindings']['n1'][0]['p_value'])
    for extra_edge in gc_result['edge_bindings']:
        for eb in gc_result['edge_bindings'][extra_edge]:        
            kge = graph['edges'][eb['id']]
            subject_node = kge['subject']
            object_node = kge['object']
            pred = kge['predicate']
            print( f"{graph['nodes'][subject_node]['name']} -[{pred}]-> {graph['nodes'][object_node]['name']}")
    
def print_pc_result(knowledge_graph,pc_result):
    print('p_value:', pc_result['node_bindings']['n1'][0]['p_values'])
    print('properties:', pc_result['node_bindings']['n1'][0]['properties'])
    for node in pc_result['node_bindings']['n1'][:5]:
        kgn = knowledge_graph['nodes'][node['id']]
        print( f"  {kgn['name']}")

# %%
#valid json file
with open('Step3a_MolecularKP_Output_DILI.json','r') as inf:
    result =json.load(inf)

# %%
chemicals = [x['object'] for x in result ]
#reformat prefix
#chemical_cc = [ f"CHEMBL.COMPOUND:{xid.split(':')[1]}" for xid in chemicals ]

# %%
chemicals
# Out:
# ['CHEBI:5001',
#  'CHEBI:9241',
#  'CHEBI:63613',
#  'PUBCHEM.COMPOUND:3177',
#  'PUBCHEM.COMPOUND:11317348',
#  'PUBCHEM.COMPOUND:41781',
#  'PUBCHEM.COMPOUND:5281881',
#  'PUBCHEM.COMPOUND:4336830',
#  'PUBCHEM.COMPOUND:73707372',
#  'PUBCHEM.COMPOUND:3540',
#  'PUBCHEM.COMPOUND:5330286',
#  'PUBCHEM.COMPOUND:9910224',
#  'CHEBI:18405',
#  'PUBCHEM.COMPOUND:5374',
#  'PUBCHEM.COMPOUND:5281071',
#  'PUBCHEM.COMPOUND:9887884',
#  'PUBCHEM.COMPOUND:2253',
#  'PUBCHEM.COMPOUND:10251',
#  'PUBCHEM.COMPOUND:5479',
#  'PUBCHEM.COMPOUND:4792',
#  'PUBCHEM.COMPOUND:445580',
#  'PUBCHEM.COMPOUND:104845',
#  'PUBCHEM.COMPOUND:73707397',
#  'PUBCHEM.COMPOUND:5614',
#  'PUBCHEM.COMPOUND:5253',
#  'PUBCHEM.COMPOUND:36462',
#  'CHEBI:35237',
#  'PUBCHEM.COMPOUND:21678144',
#  'PUBCHEM.COMPOUND:57448257',
#  'PUBCHEM.COMPOUND:4848',
#  'PUBCHEM.COMPOUND:73707417',
#  'PUBCHEM.COMPOUND:62824',
#  'PUBCHEM.COMPOUND:11689583',
#  'PUBCHEM.COMPOUND:6604926',
#  'PUBCHEM.COMPOUND:3682',
#  'PUBCHEM.COMPOUND:60773',
#  'PUBCHEM.COMPOUND:441314',
#  'PUBCHEM.COMPOUND:4810',
#  'PUBCHEM.COMPOUND:2063',
#  'PUBCHEM.COMPOUND:24707',
#  'PUBCHEM.COMPOUND:3799',
#  'PUBCHEM.COMPOUND:4452',
#  'PUBCHEM.COMPOUND:4355450',
#  'PUBCHEM.COMPOUND:133621',
#  'PUBCHEM.COMPOUND:9906875',
#  'PUBCHEM.COMPOUND:1456',
#  'PUBCHEM.COMPOUND:5517',
#  'PUBCHEM.COMPOUND:49766501',
#  'CHEBI:17561',
#  'PUBCHEM.COMPOUND:65944',
#  'PUBCHEM.COMPOUND:5788723',
#  'PUBCHEM.COMPOUND:5311097',
#  'PUBCHEM.COMPOUND:21100',
#  'PUBCHEM.COMPOUND:22752',
#  'PUBCHEM.COMPOUND:9865515',
#  'PUBCHEM.COMPOUND:3292',
#  'PUBCHEM.COMPOUND:6602440',
#  'PUBCHEM.COMPOUND:23930397',
#  'PUBCHEM.COMPOUND:105008',
#  'PUBCHEM.COMPOUND:4409',
#  'PUBCHEM.COMPOUND:149784',
#  'PUBCHEM.COMPOUND:5145950',
#  'PUBCHEM.COMPOUND:454217',
#  'PUBCHEM.COMPOUND:24964624',
#  'PUBCHEM.COMPOUND:51081',
#  'PUBCHEM.COMPOUND:3610',
#  'PUBCHEM.COMPOUND:8616',
#  'PUBCHEM.COMPOUND:10341154',
#  'PUBCHEM.COMPOUND:2125',
#  'CHEBI:18300',
#  'PUBCHEM.COMPOUND:6674',
#  'PUBCHEM.COMPOUND:49849931',
#  'PUBCHEM.COMPOUND:688272',
#  'PUBCHEM.COMPOUND:5284590',
#  'PUBCHEM.COMPOUND:71815',
#  'PUBCHEM.COMPOUND:5225086',
#  'PUBCHEM.COMPOUND:441243',
#  'PUBCHEM.COMPOUND:4090',
#  'PUBCHEM.COMPOUND:5702199',
#  'PUBCHEM.COMPOUND:47528',
#  'PUBCHEM.COMPOUND:3132',
#  'PUBCHEM.COMPOUND:2356',
#  'PUBCHEM.COMPOUND:5318562',
#  'PUBCHEM.COMPOUND:72385',
#  'PUBCHEM.COMPOUND:2129',
#  'PUBCHEM.COMPOUND:4684',
#  'PUBCHEM.COMPOUND:5387',
#  'PUBCHEM.COMPOUND:4680',
#  'PUBCHEM.COMPOUND:5244802',
#  'PUBCHEM.COMPOUND:2690',
#  'PUBCHEM.COMPOUND:60838',
#  'PUBCHEM.COMPOUND:4935',
#  'PUBCHEM.COMPOUND:60750',
#  'PUBCHEM.COMPOUND:3394',
#  'PUBCHEM.COMPOUND:932',
#  'PUBCHEM.COMPOUND:4533',
#  'PUBCHEM.COMPOUND:275510',
#  'PUBCHEM.COMPOUND:5353962',
#  'PUBCHEM.COMPOUND:4614',
#  'PUBCHEM.COMPOUND:60943',
#  'PUBCHEM.COMPOUND:5353622',
#  'PUBCHEM.COMPOUND:158781',
#  'PUBCHEM.COMPOUND:62389',
#  'PUBCHEM.COMPOUND:2375',
#  'PUBCHEM.COMPOUND:5281743',
#  'PUBCHEM.COMPOUND:10420710',
#  'PUBCHEM.COMPOUND:24868316',
#  'PUBCHEM.COMPOUND:68911',
#  'PUBCHEM.COMPOUND:2176',
#  'PUBCHEM.COMPOUND:10077147',
#  'PUBCHEM.COMPOUND:6439848',
#  'PUBCHEM.COMPOUND:57267',
#  'PUBCHEM.COMPOUND:107950',
#  'PUBCHEM.COMPOUND:2046',
#  'PUBCHEM.COMPOUND:4174',
#  'PUBCHEM.COMPOUND:3410883',
#  'PUBCHEM.COMPOUND:3647',
#  'PUBCHEM.COMPOUND:3066',
#  'PUBCHEM.COMPOUND:4098',
#  'PUBCHEM.COMPOUND:60795',
#  'PUBCHEM.COMPOUND:3683',
#  'PUBCHEM.COMPOUND:8369',
#  'PUBCHEM.COMPOUND:23725625',
#  'CHEBI:16015',
#  'PUBCHEM.COMPOUND:3926765',
#  'PUBCHEM.COMPOUND:16759155',
#  'PUBCHEM.COMPOUND:108094',
#  'PUBCHEM.COMPOUND:10367662',
#  'PUBCHEM.COMPOUND:16760039',
#  'PUBCHEM.COMPOUND:4105',
#  'PUBCHEM.COMPOUND:129989',
#  'PUBCHEM.COMPOUND:680502',
#  'CHEBI:17053',
#  'PUBCHEM.COMPOUND:2724',
#  'PUBCHEM.COMPOUND:9795867',
#  'CHEBI:28694',
#  'PUBCHEM.COMPOUND:9829523',
#  'PUBCHEM.COMPOUND:2583',
#  'PUBCHEM.COMPOUND:6253',
#  'PUBCHEM.COMPOUND:4630',
#  'PUBCHEM.COMPOUND:6610319',
#  'PUBCHEM.COMPOUND:2286',
#  'PUBCHEM.COMPOUND:84029',
#  'PUBCHEM.COMPOUND:5320556',
#  'PUBCHEM.COMPOUND:133621',
#  'PUBCHEM.COMPOUND:3177',
#  'PUBCHEM.COMPOUND:5244802',
#  'PUBCHEM.COMPOUND:158781',
#  'PUBCHEM.COMPOUND:9887884',
#  'PUBCHEM.COMPOUND:3066',
#  'PUBCHEM.COMPOUND:10251',
#  'PUBCHEM.COMPOUND:5145950',
#  'PUBCHEM.COMPOUND:3610',
#  'PUBCHEM.COMPOUND:4680',
#  'CHEBI:16015',
#  'PUBCHEM.COMPOUND:72385',
#  'PUBCHEM.COMPOUND:23725625',
#  'PUBCHEM.COMPOUND:60838',
#  'PUBCHEM.COMPOUND:129989',
#  'PUBCHEM.COMPOUND:6604926',
#  'PUBCHEM.COMPOUND:10077147',
#  'PUBCHEM.COMPOUND:60795',
#  'PUBCHEM.COMPOUND:5614',
#  'PUBCHEM.COMPOUND:2690',
#  'PUBCHEM.COMPOUND:441243',
#  'PUBCHEM.COMPOUND:4810',
#  'PUBCHEM.COMPOUND:454217',
#  'PUBCHEM.COMPOUND:21678144',
#  'PUBCHEM.COMPOUND:5320556',
#  'PUBCHEM.COMPOUND:73707372',
#  'PUBCHEM.COMPOUND:3799',
#  'PUBCHEM.COMPOUND:10341154',
#  'PUBCHEM.COMPOUND:49849931',
#  'PUBCHEM.COMPOUND:4848',
#  'PUBCHEM.COMPOUND:688272',
#  'PUBCHEM.COMPOUND:4792',
#  'PUBCHEM.COMPOUND:9910224',
#  'PUBCHEM.COMPOUND:5318562',
#  'PUBCHEM.COMPOUND:4614',
#  'PUBCHEM.COMPOUND:105008',
#  'PUBCHEM.COMPOUND:9865515',
#  'PUBCHEM.COMPOUND:9795867',
#  'PUBCHEM.COMPOUND:57267',
#  'PUBCHEM.COMPOUND:4935',
#  'PUBCHEM.COMPOUND:5330286',
#  'PUBCHEM.COMPOUND:24707',
#  'PUBCHEM.COMPOUND:4684',
#  'PUBCHEM.COMPOUND:41781',
#  'PUBCHEM.COMPOUND:73707397',
#  'PUBCHEM.COMPOUND:680502',
#  'PUBCHEM.COMPOUND:9906875',
#  'PUBCHEM.COMPOUND:4174',
#  'PUBCHEM.COMPOUND:60750',
#  'PUBCHEM.COMPOUND:445580',
#  'PUBCHEM.COMPOUND:62389',
#  'PUBCHEM.COMPOUND:4098',
#  'PUBCHEM.COMPOUND:68911',
#  'PUBCHEM.COMPOUND:5702199',
#  'CHEBI:18405',
#  'PUBCHEM.COMPOUND:6610319',
#  'PUBCHEM.COMPOUND:16760039',
#  'PUBCHEM.COMPOUND:2724',
#  'PUBCHEM.COMPOUND:49766501',
#  'PUBCHEM.COMPOUND:275510',
#  'PUBCHEM.COMPOUND:5281881',
#  'PUBCHEM.COMPOUND:3292',
#  'PUBCHEM.COMPOUND:11689583',
#  'PUBCHEM.COMPOUND:5479',
#  'PUBCHEM.COMPOUND:5311097',
#  'PUBCHEM.COMPOUND:71815',
#  'PUBCHEM.COMPOUND:47528',
#  'PUBCHEM.COMPOUND:4105',
#  'PUBCHEM.COMPOUND:10367662',
#  'PUBCHEM.COMPOUND:4630',
#  'PUBCHEM.COMPOUND:11317348',
#  'PUBCHEM.COMPOUND:65944',
#  'PUBCHEM.COMPOUND:3683',
#  'PUBCHEM.COMPOUND:2286',
#  'PUBCHEM.COMPOUND:5353622',
#  'PUBCHEM.COMPOUND:5374',
#  'PUBCHEM.COMPOUND:5281743',
#  'PUBCHEM.COMPOUND:3540',
#  'PUBCHEM.COMPOUND:2125',
#  'PUBCHEM.COMPOUND:4533',
#  'PUBCHEM.COMPOUND:8369',
#  'PUBCHEM.COMPOUND:21100',
#  'PUBCHEM.COMPOUND:2129',
#  'PUBCHEM.COMPOUND:5284590',
#  'PUBCHEM.COMPOUND:23930397',
#  'PUBCHEM.COMPOUND:22752',
#  'PUBCHEM.COMPOUND:36462',
#  'PUBCHEM.COMPOUND:6439848',
#  'PUBCHEM.COMPOUND:16759155',
#  'PUBCHEM.COMPOUND:3647',
#  'CHEBI:18300',
#  'PUBCHEM.COMPOUND:4090',
#  'PUBCHEM.COMPOUND:5788723',
#  'PUBCHEM.COMPOUND:24868316',
#  'PUBCHEM.COMPOUND:3682',
#  'PUBCHEM.COMPOUND:2176',
#  'PUBCHEM.COMPOUND:60943',
#  'PUBCHEM.COMPOUND:104845',
#  'PUBCHEM.COMPOUND:2356',
#  'PUBCHEM.COMPOUND:3926765',
#  'PUBCHEM.COMPOUND:2375',
#  'PUBCHEM.COMPOUND:2063',
#  'PUBCHEM.COMPOUND:2583',
#  'PUBCHEM.COMPOUND:10420710',
#  'PUBCHEM.COMPOUND:4452',
#  'PUBCHEM.COMPOUND:5517',
#  'PUBCHEM.COMPOUND:3410883',
#  'PUBCHEM.COMPOUND:107950',
#  'PUBCHEM.COMPOUND:5353962',
#  'PUBCHEM.COMPOUND:3394',
#  'CHEBI:35237',
#  'PUBCHEM.COMPOUND:4336830',
#  'PUBCHEM.COMPOUND:5225086',
#  'PUBCHEM.COMPOUND:6674',
#  'PUBCHEM.COMPOUND:441314',
#  'PUBCHEM.COMPOUND:149784',
#  'PUBCHEM.COMPOUND:5387',
#  'CHEBI:17053',
#  'PUBCHEM.COMPOUND:9829523',
#  'CHEBI:28694',
#  'PUBCHEM.COMPOUND:4355450',
#  'PUBCHEM.COMPOUND:1456',
#  'PUBCHEM.COMPOUND:4409',
#  'PUBCHEM.COMPOUND:51081',
#  'PUBCHEM.COMPOUND:62824',
#  'PUBCHEM.COMPOUND:6253',
#  'PUBCHEM.COMPOUND:932',
#  'PUBCHEM.COMPOUND:5281071',
#  'PUBCHEM.COMPOUND:6602440',
#  'PUBCHEM.COMPOUND:24964624',
#  'PUBCHEM.COMPOUND:3132',
#  'PUBCHEM.COMPOUND:84029',
#  'PUBCHEM.COMPOUND:60773',
#  'PUBCHEM.COMPOUND:8616',
#  'PUBCHEM.COMPOUND:108094',
#  'PUBCHEM.COMPOUND:57448257',
#  'PUBCHEM.COMPOUND:5253',
#  'PUBCHEM.COMPOUND:73707417',
#  'CHEBI:17561',
#  'PUBCHEM.COMPOUND:2253',
#  'PUBCHEM.COMPOUND:2046',
#  'PUBCHEM.COMPOUND:23582824',
#  'PUBCHEM.COMPOUND:6708778',
#  'PUBCHEM.COMPOUND:4055',
#  'PUBCHEM.COMPOUND:60838',
#  'PUBCHEM.COMPOUND:6610300',
#  'PUBCHEM.COMPOUND:4878',
#  'PUBCHEM.COMPOUND:3926765',
#  'PUBCHEM.COMPOUND:3062316',
#  'PUBCHEM.COMPOUND:5329103',
#  'PUBCHEM.COMPOUND:1400',
#  'PUBCHEM.COMPOUND:3003565',
#  'PUBCHEM.COMPOUND:5702003',
#  'PUBCHEM.COMPOUND:2538',
#  'PUBCHEM.COMPOUND:9549289',
#  'PUBCHEM.COMPOUND:210332',
#  'PUBCHEM.COMPOUND:439533',
#  'PUBCHEM.COMPOUND:5515',
#  'PUBCHEM.COMPOUND:9799509',
#  'PUBCHEM.COMPOUND:67077825',
#  'CHEBI:15811',
#  'PUBCHEM.COMPOUND:41867',
#  'PUBCHEM.COMPOUND:16038120',
#  'CHEBI:18303',
#  'CHEBI:44915',
#  'CHEBI:6367',
#  'CHEBI:8988',
#  'CHEBI:77572',
#  'CHEBI:4911',
#  'CHEBI:77572',
#  'CHEBI:168396',
#  'CHEBI:6367',
#  'CHEBI:8988',
#  'CHEBI:44915',
#  'CHEBI:47381',
#  'CHEBI:9753',
#  'CHEBI:8069',
#  'CHEBI:8988',
#  'PUBCHEM.COMPOUND:65300',
#  'CHEMBL.COMPOUND:CHEMBL1288652',
#  'PUBCHEM.COMPOUND:56929299',
#  'PUBCHEM.COMPOUND:19100',
#  'PUBCHEM.COMPOUND:5362595',
#  'PUBCHEM.COMPOUND:60195662',
#  'CHEBI:69478',
#  'PUBCHEM.COMPOUND:16666',
#  'PUBCHEM.COMPOUND:170833',
#  'PUBCHEM.COMPOUND:16078',
#  'PUBCHEM.COMPOUND:7888',
#  'CHEMBL.COMPOUND:CHEMBL3833333',
#  'PUBCHEM.COMPOUND:21037647',
#  'PUBCHEM.COMPOUND:62151',
#  'PUBCHEM.COMPOUND:5282105',
#  'PUBCHEM.COMPOUND:16095384',
#  'CHEBI:3764',
#  'PUBCHEM.COMPOUND:89576',
#  'PUBCHEM.COMPOUND:6549',
#  'PUBCHEM.COMPOUND:62907',
#  'PUBCHEM.COMPOUND:135138454',
#  'CHEBI:15409',
#  'PUBCHEM.COMPOUND:11675630',
#  'CHEBI:15396',
#  'PUBCHEM.COMPOUND:644019',
#  'PUBCHEM.COMPOUND:2812',
#  'CHEMBL.COMPOUND:CHEMBL2387541',
#  'CHEMBL.COMPOUND:CHEMBL1289953',
#  'CHEBI:15397',
#  'PUBCHEM.COMPOUND:2758',
#  'CHEMBL.COMPOUND:CHEMBL3707315',
#  'PUBCHEM.COMPOUND:5280450',
#  'PUBCHEM.COMPOUND:56929387',
#  'PUBCHEM.COMPOUND:162184',
#  'PUBCHEM.COMPOUND:5353376',
#  'PUBCHEM.COMPOUND:2733484',
#  'PUBCHEM.COMPOUND:11266244',
#  'PUBCHEM.COMPOUND:73755215',
#  'PUBCHEM.COMPOUND:9929425',
#  'DRUGBANK:DB14009',
#  'CHEBI:25187',
#  'PUBCHEM.COMPOUND:66548125',
#  'PUBCHEM.COMPOUND:5281969',
#  'PUBCHEM.COMPOUND:1598',
#  'CHEBI:2700',
#  'CHEBI:17351',
#  'PUBCHEM.COMPOUND:104897',
#  'PUBCHEM.COMPOUND:165675',
#  'PUBCHEM.COMPOUND:637566',
#  'PUBCHEM.COMPOUND:161930',
#  'CHEBI:7565',
#  'CHEBI:6432',
#  'CHEBI:15367',
#  'CHEBI:6771',
#  'CHEBI:59296',
#  'CHEBI:107660',
#  'DRUGBANK:DB07378',
#  'DRUGBANK:DB07357',
#  'CHEBI:17659',
#  'DRUGBANK:DB07341',
#  'DRUGBANK:DB04680',
#  'CHEBI:610092',
#  'DRUGBANK:DB03772',
#  'DRUGBANK:DB04141',
#  'DRUGBANK:DB07633',
#  'CHEBI:67168',
#  'CHEBI:42088',
#  'CHEBI:67119',
#  'DRUGBANK:DB01363',
#  'PUBCHEM.COMPOUND:5816',
#  'CHEMBL.COMPOUND:CHEMBL1366933',
#  'PUBCHEM.COMPOUND:122211',
#  'CHEBI:9615',
#  'CHEBI:5559',
#  'CHEBI:93630',
#  'CHEBI:6344',
#  'CHEBI:64098',
#  'PUBCHEM.COMPOUND:2803',
#  'CHEBI:90930',
#  'CHEBI:10304',
#  'CHEBI:28502',
#  'CHEBI:7470',
#  'PUBCHEM.COMPOUND:5685',
#  'CHEBI:3181',
#  'CHEBI:2788',
#  'CHEBI:5002',
#  'CHEBI:48538',
#  'CHEBI:47781',
#  'CHEBI:6809',
#  'CHEBI:34665',
#  'PUBCHEM.COMPOUND:439260',
#  'CHEBI:10093',
#  'CHEBI:8077',
#  'CHEBI:31232',
#  'CHEBI:6690',
#  'CHEBI:5554',
#  'PUBCHEM.COMPOUND:3519',
#  'CHEMBL.COMPOUND:CHEMBL609728',
#  'CHEBI:37937',
#  'CHEBI:9738',
#  'PUBCHEM.COMPOUND:5702063',
#  'DRUGBANK:DB09195',
#  'DRUGBANK:DB11124',
#  'CHEBI:36803',
#  'PUBCHEM.COMPOUND:5707',
#  'CHEBI:61058',
#  'CHEBI:36791',
#  'CHEBI:3647',
#  'CHEBI:63629',
#  'CHEBI:94754',
#  'CHEMBL.COMPOUND:CHEMBL1201454',
#  'PUBCHEM.COMPOUND:5736',
#  'PUBCHEM.COMPOUND:4636',
#  'CHEBI:7735',
#  'CHEBI:7936',
#  'CHEBI:135076',
#  'CHEBI:18357',
#  'CHEBI:135589',
#  'CHEBI:94666',
#  'CHEMBL.COMPOUND:CHEMBL2106710',
#  'CHEBI:5553',
#  'CHEBI:9609',
#  'CHEBI:92950',
#  'CHEMBL.COMPOUND:CHEMBL1256958',
#  'PUBCHEM.COMPOUND:31101',
#  'PUBCHEM.COMPOUND:838',
#  'CHEBI:51164',
#  'CHEBI:71255',
#  'CHEBI:91845',
#  'CHEMBL.COMPOUND:CHEMBL1356607',
#  'CHEBI:2789',
#  'CHEBI:59912',
#  'CHEBI:7640',
#  'PUBCHEM.COMPOUND:6005',
#  'CHEBI:8078',
#  'CHEBI:90117',
#  'CHEBI:113556',
#  'CHEBI:48558',
#  'PUBCHEM.COMPOUND:47811',
#  'CHEBI:2675',
#  'CHEBI:7862',
#  'PUBCHEM.COMPOUND:443951',
#  'CHEBI:132233',
#  'CHEBI:10082',
#  'CHEBI:4466',
#  'CHEBI:34706',
#  'CHEBI:50659',
#  'CHEBI:51368',
#  'CHEBI:50841',
#  'CHEBI:6755',
#  'CHEMBL.COMPOUND:CHEMBL2062265',
#  'PUBCHEM.COMPOUND:4205',
#  'PUBCHEM.COMPOUND:108094',
#  'PUBCHEM.COMPOUND:5775',
#  'CHEMBL.COMPOUND:CHEMBL1200996',
#  'CHEBI:6838',
#  'CHEMBL.COMPOUND:CHEMBL1255582',
#  'CHEBI:63617',
#  'CHEBI:8871',
#  'CHEMBL.COMPOUND:CHEMBL1200705',
#  'CHEBI:31472',
#  'PUBCHEM.COMPOUND:2435',
#  'PUBCHEM.COMPOUND:28864',
#  'CHEBI:3441',
#  'CHEBI:32316',
#  'CHEBI:94461',
#  'CHEMBL.COMPOUND:CHEMBL3559672',
#  'CHEBI:8081',
#  'CHEMBL.COMPOUND:CHEMBL3137348',
#  'DRUGBANK:DB05461',
#  'CHEBI:135351',
#  'CHEMBL.COMPOUND:CHEMBL1200432',
#  'CHEBI:3758',
#  'CHEBI:141146',
#  'CHEBI:4910',
#  'CHEBI:48562',
#  'CHEBI:83804',
#  'PUBCHEM.COMPOUND:5268',
#  'CHEBI:4647',
#  'CHEBI:73287',
#  'CHEBI:31524',
#  'CHEBI:71253',
#  'PUBCHEM.COMPOUND:4768',
#  'CHEBI:8888',
#  'CHEBI:5613',
#  'CHEBI:5558',
#  'CHEMBL.COMPOUND:CHEMBL2311030',
#  'PUBCHEM.COMPOUND:133621',
#  'CHEBI:3175',
#  'CHEBI:6950',
#  'CHEBI:46632',
#  'PUBCHEM.COMPOUND:121850',
#  'CHEBI:3766',
#  'PUBCHEM.COMPOUND:5504',
#  'CHEBI:92386',
#  'PUBCHEM.COMPOUND:219050',
#  'CHEBI:3286',
#  'CHEMBL.COMPOUND:CHEMBL2104619',
#  'PUBCHEM.COMPOUND:5311068',
#  'CHEBI:8435',
#  'CHEBI:64318',
#  'CHEBI:8707',
#  'CHEBI:8364',
#  'PUBCHEM.COMPOUND:54746',
#  'CHEBI:9492',
#  'CHEBI:80680',
#  'PUBCHEM.COMPOUND:8969',
#  'PUBCHEM.COMPOUND:4893',
#  'CHEMBL.COMPOUND:CHEMBL2107339',
#  'CHEMBL.COMPOUND:CHEMBL1200873',
#  'PUBCHEM.COMPOUND:643606',
#  'CHEBI:28918',
#  'CHEBI:59909',
#  'CHEBI:32193',
#  'CHEBI:51137',
#  'CHEBI:7863',
#  'CHEBI:50212',
#  'CHEBI:75725',
#  'PUBCHEM.COMPOUND:91827340',
#  'CHEMBL.COMPOUND:CHEMBL2062257',
#  'PUBCHEM.COMPOUND:2726',
#  'PUBCHEM.COMPOUND:30668',
#  'CHEBI:31236',
#  'CHEBI:10119',
#  'CHEMBL.COMPOUND:CHEMBL1200873',
#  'CHEBI:10082',
#  'CHEBI:34665',
#  'CHEBI:2675',
#  'CHEMBL.COMPOUND:CHEMBL2062265',
#  'CHEBI:90117',
#  'PUBCHEM.COMPOUND:3519',
#  'CHEBI:36791',
#  'PUBCHEM.COMPOUND:219050',
#  'CHEBI:3181',
#  'CHEBI:71253',
#  'CHEBI:31232',
#  'CHEBI:94666',
#  'CHEBI:93630',
#  'PUBCHEM.COMPOUND:2803',
#  'PUBCHEM.COMPOUND:122211',
#  'CHEBI:83804',
#  'CHEBI:32193',
#  'PUBCHEM.COMPOUND:6005',
#  'CHEBI:59912',
#  'CHEBI:7862',
#  'CHEBI:135351',
#  'CHEBI:135589',
#  'PUBCHEM.COMPOUND:4893',
#  'PUBCHEM.COMPOUND:838',
#  'CHEBI:94461',
#  'CHEBI:92950',
#  'CHEBI:36803',
#  'CHEBI:91845',
#  'CHEBI:90930',
#  'CHEBI:5558',
#  'CHEBI:71255',
#  'CHEBI:7863',
#  'CHEBI:94754',
#  'PUBCHEM.COMPOUND:5268',
#  'CHEBI:10119',
#  'PUBCHEM.COMPOUND:2435',
#  'PUBCHEM.COMPOUND:5736',
#  'CHEMBL.COMPOUND:CHEMBL2062257',
#  'CHEBI:37937',
#  'CHEBI:50212',
#  'PUBCHEM.COMPOUND:5775',
#  'PUBCHEM.COMPOUND:28864',
#  'CHEBI:2788',
#  'PUBCHEM.COMPOUND:91827340',
#  'CHEBI:135076',
#  'CHEBI:4647',
#  'CHEBI:63629',
#  'CHEBI:10304',
#  'PUBCHEM.COMPOUND:5685',
#  'PUBCHEM.COMPOUND:4768',
#  'CHEBI:5554',
#  'CHEMBL.COMPOUND:CHEMBL609728',
#  'CHEBI:9609',
#  'CHEBI:75725',
#  'CHEMBL.COMPOUND:CHEMBL1366933',
#  'PUBCHEM.COMPOUND:5702063',
#  'PUBCHEM.COMPOUND:108094',
#  'DRUGBANK:DB09195',
#  'CHEBI:6838',
#  'CHEBI:64318',
#  'CHEBI:3286',
#  'CHEBI:7640',
#  'CHEBI:32316',
#  'CHEBI:51164',
#  'PUBCHEM.COMPOUND:643606',
#  'CHEBI:63617',
#  'CHEBI:10093',
#  'PUBCHEM.COMPOUND:5504',
#  'CHEBI:18357',
#  'PUBCHEM.COMPOUND:8969',
#  'CHEBI:51137',
#  'CHEBI:51368',
#  'CHEBI:8078',
#  'PUBCHEM.COMPOUND:5707',
#  'CHEMBL.COMPOUND:CHEMBL3559672',
#  'PUBCHEM.COMPOUND:47811',
#  'CHEMBL.COMPOUND:CHEMBL2107339',
#  'CHEBI:141146',
#  'CHEBI:9615',
#  'CHEBI:6344',
#  'CHEMBL.COMPOUND:CHEMBL2104619',
#  'CHEBI:113556',
#  'CHEBI:3175',
#  'CHEMBL.COMPOUND:CHEMBL1200996',
#  'CHEBI:8077',
#  'CHEBI:31524',
#  'CHEBI:3441',
#  'CHEBI:48538',
#  'DRUGBANK:DB05461',
#  'CHEBI:2789',
#  'PUBCHEM.COMPOUND:4205',
#  'PUBCHEM.COMPOUND:4636',
#  'CHEBI:6950',
#  'CHEMBL.COMPOUND:CHEMBL2106710',
#  'CHEBI:50659',
#  'CHEBI:5559',
#  'CHEBI:6690',
#  'CHEBI:8435',
#  'CHEBI:5553',
#  'CHEBI:4910',
#  'CHEBI:132233',
#  'CHEBI:6755',
#  'CHEBI:73287',
#  'CHEBI:46632',
#  'CHEBI:80680',
#  'CHEMBL.COMPOUND:CHEMBL1256958',
#  'PUBCHEM.COMPOUND:54746',
#  'CHEBI:61058',
#  'CHEBI:31472',
#  'DRUGBANK:DB01363',
#  'CHEBI:8081',
#  'CHEBI:50841',
#  'CHEBI:6809',
#  'CHEBI:3758',
#  'PUBCHEM.COMPOUND:133621',
#  'CHEMBL.COMPOUND:CHEMBL1200705',
#  'CHEBI:3647',
#  'CHEBI:8364',
#  'CHEMBL.COMPOUND:CHEMBL1356607',
#  'PUBCHEM.COMPOUND:121850',
#  'CHEBI:31236',
#  'CHEBI:92386',
#  'CHEBI:3766',
#  'DRUGBANK:DB11124',
#  'CHEBI:9738',
#  'CHEBI:8888',
#  'CHEMBL.COMPOUND:CHEMBL1200432',
#  'CHEBI:59909',
#  'PUBCHEM.COMPOUND:5311068',
#  'CHEMBL.COMPOUND:CHEMBL3137348',
#  'CHEBI:28918',
#  'CHEBI:48562',
#  'CHEBI:64098',
#  'CHEBI:8871',
#  'CHEBI:5002',
#  'CHEBI:7936',
#  'CHEBI:9492',
#  'PUBCHEM.COMPOUND:30668',
#  'CHEBI:7735',
#  'CHEBI:34706',
#  'PUBCHEM.COMPOUND:31101',
#  'PUBCHEM.COMPOUND:5816',
#  'CHEBI:47781',
#  'PUBCHEM.COMPOUND:2726',
#  'CHEBI:5613',
#  'PUBCHEM.COMPOUND:443951',
#  'CHEMBL.COMPOUND:CHEMBL2311030',
#  'CHEBI:4466',
#  'CHEMBL.COMPOUND:CHEMBL1201454',
#  'CHEBI:8707',
#  'CHEBI:48558',
#  'CHEMBL.COMPOUND:CHEMBL1255582',
#  'PUBCHEM.COMPOUND:439260',
#  'CHEBI:28502',
#  'CHEBI:7470',
#  'PUBCHEM.COMPOUND:11410354',
#  'CHEMBL.COMPOUND:CHEMBL2108078',
#  'PUBCHEM.COMPOUND:6305',
#  'CHEBI:7903',
#  'CHEMBL.COMPOUND:CHEMBL3707306',
#  'CHEBI:7507',
#  'CHEMBL.COMPOUND:CHEMBL2107572',
#  'CHEMBL.COMPOUND:CHEMBL180672',
#  'PUBCHEM.COMPOUND:46917559',
#  'PUBCHEM.COMPOUND:8378',
#  'PUBCHEM.COMPOUND:10345214',
#  'CHEBI:4496',
#  'CHEBI:134700',
#  'PUBCHEM.COMPOUND:9882793',
#  'PUBCHEM.COMPOUND:9910902',
#  'CHEBI:48391',
#  'GTOPDB:707',
#  'PUBCHEM.COMPOUND:9841421',
#  'PUBCHEM.COMPOUND:156419',
#  'CHEMBL.COMPOUND:CHEMBL1198855',
#  'CHEMBL.COMPOUND:CHEMBL3545100',
#  'CHEBI:2666',
#  'PUBCHEM.COMPOUND:71242808',
#  'CHEMBL.COMPOUND:CHEMBL1672973',
#  'CHEMBL.COMPOUND:CHEMBL1084513',
#  'PUBCHEM.COMPOUND:52943938',
#  'PUBCHEM.COMPOUND:158797',
#  'PUBCHEM.COMPOUND:11849514',
#  'PUBCHEM.COMPOUND:11710462',
#  'PUBCHEM.COMPOUND:44405854',
#  'PUBCHEM.COMPOUND:135948915',
#  'CHEBI:57912',
#  'PUBCHEM.COMPOUND:888',
#  'PUBCHEM.COMPOUND:6918446',
#  'CHEBI:47782',
#  'PUBCHEM.COMPOUND:1103',
#  'CHEMBL.COMPOUND:CHEMBL292376',
#  'PUBCHEM.COMPOUND:10158373',
#  'CHEMBL.COMPOUND:CHEMBL2106123',
#  'CHEBI:15746',
#  'CHEBI:58455',
#  'CHEMBL.COMPOUND:CHEMBL1255',
#  'CHEMBL.COMPOUND:CHEMBL1801356',
#  'PUBCHEM.COMPOUND:71716572',
#  'CHEBI:9679',
#  'CHEMBL.COMPOUND:CHEMBL2109588',
#  'PUBCHEM.COMPOUND:44415153',
#  'CHEMBL.COMPOUND:CHEMBL194764',
#  'CHEBI:48390',
#  'PUBCHEM.COMPOUND:3969',
#  'PUBCHEM.COMPOUND:5353391',
#  'PUBCHEM.COMPOUND:5573',
#  'PUBCHEM.COMPOUND:2343',
#  'PUBCHEM.COMPOUND:5280954',
#  'PUBCHEM.COMPOUND:84029',
#  'PUBCHEM.COMPOUND:200',
#  'PUBCHEM.COMPOUND:5462501',
#  'PUBCHEM.COMPOUND:24768935',
#  'PUBCHEM.COMPOUND:3616',
#  'PUBCHEM.COMPOUND:57448257',
#  'PUBCHEM.COMPOUND:34040',
#  'PUBCHEM.COMPOUND:609483',
#  'PUBCHEM.COMPOUND:36462',
#  'PUBCHEM.COMPOUND:5702028',
#  'PUBCHEM.COMPOUND:107867',
#  'PUBCHEM.COMPOUND:4462449',
#  'PUBCHEM.COMPOUND:126941',
#  'PUBCHEM.COMPOUND:2775510',
#  'PUBCHEM.COMPOUND:10127622',
#  'PUBCHEM.COMPOUND:4075',
#  'PUBCHEM.COMPOUND:9956637',
#  'PUBCHEM.COMPOUND:941361',
#  'PUBCHEM.COMPOUND:5311309',
#  'PUBCHEM.COMPOUND:12478',
#  'PUBCHEM.COMPOUND:60648',
#  'PUBCHEM.COMPOUND:688272',
#  'PUBCHEM.COMPOUND:9982218',
#  'PUBCHEM.COMPOUND:5280804',
#  'PUBCHEM.COMPOUND:49766501',
#  'PUBCHEM.COMPOUND:5281643',
#  'PUBCHEM.COMPOUND:3333',
#  'PUBCHEM.COMPOUND:1204',
#  'PUBCHEM.COMPOUND:57364',
#  'PUBCHEM.COMPOUND:24964624',
#  'PUBCHEM.COMPOUND:3100',
#  'PUBCHEM.COMPOUND:456201',
#  'PUBCHEM.COMPOUND:220184',
#  'PUBCHEM.COMPOUND:9604992',
#  'PUBCHEM.COMPOUND:5328940',
#  'PUBCHEM.COMPOUND:16759175',
#  'PUBCHEM.COMPOUND:656665',
#  'PUBCHEM.COMPOUND:2366',
#  'PUBCHEM.COMPOUND:3250',
#  'PUBCHEM.COMPOUND:60773',
#  'PUBCHEM.COMPOUND:3354',
#  'PUBCHEM.COMPOUND:5419',
#  'PUBCHEM.COMPOUND:44118238',
#  'PUBCHEM.COMPOUND:10377751',
#  'PUBCHEM.COMPOUND:4748',
#  'PUBCHEM.COMPOUND:4534086',
#  'PUBCHEM.COMPOUND:44187362',
#  'PUBCHEM.COMPOUND:5311221',
#  'PUBCHEM.COMPOUND:5311281',
#  'PUBCHEM.COMPOUND:6253',
#  'PUBCHEM.COMPOUND:449459',
#  'CHEBI:66910',
#  'CHEMBL.COMPOUND:CHEMBL3545158',
#  'CHEBI:91435',
#  'CHEBI:27666',
#  'CHEBI:15422',
#  'CHEMBL.COMPOUND:CHEMBL1292',
#  'PUBCHEM.COMPOUND:12544',
#  'CHEBI:8427',
#  'CHEBI:3749',
#  'CHEBI:89929',
#  'CHEBI:5441',
#  'PUBCHEM.COMPOUND:5353622',
#  'PUBCHEM.COMPOUND:60773',
#  'PUBCHEM.COMPOUND:4630',
#  'PUBCHEM.COMPOUND:6708539',
#  'PUBCHEM.COMPOUND:2564',
#  'PUBCHEM.COMPOUND:68712',
#  'PUBCHEM.COMPOUND:71760892',
#  'PUBCHEM.COMPOUND:1894361',
#  'PUBCHEM.COMPOUND:2913564',
#  'PUBCHEM.COMPOUND:483168',
#  'PUBCHEM.COMPOUND:439533',
#  'PUBCHEM.COMPOUND:9874913',
#  'PUBCHEM.COMPOUND:656665',
#  'PUBCHEM.COMPOUND:107867',
#  'PUBCHEM.COMPOUND:200',
#  'PUBCHEM.COMPOUND:3262',
#  'PUBCHEM.COMPOUND:71815',
#  'PUBCHEM.COMPOUND:4839',
#  'PUBCHEM.COMPOUND:62389',
#  'PUBCHEM.COMPOUND:5311221',
#  'PUBCHEM.COMPOUND:439503',
#  'PUBCHEM.COMPOUND:5280881',
#  'PUBCHEM.COMPOUND:688020',
#  'PUBCHEM.COMPOUND:4308',
#  'PUBCHEM.COMPOUND:3454',
#  'PUBCHEM.COMPOUND:4486',
#  'PUBCHEM.COMPOUND:609483',
#  'PUBCHEM.COMPOUND:34312',
#  'PUBCHEM.COMPOUND:220184',
#  'PUBCHEM.COMPOUND:60490',
#  'PUBCHEM.COMPOUND:60857',
#  'PUBCHEM.COMPOUND:24875320',
#  'PUBCHEM.COMPOUND:3505',
#  'PUBCHEM.COMPOUND:693139',
#  'PUBCHEM.COMPOUND:3373',
#  'PUBCHEM.COMPOUND:16759359',
#  'PUBCHEM.COMPOUND:60953',
#  'PUBCHEM.COMPOUND:9893887',
#  'PUBCHEM.COMPOUND:24768935',
#  'PUBCHEM.COMPOUND:10127622',
#  'PUBCHEM.COMPOUND:60648',
#  'PUBCHEM.COMPOUND:71277',
#  'PUBCHEM.COMPOUND:3616',
#  'PUBCHEM.COMPOUND:10377751',
#  'PUBCHEM.COMPOUND:6710772',
#  'PUBCHEM.COMPOUND:47528',
#  'PUBCHEM.COMPOUND:2315',
#  'PUBCHEM.COMPOUND:3100',
#  'PUBCHEM.COMPOUND:65833',
#  'PUBCHEM.COMPOUND:1714884',
#  'PUBCHEM.COMPOUND:65944',
#  'PUBCHEM.COMPOUND:5387',
#  'PUBCHEM.COMPOUND:4197',
#  'PUBCHEM.COMPOUND:5702042',
#  'PUBCHEM.COMPOUND:11749858',
#  'PUBCHEM.COMPOUND:6708600',
#  'PUBCHEM.COMPOUND:5330790',
#  'PUBCHEM.COMPOUND:5329103',
#  'PUBCHEM.COMPOUND:24995524',
#  'PUBCHEM.COMPOUND:6335412',
#  'PUBCHEM.COMPOUND:11395181',
#  'PUBCHEM.COMPOUND:6674',
#  'PUBCHEM.COMPOUND:9547215',
#  'PUBCHEM.COMPOUND:5392',
#  'PUBCHEM.COMPOUND:5702003',
#  'PUBCHEM.COMPOUND:23947601',
#  'PUBCHEM.COMPOUND:6445533',
#  'PUBCHEM.COMPOUND:2900',
#  'PUBCHEM.COMPOUND:6604887',
#  'PUBCHEM.COMPOUND:442544',
#  'PUBCHEM.COMPOUND:5284513',
#  'PUBCHEM.COMPOUND:6708764',
#  'PUBCHEM.COMPOUND:156314',
#  'PUBCHEM.COMPOUND:4991',
#  'PUBCHEM.COMPOUND:6610267',
#  'PUBCHEM.COMPOUND:222786',
#  'PUBCHEM.COMPOUND:44219749',
#  'PUBCHEM.COMPOUND:72376',
#  'PUBCHEM.COMPOUND:4369270',
#  'PUBCHEM.COMPOUND:10077147',
#  'PUBCHEM.COMPOUND:442195',
#  'PUBCHEM.COMPOUND:300471',
#  'PUBCHEM.COMPOUND:9865515',
#  'PUBCHEM.COMPOUND:44483284',
#  'PUBCHEM.COMPOUND:5387',
#  'PUBCHEM.COMPOUND:3213',
#  'PUBCHEM.COMPOUND:5702265',
#  'PUBCHEM.COMPOUND:5487',
#  'PUBCHEM.COMPOUND:23340',
#  'PUBCHEM.COMPOUND:4792',
#  'PUBCHEM.COMPOUND:439620',
#  'PUBCHEM.COMPOUND:253602',
#  'PUBCHEM.COMPOUND:4928',
#  'PUBCHEM.COMPOUND:67077825',
#  'PUBCHEM.COMPOUND:285033',
#  'PUBCHEM.COMPOUND:680502',
#  'PUBCHEM.COMPOUND:5702107',
#  'PUBCHEM.COMPOUND:5702048',
#  'PUBCHEM.COMPOUND:3538',
#  'PUBCHEM.COMPOUND:3976',
#  'PUBCHEM.COMPOUND:4450',
#  'PUBCHEM.COMPOUND:197810',
#  'PUBCHEM.COMPOUND:25195294',
#  'PUBCHEM.COMPOUND:1830',
#  'PUBCHEM.COMPOUND:10379137',
#  'PUBCHEM.COMPOUND:123692',
#  'PUBCHEM.COMPOUND:73707427',
#  'PUBCHEM.COMPOUND:668081',
#  'PUBCHEM.COMPOUND:42623900',
#  'PUBCHEM.COMPOUND:15459',
#  'PUBCHEM.COMPOUND:65944',
#  'PUBCHEM.COMPOUND:11012',
#  'PUBCHEM.COMPOUND:5573',
#  'PUBCHEM.COMPOUND:10666',
#  'PUBCHEM.COMPOUND:50515',
#  'PUBCHEM.COMPOUND:3926765',
#  'PUBCHEM.COMPOUND:4259181',
#  'PUBCHEM.COMPOUND:10109823',
#  'PUBCHEM.COMPOUND:5702041',
#  'PUBCHEM.COMPOUND:3958',
#  'PUBCHEM.COMPOUND:2512',
#  'PUBCHEM.COMPOUND:16760041',
#  'PUBCHEM.COMPOUND:354624',
#  'PUBCHEM.COMPOUND:3971',
#  'PUBCHEM.COMPOUND:5597',
#  'PUBCHEM.COMPOUND:44259',
#  'PUBCHEM.COMPOUND:4472',
#  'PUBCHEM.COMPOUND:5311340',
#  'PUBCHEM.COMPOUND:5225086',
#  'PUBCHEM.COMPOUND:4516886',
#  'PUBCHEM.COMPOUND:941650']

# %%
answer = enrich('biolink:ChemicalSubstance',chemicals)

# %%
ac_to_table(answer,'n1')
# Out:
#       N_Answer_Nodes  N_Merged_Nodes               Method
# 0                  1             183  property_enrichment
# 1                  1             185  property_enrichment
# 2                  1             186  property_enrichment
# 3                  1             185  property_enrichment
# 4                  1             192  property_enrichment
# ...              ...             ...                  ...
# 1646               1               1             Original
# 1647               1               1             Original
# 1648               1               1             Original
# 1649               1               1             Original
# 1650               1               1             Original
#
# [1651 rows x 3 columns]

# %%
x = filter_to_gc(answer,'n1')
# Out:
# 534

# %%
for i,result in enumerate(x['message']['results']):
    print('Result',i)
    print_gc_result(x['message']['knowledge_graph'],result)
# Out:
# Result 0
# p_value: 5.812446102651206e-85
# Propofol -[biolink:causes_adverse_event]-> delirium
# Olmesartan -[biolink:causes_adverse_event]-> delirium
# (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate -[biolink:causes_adverse_event]-> delirium
# Spironolactone -[biolink:causes_adverse_event]-> delirium
# Quetiapine -[biolink:causes_adverse_event]-> delirium
# Axitinib -[biolink:causes_adverse_event]-> delirium
# Dexmedetomidine -[biolink:causes_adverse_event]-> delirium
# Prochlorperazine -[biolink:causes_adverse_event]-> delirium
# Zotepine -[biolink:causes_adverse_event]-> delirium
# (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate -[biolink:causes_adverse_event]-> delirium
# Cabergoline -[biolink:causes_adverse_event]-> delirium
# Ziprasidone -[biolink:causes_adverse_event]-> delirium
# Apomorphine -[biolink:causes_adverse_event]-> delirium
# Rotigotine -[biolink:causes_adverse_event]-> delirium
# Lamotrigine -[biolink:causes_adverse_event]-> delirium
# Dihydroergocristine -[biolink:causes_adverse_event]-> delirium
# Methamphetamine -[biolink:causes_adverse_event]-> delirium
# Paroxetine -[biolink:causes_adverse_event]-> delirium
# Lofepramine -[biolink:causes_adverse_event]-> delirium
# Tretinoin -[biolink:causes_adverse_event]-> delirium
# Prazosin -[biolink:causes_adverse_event]-> delirium
# Chlorpromazine -[biolink:causes_adverse_event]-> delirium
# Aripiprazole -[biolink:causes_adverse_event]-> delirium
# Dronabinol -[biolink:causes_adverse_event]-> delirium
# Ropinirole -[biolink:causes_adverse_event]-> delirium
# Nicergoline -[biolink:causes_adverse_event]-> delirium
# Escitalopram -[biolink:causes_adverse_event]-> delirium
# Pergolide -[biolink:causes_adverse_event]-> delirium
# Clarithromycin -[biolink:causes_adverse_event]-> delirium
# Oxcarbazepine -[biolink:causes_adverse_event]-> delirium
# Maprotiline -[biolink:causes_adverse_event]-> delirium
# Nicorandil -[biolink:causes_adverse_event]-> delirium
# Torsemide -[biolink:causes_adverse_event]-> delirium
# Haloperidol -[biolink:causes_adverse_event]-> delirium
# Amoxapine -[biolink:causes_adverse_event]-> delirium
# Clozapine -[biolink:causes_adverse_event]-> delirium
# Diclofenac -[biolink:causes_adverse_event]-> delirium
# Risperidone -[biolink:causes_adverse_event]-> delirium
# Olanzapine -[biolink:causes_adverse_event]-> delirium
# Betahistine -[biolink:causes_adverse_event]-> delirium
# Dosulepin -[biolink:causes_adverse_event]-> delirium
# Tiapride -[biolink:causes_adverse_event]-> delirium
# Ergotamine -[biolink:causes_adverse_event]-> delirium
# Rilmenidine -[biolink:causes_adverse_event]-> delirium
# Norepinephrine -[biolink:causes_adverse_event]-> delirium
# Pizotifen -[biolink:causes_adverse_event]-> delirium
# Nifedipine -[biolink:causes_adverse_event]-> delirium
# Bromocriptine -[biolink:causes_adverse_event]-> delirium
# Famotidine -[biolink:causes_adverse_event]-> delirium
# Nortriptyline -[biolink:causes_adverse_event]-> delirium
# Loxapine -[biolink:causes_adverse_event]-> delirium
# Adenosine-5'-triphosphate -[biolink:causes_adverse_event]-> delirium
# Flavoxate -[biolink:causes_adverse_event]-> delirium
# Phenobarbital -[biolink:causes_adverse_event]-> delirium
# Tizanidine -[biolink:causes_adverse_event]-> delirium
# Levomepromazine -[biolink:causes_adverse_event]-> delirium
# Irinotecan -[biolink:causes_adverse_event]-> delirium
# Amitriptyline -[biolink:causes_adverse_event]-> delirium
# Perphenazine -[biolink:causes_adverse_event]-> delirium
# Desipramine -[biolink:causes_adverse_event]-> delirium
# Result 1
# p_value: 5.907759894966317e-81
# Mesalamine -[biolink:contraindicated_for]-> liver disease
# Lamotrigine -[biolink:contraindicated_for]-> liver disease
# Methamphetamine -[biolink:contraindicated_for]-> liver disease
# Amitriptyline -[biolink:contraindicated_for]-> liver disease
# Saquinavir -[biolink:contraindicated_for]-> liver disease
# Flumazenil -[biolink:contraindicated_for]-> liver disease
# Nabumetone -[biolink:contraindicated_for]-> liver disease
# (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate -[biolink:contraindicated_for]-> liver disease
# 3-[(4,5-Dihydro-1H-imidazol-3-ium-2-ylmethyl)(4-methylphenyl)amino]phenolate -[biolink:contraindicated_for]-> liver disease
# Cabergoline -[biolink:contraindicated_for]-> liver disease
# Glyburide -[biolink:contraindicated_for]-> liver disease
# Nifedipine -[biolink:contraindicated_for]-> liver disease
# Tretinoin -[biolink:contraindicated_for]-> liver disease
# Maprotiline -[biolink:contraindicated_for]-> liver disease
# Yohimbine -[biolink:contraindicated_for]-> liver disease
# Tramadol -[biolink:contraindicated_for]-> liver disease
# Mycophenolic acid -[biolink:contraindicated_for]-> liver disease
# Famotidine -[biolink:contraindicated_for]-> liver disease
# Flurbiprofen -[biolink:contraindicated_for]-> liver disease
# Clozapine -[biolink:contraindicated_for]-> liver disease
# Bromocriptine -[biolink:contraindicated_for]-> liver disease
# Carbinoxamine -[biolink:contraindicated_for]-> liver disease
# Dasatinib -[biolink:contraindicated_for]-> liver disease
# Paroxetine -[biolink:contraindicated_for]-> liver disease
# Gemcitabine -[biolink:contraindicated_for]-> liver disease
# Apomorphine -[biolink:contraindicated_for]-> liver disease
# Bendroflumethiazide -[biolink:contraindicated_for]-> liver disease
# Perphenazine -[biolink:contraindicated_for]-> liver disease
# Chlorpromazine -[biolink:contraindicated_for]-> liver disease
# Methyldopa -[biolink:contraindicated_for]-> liver disease
# Dactinomycin -[biolink:contraindicated_for]-> liver disease
# Quetiapine -[biolink:contraindicated_for]-> liver disease
# Bicalutamide -[biolink:contraindicated_for]-> liver disease
# Amoxapine -[biolink:contraindicated_for]-> liver disease
# Escitalopram -[biolink:contraindicated_for]-> liver disease
# Methotrexate -[biolink:contraindicated_for]-> liver disease
# Guanfacine -[biolink:contraindicated_for]-> liver disease
# Fenofibrate -[biolink:contraindicated_for]-> liver disease
# Ethotoin -[biolink:contraindicated_for]-> liver disease
# Trimipramine -[biolink:contraindicated_for]-> liver disease
# l-Menthol -[biolink:contraindicated_for]-> liver disease
# Levomepromazine -[biolink:contraindicated_for]-> liver disease
# Olanzapine -[biolink:contraindicated_for]-> liver disease
# Ergotamine -[biolink:contraindicated_for]-> liver disease
# Zileuton -[biolink:contraindicated_for]-> liver disease
# Diclofenac -[biolink:contraindicated_for]-> liver disease
# Nevirapine -[biolink:contraindicated_for]-> liver disease
# Dexmedetomidine -[biolink:contraindicated_for]-> liver disease
# Irinotecan -[biolink:contraindicated_for]-> liver disease
# Lorazepam -[biolink:contraindicated_for]-> liver disease
# Haloperidol -[biolink:contraindicated_for]-> liver disease
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:contraindicated_for]-> liver disease
# Phenobarbital -[biolink:contraindicated_for]-> liver disease
# Clarithromycin -[biolink:contraindicated_for]-> liver disease
# Epirubicin -[biolink:contraindicated_for]-> liver disease
# Desipramine -[biolink:contraindicated_for]-> liver disease
# Zolmitriptan -[biolink:contraindicated_for]-> liver disease
# Amphetamine -[biolink:contraindicated_for]-> liver disease
# N-(2,6-Dichlorobenzylidene)-N'-amidinohydrazine -[biolink:contraindicated_for]-> liver disease
# Capecitabine -[biolink:contraindicated_for]-> liver disease
# Prochlorperazine -[biolink:contraindicated_for]-> liver disease
# Risperidone -[biolink:contraindicated_for]-> liver disease
# Mirtazapine -[biolink:contraindicated_for]-> liver disease
# Cinacalcet -[biolink:contraindicated_for]-> liver disease
# Papaverine -[biolink:contraindicated_for]-> liver disease
# Felodipine -[biolink:contraindicated_for]-> liver disease
# Result 2
# p_value: 3.782258112381337e-78
# CYP3A4 -[biolink:increases_degradation_of]-> Dronabinol
# CYP3A4 -[biolink:increases_degradation_of]-> Bromocriptine
# CYP3A4 -[biolink:increases_degradation_of]-> Trimebutine
# CYP3A4 -[biolink:increases_degradation_of]-> Tranilast
# CYP3A4 -[biolink:increases_degradation_of]-> Dihydroergocristine
# CYP3A4 -[biolink:increases_degradation_of]-> l-Menthol
# CYP3A4 -[biolink:increases_degradation_of]-> Dronedarone
# CYP3A4 -[biolink:increases_degradation_of]-> Methotrexate
# CYP3A4 -[biolink:increases_degradation_of]-> (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate
# CYP3A4 -[biolink:increases_degradation_of]-> Guanfacine
# CYP3A4 -[biolink:increases_degradation_of]-> Clotrimazole
# CYP3A4 -[biolink:increases_degradation_of]-> Nortriptyline
# CYP3A4 -[biolink:increases_degradation_of]-> Midostaurin
# CYP3A4 -[biolink:increases_degradation_of]-> Saquinavir
# CYP3A4 -[biolink:increases_degradation_of]-> Clonidine
# CYP3A4 -[biolink:increases_degradation_of]-> Etoposide
# CYP3A4 -[biolink:increases_degradation_of]-> Desipramine
# CYP3A4 -[biolink:increases_degradation_of]-> Mirtazapine
# CYP3A4 -[biolink:increases_degradation_of]-> Tinidazole
# CYP3A4 -[biolink:increases_degradation_of]-> Cabergoline
# CYP3A4 -[biolink:increases_degradation_of]-> Bicalutamide
# CYP3A4 -[biolink:increases_degradation_of]-> Yohimbine
# CYP3A4 -[biolink:increases_degradation_of]-> Selumetinib
# CYP3A4 -[biolink:increases_degradation_of]-> Glyburide
# CYP3A4 -[biolink:increases_degradation_of]-> Bosutinib
# CYP3A4 -[biolink:increases_degradation_of]-> Tramadol
# CYP3A4 -[biolink:increases_degradation_of]-> Tretinoin
# CYP3A4 -[biolink:increases_degradation_of]-> Irinotecan
# CYP3A4 -[biolink:increases_degradation_of]-> Zileuton
# CYP3A4 -[biolink:increases_degradation_of]-> Clarithromycin
# CYP3A4 -[biolink:increases_degradation_of]-> Lisuride
# CYP3A4 -[biolink:increases_degradation_of]-> Aranidipine
# CYP3A4 -[biolink:increases_degradation_of]-> Mianserin
# CYP3A4 -[biolink:increases_degradation_of]-> Diclofenac
# CYP3A4 -[biolink:increases_degradation_of]-> Ziprasidone
# CYP3A4 -[biolink:increases_degradation_of]-> Cannabidiol
# CYP3A4 -[biolink:increases_degradation_of]-> Risperidone
# CYP3A4 -[biolink:increases_degradation_of]-> Rotigotine
# CYP3A4 -[biolink:increases_degradation_of]-> Clozapine
# CYP3A4 -[biolink:increases_degradation_of]-> Olaparib
# CYP3A4 -[biolink:increases_degradation_of]-> Felodipine
# CYP3A4 -[biolink:increases_degradation_of]-> Aripiprazole lauroxil
# CYP3A4 -[biolink:increases_degradation_of]-> Perphenazine
# CYP3A4 -[biolink:increases_degradation_of]-> Quetiapine
# CYP3A4 -[biolink:increases_degradation_of]-> Dihydroergocornine
# CYP3A4 -[biolink:increases_degradation_of]-> Cinacalcet
# CYP3A4 -[biolink:increases_degradation_of]-> Paliperidone
# CYP3A4 -[biolink:increases_degradation_of]-> Zotepine
# CYP3A4 -[biolink:increases_degradation_of]-> Ergotamine
# CYP3A4 -[biolink:increases_degradation_of]-> Terguride
# CYP3A4 -[biolink:increases_degradation_of]-> Escitalopram
# CYP3A4 -[biolink:increases_degradation_of]-> Carvedilol
# CYP3A4 -[biolink:increases_degradation_of]-> 7-Ethyl-10-hydroxycamptothecin
# CYP3A4 -[biolink:increases_degradation_of]-> Dasatinib
# CYP3A4 -[biolink:increases_degradation_of]-> Artemether
# CYP3A4 -[biolink:increases_degradation_of]-> Haloperidol
# CYP3A4 -[biolink:increases_degradation_of]-> Aripiprazole
# CYP3A4 -[biolink:increases_degradation_of]-> Nevirapine
# CYP3A4 -[biolink:increases_degradation_of]-> Amitriptyline
# CYP3A4 -[biolink:increases_degradation_of]-> Axitinib
# CYP3A4 -[biolink:increases_degradation_of]-> Palbociclib
# CYP3A4 -[biolink:increases_degradation_of]-> Flunarizine
# CYP3A4 -[biolink:increases_degradation_of]-> Paroxetine
# CYP3A4 -[biolink:increases_degradation_of]-> Lorazepam
# CYP3A4 -[biolink:increases_degradation_of]-> Nifedipine
# Result 3
# p_value: 3.249827780933832e-76
# Ropinirole -[biolink:prevents]-> rosacea
# Prochlorperazine -[biolink:prevents]-> rosacea
# Cortisone -[biolink:prevents]-> rosacea
# Clonidine -[biolink:prevents]-> rosacea
# (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate -[biolink:prevents]-> rosacea
# Tretinoin -[biolink:prevents]-> rosacea
# Zolmitriptan -[biolink:prevents]-> rosacea
# Tizanidine -[biolink:prevents]-> rosacea
# Clotrimazole -[biolink:prevents]-> rosacea
# Risperidone -[biolink:prevents]-> rosacea
# Oxcarbazepine -[biolink:prevents]-> rosacea
# Cabergoline -[biolink:prevents]-> rosacea
# Bromocriptine -[biolink:prevents]-> rosacea
# Nevirapine -[biolink:prevents]-> rosacea
# Mycophenolic acid -[biolink:prevents]-> rosacea
# Capecitabine -[biolink:prevents]-> rosacea
# Latanoprost -[biolink:prevents]-> rosacea
# Guanfacine -[biolink:prevents]-> rosacea
# Epirubicin -[biolink:prevents]-> rosacea
# Etoposide -[biolink:prevents]-> rosacea
# Amitriptyline -[biolink:prevents]-> rosacea
# Aripiprazole -[biolink:prevents]-> rosacea
# Torsemide -[biolink:prevents]-> rosacea
# Nifedipine -[biolink:prevents]-> rosacea
# Clarithromycin -[biolink:prevents]-> rosacea
# Oxymetazoline -[biolink:prevents]-> rosacea
# Nicorandil -[biolink:prevents]-> rosacea
# Haloperidol -[biolink:prevents]-> rosacea
# Clozapine -[biolink:prevents]-> rosacea
# Lamotrigine -[biolink:prevents]-> rosacea
# Milrinone -[biolink:prevents]-> rosacea
# Quetiapine -[biolink:prevents]-> rosacea
# Mesalamine -[biolink:prevents]-> rosacea
# Spironolactone -[biolink:prevents]-> rosacea
# Dronedarone -[biolink:prevents]-> rosacea
# Axitinib -[biolink:prevents]-> rosacea
# Glyburide -[biolink:prevents]-> rosacea
# Famotidine -[biolink:prevents]-> rosacea
# Norepinephrine -[biolink:prevents]-> rosacea
# Methotrexate -[biolink:prevents]-> rosacea
# Chlorpromazine -[biolink:prevents]-> rosacea
# Diclofenac -[biolink:prevents]-> rosacea
# Ziprasidone -[biolink:prevents]-> rosacea
# Nortriptyline -[biolink:prevents]-> rosacea
# Escitalopram -[biolink:prevents]-> rosacea
# Dronabinol -[biolink:prevents]-> rosacea
# Cinacalcet -[biolink:prevents]-> rosacea
# Propofol -[biolink:prevents]-> rosacea
# Irinotecan -[biolink:prevents]-> rosacea
# Gemcitabine -[biolink:prevents]-> rosacea
# Paroxetine -[biolink:prevents]-> rosacea
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:prevents]-> rosacea
# Phenobarbital -[biolink:prevents]-> rosacea
# Olanzapine -[biolink:prevents]-> rosacea
# Result 4
# p_value: 4.654305359958528e-76
# Methotrexate -[biolink:prevents]-> acute diarrhea
# Guanfacine -[biolink:prevents]-> acute diarrhea
# Nifedipine -[biolink:prevents]-> acute diarrhea
# Methamphetamine -[biolink:prevents]-> acute diarrhea
# Acitretin -[biolink:prevents]-> acute diarrhea
# Norepinephrine -[biolink:prevents]-> acute diarrhea
# Zolmitriptan -[biolink:prevents]-> acute diarrhea
# Ziprasidone -[biolink:prevents]-> acute diarrhea
# Perphenazine -[biolink:prevents]-> acute diarrhea
# Prazosin -[biolink:prevents]-> acute diarrhea
# Dactinomycin -[biolink:prevents]-> acute diarrhea
# Tizanidine -[biolink:prevents]-> acute diarrhea
# Nicorandil -[biolink:prevents]-> acute diarrhea
# Etomidate -[biolink:prevents]-> acute diarrhea
# Nortriptyline -[biolink:prevents]-> acute diarrhea
# Milrinone -[biolink:prevents]-> acute diarrhea
# Quetiapine -[biolink:prevents]-> acute diarrhea
# Cabergoline -[biolink:prevents]-> acute diarrhea
# Oxymetazoline -[biolink:prevents]-> acute diarrhea
# Oxaprozin -[biolink:prevents]-> acute diarrhea
# Aripiprazole -[biolink:prevents]-> acute diarrhea
# Ropinirole -[biolink:prevents]-> acute diarrhea
# Levomepromazine -[biolink:prevents]-> acute diarrhea
# Haloperidol -[biolink:prevents]-> acute diarrhea
# Brimonidine -[biolink:prevents]-> acute diarrhea
# Apomorphine -[biolink:prevents]-> acute diarrhea
# Clonidine -[biolink:prevents]-> acute diarrhea
# Paroxetine -[biolink:prevents]-> acute diarrhea
# Nabumetone -[biolink:prevents]-> acute diarrhea
# (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate -[biolink:prevents]-> acute diarrhea
# Pergolide -[biolink:prevents]-> acute diarrhea
# Propofol -[biolink:prevents]-> acute diarrhea
# Clozapine -[biolink:prevents]-> acute diarrhea
# Torsemide -[biolink:prevents]-> acute diarrhea
# Papaverine -[biolink:prevents]-> acute diarrhea
# Diphenhydramine -[biolink:prevents]-> acute diarrhea
# Chlorpromazine -[biolink:prevents]-> acute diarrhea
# Olanzapine -[biolink:prevents]-> acute diarrhea
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:prevents]-> acute diarrhea
# Amitriptyline -[biolink:prevents]-> acute diarrhea
# Risperidone -[biolink:prevents]-> acute diarrhea
# Oxcarbazepine -[biolink:prevents]-> acute diarrhea
# Latanoprost -[biolink:prevents]-> acute diarrhea
# Lamotrigine -[biolink:prevents]-> acute diarrhea
# Bromocriptine -[biolink:prevents]-> acute diarrhea
# Loxapine -[biolink:prevents]-> acute diarrhea
# Phenobarbital -[biolink:prevents]-> acute diarrhea
# Maprotiline -[biolink:prevents]-> acute diarrhea
# Tretinoin -[biolink:prevents]-> acute diarrhea
# Rotigotine -[biolink:prevents]-> acute diarrhea
# Diclofenac -[biolink:prevents]-> acute diarrhea
# Cortisone -[biolink:prevents]-> acute diarrhea
# Result 5
# p_value: 1.292942664238473e-71
# Desipramine -[biolink:prevents]-> subendocardial myocardial infarction
# Clotrimazole -[biolink:prevents]-> subendocardial myocardial infarction
# Clarithromycin -[biolink:prevents]-> subendocardial myocardial infarction
# Gemcitabine -[biolink:prevents]-> subendocardial myocardial infarction
# Phenobarbital -[biolink:prevents]-> subendocardial myocardial infarction
# Zolmitriptan -[biolink:prevents]-> subendocardial myocardial infarction
# Etoposide -[biolink:prevents]-> subendocardial myocardial infarction
# Cortisone -[biolink:prevents]-> subendocardial myocardial infarction
# Dronedarone -[biolink:prevents]-> subendocardial myocardial infarction
# Ziprasidone -[biolink:prevents]-> subendocardial myocardial infarction
# Axitinib -[biolink:prevents]-> subendocardial myocardial infarction
# Dronabinol -[biolink:prevents]-> subendocardial myocardial infarction
# Latanoprost -[biolink:prevents]-> subendocardial myocardial infarction
# Methamphetamine -[biolink:prevents]-> subendocardial myocardial infarction
# Capecitabine -[biolink:prevents]-> subendocardial myocardial infarction
# Irinotecan -[biolink:prevents]-> subendocardial myocardial infarction
# Olanzapine -[biolink:prevents]-> subendocardial myocardial infarction
# (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate -[biolink:prevents]-> subendocardial myocardial infarction
# Mycophenolic acid -[biolink:prevents]-> subendocardial myocardial infarction
# Moxonidine -[biolink:prevents]-> subendocardial myocardial infarction
# Mesalamine -[biolink:prevents]-> subendocardial myocardial infarction
# Oxymetazoline -[biolink:prevents]-> subendocardial myocardial infarction
# Rilmenidine -[biolink:prevents]-> subendocardial myocardial infarction
# Methotrexate -[biolink:prevents]-> subendocardial myocardial infarction
# Prochlorperazine -[biolink:prevents]-> subendocardial myocardial infarction
# Chlorpromazine -[biolink:prevents]-> subendocardial myocardial infarction
# Pergolide -[biolink:prevents]-> subendocardial myocardial infarction
# Bromocriptine -[biolink:prevents]-> subendocardial myocardial infarction
# Diphenhydramine -[biolink:prevents]-> subendocardial myocardial infarction
# Guanfacine -[biolink:prevents]-> subendocardial myocardial infarction
# Escitalopram -[biolink:prevents]-> subendocardial myocardial infarction
# Famotidine -[biolink:prevents]-> subendocardial myocardial infarction
# Nortriptyline -[biolink:prevents]-> subendocardial myocardial infarction
# Paroxetine -[biolink:prevents]-> subendocardial myocardial infarction
# Nevirapine -[biolink:prevents]-> subendocardial myocardial infarction
# Quetiapine -[biolink:prevents]-> subendocardial myocardial infarction
# Ropinirole -[biolink:prevents]-> subendocardial myocardial infarction
# Brimonidine -[biolink:prevents]-> subendocardial myocardial infarction
# Diclofenac -[biolink:prevents]-> subendocardial myocardial infarction
# Risperidone -[biolink:prevents]-> subendocardial myocardial infarction
# Aripiprazole -[biolink:prevents]-> subendocardial myocardial infarction
# Olmesartan -[biolink:prevents]-> subendocardial myocardial infarction
# Oxcarbazepine -[biolink:prevents]-> subendocardial myocardial infarction
# Cabergoline -[biolink:prevents]-> subendocardial myocardial infarction
# Epirubicin -[biolink:prevents]-> subendocardial myocardial infarction
# Spironolactone -[biolink:prevents]-> subendocardial myocardial infarction
# Tretinoin -[biolink:prevents]-> subendocardial myocardial infarction
# Propofol -[biolink:prevents]-> subendocardial myocardial infarction
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:prevents]-> subendocardial myocardial infarction
# Lamotrigine -[biolink:prevents]-> subendocardial myocardial infarction
# Tizanidine -[biolink:prevents]-> subendocardial myocardial infarction
# Amitriptyline -[biolink:prevents]-> subendocardial myocardial infarction
# Haloperidol -[biolink:prevents]-> subendocardial myocardial infarction
# Result 6
# p_value: 1.0348269291644976e-68
# Epirubicin -[biolink:prevents]-> disorder involving pain
# Bromocriptine -[biolink:prevents]-> disorder involving pain
# Rilmenidine -[biolink:prevents]-> disorder involving pain
# Dactinomycin -[biolink:prevents]-> disorder involving pain
# Guanfacine -[biolink:prevents]-> disorder involving pain
# Capecitabine -[biolink:prevents]-> disorder involving pain
# Gemcitabine -[biolink:prevents]-> disorder involving pain
# Aripiprazole -[biolink:prevents]-> disorder involving pain
# Torsemide -[biolink:prevents]-> disorder involving pain
# Clarithromycin -[biolink:prevents]-> disorder involving pain
# Methamphetamine -[biolink:prevents]-> disorder involving pain
# Famotidine -[biolink:prevents]-> disorder involving pain
# Latanoprost -[biolink:prevents]-> disorder involving pain
# Oxcarbazepine -[biolink:prevents]-> disorder involving pain
# Quetiapine -[biolink:prevents]-> disorder involving pain
# Betahistine -[biolink:prevents]-> disorder involving pain
# Ziprasidone -[biolink:prevents]-> disorder involving pain
# Prochlorperazine -[biolink:prevents]-> disorder involving pain
# Mycophenolic acid -[biolink:prevents]-> disorder involving pain
# Chlorpromazine -[biolink:prevents]-> disorder involving pain
# Perphenazine -[biolink:prevents]-> disorder involving pain
# Dosulepin -[biolink:prevents]-> disorder involving pain
# Phenobarbital -[biolink:prevents]-> disorder involving pain
# Loxapine -[biolink:prevents]-> disorder involving pain
# Pyridostigmine -[biolink:prevents]-> disorder involving pain
# Clozapine -[biolink:prevents]-> disorder involving pain
# Brimonidine -[biolink:prevents]-> disorder involving pain
# Spironolactone -[biolink:prevents]-> disorder involving pain
# Cabergoline -[biolink:prevents]-> disorder involving pain
# Etoposide -[biolink:prevents]-> disorder involving pain
# Risperidone -[biolink:prevents]-> disorder involving pain
# Prazosin -[biolink:prevents]-> disorder involving pain
# Nevirapine -[biolink:prevents]-> disorder involving pain
# Olmesartan -[biolink:prevents]-> disorder involving pain
# Olanzapine -[biolink:prevents]-> disorder involving pain
# Miglitol -[biolink:prevents]-> disorder involving pain
# Nicorandil -[biolink:prevents]-> disorder involving pain
# Moxonidine -[biolink:prevents]-> disorder involving pain
# Haloperidol -[biolink:prevents]-> disorder involving pain
# Irinotecan -[biolink:prevents]-> disorder involving pain
# Paroxetine -[biolink:prevents]-> disorder involving pain
# Amoxapine -[biolink:prevents]-> disorder involving pain
# Saquinavir -[biolink:prevents]-> disorder involving pain
# Maprotiline -[biolink:prevents]-> disorder involving pain
# Lamotrigine -[biolink:prevents]-> disorder involving pain
# Rotigotine -[biolink:prevents]-> disorder involving pain
# Acitretin -[biolink:prevents]-> disorder involving pain
# Dronedarone -[biolink:prevents]-> disorder involving pain
# Nifedipine -[biolink:prevents]-> disorder involving pain
# Pergolide -[biolink:prevents]-> disorder involving pain
# Glyburide -[biolink:prevents]-> disorder involving pain
# Result 7
# p_value: 9.691125553618667e-63
# Levomepromazine -[biolink:interacts_with]-> ADRA2A
# Amoxapine -[biolink:interacts_with]-> ADRA2A
# Bethanidine -[biolink:interacts_with]-> ADRA2A
# Aripiprazole -[biolink:interacts_with]-> ADRA2A
# Oxymetazoline -[biolink:interacts_with]-> ADRA2A
# Apomorphine -[biolink:interacts_with]-> ADRA2A
# Guanfacine -[biolink:interacts_with]-> ADRA2A
# Xylometazoline -[biolink:interacts_with]-> ADRA2A
# Mirtazapine -[biolink:interacts_with]-> ADRA2A
# Paliperidone -[biolink:interacts_with]-> ADRA2A
# Yohimbine -[biolink:interacts_with]-> ADRA2A
# Bromocriptine -[biolink:interacts_with]-> ADRA2A
# 3-[(4,5-Dihydro-1H-imidazol-3-ium-2-ylmethyl)(4-methylphenyl)amino]phenolate -[biolink:interacts_with]-> ADRA2A
# Tolazoline -[biolink:interacts_with]-> ADRA2A
# Norepinephrine -[biolink:interacts_with]-> ADRA2A
# Lofexidine -[biolink:interacts_with]-> ADRA2A
# Methamphetamine -[biolink:interacts_with]-> ADRA2A
# Lisuride -[biolink:interacts_with]-> ADRA2A
# Tizanidine -[biolink:interacts_with]-> ADRA2A
# Fenoldopam -[biolink:interacts_with]-> ADRA2A
# Ergotamine -[biolink:interacts_with]-> ADRA2A
# Brimonidine -[biolink:interacts_with]-> ADRA2A
# Dexmedetomidine -[biolink:interacts_with]-> ADRA2A
# Apraclonidine -[biolink:interacts_with]-> ADRA2A
# Ziprasidone -[biolink:interacts_with]-> ADRA2A
# Cabergoline -[biolink:interacts_with]-> ADRA2A
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:interacts_with]-> ADRA2A
# Mianserin -[biolink:interacts_with]-> ADRA2A
# Phenoxybenzamine -[biolink:interacts_with]-> ADRA2A
# Ropinirole -[biolink:interacts_with]-> ADRA2A
# Pergolide -[biolink:interacts_with]-> ADRA2A
# Result 8
# p_value: 4.533980477088319e-62
# Risperidone -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Loxapine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Perphenazine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Propofol -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Tiapride -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Lamotrigine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Clarithromycin -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Paroxetine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Haloperidol -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Ziprasidone -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Desipramine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Clozapine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Quetiapine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Nifedipine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Oxcarbazepine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Cabergoline -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Dosulepin -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Olanzapine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Spironolactone -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Levomepromazine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Phenobarbital -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Chlorpromazine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Dexmedetomidine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Guanfacine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Etoposide -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Nicergoline -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Apomorphine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Amitriptyline -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Bromocriptine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Clonidine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Pergolide -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Rotigotine -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Nortriptyline -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Escitalopram -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Aripiprazole -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Dronabinol -[biolink:causes_adverse_event]-> lingual-facial-buccal dyskinesia
# Result 9
# p_value: 1.8123194437271728e-61
# Amoxapine -[biolink:prevents]-> Chronic fatigue
# Bromocriptine -[biolink:prevents]-> Chronic fatigue
# Dronabinol -[biolink:prevents]-> Chronic fatigue
# Loxapine -[biolink:prevents]-> Chronic fatigue
# Cinacalcet -[biolink:prevents]-> Chronic fatigue
# Etoposide -[biolink:prevents]-> Chronic fatigue
# Zotepine -[biolink:prevents]-> Chronic fatigue
# Flavoxate -[biolink:prevents]-> Chronic fatigue
# Nicorandil -[biolink:prevents]-> Chronic fatigue
# Milrinone -[biolink:prevents]-> Chronic fatigue
# Rilmenidine -[biolink:prevents]-> Chronic fatigue
# Acitretin -[biolink:prevents]-> Chronic fatigue
# Pergolide -[biolink:prevents]-> Chronic fatigue
# Tiapride -[biolink:prevents]-> Chronic fatigue
# Prazosin -[biolink:prevents]-> Chronic fatigue
# Gemcitabine -[biolink:prevents]-> Chronic fatigue
# (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate -[biolink:prevents]-> Chronic fatigue
# Betahistine -[biolink:prevents]-> Chronic fatigue
# Chlorpromazine -[biolink:prevents]-> Chronic fatigue
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:prevents]-> Chronic fatigue
# Brimonidine -[biolink:prevents]-> Chronic fatigue
# Miglitol -[biolink:prevents]-> Chronic fatigue
# Flumazenil -[biolink:prevents]-> Chronic fatigue
# Lamotrigine -[biolink:prevents]-> Chronic fatigue
# Papaverine -[biolink:prevents]-> Chronic fatigue
# Nicergoline -[biolink:prevents]-> Chronic fatigue
# Methamphetamine -[biolink:prevents]-> Chronic fatigue
# Saquinavir -[biolink:prevents]-> Chronic fatigue
# Spironolactone -[biolink:prevents]-> Chronic fatigue
# Maprotiline -[biolink:prevents]-> Chronic fatigue
# Tretinoin -[biolink:prevents]-> Chronic fatigue
# Torsemide -[biolink:prevents]-> Chronic fatigue
# Glyburide -[biolink:prevents]-> Chronic fatigue
# Proparacaine -[biolink:prevents]-> Chronic fatigue
# Norepinephrine -[biolink:prevents]-> Chronic fatigue
# Moxonidine -[biolink:prevents]-> Chronic fatigue
# Nabumetone -[biolink:prevents]-> Chronic fatigue
# Oxymetazoline -[biolink:prevents]-> Chronic fatigue
# Nevirapine -[biolink:prevents]-> Chronic fatigue
# Ziprasidone -[biolink:prevents]-> Chronic fatigue
# Etomidate -[biolink:prevents]-> Chronic fatigue
# Propofol -[biolink:prevents]-> Chronic fatigue
# (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate -[biolink:prevents]-> Chronic fatigue
# Phenobarbital -[biolink:prevents]-> Chronic fatigue
# Guanfacine -[biolink:prevents]-> Chronic fatigue
# Levomepromazine -[biolink:prevents]-> Chronic fatigue
# Result 10
# p_value: 4.8898197598656345e-61
# Phenobarbital -[biolink:causes_adverse_event]-> respiratory failure
# Dexmedetomidine -[biolink:causes_adverse_event]-> respiratory failure
# Gemcitabine -[biolink:causes_adverse_event]-> respiratory failure
# (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate -[biolink:causes_adverse_event]-> respiratory failure
# Amitriptyline -[biolink:causes_adverse_event]-> respiratory failure
# Zotepine -[biolink:causes_adverse_event]-> respiratory failure
# Tretinoin -[biolink:causes_adverse_event]-> respiratory failure
# Milrinone -[biolink:causes_adverse_event]-> respiratory failure
# Norepinephrine -[biolink:causes_adverse_event]-> respiratory failure
# Nabumetone -[biolink:causes_adverse_event]-> respiratory failure
# Irinotecan -[biolink:causes_adverse_event]-> respiratory failure
# Dactinomycin -[biolink:causes_adverse_event]-> respiratory failure
# Haloperidol -[biolink:causes_adverse_event]-> respiratory failure
# Etoposide -[biolink:causes_adverse_event]-> respiratory failure
# Nifedipine -[biolink:causes_adverse_event]-> respiratory failure
# Torsemide -[biolink:causes_adverse_event]-> respiratory failure
# Nevirapine -[biolink:causes_adverse_event]-> respiratory failure
# Mycophenolic acid -[biolink:causes_adverse_event]-> respiratory failure
# Etomidate -[biolink:causes_adverse_event]-> respiratory failure
# Risperidone -[biolink:causes_adverse_event]-> respiratory failure
# Levomepromazine -[biolink:causes_adverse_event]-> respiratory failure
# Flumazenil -[biolink:causes_adverse_event]-> respiratory failure
# Famotidine -[biolink:causes_adverse_event]-> respiratory failure
# Propofol -[biolink:causes_adverse_event]-> respiratory failure
# Clarithromycin -[biolink:causes_adverse_event]-> respiratory failure
# Tizanidine -[biolink:causes_adverse_event]-> respiratory failure
# Clozapine -[biolink:causes_adverse_event]-> respiratory failure
# Prochlorperazine -[biolink:causes_adverse_event]-> respiratory failure
# Quetiapine -[biolink:causes_adverse_event]-> respiratory failure
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:causes_adverse_event]-> respiratory failure
# Clonidine -[biolink:causes_adverse_event]-> respiratory failure
# Clotrimazole -[biolink:causes_adverse_event]-> respiratory failure
# Methotrexate -[biolink:causes_adverse_event]-> respiratory failure
# Spironolactone -[biolink:causes_adverse_event]-> respiratory failure
# Loxapine -[biolink:causes_adverse_event]-> respiratory failure
# Paroxetine -[biolink:causes_adverse_event]-> respiratory failure
# Methamphetamine -[biolink:causes_adverse_event]-> respiratory failure
# Dronabinol -[biolink:causes_adverse_event]-> respiratory failure
# Chlorpromazine -[biolink:causes_adverse_event]-> respiratory failure
# Nortriptyline -[biolink:causes_adverse_event]-> respiratory failure
# Nicorandil -[biolink:causes_adverse_event]-> respiratory failure
# Diclofenac -[biolink:causes_adverse_event]-> respiratory failure
# Pyridostigmine -[biolink:causes_adverse_event]-> respiratory failure
# Olanzapine -[biolink:causes_adverse_event]-> respiratory failure
# Result 11
# p_value: 8.498462628718462e-61
# 3-[(4,5-Dihydro-1H-imidazol-3-ium-2-ylmethyl)(4-methylphenyl)amino]phenolate -[biolink:decreases_activity_of]-> ADRA2B
# Lofexidine -[biolink:decreases_activity_of]-> ADRA2B
# Mianserin -[biolink:decreases_activity_of]-> ADRA2B
# Nortriptyline -[biolink:decreases_activity_of]-> ADRA2B
# Fipamezole -[biolink:decreases_activity_of]-> ADRA2B
# Levomepromazine -[biolink:decreases_activity_of]-> ADRA2B
# Rilmenidine -[biolink:decreases_activity_of]-> ADRA2B
# Mirtazapine -[biolink:decreases_activity_of]-> ADRA2B
# Paliperidone -[biolink:decreases_activity_of]-> ADRA2B
# Ziprasidone -[biolink:decreases_activity_of]-> ADRA2B
# Aripiprazole -[biolink:decreases_activity_of]-> ADRA2B
# Carvedilol -[biolink:decreases_activity_of]-> ADRA2B
# Pizotifen -[biolink:decreases_activity_of]-> ADRA2B
# (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane -[biolink:decreases_activity_of]-> ADRA2B
# Ergotamine -[biolink:decreases_activity_of]-> ADRA2B
# Cabergoline -[biolink:decreases_activity_of]-> ADRA2B
# N-(2,6-Dichlorobenzylidene)-N'-amidinohydrazine -[biolink:decreases_activity_of]-> ADRA2B
# Risperidone -[biolink:decreases_activity_of]-> ADRA2B
# Phenoxybenzamine -[biolink:decreases_activity_of]-> ADRA2B
# 2-Methoxyidazoxan -[biolink:decreases_activity_of]-> ADRA2B
# Zotepine -[biolink:decreases_activity_of]-> ADRA2B
# Dronedarone -[biolink:decreases_activity_of]-> ADRA2B
# Celiprolol -[biolink:decreases_activity_of]-> ADRA2B
# Lisuride -[biolink:decreases_activity_of]-> ADRA2B
# Quetiapine -[biolink:decreases_activity_of]-> ADRA2B
# Rauwolscine -[biolink:decreases_activity_of]-> ADRA2B
# Chlorpromazine -[biolink:decreases_activity_of]-> ADRA2B
# Prochlorperazine -[biolink:decreases_activity_of]-> ADRA2B
# Amitriptyline -[biolink:decreases_activity_of]-> ADRA2B
# Tolazoline -[biolink:decreases_activity_of]-> ADRA2B
# Prazosin -[biolink:decreases_activity_of]-> ADRA2B
# Bromocriptine -[biolink:decreases_activity_of]-> ADRA2B
# Pergolide -[biolink:decreases_activity_of]-> ADRA2B
# Yohimbine -[biolink:decreases_activity_of]-> ADRA2B
# Rotigotine -[biolink:decreases_activity_of]-> ADRA2B
# Clozapine -[biolink:decreases_activity_of]-> ADRA2B
# Fenoldopam -[biolink:decreases_activity_of]-> ADRA2B
# Olanzapine -[biolink:decreases_activity_of]-> ADRA2B
# Result 12
# p_value: 2.0532400523870095e-60
# Clonidine -[biolink:prevents]-> exanthem (disease)
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:prevents]-> exanthem (disease)
# Latanoprost -[biolink:prevents]-> exanthem (disease)
# Spironolactone -[biolink:prevents]-> exanthem (disease)
# Dosulepin -[biolink:prevents]-> exanthem (disease)
# Nifedipine -[biolink:prevents]-> exanthem (disease)
# Prazosin -[biolink:prevents]-> exanthem (disease)
# Oxymetazoline -[biolink:prevents]-> exanthem (disease)
# Glyburide -[biolink:prevents]-> exanthem (disease)
# Norepinephrine -[biolink:prevents]-> exanthem (disease)
# (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate -[biolink:prevents]-> exanthem (disease)
# Nicorandil -[biolink:prevents]-> exanthem (disease)
# Desipramine -[biolink:prevents]-> exanthem (disease)
# Epirubicin -[biolink:prevents]-> exanthem (disease)
# Escitalopram -[biolink:prevents]-> exanthem (disease)
# Bromocriptine -[biolink:prevents]-> exanthem (disease)
# Propofol -[biolink:prevents]-> exanthem (disease)
# Quetiapine -[biolink:prevents]-> exanthem (disease)
# Etoposide -[biolink:prevents]-> exanthem (disease)
# Mycophenolic acid -[biolink:prevents]-> exanthem (disease)
# Risperidone -[biolink:prevents]-> exanthem (disease)
# Dronabinol -[biolink:prevents]-> exanthem (disease)
# Chlorpromazine -[biolink:prevents]-> exanthem (disease)
# Amitriptyline -[biolink:prevents]-> exanthem (disease)
# Saquinavir -[biolink:prevents]-> exanthem (disease)
# Methamphetamine -[biolink:prevents]-> exanthem (disease)
# Olanzapine -[biolink:prevents]-> exanthem (disease)
# Ropinirole -[biolink:prevents]-> exanthem (disease)
# Etomidate -[biolink:prevents]-> exanthem (disease)
# Loxapine -[biolink:prevents]-> exanthem (disease)
# Haloperidol -[biolink:prevents]-> exanthem (disease)
# Dactinomycin -[biolink:prevents]-> exanthem (disease)
# Ziprasidone -[biolink:prevents]-> exanthem (disease)
# Paroxetine -[biolink:prevents]-> exanthem (disease)
# Torsemide -[biolink:prevents]-> exanthem (disease)
# Nortriptyline -[biolink:prevents]-> exanthem (disease)
# Perphenazine -[biolink:prevents]-> exanthem (disease)
# Cabergoline -[biolink:prevents]-> exanthem (disease)
# Tizanidine -[biolink:prevents]-> exanthem (disease)
# Rilmenidine -[biolink:prevents]-> exanthem (disease)
# Clozapine -[biolink:prevents]-> exanthem (disease)
# Result 13
# p_value: 5.816437894349901e-60
# CYP2D6 -[biolink:increases_degradation_of]-> Haloperidol
# CYP2D6 -[biolink:increases_degradation_of]-> Celiprolol
# CYP2D6 -[biolink:increases_degradation_of]-> Risperidone
# CYP2D6 -[biolink:increases_degradation_of]-> Paliperidone
# CYP2D6 -[biolink:increases_degradation_of]-> Nicergoline
# CYP2D6 -[biolink:increases_degradation_of]-> Rotigotine
# CYP2D6 -[biolink:increases_degradation_of]-> Methamphetamine
# CYP2D6 -[biolink:increases_degradation_of]-> Flunarizine
# CYP2D6 -[biolink:increases_degradation_of]-> Desipramine
# CYP2D6 -[biolink:increases_degradation_of]-> Trimipramine
# CYP2D6 -[biolink:increases_degradation_of]-> Debrisoquine
# CYP2D6 -[biolink:increases_degradation_of]-> Quetiapine
# CYP2D6 -[biolink:increases_degradation_of]-> Dosulepin
# CYP2D6 -[biolink:increases_degradation_of]-> Paroxetine
# CYP2D6 -[biolink:increases_degradation_of]-> Prochlorperazine
# CYP2D6 -[biolink:increases_degradation_of]-> Mirtazapine
# CYP2D6 -[biolink:increases_degradation_of]-> Carteolol
# CYP2D6 -[biolink:increases_degradation_of]-> Olanzapine
# CYP2D6 -[biolink:increases_degradation_of]-> Chlorpromazine
# CYP2D6 -[biolink:increases_degradation_of]-> Diphenhydramine
# CYP2D6 -[biolink:increases_degradation_of]-> Aripiprazole
# CYP2D6 -[biolink:increases_degradation_of]-> Levomepromazine
# CYP2D6 -[biolink:increases_degradation_of]-> Tramadol
# CYP2D6 -[biolink:increases_degradation_of]-> Clonidine
# CYP2D6 -[biolink:increases_degradation_of]-> Nortriptyline
# CYP2D6 -[biolink:increases_degradation_of]-> Lofexidine
# CYP2D6 -[biolink:increases_degradation_of]-> Amitriptyline
# CYP2D6 -[biolink:increases_degradation_of]-> Nevirapine
# CYP2D6 -[biolink:increases_degradation_of]-> Escitalopram
# CYP2D6 -[biolink:increases_degradation_of]-> Aripiprazole lauroxil
# CYP2D6 -[biolink:increases_degradation_of]-> Amoxapine
# CYP2D6 -[biolink:increases_degradation_of]-> Amphetamine
# CYP2D6 -[biolink:increases_degradation_of]-> Mianserin
# CYP2D6 -[biolink:increases_degradation_of]-> Carvedilol
# CYP2D6 -[biolink:increases_degradation_of]-> Cannabidiol
# CYP2D6 -[biolink:increases_degradation_of]-> Clozapine
# CYP2D6 -[biolink:increases_degradation_of]-> Dronedarone
# CYP2D6 -[biolink:increases_degradation_of]-> Perphenazine
# CYP2D6 -[biolink:increases_degradation_of]-> Yohimbine
# CYP2D6 -[biolink:increases_degradation_of]-> Sotalol
# CYP2D6 -[biolink:increases_degradation_of]-> Maprotiline
# Result 14
# p_value: 2.3163501671279216e-59
# Saquinavir -[biolink:prevents]-> headache disorder
# Capecitabine -[biolink:prevents]-> headache disorder
# Nicorandil -[biolink:prevents]-> headache disorder
# Irinotecan -[biolink:prevents]-> headache disorder
# Quetiapine -[biolink:prevents]-> headache disorder
# Chlorpromazine -[biolink:prevents]-> headache disorder
# Etoposide -[biolink:prevents]-> headache disorder
# Norepinephrine -[biolink:prevents]-> headache disorder
# Pergolide -[biolink:prevents]-> headache disorder
# Famotidine -[biolink:prevents]-> headache disorder
# Olanzapine -[biolink:prevents]-> headache disorder
# Spironolactone -[biolink:prevents]-> headache disorder
# Dronedarone -[biolink:prevents]-> headache disorder
# Loxapine -[biolink:prevents]-> headache disorder
# Nevirapine -[biolink:prevents]-> headache disorder
# Prochlorperazine -[biolink:prevents]-> headache disorder
# Nifedipine -[biolink:prevents]-> headache disorder
# Rilmenidine -[biolink:prevents]-> headache disorder
# Perphenazine -[biolink:prevents]-> headache disorder
# Torsemide -[biolink:prevents]-> headache disorder
# Diclofenac -[biolink:prevents]-> headache disorder
# Haloperidol -[biolink:prevents]-> headache disorder
# Moxonidine -[biolink:prevents]-> headache disorder
# Dactinomycin -[biolink:prevents]-> headache disorder
# Mycophenolic acid -[biolink:prevents]-> headache disorder
# Nicergoline -[biolink:prevents]-> headache disorder
# Clozapine -[biolink:prevents]-> headache disorder
# Milrinone -[biolink:prevents]-> headache disorder
# Clarithromycin -[biolink:prevents]-> headache disorder
# Glyburide -[biolink:prevents]-> headache disorder
# Propofol -[biolink:prevents]-> headache disorder
# Risperidone -[biolink:prevents]-> headache disorder
# Papaverine -[biolink:prevents]-> headache disorder
# Rotigotine -[biolink:prevents]-> headache disorder
# Miglitol -[biolink:prevents]-> headache disorder
# Ziprasidone -[biolink:prevents]-> headache disorder
# Gemcitabine -[biolink:prevents]-> headache disorder
# Flavoxate -[biolink:prevents]-> headache disorder
# Phenobarbital -[biolink:prevents]-> headache disorder
# Dronabinol -[biolink:prevents]-> headache disorder
# Aripiprazole -[biolink:prevents]-> headache disorder
# Clotrimazole -[biolink:prevents]-> headache disorder
# Cinacalcet -[biolink:prevents]-> headache disorder
# Epirubicin -[biolink:prevents]-> headache disorder
# Result 15
# p_value: 1.1962355551498704e-58
# Felodipine -[biolink:interacts_with]-> CYP3A4
# Cinacalcet -[biolink:interacts_with]-> CYP3A4
# Tinidazole -[biolink:interacts_with]-> CYP3A4
# Pergolide -[biolink:interacts_with]-> CYP3A4
# Mirtazapine -[biolink:interacts_with]-> CYP3A4
# Etoposide -[biolink:interacts_with]-> CYP3A4
# Irinotecan -[biolink:interacts_with]-> CYP3A4
# Pyridostigmine -[biolink:interacts_with]-> CYP3A4
# Escitalopram -[biolink:interacts_with]-> CYP3A4
# Fenofibrate -[biolink:interacts_with]-> CYP3A4
# Linoleic acid -[biolink:interacts_with]-> CYP3A4
# Chlorpromazine -[biolink:interacts_with]-> CYP3A4
# Artemether -[biolink:interacts_with]-> CYP3A4
# Paliperidone -[biolink:interacts_with]-> CYP3A4
# Eucalyptol -[biolink:interacts_with]-> CYP3A4
# Aripiprazole -[biolink:interacts_with]-> CYP3A4
# Dasatinib -[biolink:interacts_with]-> CYP3A4
# Yohimbine -[biolink:interacts_with]-> CYP3A4
# Lisuride -[biolink:interacts_with]-> CYP3A4
# Dronabinol -[biolink:interacts_with]-> CYP3A4
# Prochlorperazine -[biolink:interacts_with]-> CYP3A4
# Ziprasidone -[biolink:interacts_with]-> CYP3A4
# Formaldehyde -[biolink:interacts_with]-> CYP3A4
# Desipramine -[biolink:interacts_with]-> CYP3A4
# Clofazimine -[biolink:interacts_with]-> CYP3A4
# Nifedipine -[biolink:interacts_with]-> CYP3A4
# Bicalutamide -[biolink:interacts_with]-> CYP3A4
# Tretinoin -[biolink:interacts_with]-> CYP3A4
# Mianserin -[biolink:interacts_with]-> CYP3A4
# Bromocriptine -[biolink:interacts_with]-> CYP3A4
# Ergotamine -[biolink:interacts_with]-> CYP3A4
# Haloperidol -[biolink:interacts_with]-> CYP3A4
# Cabergoline -[biolink:interacts_with]-> CYP3A4
# Diphenhydramine -[biolink:interacts_with]-> CYP3A4
# Ropinirole -[biolink:interacts_with]-> CYP3A4
# Carbinoxamine -[biolink:interacts_with]-> CYP3A4
# Oxcarbazepine -[biolink:interacts_with]-> CYP3A4
# Phenoxybenzamine -[biolink:interacts_with]-> CYP3A4
# Trimipramine -[biolink:interacts_with]-> CYP3A4
# Glyburide -[biolink:interacts_with]-> CYP3A4
# Guanfacine -[biolink:interacts_with]-> CYP3A4
# Tramadol -[biolink:interacts_with]-> CYP3A4
# Perphenazine -[biolink:interacts_with]-> CYP3A4
# (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate -[biolink:interacts_with]-> CYP3A4
# Clarithromycin -[biolink:interacts_with]-> CYP3A4
# Quetiapine -[biolink:interacts_with]-> CYP3A4
# Nortriptyline -[biolink:interacts_with]-> CYP3A4
# Metyrapone -[biolink:interacts_with]-> CYP3A4
# Result 16
# p_value: 3.397323201792267e-58
# Cabergoline -[biolink:prevents]-> pleuropneumonia
# Quetiapine -[biolink:prevents]-> pleuropneumonia
# Dactinomycin -[biolink:prevents]-> pleuropneumonia
# Nabumetone -[biolink:prevents]-> pleuropneumonia
# Mesalamine -[biolink:prevents]-> pleuropneumonia
# Etomidate -[biolink:prevents]-> pleuropneumonia
# Amitriptyline -[biolink:prevents]-> pleuropneumonia
# Betahistine -[biolink:prevents]-> pleuropneumonia
# Latanoprost -[biolink:prevents]-> pleuropneumonia
# Loxapine -[biolink:prevents]-> pleuropneumonia
# Olanzapine -[biolink:prevents]-> pleuropneumonia
# Ziprasidone -[biolink:prevents]-> pleuropneumonia
# Escitalopram -[biolink:prevents]-> pleuropneumonia
# Diclofenac -[biolink:prevents]-> pleuropneumonia
# Clonidine -[biolink:prevents]-> pleuropneumonia
# Haloperidol -[biolink:prevents]-> pleuropneumonia
# Dronedarone -[biolink:prevents]-> pleuropneumonia
# Milrinone -[biolink:prevents]-> pleuropneumonia
# Guanfacine -[biolink:prevents]-> pleuropneumonia
# Olmesartan -[biolink:prevents]-> pleuropneumonia
# Risperidone -[biolink:prevents]-> pleuropneumonia
# Methamphetamine -[biolink:prevents]-> pleuropneumonia
# Paroxetine -[biolink:prevents]-> pleuropneumonia
# Glyburide -[biolink:prevents]-> pleuropneumonia
# Lamotrigine -[biolink:prevents]-> pleuropneumonia
# Zolmitriptan -[biolink:prevents]-> pleuropneumonia
# (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate -[biolink:prevents]-> pleuropneumonia
# Nortriptyline -[biolink:prevents]-> pleuropneumonia
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:prevents]-> pleuropneumonia
# Capecitabine -[biolink:prevents]-> pleuropneumonia
# Chlorpromazine -[biolink:prevents]-> pleuropneumonia
# Rilmenidine -[biolink:prevents]-> pleuropneumonia
# Acitretin -[biolink:prevents]-> pleuropneumonia
# Aripiprazole -[biolink:prevents]-> pleuropneumonia
# Oxcarbazepine -[biolink:prevents]-> pleuropneumonia
# Propofol -[biolink:prevents]-> pleuropneumonia
# Desipramine -[biolink:prevents]-> pleuropneumonia
# Brimonidine -[biolink:prevents]-> pleuropneumonia
# Tizanidine -[biolink:prevents]-> pleuropneumonia
# Ropinirole -[biolink:prevents]-> pleuropneumonia
# Diphenhydramine -[biolink:prevents]-> pleuropneumonia
# Result 17
# p_value: 5.356026602489079e-58
# Ropinirole -[biolink:prevents]-> kidney failure
# Apomorphine -[biolink:prevents]-> kidney failure
# ...
# Mesalamine -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Torsemide -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Ropinirole -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Diclofenac -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Risperidone -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Famotidine -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Lamotrigine -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Spironolactone -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Nortriptyline -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Nifedipine -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Quetiapine -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Escitalopram -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Olanzapine -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Clozapine -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Methotrexate -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Diphenhydramine -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Clonidine -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Tizanidine -[biolink:prevents]-> female breast upper-outer quadrant cancer
# Result 89
# p_value: 1.3513136069460173e-41
# Dronedarone -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Phenobarbital -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Betahistine -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Levomepromazine -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Gemcitabine -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Pergolide -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Lamotrigine -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Epirubicin -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Dexmedetomidine -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Zotepine -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Saquinavir -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Loxapine -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Etoposide -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Spironolactone -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Tranilast -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Maprotiline -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Nicorandil -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Norepinephrine -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Flavoxate -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Rilmenidine -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Tiapride -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Bosutinib -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Acitretin -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Torsemide -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Nevirapine -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Probucol -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Miglitol -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Propofol -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Amoxapine -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Nicergoline -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Chlorpromazine -[biolink:causes_adverse_event]-> Elevated serum alanine aminotransferase
# Result 90
# p_value: 1.4351960378413443e-41
# Paroxetine -[biolink:causes_adverse_event]-> serotonin syndrome
# Amitriptyline -[biolink:causes_adverse_event]-> serotonin syndrome
# Olanzapine -[biolink:causes_adverse_event]-> serotonin syndrome
# Aripiprazole -[biolink:causes_adverse_event]-> serotonin syndrome
# Amoxapine -[biolink:causes_adverse_event]-> serotonin syndrome
# Perphenazine -[biolink:causes_adverse_event]-> serotonin syndrome
# Dosulepin -[biolink:causes_adverse_event]-> serotonin syndrome
# Rotigotine -[biolink:causes_adverse_event]-> serotonin syndrome
# Chlorpromazine -[biolink:causes_adverse_event]-> serotonin syndrome
# Haloperidol -[biolink:causes_adverse_event]-> serotonin syndrome
# Zolmitriptan -[biolink:causes_adverse_event]-> serotonin syndrome
# Loxapine -[biolink:causes_adverse_event]-> serotonin syndrome
# Oxcarbazepine -[biolink:causes_adverse_event]-> serotonin syndrome
# Desipramine -[biolink:causes_adverse_event]-> serotonin syndrome
# Propofol -[biolink:causes_adverse_event]-> serotonin syndrome
# Methamphetamine -[biolink:causes_adverse_event]-> serotonin syndrome
# Dronabinol -[biolink:causes_adverse_event]-> serotonin syndrome
# Tizanidine -[biolink:causes_adverse_event]-> serotonin syndrome
# Etomidate -[biolink:causes_adverse_event]-> serotonin syndrome
# Nortriptyline -[biolink:causes_adverse_event]-> serotonin syndrome
# Risperidone -[biolink:causes_adverse_event]-> serotonin syndrome
# Lamotrigine -[biolink:causes_adverse_event]-> serotonin syndrome
# Quetiapine -[biolink:causes_adverse_event]-> serotonin syndrome
# (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate -[biolink:causes_adverse_event]-> serotonin syndrome
# Maprotiline -[biolink:causes_adverse_event]-> serotonin syndrome
# Ziprasidone -[biolink:causes_adverse_event]-> serotonin syndrome
# Result 91
# p_value: 2.4949707642373474e-41
# l-Menthol -[biolink:contraindicated_for]-> Pregnancy
# Tretinoin -[biolink:contraindicated_for]-> Pregnancy
# Bendroflumethiazide -[biolink:contraindicated_for]-> Pregnancy
# Dasatinib -[biolink:contraindicated_for]-> Pregnancy
# Epirubicin -[biolink:contraindicated_for]-> Pregnancy
# Brimonidine -[biolink:contraindicated_for]-> Pregnancy
# Gemcitabine -[biolink:contraindicated_for]-> Pregnancy
# Dactinomycin -[biolink:contraindicated_for]-> Pregnancy
# Methamphetamine -[biolink:contraindicated_for]-> Pregnancy
# Nabumetone -[biolink:contraindicated_for]-> Pregnancy
# Lamotrigine -[biolink:contraindicated_for]-> Pregnancy
# Phenobarbital -[biolink:contraindicated_for]-> Pregnancy
# Ergotamine -[biolink:contraindicated_for]-> Pregnancy
# Mycophenolic acid -[biolink:contraindicated_for]-> Pregnancy
# (3-Azaniumyl-1-hydroxy-1-phosphonopropyl)-hydroxyphosphinate -[biolink:contraindicated_for]-> Pregnancy
# Bicalutamide -[biolink:contraindicated_for]-> Pregnancy
# Felodipine -[biolink:contraindicated_for]-> Pregnancy
# Carvedilol -[biolink:contraindicated_for]-> Pregnancy
# Paroxetine -[biolink:contraindicated_for]-> Pregnancy
# Oxaprozin -[biolink:contraindicated_for]-> Pregnancy
# Sotalol -[biolink:contraindicated_for]-> Pregnancy
# Amphetamine -[biolink:contraindicated_for]-> Pregnancy
# Carteolol -[biolink:contraindicated_for]-> Pregnancy
# Irinotecan -[biolink:contraindicated_for]-> Pregnancy
# Lorazepam -[biolink:contraindicated_for]-> Pregnancy
# Capecitabine -[biolink:contraindicated_for]-> Pregnancy
# Ethotoin -[biolink:contraindicated_for]-> Pregnancy
# Flurbiprofen -[biolink:contraindicated_for]-> Pregnancy
# Diclofenac -[biolink:contraindicated_for]-> Pregnancy
# Dronedarone -[biolink:contraindicated_for]-> Pregnancy
# Tramadol -[biolink:contraindicated_for]-> Pregnancy
# Methotrexate -[biolink:contraindicated_for]-> Pregnancy
# Acitretin -[biolink:contraindicated_for]-> Pregnancy
# Etoposide -[biolink:contraindicated_for]-> Pregnancy
# Amitriptyline -[biolink:contraindicated_for]-> Pregnancy
# Result 92
# p_value: 3.145156403574994e-41
# Spironolactone -[biolink:contraindicated_for]-> Acute nephropathy
# Oxcarbazepine -[biolink:contraindicated_for]-> Acute nephropathy
# Rotigotine -[biolink:contraindicated_for]-> Acute nephropathy
# Apraclonidine -[biolink:contraindicated_for]-> Acute nephropathy
# Acitretin -[biolink:contraindicated_for]-> Acute nephropathy
# Risperidone -[biolink:contraindicated_for]-> Acute nephropathy
# Ergotamine -[biolink:contraindicated_for]-> Acute nephropathy
# Metaxalone -[biolink:contraindicated_for]-> Acute nephropathy
# Apomorphine -[biolink:contraindicated_for]-> Acute nephropathy
# Methotrexate -[biolink:contraindicated_for]-> Acute nephropathy
# Bendroflumethiazide -[biolink:contraindicated_for]-> Acute nephropathy
# Tramadol -[biolink:contraindicated_for]-> Acute nephropathy
# Mycophenolic acid -[biolink:contraindicated_for]-> Acute nephropathy
# Flurbiprofen -[biolink:contraindicated_for]-> Acute nephropathy
# Ropinirole -[biolink:contraindicated_for]-> Acute nephropathy
# Nabumetone -[biolink:contraindicated_for]-> Acute nephropathy
# Clarithromycin -[biolink:contraindicated_for]-> Acute nephropathy
# Diclofenac -[biolink:contraindicated_for]-> Acute nephropathy
# Escitalopram -[biolink:contraindicated_for]-> Acute nephropathy
# Paroxetine -[biolink:contraindicated_for]-> Acute nephropathy
# Lorazepam -[biolink:contraindicated_for]-> Acute nephropathy
# Lamotrigine -[biolink:contraindicated_for]-> Acute nephropathy
# Phenobarbital -[biolink:contraindicated_for]-> Acute nephropathy
# Glyburide -[biolink:contraindicated_for]-> Acute nephropathy
# d,l-Aspartic acid -[biolink:contraindicated_for]-> Acute nephropathy
# Clonidine -[biolink:contraindicated_for]-> Acute nephropathy
# Methyldopa -[biolink:contraindicated_for]-> Acute nephropathy
# Capecitabine -[biolink:contraindicated_for]-> Acute nephropathy
# Nevirapine -[biolink:contraindicated_for]-> Acute nephropathy
# Fenofibrate -[biolink:contraindicated_for]-> Acute nephropathy
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:contraindicated_for]-> Acute nephropathy
# Result 93
# p_value: 3.4579884138207136e-41
# Cortisone -[biolink:contributes_to]-> drug-induced akathisia
# Prochlorperazine -[biolink:contributes_to]-> drug-induced akathisia
# Haloperidol -[biolink:contributes_to]-> drug-induced akathisia
# Ziprasidone -[biolink:contributes_to]-> drug-induced akathisia
# Pefloxacin -[biolink:contributes_to]-> drug-induced akathisia
# Maprotiline -[biolink:contributes_to]-> drug-induced akathisia
# Olanzapine -[biolink:contributes_to]-> drug-induced akathisia
# Levomepromazine -[biolink:contributes_to]-> drug-induced akathisia
# Oxymetazoline -[biolink:contributes_to]-> drug-induced akathisia
# Etomidate -[biolink:contributes_to]-> drug-induced akathisia
# Clozapine -[biolink:contributes_to]-> drug-induced akathisia
# Risperidone -[biolink:contributes_to]-> drug-induced akathisia
# Mephentermine -[biolink:contributes_to]-> drug-induced akathisia
# Perphenazine -[biolink:contributes_to]-> drug-induced akathisia
# Zotepine -[biolink:contributes_to]-> drug-induced akathisia
# Amitriptyline -[biolink:contributes_to]-> drug-induced akathisia
# Chlorpromazine -[biolink:contributes_to]-> drug-induced akathisia
# Yohimbine -[biolink:contributes_to]-> drug-induced akathisia
# Flunarizine -[biolink:contributes_to]-> drug-induced akathisia
# Diphenhydramine -[biolink:contributes_to]-> drug-induced akathisia
# Apomorphine -[biolink:contributes_to]-> drug-induced akathisia
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:contributes_to]-> drug-induced akathisia
# Amoxapine -[biolink:contributes_to]-> drug-induced akathisia
# Aripiprazole -[biolink:contributes_to]-> drug-induced akathisia
# Methamphetamine -[biolink:contributes_to]-> drug-induced akathisia
# Clarithromycin -[biolink:contributes_to]-> drug-induced akathisia
# Result 94
# p_value: 3.510415772964332e-41
# Diphenhydramine -[biolink:prevents]-> immature cataract
# Tizanidine -[biolink:prevents]-> immature cataract
# Nevirapine -[biolink:prevents]-> immature cataract
# Gemcitabine -[biolink:prevents]-> immature cataract
# Ropinirole -[biolink:prevents]-> immature cataract
# Prochlorperazine -[biolink:prevents]-> immature cataract
# Mesalamine -[biolink:prevents]-> immature cataract
# Paroxetine -[biolink:prevents]-> immature cataract
# Dronedarone -[biolink:prevents]-> immature cataract
# Olanzapine -[biolink:prevents]-> immature cataract
# Spironolactone -[biolink:prevents]-> immature cataract
# Irinotecan -[biolink:prevents]-> immature cataract
# Oxcarbazepine -[biolink:prevents]-> immature cataract
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:prevents]-> immature cataract
# Lamotrigine -[biolink:prevents]-> immature cataract
# Escitalopram -[biolink:prevents]-> immature cataract
# Torsemide -[biolink:prevents]-> immature cataract
# Nicorandil -[biolink:prevents]-> immature cataract
# Clozapine -[biolink:prevents]-> immature cataract
# Etoposide -[biolink:prevents]-> immature cataract
# Ziprasidone -[biolink:prevents]-> immature cataract
# Propofol -[biolink:prevents]-> immature cataract
# Clarithromycin -[biolink:prevents]-> immature cataract
# Risperidone -[biolink:prevents]-> immature cataract
# Haloperidol -[biolink:prevents]-> immature cataract
# Aripiprazole -[biolink:prevents]-> immature cataract
# Capecitabine -[biolink:prevents]-> immature cataract
# Result 95
# p_value: 6.153214388511276e-41
# Cinacalcet -[biolink:prevents]-> osteoarthritis susceptibility 5
# Diphenhydramine -[biolink:prevents]-> osteoarthritis susceptibility 5
# Mycophenolic acid -[biolink:prevents]-> osteoarthritis susceptibility 5
# Capecitabine -[biolink:prevents]-> osteoarthritis susceptibility 5
# Lamotrigine -[biolink:prevents]-> osteoarthritis susceptibility 5
# Aripiprazole -[biolink:prevents]-> osteoarthritis susceptibility 5
# Clozapine -[biolink:prevents]-> osteoarthritis susceptibility 5
# Quetiapine -[biolink:prevents]-> osteoarthritis susceptibility 5
# Phenobarbital -[biolink:prevents]-> osteoarthritis susceptibility 5
# Chlorpromazine -[biolink:prevents]-> osteoarthritis susceptibility 5
# Risperidone -[biolink:prevents]-> osteoarthritis susceptibility 5
# Olanzapine -[biolink:prevents]-> osteoarthritis susceptibility 5
# Ziprasidone -[biolink:prevents]-> osteoarthritis susceptibility 5
# Propofol -[biolink:prevents]-> osteoarthritis susceptibility 5
# 2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate -[biolink:prevents]-> osteoarthritis susceptibility 5
# Gemcitabine -[biolink:prevents]-> osteoarthritis susceptibility 5
# Torsemide -[biolink:prevents]-> osteoarthritis susceptibility 5
# Haloperidol -[biolink:prevents]-> osteoarthritis susceptibility 5
# Nevirapine -[biolink:prevents]-> osteoarthritis susceptibility 5
# Etoposide -[biolink:prevents]-> osteoarthritis susceptibility 5
# Mesalamine -[biolink:prevents]-> osteoarthritis susceptibility 5
# Oxcarbazepine -[biolink:prevents]-> osteoarthritis susceptibility 5
# Spironolactone -[biolink:prevents]-> osteoarthritis susceptibility 5
# Clarithromycin -[biolink:prevents]-> osteoarthritis susceptibility 5
# Escitalopram -[biolink:prevents]-> osteoarthritis susceptibility 5
# Cabergoline -[biolink:prevents]-> osteoarthritis susceptibility 5
# Paroxetine -[biolink:prevents]-> osteoarthritis susceptibility 5
# Result 96
# p_value: 8.012380354692359e-41
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-382294cd8269> in <module>
#       1 for i,result in enumerate(x['message']['results']):
#       2     print('Result',i)
# ----> 3     print_gc_result(x['message']['knowledge_graph'],result)
#
# <ipython-input-9-dbb6b938c311> in print_gc_result(graph, gc_result)
#       7             object_node = kge['object']
#       8             pred = kge['predicate']
# ----> 9             print( f"{graph['nodes'][subject_node]['name']} -[{pred}]-> {graph['nodes'][object_node]['name']}")
#      10
#      11 def print_pc_result(knowledge_graph,pc_result):
#
# KeyError: 'name'

# %%
p = filter_to_pc(answer,'n1')
for i,result in enumerate(p['message']['results']):
    print('Result',i)
    print_pc_result(p['message']['knowledge_graph'],result)
# Out:
# 534
# Result 0
# p_value: [1.1495370818557763e-270]
# properties: ['drugbank.approved']
#   Prazosin
#   Paliperidone
#   Olanzapine
#   Amoxapine
#   Tizanidine
# Result 1
# p_value: [6.59644127909771e-252]
# properties: ['therapeutic_flag']
#   Prazosin
#   Linifanib
#   Paliperidone
#   Olanzapine
#   Rescinnamine
# Result 2
# p_value: [6.015893583648995e-197]
# properties: ['pharmaceutical']
#   Prazosin
#   Linifanib
#   (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane
#   Olanzapine
#   Rescinnamine
# Result 3
# p_value: [1.6424020007278837e-196]
# properties: ['drug']
#   Prazosin
#   Linifanib
#   (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane
#   Olanzapine
#   Rescinnamine
# Result 4
# p_value: [5.453354578023201e-175]
# properties: ['application']
#   Prazosin
#   Linifanib
#   (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane
#   Olanzapine
#   Rescinnamine
# Result 5
# p_value: [8.838117408888529e-156]
# properties: ['Cytochrome P-450 Substrates']
#   Paliperidone
#   Dronabinol
#   Olanzapine
#   Amoxapine
#   Tinidazole
# Result 6
# p_value: [1.4463009932899652e-153]
# properties: ['oral']
#   Prazosin
#   Paliperidone
#   Dronabinol
#   Olanzapine
#   Rescinnamine
# Result 7
# p_value: [3.0808261961301157e-145]
# properties: ['Neurotransmitter Agents']
#   Paliperidone
#   Dronabinol
#   Olanzapine
#   Methapyrilene
#   Amoxapine
# Result 8
# p_value: [1.1331958084532377e-129]
# properties: ['pharmacological_role']
#   Prazosin
#   (13S,17R)-17-Ethynyl-13-methyl-7,8,9,11,12,14,15,16-octahydro-6H-cyclopenta[a]phenanthrene-3,17-diol
#   Dronabinol
#   (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane
#   Olanzapine
# Result 9
# p_value: [1.7584560093269292e-124]
# properties: ['Agents that produce hypertension']
#   Mianserin
#   Paliperidone
#   Flurbiprofen
#   Amoxapine
#   Bromocriptine
# Result 10
# p_value: [1.9816519254910114e-120]
# properties: ['biological_role']
#   Prazosin
#   neomycin
#   Linifanib
#   (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane
#   Olanzapine
# Result 11
# p_value: [1.7379182893626893e-118]
# properties: ['neurotransmitter_agent']
#   Prazosin
#   (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane
#   Olanzapine
#   Methapyrilene
#   Amoxapine
# Result 12
# p_value: [5.938916923225131e-116]
# properties: ['drugbank.investigational']
#   Olanzapine
#   Tinidazole
#   Tizanidine
#   Bromocriptine
#   Cytarabine
# Result 13
# p_value: [3.7001729872136355e-112]
# properties: ['Central Nervous System Depressants']
#   Mianserin
#   Ropinirole
#   Paliperidone
#   Dronabinol
#   Olanzapine
# Result 14
# p_value: [4.4145457685593265e-112]
# properties: ['Cytochrome P-450 CYP3A Substrates']
#   Etoposide
#   Mianserin
#   Paliperidone
#   Dronabinol
#   Tretinoin
# Result 15
# p_value: [2.3270820950944408e-107]
# properties: ['Central Nervous System Agents']
#   Mianserin
#   Ropinirole
#   Paliperidone
#   Dronabinol
#   Olanzapine
# Result 16
# p_value: [2.4967039360832676e-107]
# properties: ['Cytochrome P-450 CYP3A4 Substrates']
#   Etoposide
#   Mianserin
#   Paliperidone
#   Dronabinol
#   Tretinoin
# Result 17
# p_value: [6.736814368507237e-98]
# properties: ['Nervous System']
#   Mianserin
#   Ropinirole
#   Paliperidone
#   Olanzapine
#   Etoperidone
# Result 18
# p_value: [7.906099252098148e-96]
# properties: ['Heterocyclic Compounds, Fused-Ring']
#   Prazosin
#   Mianserin
#   Ropinirole
#   Staurosporine
#   Olanzapine
# Result 19
# p_value: [8.698868717422565e-93]
# properties: ['Agents producing tachycardia']
#   Dronabinol
#   Olanzapine
#   Amoxapine
#   Tizanidine
#   Bromocriptine
# Result 20
# p_value: [1.5039798546378416e-87]
# properties: ['Cytochrome P-450 Enzyme Inhibitors']
#   Etoposide
#   Olanzapine
#   Amoxapine
#   Bromocriptine
#   Risperidone
# Result 21
# p_value: [4.928705688607462e-84]
# properties: ['adrenergic_agent']
#   Prazosin
#   (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane
#   Amoxapine
#   Tizanidine
#   1-(Tert-butyl)-3-(4-chlorophenyl)-1H-pyrazolo[3,4-d]pyrimidin-4-amine
# Result 22
# p_value: [2.073987849086623e-82]
# properties: ['QTc Prolonging Agents']
#   Celiprolol
#   Mocetinostat
#   Paliperidone
#   Olanzapine
#   Amoxapine
# Result 23
# p_value: [3.380781720726929e-82]
# properties: ['Antidepressive Agents']
#   Ropinirole
#   Paliperidone
#   Olanzapine
#   Etoperidone
#   Amoxapine
# Result 24
# p_value: [4.1982976459735503e-81]
# properties: ['Serotonergic Drugs Shown to Increase Risk of Serotonin Syndrome']
#   Paliperidone
#   Olanzapine
#   Etoperidone
#   Amoxapine
#   Lofepramine
# Result 25
# p_value: [1.6787398528692767e-79]
# properties: ['Adrenergic Agents']
#   Celiprolol
#   Mianserin
#   Amoxapine
#   Tizanidine
#   Maprotiline
# Result 26
# p_value: [3.548695570638029e-79]
# properties: ['Cytochrome P-450 CYP2D6 Substrates']
#   Celiprolol
#   Mianserin
#   Paliperidone
#   Olanzapine
#   Amoxapine
# Result 27
# p_value: [3.492925999034577e-78]
# properties: ['Cardiovascular Agents']
#   Celiprolol
#   Prazosin
#   Moxonidine
#   Levonordefrin
#   Fenoldopam
# Result 28
# p_value: [1.7794666834429223e-74]
# properties: ['Serotonin Agents']
#   Paliperidone
#   Olanzapine
#   Etoperidone
#   Amoxapine
#   Bromocriptine
# Result 29
# p_value: [2.161968008065358e-71]
# properties: ['alpha_adrenergic_drug']
#   Prazosin
#   Clonidine
#   Roxindole
#   (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane
#   Brimonidine
# Result 30
# p_value: [2.424164107461535e-71]
# properties: ['cardiovascular_drug']
#   Prazosin
#   Rescinnamine
#   Levonordefrin
#   Fenoldopam
#   (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate
# Result 31
# p_value: [1.8590960017310096e-70]
# properties: ['central_nervous_system_drug']
#   Mianserin
#   Ropinirole
#   Dronabinol
#   Olanzapine
#   Methapyrilene
# Result 32
# p_value: [1.2913547783866684e-69]
# properties: ['Drugs that are Mainly Renally Excreted']
#   Paliperidone
#   Flurbiprofen
#   Etoperidone
#   Pidotimod
#   Tinidazole
# Result 33
# p_value: [2.1158297866e-68]
# properties: ['Hypotensive Agents']
#   Prazosin
#   Clonidine
#   Ropinirole
#   Guanfacine
#   Olanzapine
# Result 34
# p_value: [1.4497861374582574e-65]
# properties: ['Adrenergic Antagonists']
#   Celiprolol
#   Prazosin
#   Paliperidone
#   Olanzapine
#   Aripiprazole lauroxil
# Result 35
# p_value: [6.767497845577797e-65]
# properties: ['Peripheral Nervous System Agents']
#   Celiprolol
#   Dronabinol
#   Olanzapine
#   Flurbiprofen
#   Levomepromazine
# Result 36
# p_value: [8.265578569289495e-65]
# properties: ['parenteral']
#   Etoposide
#   Olanzapine
#   Cytarabine
#   Levonordefrin
#   Fenoldopam
# Result 37
# p_value: [1.5119017892873988e-64]
# properties: ['Psychotropic Drugs']
#   Mianserin
#   Paliperidone
#   Dronabinol
#   Olanzapine
#   Aripiprazole lauroxil
# Result 38
# p_value: [2.2110586891615205e-62]
# properties: ['Adrenergic alpha-Agonists']
#   Etomidate
#   Clonidine
#   Methylephedrine
#   Brimonidine
#   Tizanidine
# Result 39
# p_value: [2.892418395710558e-62]
# properties: ['Adrenergic alpha-Antagonists']
#   Prazosin
#   Paliperidone
#   Olanzapine
#   Aripiprazole lauroxil
#   Amoxapine
# Result 40
# p_value: [4.176601428913474e-62]
# properties: ['chemical_role']
#   Linifanib
#   3-Oxalomalic acid
#   (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane
#   Olanzapine
#   Methapyrilene
# Result 41
# p_value: [2.2522383277237823e-61, 2.4482364498297613e-61, 2.629571461006743e-61]
# properties: ['Bronsted_base', 'base', 'acceptor']
#   Linifanib
#   (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane
#   Olanzapine
#   Methapyrilene
#   Pidotimod
# Result 42
# p_value: [8.786384070596464e-60]
# properties: ['P-glycoprotein substrates']
#   Celiprolol
#   Palbociclib
#   Etoposide
#   Clonidine
#   Paliperidone
# Result 43
# p_value: [6.872052621565929e-59]
# properties: ['Serotonin 5-HT2 Receptor Antagonists']
#   Paliperidone
#   Olanzapine
#   Etoperidone
#   Aripiprazole lauroxil
#   Amoxapine
# Result 44
# p_value: [2.0687613965767192e-58]
# properties: ['Adrenergic Agonists']
#   Celiprolol
#   Etomidate
#   Clonidine
#   Methylephedrine
#   Brimonidine
# Result 45
# p_value: [2.3219270996942153e-58]
# properties: ['Adrenergic alpha-2 Receptor Agonists']
#   Etomidate
#   Clonidine
#   Methylephedrine
#   Brimonidine
#   Tizanidine
# Result 46
# p_value: [3.2367927870765425e-58]
# properties: ['enzyme_inhibitor']
#   Prazosin
#   Etoposide
#   Mianserin
#   Linifanib
#   Staurosporine
# Result 47
# p_value: [2.430010639824609e-57]
# properties: ['Cytochrome P-450 CYP3A Inhibitors']
#   Palbociclib
#   Etoposide
#   Olanzapine
#   Dasatinib
#   Bromocriptine
# Result 48
# p_value: [3.3826267555915006e-57]
# properties: ['Serotonin Receptor Antagonists']
#   Paliperidone
#   Olanzapine
#   Etoperidone
#   Aripiprazole lauroxil
#   Amoxapine
# Result 49
# p_value: [4.306374546405462e-57]
# properties: ['inhibitor']
#   Prazosin
#   Etoposide
#   Mianserin
#   Linifanib
#   Staurosporine
# Result 50
# p_value: [2.32496049636851e-56]
# properties: ['Adrenergic alpha-1 Receptor Antagonists']
#   Prazosin
#   Paliperidone
#   Olanzapine
#   Aripiprazole lauroxil
#   Amoxapine
# Result 51
# p_value: [6.02861379359182e-56]
# properties: ['Enzyme Inhibitors']
#   Etoposide
#   Mocetinostat
#   Staurosporine
#   Flurbiprofen
#   Paroxetine
# Result 52
# p_value: [9.538723732168478e-54]
# properties: ['P-glycoprotein inhibitors']
#   Palbociclib
#   Etoposide
#   Prazosin
#   Paliperidone
#   Dronabinol
# Result 53
# p_value: [2.7299146461433968e-53]
# properties: ['biochemical_role']
#   Prazosin
#   Linifanib
#   Linalool
#   Dronabinol
#   Ellipticine
# Result 54
# p_value: [6.7762126787147775e-53]
# properties: ['Dopamine Agents']
#   Ropinirole
#   Paliperidone
#   Amoxapine
#   Bromocriptine
#   Methamphetamine
# Result 55
# p_value: [1.4610272353075084e-52]
# properties: ['Cytochrome P-450 CYP3A4 Inhibitors']
#   Palbociclib
#   Etoposide
#   Olanzapine
#   Dasatinib
#   Bromocriptine
# Result 56
# p_value: [1.7503774401177181e-51]
# properties: ['psychotropic_drug']
#   Mianserin
#   Dronabinol
#   Olanzapine
#   Aripiprazole lauroxil
#   Amoxapine
# Result 57
# p_value: [5.0869466643807796e-51]
# properties: ['Cytochrome P-450 CYP1A2 Substrates']
#   Etoposide
#   Clonidine
#   Ropinirole
#   Olanzapine
#   Zolmitriptan
# Result 58
# p_value: [2.2922912963866975e-49]
# properties: ['Cytochrome P-450 CYP2D6 Inhibitors']
#   Saquinavir
#   Olanzapine
#   Amoxapine
#   Dexmedetomidine
#   Ziprasidone
# Result 59
# p_value: [6.775535938446218e-49]
# properties: ['central_nervous_system_depressant']
#   Etomidate
#   Olanzapine
#   Methapyrilene
#   Aripiprazole lauroxil
#   Dexmedetomidine
# Result 60
# p_value: [2.7083793507757792e-48]
# properties: ['Histamine Antagonists']
#   Olanzapine
#   Methapyrilene
#   Aripiprazole lauroxil
#   Amoxapine
#   Ziprasidone
# Result 61
# p_value: [1.371193036085832e-47]
# properties: ['antagonist']
#   Olanzapine
#   Methapyrilene
#   Aripiprazole lauroxil
#   Tretinoin
#   Axitinib
# Result 62
# p_value: [2.095361992214114e-46]
# properties: ['Autonomic Agents']
#   Celiprolol
#   Clonidine
#   Olanzapine
#   Tizanidine
#   Methamphetamine
# Result 63
# p_value: [2.4572820626336444e-46]
# properties: ['Potential QTc-Prolonging Agents']
#   Celiprolol
#   Olanzapine
#   Aripiprazole lauroxil
#   Amoxapine
#   Tizanidine
# Result 64
# p_value: [7.264075016097391e-46]
# properties: ['Dopamine Antagonists']
#   Paliperidone
#   Olanzapine
#   Amoxapine
#   Prochlorperazine
#   Ziprasidone
# Result 65
# p_value: [1.5754514657575015e-45]
# properties: ['Histamine H1 Antagonists']
#   Olanzapine
#   Methapyrilene
#   Aripiprazole lauroxil
#   Amoxapine
#   Ziprasidone
# Result 66
# p_value: [1.6346927123988555e-45]
# properties: ['Muscarinic Antagonists']
#   Olanzapine
#   Amoxapine
#   Ziprasidone
#   Desipramine
#   Maprotiline
# Result 67
# p_value: [2.779937412398924e-44]
# properties: ['Anticholinergic Agents']
#   Olanzapine
#   Amoxapine
#   Ziprasidone
#   Desipramine
#   Maprotiline
# Result 68
# p_value: [6.334290820996266e-43]
# properties: ['Dopamine D2 Receptor Antagonists']
#   Paliperidone
#   Olanzapine
#   Amoxapine
#   Prochlorperazine
#   Ziprasidone
# Result 69
# p_value: [9.200958043485629e-43]
# properties: ['Cytochrome P-450 CYP3A5 Substrates']
#   Etoposide
#   Clonidine
#   Paliperidone
#   Aripiprazole lauroxil
#   Tretinoin
# Result 70
# p_value: [5.546295321816675e-42]
# properties: ['serotonergic_drug']
#   Roxindole
#   Olanzapine
#   Yohimbine
#   Zolmitriptan
#   Aripiprazole lauroxil
# Result 71
# p_value: [1.19577684624257e-41]
# properties: ['dopaminergic_agent']
#   Ropinirole
#   Olanzapine
#   1-[1-(1-Benzothiophen-2-yl)cyclohexyl]piperidine
#   Amoxapine
#   Bromocriptine
# Result 72
# p_value: [3.513064451911437e-41]
# properties: ['Antihypertensive Agents']
#   Celiprolol
#   Prazosin
#   Clonidine
#   Moxonidine
#   Fenoldopam
# Result 73
# p_value: [6.272213861595565e-40]
# properties: ['Neurotoxic agents']
#   Paliperidone
#   Aripiprazole lauroxil
#   Amoxapine
#   Prochlorperazine
#   Ziprasidone
# Result 74
# p_value: [7.615488278754621e-40]
# properties: ['adrenergic_antagonist']
#   Prazosin
#   Roxindole
#   (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane
#   2-Methoxyidazoxan
#   1-(Tert-butyl)-3-(4-chlorophenyl)-1H-pyrazolo[3,4-d]pyrimidin-4-amine
# Result 75
# p_value: [2.1370866389424014e-39]
# properties: ['Membrane Transport Modulators']
#   Amoxapine
#   Methamphetamine
#   Desipramine
#   Maprotiline
#   Oxcarbazepine
# Result 76
# p_value: [2.378801339539816e-38]
# properties: ['Cytochrome P-450 CYP2C9 Substrates']
#   Dronabinol
#   Flurbiprofen
#   Tretinoin
#   Docosahexaenoic acid
#   Glyburide
# Result 77
# p_value: [3.129590948352178e-37]
# properties: ['topical']
#   Menthol
#   Clonidine
#   Zolmitriptan
#   Flurbiprofen
#   Brimonidine
# Result 78
# p_value: [7.713069751835328e-37]
# properties: ['Tranquilizing Agents']
#   Paliperidone
#   Olanzapine
#   Aripiprazole lauroxil
#   Prochlorperazine
#   Ziprasidone
# Result 79
# p_value: [8.661073442720597e-37]
# properties: ['Benzene Derivatives']
#   Celiprolol
#   Etoposide
#   Mocetinostat
#   Flurbiprofen
#   4-Chlorophenol
# Result 80
# p_value: [1.1568258032185862e-36]
# properties: ['antihypertensive_agent']
#   Prazosin
#   Clonidine
#   Rescinnamine
#   Brimonidine
#   Fenoldopam
# Result 81
# p_value: [3.7798021764179345e-36]
# properties: ['Amines']
#   Celiprolol
#   Spermine
#   Zolmitriptan
#   Methapyrilene
#   Methamphetamine
# Result 82
# p_value: [6.762676293945448e-36]
# properties: ['alpha_adrenergic_agonist']
#   Clonidine
#   6-(Tert-butyl)-3-(2-imidazolin-2-ylmethyl)-2,4-dimethylphenol, chloride
#   Brimonidine
#   Ergotamine
#   Tizanidine
# Result 83
# p_value: [1.1161958107260422e-34]
# properties: ['Antipsychotic Agents']
#   Paliperidone
#   Chlorpromazine
#   Olanzapine
#   Flupentixol
#   Haloperidol
# Result 84
# p_value: [8.80416696080974e-34]
# properties: ['Antineoplastic Agents']
#   Palbociclib
#   Etoposide
#   Mocetinostat
#   Amonafide
#   (3-Azaniumyl-1-hydroxy-1-phosphonopropyl)-hydroxyphosphinate
# Result 85
# p_value: [1.5123698064867116e-33]
# properties: ['Serotonin Modulators']
#   Nortriptyline
#   Mianserin
#   Zolmitriptan
#   Trimipramine
#   Etoperidone
# Result 86
# p_value: [3.794416337031484e-33]
# properties: ['Bradycardia-Causing Agents']
#   Celiprolol
#   Clonidine
#   Tizanidine
#   Dexmedetomidine
#   l-Menthol
# Result 87
# p_value: [4.3437904669247244e-33]
# properties: ['Vasodilating Agents']
#   Celiprolol
#   Prazosin
#   Fenoldopam
#   Dihydroergocristine
#   3-[(4,5-Dihydro-1H-imidazol-3-ium-2-ylmethyl)(4-methylphenyl)amino]phenolate
# Result 88
# p_value: [2.9476983557414273e-32]
# properties: ['alpha_adrenergic_antagonist']
#   Prazosin
#   Mianserin
#   Roxindole
#   (2-(2',6'-Dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane
#   Carvedilol
# Result 89
# p_value: [4.9148749371373415e-32]
# properties: ['tranquilizing_drug']
#   Olanzapine
#   Aripiprazole lauroxil
#   Prochlorperazine
#   Ziprasidone
#   Risperidone
# Result 90
# p_value: [9.075923406420253e-32]
# properties: ['Analgesics']
#   Clonidine
#   Dronabinol
#   Zolmitriptan
#   Flurbiprofen
#   Tizanidine
# Result 91
# p_value: [9.559524249300566e-32]
# properties: ['Sulfur Compounds']
#   Pidotimod
#   Dasatinib
#   Prochlorperazine
#   Ziprasidone
#   Levamisole
# Result 92
# p_value: [3.199804488497654e-31]
# properties: ['Psycholeptics']
#   Paliperidone
#   Olanzapine
#   Dexmedetomidine
#   Prochlorperazine
#   Ziprasidone
# Result 93
# p_value: [1.2344360586370541e-30]
# properties: ['Cytochrome P-450 CYP2C19 Substrates']
#   Guanfacine
#   Axitinib
#   Glyburide
#   Perphenazine
#   Paroxetine
# Result 94
# p_value: [2.5009789409660112e-30]
# properties: ['Cytochrome P-450 CYP3A4 Inhibitors (strength unknown)']
#   Bosutinib
#   Etoposide
#   Diclofenac
#   7-Ethyl-10-hydroxycamptothecin
#   Cabergoline
# Result 95
# p_value: [2.745689221418474e-30]
# properties: ['Agents causing hyperkalemia']
#   Celiprolol
#   Flurbiprofen
#   Mesalamine
#   l-Menthol
#   Trimebutine
# Result 96
# p_value: [4.189935939148004e-30]
# properties: ['drugbank.experimental']
#   Staurosporine
#   Spermine
#   Lanthanum(3+)
#   Hydroxycitronellal
#   Glycochenodeoxycholic acid
# Result 97
# p_value: [4.529536624912979e-30]
# properties: ['antipsychotic_agent']
#   Chlorpromazine
#   Olanzapine
#   Haloperidol
#   Aripiprazole lauroxil
#   asenapine
# Result 98
# p_value: [5.367943403527809e-30]
# properties: ['Agents that reduce seizure threshold']
#   Nortriptyline
#   Propofol
#   Chlorpromazine
#   Trimipramine
#   Haloperidol
# Result 99
# p_value: [7.786862784426518e-30]
# properties: ['Imidazoles']
#   Ethotoin
#   Olmesartan
#   Clonidine
#   Secnidazole
#   Etomidate
# Result 100
# p_value: [7.786862784426518e-30]
# properties: ['dopaminergic_antagonist']
#   Olanzapine
#   Chlorpromazine
#   Haloperidol
#   Amoxapine
#   asenapine
# Result 101
# p_value: [1.2774624694249777e-29]
# properties: ['adrenergic_agonist']
#   Clonidine
#   6-(Tert-butyl)-3-(2-imidazolin-2-ylmethyl)-2,4-dimethylphenol, chloride
#   Brimonidine
#   [2-[3,4-Bis(2,2-dimethylpropanoyloxy)phenyl]-2-hydroxyethyl]-methylazanium;chloride
#   Ergotamine
# Result 102
# p_value: [1.5432819129844417e-29]
# properties: ['Cytochrome P-450 Enzyme Inducers']
#   Etoposide
#   Cortisone
#   Menadione
#   Oxcarbazepine
#   Troglitazone
# Result 103
# p_value: [3.878419854607709e-29]
# properties: ['Antineoplastic and Immunomodulating Agents']
#   Palbociclib
#   Etoposide
#   Axitinib
#   Pidotimod
#   Tretinoin
# Result 104
# p_value: [4.6457007982440783e-29]
# properties: ['antineoplastic_agent']
#   Palbociclib
#   Etoposide
#   Linifanib
#   6-Anilino-5,8-quinolinedione
#   Bufalin
# Result 105
# p_value: [8.446947183245389e-29]
# properties: ['Psychoanaleptics']
#   Nortriptyline
#   Mianserin
#   Trimipramine
#   Etoperidone
#   Amoxapine
# Result 106
# p_value: [1.3222208572151083e-28]
# properties: ['Alkaloids']
#   Midostaurin
#   Lisuride
#   Miglitol
#   Terguride
#   Staurosporine
# Result 107
# p_value: [1.9160099667326772e-28]
# properties: ['Adrenergic alpha-1 Receptor Agonists']
#   Clonidine
#   Cirazoline
#   Pergolide
#   Bromocriptine
#   Norepinephrine
# Result 108
# p_value: [9.099388106583023e-28]
# properties: ['Sensory System Agents']
#   Clonidine
#   Dronabinol
#   Flurbiprofen
#   Tizanidine
#   Proparacaine
# Result 109
# p_value: [1.739338321754768e-27]
# properties: ['Cytochrome P-450 CYP3A Inducers']
#   Phenobarbital
#   Ethotoin
#   Etoposide
#   Midostaurin
#   Methotrexate
# Result 110
# p_value: [4.414894465281266e-26]
# properties: ['Moderate Risk QTc-Prolonging Agents']
#   Mocetinostat
#   Probucol
#   Chlorpromazine
#   Haloperidol
#   Lofexidine
# Result 111
# p_value: [5.468256944044578e-26]
# properties: ['histaminergic_drug']
#   Betahistine
#   Olanzapine
#   Methapyrilene
#   Aripiprazole lauroxil
#   Diphenhydramine
# Result 112
# p_value: [5.966214024262945e-26]
# properties: ['Hyperglycemia-Associated Agents']
#   Torsemide
#   Paliperidone
#   Chlorpromazine
#   Olanzapine
#   Haloperidol
# Result 113
# p_value: [3.682693348528657e-25]
# properties: ['antidepressant']
#   Nortriptyline
#   Mianserin
#   Trimipramine
#   Amoxapine
#   Lofepramine
# Result 114
# p_value: [5.483734404821041e-25]
# properties: ['Cytochrome P-450 CYP2B6 Substrates']
#   Nortriptyline
#   Propofol
#   Diclofenac
#   Trimipramine
#   Amitriptyline
# Result 115
# p_value: [7.625022571101104e-25]
# properties: ['serotonergic_antagonist']
#   Olanzapine
#   Haloperidol
#   N-[2-[4-[3-[4-Amino-5-chloro-2-[(3,5-dimethoxyphenyl)methoxy]phenyl]-3-oxopropyl]piperidin-1-yl]ethyl]methanesulfonamide
#   asenapine
#   Pizotifen
# Result 116
# p_value: [9.040141211834622e-25]
# properties: ['Dopamine Agonists']
#   Lisuride
#   Ropinirole
#   Cabergoline
#   Pergolide
#   Bromocriptine
# Result 117
# p_value: [1.2998726315308633e-24]
# properties: ['histamine_antagonist']
#   Olanzapine
#   Methapyrilene
#   Aripiprazole lauroxil
#   Diphenhydramine
#   Pizotifen
# Result 118
# p_value: [1.803481157051e-24]
# properties: ['UGT1A1 Substrates']
#   Etoposide
#   Propofol
#   Carvedilol
#   Diclofenac
#   Flurbiprofen
# Result 119
# p_value: [2.091538897515992e-24]
# properties: ['Antiarrhythmic agents']
#   Nicorandil
#   Celiprolol
#   Dronedarone
#   Carteolol
#   Carvedilol
# Result 120
# p_value: [4.028632567828925e-24]
# properties: ['Cytochrome P-450 CYP3A4 Inducers']
#   Phenobarbital
#   Ethotoin
#   Etoposide
#   Midostaurin
#   Methotrexate
# Result 121
# p_value: [4.107906949774672e-24]
# properties: ['Cytochrome P-450 CYP3A7 Substrates']
#   Haloperidol
#   Aripiprazole lauroxil
#   Tretinoin
#   Nevirapine
#   Irinotecan
# Result 122
# p_value: [4.6406626739191e-24]
# properties: ['vasodilator_agent']
#   Nicorandil
#   Betahistine
#   Carvedilol
#   3-[(4,5-Dihydro-1H-imidazol-3-ium-2-ylmethyl)(4-methylphenyl)amino]phenolate
#   Anandamide
# Result 123
# p_value: [4.853217723954886e-24]
# properties: ['BSEP/ABCB11 Substrates']
#   Olmesartan
#   Diclofenac
#   Felodipine
#   Glycochenodeoxycholic acid
#   Tinidazole
# Result 124
# p_value: [5.782409835875921e-24]
# properties: ['Cytochrome P-450 CYP2C9 Inhibitors']
#   Torsemide
#   Midostaurin
#   Olanzapine
#   Nevirapine
#   Docosahexaenoic acid
# Result 125
# p_value: [6.44674871481388e-24]
# properties: ['Analgesics, Non-Narcotic']
#   Oxaprozin
#   Zileuton
#   Dronabinol
#   Diclofenac
#   Flurbiprofen
# Result 126
# p_value: [1.0974313832618577e-23]
# properties: ['Pyridines']
#   Nicorandil
#   Torsemide
#   Betahistine
#   Pimasertib
#   Etoperidone
# Result 127
# p_value: [1.2193686128035525e-23]
# properties: ['Neurotransmitter Uptake Inhibitors']
#   Nortriptyline
#   Trimipramine
#   Amoxapine
#   Methamphetamine
#   Desipramine
# Result 128
# p_value: [1.2796423874644937e-23]
# properties: ['Anti-Infective Agents']
#   Amonafide
#   Secnidazole
#   Neomycin
#   4-Chlorophenol
#   Tinidazole
# Result 129
# p_value: [1.329430232268764e-23]
# properties: ['Serotonin 5-HT1 Receptor Antagonists']
#   Nortriptyline
#   Chlorpromazine
#   Trimipramine
#   Amoxapine
#   Pizotifen
# Result 130
# p_value: [6.240958596159585e-23]
# properties: ['Serotonin Receptor Agonists']
#   Lisuride
#   Zolmitriptan
#   Cabergoline
#   Pergolide
#   Lofexidine
# Result 131
# p_value: [7.715672547983784e-23]
# properties: ['Ergot Alkaloids and Derivatives']
#   Lisuride
#   Terguride
#   Cabergoline
#   Ergotamine
#   Pergolide
# Result 132
# p_value: [1.1756693299500075e-22]
# properties: ['Cytochrome P-450 CYP2D6 Inhibitors (strength unknown)']
#   Chlorpromazine
#   Olanzapine
#   Haloperidol
#   Pergolide
#   Amoxapine
# Result 133
# p_value: [1.7238592297319991e-22]
# properties: ['Combined Inhibitors of Serotonin/Norepinephrine Reuptake']
#   Nortriptyline
#   Trimipramine
#   Etoperidone
#   Escitalopram
#   Amitriptyline
# Result 134
# p_value: [2.1007389457022945e-22]
# properties: ['Narrow Therapeutic Index Drugs']
#   Phenobarbital
#   Nortriptyline
#   Clonidine
#   Trimipramine
#   Neomycin
# Result 135
# p_value: [3.7385556830217233e-22]
# properties: ['Sympatholytics']
#   Moxisylyte
#   Clonidine
#   Carteolol
#   Sotalol
#   Debrisoquine
# Result 136
# p_value: [7.960683055414589e-22]
# properties: ['drugbank.vet_approved']
#   Formaldehyde
#   Propofol
#   Chlorpromazine
#   Diclofenac
#   Pergolide
# Result 137
# p_value: [8.306037353691528e-22]
# properties: ['Phenols']
#   Propofol
#   4-Chlorophenol
#   Methyldopa
#   Norepinephrine
#   Levonordefrin
# Result 138
# p_value: [1.1102905961096785e-21]
# properties: ['Ophthalmologicals']
#   Latanoprost
#   Clonidine
#   Cortisone
#   Diclofenac
#   Flurbiprofen
# Result 139
# p_value: [1.3102204721068876e-21, 4.6421430760833163e-17]
# properties: ['EC_3.4.21.26_(prolyl_oligopeptidase)_inhibitor', 'EC_3.4.21.*_(serine_endopeptidase)_inhibitor']
#   Prazosin
#   Mianserin
#   Chlorpromazine
#   Prochlorperazine
#   Lamotrigine
# Result 140
# p_value: [1.3102204721068876e-21]
# properties: ['Vasoconstrictor Agents']
#   Cirazoline
#   Ergotamine
#   Norepinephrine
#   Levonordefrin
#   Mephentermine
# Result 141
# p_value: [7.603528892346582e-21]
# properties: ['Adrenergic Uptake Inhibitors']
#   Nortriptyline
#   Trimipramine
#   Amoxapine
#   Methamphetamine
#   Desipramine
# Result 142
# p_value: [7.603528892346582e-21]
# properties: ['Cytochrome P-450 CYP2D6 Substrates with a Narrow Therapeutic Index']
#   Nortriptyline
#   Clonidine
#   Trimipramine
#   Sotalol
#   Amoxapine
# Result 143
# p_value: [8.082089774202343e-21]
# properties: ['Myelosuppressive Agents']
#   Bosutinib
#   Palbociclib
#   Etoposide
#   Olaparib
#   Dactinomycin
# Result 144
# p_value: [2.78837812788848e-20]
# properties: ['Immunosuppressive Agents']
#   Bosutinib
#   Palbociclib
#   Etoposide
#   Olaparib
#   Dactinomycin
# Result 145
# p_value: [5.457771189440094e-20]
# properties: ['EC_3.*_(hydrolase)_inhibitor']
#   Prazosin
#   N-(p-Amylcinnamoyl)anthranilic acid
#   Prochlorperazine
#   Temephos
#   Levamisole
# Result 146
# p_value: [7.725345083778333e-20]
# properties: ['Sensory Organs']
#   Latanoprost
#   Clonidine
#   Cortisone
#   Diclofenac
#   Flurbiprofen
# Result 147
# p_value: [1.59521983639151e-19]
# properties: ['metabolite']
#   Linalool
#   Dronabinol
#   Ellipticine
#   Rescinnamine
#   Prostratin
# Result 148
# p_value: [1.6334434718300217e-19]
# properties: ['Gastrointestinal Agents']
#   Pirenzepine
#   Lorazepam
#   Glutamic acid
#   Chlorpromazine
#   Olanzapine
# Result 149
# p_value: [1.6435017064267254e-19]
# properties: ['environmental_contaminant']
#   Formaldehyde
#   Dronedarone
#   Diclofenac
#   Trimipramine
#   Prometon
# Result 150
# p_value: [3.761516081227242e-19]
# properties: ['analgesic']
#   Oxaprozin
#   Nortriptyline
#   Clonidine
#   Dronabinol
#   Diclofenac
# Result 151
# p_value: [4.987931324992783e-19]
# properties: ['Antipsychotic Agents (Second Generation [Atypical])']
#   Ziprasidone
#   Aripiprazole
#   Quetiapine
#   Risperidone
#   Zotepine
# Result 152
# p_value: [8.605210699248651e-19]
# properties: ['second_generation_antipsychotic']
#   Olanzapine
#   Aripiprazole lauroxil
#   asenapine
#   Aripiprazole
#   Quetiapine
# Result 153
# p_value: [1.026674008411291e-18]
# properties: ['Cytochrome P-450 CYP2E1 Inhibitors']
#   Nortriptyline
#   Propofol
#   Midostaurin
#   Chlorpromazine
#   Diclofenac
# Result 154
# p_value: [1.3163877352278461e-18]
# properties: ['Alimentary Tract and Metabolism']
#   Piperidolate
#   Pirenzepine
#   Miglitol
#   Glutamic acid
#   Dronabinol
# Result 155
# p_value: [2.3112476125404456e-18]
# properties: ['Non-Selective Monoamine Reuptake Inhibitors']
#   Nortriptyline
#   Lofepramine
#   Desipramine
#   Maprotiline
#   Trimipramine
# Result 156
# p_value: [3.6276156591380575e-18]
# properties: ['Serotonin 5-HT1 Receptor Agonists']
#   Ziprasidone
#   Aripiprazole
#   Rotigotine
#   Lisuride
#   Cabergoline
# Result 157
# p_value: [4.1109200707934936e-18]
# properties: ['Calcium Channel Blockers']
#   Carvedilol
#   Felodipine
#   Aranidipine
#   Flunarizine
#   Lamotrigine
# Result 158
# p_value: [4.617397634437721e-18]
# properties: ['Cytochrome P-450 CYP3A4 Inducers (strength unknown)']
#   Ethotoin
#   Etoposide
#   Midostaurin
#   Cortisone
#   Chlorpromazine
# Result 159
# p_value: [5.5085530314997274e-18]
# properties: ['Genito Urinary System and Sex Hormones']
#   Moxisylyte
#   Hydroflumethiazide
#   Lisuride
#   Terguride
#   Flavoxate
# Result 160
# p_value: [5.566538133889403e-18]
# properties: ['Cytochrome P-450 CYP2C9 Inhibitors (strength unknown)']
#   Torsemide
#   Midostaurin
#   Nevirapine
#   Docosahexaenoic acid
#   Glyburide
# Result 161
# p_value: [5.907869558700302e-18, 3.2698819133606506e-16]
# properties: ['cholinergic_antagonist', 'cholinergic_drug']
#   Pirenzepine
#   Flavoxate
#   Olanzapine
#   Diphenhydramine
#   Pizotifen
# Result 162
# p_value: [6.7350051502293256e-18]
# properties: ['Dibenzazepines']
#   Lofepramine
#   Desipramine
#   Setiptiline
#   Trimipramine
#   Oxcarbazepine
# Result 163
# p_value: [1.0552093978885655e-17]
# properties: ['UGT1A9 Substrates']
#   Propofol
#   Zileuton
#   Diclofenac
#   Flurbiprofen
#   Haloperidol
# Result 164
# p_value: [1.0865275876979825e-17]
# properties: ['drugbank.withdrawn']
#   Zileuton
#   Etoperidone
#   Flupentixol
#   Methapyrilene
#   Pergolide
# Result 165
# p_value: [1.3174174352601868e-17]
# properties: ['vasoconstrictor_agent']
#   6-(Tert-butyl)-3-(2-imidazolin-2-ylmethyl)-2,4-dimethylphenol, chloride
#   Zolmitriptan
#   Ergotamine
#   Norepinephrine
#   Levonordefrin
# Result 166
# p_value: [1.4350069055385912e-17]
# properties: ['Cytochrome P-450 CYP2C19 Inhibitors']
#   Nortriptyline
#   Midostaurin
#   Olanzapine
#   Bicalutamide
#   Troglitazone
# Result 167
# p_value: [2.4842463910248092e-17]
# properties: ['Sympathomimetics']
#   Celiprolol
#   Methamphetamine
#   Norepinephrine
#   Mephentermine
#   (-)-Norephedrine
# Result 168
# p_value: [2.701009177630742e-17]
# properties: ['EC_2.*_(transferase)_inhibitor']
#   Bosutinib
#   Palbociclib
#   Midostaurin
#   5-[(Z)-(5-Chloro-2-oxo-1,2-dihydro-3H-indol-3-ylidene)methyl]-N-[2-(diethylamino)ethyl]-2,4-dimethyl-1H-pyrrole-3-carboxamide
#   Linifanib
# Result 169
# p_value: [4.154398065214315e-17]
# properties: ['EC_2.7.*_(P_containing_group_transferase)_inhibitor']
#   Bosutinib
#   Palbociclib
#   Midostaurin
#   5-[(Z)-(5-Chloro-2-oxo-1,2-dihydro-3H-indol-3-ylidene)methyl]-N-[2-(diethylamino)ethyl]-2,4-dimethyl-1H-pyrrole-3-carboxamide
#   Linifanib
# Result 170
# p_value: [4.5802040556143397e-17, 3.331990117873207e-16]
# properties: ['membrane_transport_modulator', 'biophysical_role']
#   Nicorandil
#   Phenobarbital
#   2-Aminoethyl diphenylborinate
#   Otenzepad
#   Telenzepine
# Result 171
# p_value: [5.423401610985824e-17]
# properties: ['Cytochrome P-450 CYP2D6 Inhibitors (weak)']
#   Nortriptyline
#   Saquinavir
#   Nevirapine
#   Ziprasidone
#   Risperidone
# Result 172
# p_value: [9.339108799306711e-17]
# properties: ['antidyskinesia_agent']
#   Lisuride
#   Ropinirole
#   Cabergoline
#   Haloperidol
#   Diphenhydramine
# Result 173
# p_value: [1.3611508162330057e-16]
# properties: ['drugbank.nutraceutical']
#   Glutamic acid
#   Magnesium ion
#   Spermine
#   Tretinoin
#   d,l-Aspartic acid
# Result 174
# p_value: [1.5544798376810232e-16]
# properties: ['dopamine_agonist']
#   Cabergoline
#   Fenoldopam
#   Lisuride
#   Ropinirole
#   Carmoxirole
# Result 175
# p_value: [3.4428006343709865e-16]
# properties: ['Cytochrome P-450 CYP3A4 Substrates (strength unknown)']
#   Lorazepam
#   Chlorpromazine
#   Prochlorperazine
#   Ziprasidone
#   Dihydroergocristine
# Result 176
# p_value: [5.132064587669704e-16]
# properties: ['Alcohols']
#   Celiprolol
#   Chlorphenesin carbamate
#   Carvedilol
#   Sotalol
#   Norepinephrine
# Result 177
# p_value: [8.297087054857492e-16]
# properties: ['xenobiotic']
#   Dronedarone
#   Diclofenac
#   Trimipramine
#   Prometon
#   Sotalol
# Result 178
# p_value: [9.783706261081692e-16]
# properties: ['Antipsychotic Agents (First Generation [Typical])']
#   Prochlorperazine
#   Perphenazine
#   Chlorpromazine
#   Levomepromazine
#   Flupentixol
# Result 179
# p_value: [1.042591507585997e-15]
# properties: ['Cytochrome P-450 CYP1A2 Inhibitors']
#   Midostaurin
#   Propofol
#   Nevirapine
#   Dexmedetomidine
#   Pefloxacin
# Result 180
# p_value: [1.3073172046532392e-15]
# properties: ['Cytochrome P-450 CYP2E1 Inhibitors (strength unknown)']
#   Nortriptyline
#   Propofol
#   Chlorpromazine
#   Diclofenac
#   Metyrapone
# Result 181
# p_value: [1.43325069819958e-15]
# properties: ['Antidepressive Agents, Tricyclic']
#   Nortriptyline
#   Lofepramine
#   Desipramine
#   Trimipramine
#   Dosulepin
# Result 182
# p_value: [1.5864878277604178e-15]
# properties: ['Anticonvulsants']
#   Phenobarbital
#   Ethotoin
#   Lorazepam
#   Tizanidine
#   Flunarizine
# Result 183
# p_value: [1.5864878277604178e-15]
# properties: ['Histamine Agents']
#   Betahistine
#   Methapyrilene
#   Diphenhydramine
#   Flunarizine
#   Mirtazapine
# Result 184
# p_value: [2.3054499129400606e-15]
# properties: ['Cytochrome P-450 CYP2C8 Inhibitors']
#   Bosutinib
#   Midostaurin
#   Felodipine
#   Troglitazone
#   Nifedipine
# Result 185
# p_value: [2.3789385980313935e-15]
# properties: ['Cytochrome P-450 CYP3A4 Inhibitors (weak)']
#   Palbociclib
#   Propofol
#   Glyburide
#   Bicalutamide
#   Olanzapine
# Result 186
# p_value: [2.907991108087719e-15]
# properties: ['Cytochrome P-450 CYP2B6 Substrates with a Narrow Therapeutic Index']
#   Nortriptyline
#   Lofepramine
#   Desipramine
#   Trimipramine
#   Dosulepin
# Result 187
# p_value: [2.907991108087719e-15]
# properties: ['Ergolines']
#   Terguride
#   Lisuride
#   Cabergoline
#   Pergolide
#   Nicergoline
# Result 188
# p_value: [3.2161486358774293e-15]
# properties: ['non_narcotic_analgesic']
#   Clonidine
#   Dronabinol
#   Diclofenac
#   Flurbiprofen
#   Ergotamine
# Result 189
# p_value: [4.091557753322834e-15]
# properties: ['Toxic Actions']
#   Bisphenol A diglycidyl ether
#   Tinidazole
#   Cytarabine
#   Temephos
#   Nonoxynol-9
# Result 190
# p_value: [4.445018055398363e-15]
# properties: ['EC_3.4.*_(hydrolases_acting_on_peptide_bond)_inhibitor']
#   Prazosin
#   Mianserin
#   Enalaprilat
#   Chlorpromazine
#   Prochlorperazine
# Result 191
# p_value: [4.676660753365432e-15]
# properties: ['Antidepressive Agents, Tetracyclic']
#   Setiptiline
#   Maprotiline
#   Amoxapine
#   Mirtazapine
#   Mianserin
# Result 192
# p_value: [5.8898807391215174e-15, 6.977318708380898e-15]
# properties: ['Dietary Supplements', 'Supplements']
#   Pyridoxal phosphate
#   Glutamic acid
#   Spermine
#   Adenosine-5'-triphosphate
#   d,l-Aspartic acid
# Result 193
# p_value: [6.505804508310714e-15]
# properties: ['Cytochrome P-450 CYP3A4 Substrates with a Narrow Therapeutic Index']
#   Nortriptyline
#   Clonidine
#   Dronedarone
#   Ergotamine
#   Dasatinib
# Result 194
# p_value: [8.959962038941862e-15]
# properties: ['H1_receptor_antagonist']
#   Methapyrilene
#   Aripiprazole lauroxil
#   Diphenhydramine
#   Aripiprazole
#   Risperidone
# Result 195
# p_value: [9.43063714755368e-15]
# properties: ['Amino Acids, Peptides, and Proteins']
#   Enalaprilat
#   Glutamic acid
#   Dactinomycin
#   d,l-Aspartic acid
#   Pidotimod
# Result 196
# p_value: [9.688650363054584e-15]
# properties: ['Cytochrome P-450 CYP2B6 Inducers']
#   Nevirapine
#   Phenobarbital
#   Midostaurin
#   Troglitazone
#   Nifedipine
# Result 197
# p_value: [9.688650363054584e-15]
# properties: ['antiparkinson_drug']
#   Cabergoline
#   Lisuride
#   Ropinirole
#   Diphenhydramine
#   Apomorphine
# Result 198
# p_value: [1.0704159738230194e-14]
# properties: ['antirheumatic_drug']
#   Oxaprozin
#   Zileuton
#   Diclofenac
#   Flurbiprofen
#   Ampiroxicam
# Result 199
# p_value: [1.2668860592117919e-14]
# properties: ['Noxae']
#   Bisphenol A diglycidyl ether
#   Tinidazole
#   Cytarabine
#   Nonoxynol-9
#   Gemcitabine
# Result 200
# p_value: [1.8836353353386924e-14]
# properties: ['Serotonin 5-HT2 Receptor Agonists']
#   Cabergoline
#   Ergotamine
#   Cannabidiol
#   Pergolide
#   Lofexidine
# Result 201
# p_value: [2.8028309890908097e-14]
# properties: ['Central alpha-2 Adrenergic Agonist']
#   Dexmedetomidine
#   Clonidine
#   Guanfacine
#   Tizanidine
#   Methyldopa
# Result 202
# p_value: [2.8028309890908097e-14]
# properties: ['Imidazolines']
#   Clonidine
#   Lofexidine
#   Tizanidine
#   Tolazoline
#   Apraclonidine
# Result 203
# p_value: [3.188411521346494e-14]
# properties: ['Hormone Antagonists']
#   Cinacalcet
#   Zileuton
#   Bicalutamide
#   4-Hydroxytamoxifen
#   Relcovaptan
# Result 204
# p_value: [3.656391680618373e-14]
# properties: ['OCT2 Inhibitors']
#   Norepinephrine
#   Lamotrigine
#   Phenoxybenzamine
#   Desipramine
#   Dronedarone
# Result 205
# p_value: [4.183222763644125e-14]
# properties: ['antiemetic']
#   Prochlorperazine
#   Levosulpiride
#   Propofol
#   Perphenazine
#   Chlorpromazine
# Result 206
# p_value: [5.388414036826383e-14]
# properties: ['Cardiac Therapy']
#   Nicorandil
#   Dronedarone
#   Norepinephrine
#   Fenoldopam
#   Mephentermine
# Result 207
# p_value: [5.5606562385073177e-14]
# properties: ['anti_inflammatory_drug']
#   Oxaprozin
#   Zileuton
#   Zolmitriptan
#   Diclofenac
#   Flurbiprofen
# Result 208
# p_value: [5.565230179275093e-14]
# properties: ['Anti-Parkinson Drugs']
#   Rotigotine
#   Cabergoline
#   Lisuride
#   Ropinirole
#   Apomorphine
# Result 209
# p_value: [8.174909218552252e-14]
# properties: ['muscarinic_antagonist']
#   Pirenzepine
#   Flavoxate
#   Olanzapine
#   Diphenhydramine
#   Pizotifen
# Result 210
# p_value: [8.48387149463473e-14]
# properties: ['EC_1.*_(oxidoreductase)_inhibitor']
#   Cinacalcet
#   Zileuton
#   Diclofenac
#   Flurbiprofen
#   (2S)-2-Azaniumyl-3-phosphonooxypropanoate
# Result 211
# p_value: [9.798842170334811e-14]
# properties: ['Ergot-derivative Dopamine Receptor Agonists']
#   Lisuride
#   Dihydroergocornine
#   Cabergoline
#   Pergolide
#   Bromocriptine
# Result 212
# p_value: [2.326487605866843e-13, 2.4173663420681795e-13, 4.911771168806796e-12]
# properties: ['Bronsted_acid', 'acid', 'donor']
#   3-Oxalomalic acid
#   Tropisetron
#   Flurbiprofen
#   Tretinoin
#   Thiorphan
# Result 213
# p_value: [2.487525180503559e-13]
# properties: ['sedative']
#   Phenobarbital
#   Dexmedetomidine
#   Propofol
#   Etomidate
#   Dexmedetomidine hydrochloride
# Result 214
# p_value: [2.6100769846614507e-13]
# properties: ['Tricyclics and Other Norepinephrine-reuptake Inhibitors']
#   Nortriptyline
#   Desipramine
#   Maprotiline
#   Trimipramine
#   Amitriptyline
# Result 215
# p_value: [3.0679959286941856e-13]
# properties: ['BCRP/ABCG2 Substrates']
#   Irinotecan
#   Palbociclib
#   Etoposide
#   Prazosin
#   Methotrexate
# Result 216
# p_value: [3.7115696717832783e-13]
# properties: ['Biogenic Amines']
#   Norepinephrine
#   Levonordefrin
#   (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate
#   Spermine
#   Zolmitriptan
# Result 217
# p_value: [3.9926024591176166e-13]
# properties: ['eukaryotic_metabolite']
#   Menthol
#   Linalool
#   Ellipticine
#   Glycochenodeoxycholic acid
#   Tretinoin
# Result 218
# p_value: [4.754131956639997e-13]
# properties: ['Anti-Inflammatory Agents']
#   Oxaprozin
#   Zileuton
#   Cortisone
#   Diclofenac
#   Flurbiprofen
# Result 219
# p_value: [5.131729959578968e-13]
# properties: ['OCT1 inhibitors']
#   Nevirapine
#   Palbociclib
#   Prazosin
#   Phenoxybenzamine
#   Desipramine
# Result 220
# p_value: [5.575668995937911e-13]
# properties: ['Hypnotics and Sedatives']
#   Phenobarbital
#   Dexmedetomidine
#   Propofol
#   Etomidate
#   Lorazepam
# Result 221
# p_value: [5.866048813346989e-13]
# properties: ['Nasal Decongestants']
#   Cirazoline
#   (-)-Norephedrine
#   Oxymetazoline
#   Xylometazoline
#   Tetrahydrozoline
# Result 222
# p_value: [5.866048813346989e-13]
# properties: ['nasal_decongestant']
#   Levonordefrin
#   6-(Tert-butyl)-3-(2-imidazolin-2-ylmethyl)-2,4-dimethylphenol, chloride
#   Oxymetazoline
#   Tetrahydrozoline hydrochloride
#   Tetrahydrozoline
# Result 223
# p_value: [8.121424426818401e-13]
# properties: ['Highest Risk QTc-Prolonging Agents']
#   Ziprasidone
#   Paliperidone
#   Dronedarone
#   Flupentixol
#   Sotalol
# Result 224
# p_value: [8.345307852575325e-13]
# properties: ['Catecholamines']
#   Norepinephrine
#   Levonordefrin
#   (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate
#   Methyldopa
#   Debrisoquine
# Result 225
# p_value: [8.349439390886571e-13]
# properties: ['protein_kinase_inhibitor']
#   Bosutinib
#   Palbociclib
#   Midostaurin
#   5-[(Z)-(5-Chloro-2-oxo-1,2-dihydro-3H-indol-3-ylidene)methyl]-N-[2-(diethylamino)ethyl]-2,4-dimethyl-1H-pyrrole-3-carboxamide
#   Linifanib
# Result 226
# p_value: [9.402368952977632e-13]
# properties: ['Nucleic Acid Synthesis Inhibitors']
#   Nevirapine
#   Cytarabine
#   Gemcitabine
#   Capecitabine
#   Dactinomycin
# Result 227
# p_value: [1.1180562774131842e-12]
# properties: ['Compounds used in a research, industrial, or household setting']
#   Amonafide
#   Flumazenil
#   Carvedilol
#   Glycochenodeoxycholic acid
#   INDIGOTINDISULFONATE
# Result 228
# p_value: [1.2257962707536523e-12]
# properties: ['Carbohydrates']
#   Etoposide
#   Miglitol
#   Neomycin
#   Adenosine-5'-triphosphate
#   Epirubicin
# Result 229
# p_value: [1.2488818255787747e-12]
# properties: ['sympathomimetic_agent']
#   Norepinephrine
#   Oxymetazoline
#   6-(Tert-butyl)-3-(2-imidazolin-2-ylmethyl)-2,4-dimethylphenol, chloride
#   [2-[3,4-Bis(2,2-dimethylpropanoyloxy)phenyl]-2-hydroxyethyl]-methylazanium;chloride
#   Tetrahydrozoline hydrochloride
# Result 230
# p_value: [1.4937049346424517e-12]
# properties: ['Hormones, Hormone Substitutes, and Hormone Antagonists']
#   Cinacalcet
#   Zileuton
#   Cortisone
#   Dronabinol
#   4-Hydroxytamoxifen
# Result 231
# p_value: [1.828973534780004e-12]
# properties: ['BSEP/ABCB11 Inhibitors']
#   Glyburide
#   Chlorpromazine
#   Troglitazone
#   Glycochenodeoxycholic acid
#   Clofazimine
# Result 232
# p_value: [1.828973534780004e-12]
# properties: ['Peripheral Vasodilators']
#   Moxisylyte
#   Dihydroergocristine
#   Phenoxybenzamine
#   3-[(4,5-Dihydro-1H-imidazol-3-ium-2-ylmethyl)(4-methylphenyl)amino]phenolate
#   Nicergoline
# Result 233
# p_value: [1.8723778448003816e-12]
# properties: ['Calcium-Regulating Hormones and Agents']
#   Cinacalcet
#   Lamotrigine
#   Nifedipine
#   Carvedilol
#   Felodipine
# Result 234
# p_value: [2.3250898324087817e-12]
# properties: ['adrenergic_uptake_inhibitor']
#   Nortriptyline
#   Tramadol
#   Desipramine
#   Amitriptyline
#   Amoxapine
# Result 235
# p_value: [2.448161513809727e-12]
# properties: ['Amino Alcohols']
#   Celiprolol
#   Norepinephrine
#   Levonordefrin
#   (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate
#   Carvedilol
# Result 236
# p_value: [2.4724349033378307e-12]
# properties: ['Lipids']
#   Oxaprozin
#   Latanoprost
#   Flurbiprofen
#   Prostaglandin B2
#   Linoleic acid
# Result 237
# p_value: [2.649005547091012e-12]
# properties: ['Terpenes']
#   Cannabidiol
#   Dronabinol
#   l-Menthol
#   Artemether
#   Acitretin
# Result 238
# p_value: [2.864053550201949e-12]
# properties: ['OATP1B1/SLCO1B1 Inhibitors']
#   Irinotecan
#   Dronedarone
#   Troglitazone
#   Diclofenac
#   Nifedipine
# Result 239
# p_value: [2.9282413958291438e-12]
# properties: ['Anti-Dyskinesia Agents']
#   Lisuride
#   (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate
#   Ropinirole
#   Cabergoline
#   Haloperidol
# Result 240
# p_value: [3.026848125032574e-12]
# properties: ['non_steroidal_anti_inflammatory_drug']
#   Oxaprozin
#   Zileuton
#   Diclofenac
#   Flurbiprofen
#   Ampiroxicam
# Result 241
# p_value: [3.9424955528776184e-12]
# properties: ['Protein Kinase Inhibitors']
#   Bosutinib
#   Palbociclib
#   Midostaurin
#   Pimasertib
#   1-(3-Chlorophenyl)-3-{5-[2-(Thieno[3,2-D]pyrimidin-4-Ylamino)ethyl]-1,3-Thiazol-2-Yl}urea
# Result 242
# p_value: [4.152621969359911e-12]
# properties: ['Amino Acids']
#   Glutamic acid
#   Glycochenodeoxycholic acid
#   d,l-Aspartic acid
#   Pidotimod
#   L-Cysteine
# Result 243
# p_value: [4.528272562715943e-12]
# properties: ['Antiglaucoma Preparations and Miotics']
#   Latanoprost
#   Clonidine
#   2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate
#   Brimonidine
#   Carteolol
# Result 244
# p_value: [4.528272562715943e-12]
# properties: ['Cardiotoxic antineoplastic agents']
#   Cytarabine
#   Etoposide
#   Capecitabine
#   Tretinoin
#   Epirubicin
# Result 245
# p_value: [5.3583019052412314e-12]
# properties: ['Fatty Acids']
#   Oxaprozin
#   Latanoprost
#   Flurbiprofen
#   Prostaglandin B2
#   Linoleic acid
# Result 246
# p_value: [5.561312437833749e-12]
# properties: ['Cytochrome P-450 CYP2C19 inhibitors (strength unknown)']
#   Bicalutamide
#   Troglitazone
#   Oxcarbazepine
#   Paroxetine
#   Dosulepin
# Result 247
# p_value: [6.796000414151375e-12]
# properties: ['Cardiac Stimulants Excl. Cardiac Glycosides']
#   Norepinephrine
#   Fenoldopam
#   Mephentermine
#   (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate
#   Milrinone
# Result 248
# p_value: [7.825777842019367e-12]
# properties: ['anti_inflammatory_agent']
#   Oxaprozin
#   Zileuton
#   Zolmitriptan
#   Diclofenac
#   Flurbiprofen
# Result 249
# p_value: [9.691890967659783e-12]
# properties: ['Pyrimidines']
#   Cytarabine
#   Phenobarbital
#   Gemcitabine
#   Risperidone
#   Paliperidone
# Result 250
# p_value: [9.936613638988055e-12]
# properties: ['Antiemetics']
#   Prochlorperazine
#   Lorazepam
#   Chlorpromazine
#   Olanzapine
#   Haloperidol
# Result 251
# p_value: [1.0533159684342038e-11]
# properties: ['Glycosides']
#   Etoposide
#   Neomycin
#   Adenosine-5'-triphosphate
#   Epirubicin
#   Cytarabine
# Result 252
# p_value: [1.191013554449564e-11]
# properties: ['Catechols']
#   Norepinephrine
#   Levonordefrin
#   2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate
#   (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate
#   Amphetamine
# Result 253
# p_value: [1.2581010028525031e-11]
# properties: ['Cytochrome P-450 CYP2C8 Substrates']
#   Torsemide
#   Propofol
#   Perphenazine
#   Troglitazone
#   Diclofenac
# Result 254
# p_value: [1.7221949098027524e-11]
# properties: ['Diazepines, Oxazepines, Thiazepines and Oxepines']
#   Quetiapine
#   Loxapine
#   Olanzapine
#   Clozapine
# Result 255
# p_value: [1.7221949098027524e-11]
# properties: ['Ergotamines']
#   Dihydroergocornine
#   Dihydroergocristine
#   Ergotamine
#   Bromocriptine
# Result 256
# p_value: [1.7221949098027524e-11, 7.194067409275216e-10]
# properties: ['Imidazoline Receptor Agonists', 'Antiadrenergic Agents, Centrally Acting']
#   Moxonidine
#   Clonidine
#   Rilmenidine
#   Guanfacine
# Result 257
# p_value: [1.7221949098027524e-11]
# properties: ['Sympathomimetics in Glaucoma Therapy']
#   Clonidine
#   2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate
#   Brimonidine
#   Apraclonidine
# Result 258
# p_value: [1.8940119703081428e-11]
# properties: ['Anesthetics']
#   Alfaxalone
#   Dexmedetomidine
#   Propofol
#   Clonidine
#   Etomidate
# Result 259
# p_value: [1.9880726426718214e-11]
# properties: ['Biogenic Monoamines']
#   Norepinephrine
#   Levonordefrin
#   (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate
#   Zolmitriptan
#   Amphetamine
# Result 260
# p_value: [2.0175626554316857e-11]
# properties: ['Antimigraine Preparations']
#   Clonidine
#   Lisuride
#   Zolmitriptan
#   Ergotamine
#   Pizotifen
# Result 261
# p_value: [2.0175626554316857e-11]
# properties: ['Cytochrome P-450 CYP1A2 Substrates with a Narrow Therapeutic Index']
#   Nortriptyline
#   Clonidine
#   Desipramine
#   Amitriptyline
#   Tizanidine
# Result 262
# p_value: [2.067426868210838e-11]
# properties: ['Antirheumatic Agents']
#   Oxaprozin
#   Nabumetone
#   Levamisole
#   Methotrexate
#   Diclofenac
# Result 263
# p_value: [2.2776616152072224e-11]
# properties: ['Cytochrome P-450 CYP1A2 Inhibitors (strength unknown)']
#   Dexmedetomidine
#   Propofol
#   Pefloxacin
#   Nifedipine
#   Paroxetine
# Result 264
# p_value: [2.542712768600279e-11, 5.0360105864344503e-11]
# properties: ['GABA_modulator', 'GABA_agent']
#   Phenobarbital
#   Otenzepad
#   Flumazenil
#   Telenzepine
#   Lorazepam
# Result 265
# p_value: [2.8549904576314786e-11]
# properties: ['Antidepressive Agents, Second-Generation']
#   Mianserin
#   Maprotiline
#   Paroxetine
#   Escitalopram
#   Tryptophan
# Result 266
# p_value: [2.8549904576314786e-11]
# properties: ['UGT1A4 substrates']
#   Lamotrigine
#   Troglitazone
#   Olanzapine
#   Amitriptyline
#   Clozapine
# Result 267
# p_value: [3.1854240507432483e-11]
# properties: ['Nasal Preparations']
#   Neomycin
#   (-)-Norephedrine
#   Oxymetazoline
#   Xylometazoline
#   Tetrahydrozoline
# Result 268
# p_value: [3.9814968126152205e-11]
# properties: ['pro_agent']
#   Latanoprost
#   Aripiprazole lauroxil
#   Ampiroxicam
#   Irinotecan
#   Nabumetone
# Result 269
# p_value: [4.92881369191318e-11]
# properties: ['UGT2B7 substrates']
#   Mycophenolic acid
#   Troglitazone
#   Diclofenac
#   Flurbiprofen
#   Carvedilol
# Result 270
# p_value: [5.160979067168377e-11]
# properties: ['Prolactine Inhibitors']
#   Terguride
#   Lisuride
#   Cabergoline
#   Bromocriptine
# Result 271
# p_value: [5.350479741027068e-11]
# properties: ['anticonvulsant']
#   Phenobarbital
#   Ethotoin
#   Propofol
#   Lamotrigine
#   Oxcarbazepine
# Result 272
# p_value: [5.35277926425161e-11]
# properties: ['sympatholytic_agent']
#   Clonidine
#   Debrisoquine
#   ergoloid mesylate
#   Carteolol
#   Methyldopa
# Result 273
# p_value: [5.6502010699526516e-11]
# properties: ['Acids, Carbocyclic']
#   Mocetinostat
#   Diclofenac
#   Axitinib
#   Tiapride
#   Trimebutine
# Result 274
# p_value: [5.661576869536126e-11]
# properties: ['Cytochrome P-450 CYP3A5 Inhibitors']
#   Dronedarone
#   Troglitazone
#   Oxcarbazepine
#   Cannabidiol
#   Saquinavir
# Result 275
# p_value: [5.890167796513771e-11]
# properties: ['aetiopathogenetic_role']
#   Phenobarbital
#   Copper
#   Diclofenac
#   Neomycin
#   Methapyrilene
# Result 276
# p_value: [7.321909605405593e-11]
# properties: ['Agents Causing Muscle Toxicity']
#   Cytarabine
#   Propofol
#   (3-Azaniumyl-1-hydroxy-1-phosphonopropyl)-hydroxyphosphinate
#   Saquinavir
#   Fenofibrate
# Result 277
# p_value: [7.400102256669513e-11]
# properties: ['Benzazepines']
#   Pirenzepine
#   Flumazenil
#   Fenoldopam
#   Lorazepam
#   Olanzapine
# Result 278
# p_value: [8.422917439949045e-11]
# properties: ['P-glycoprotein inducers']
#   Phenobarbital
#   Oxcarbazepine
#   Nifedipine
#   Saquinavir
#   Spironolactone
# Result 279
# p_value: [1.2029219363635503e-10]
# properties: ['Anti-Parkinson Agents (Dopamine Agonist)']
#   Apomorphine
#   Rotigotine
#   Ropinirole
#   Bromocriptine
# Result 280
# p_value: [1.3764168002062654e-10]
# properties: ['Cytochrome P-450 CYP2D6 Inhibitors (moderate)']
#   Desipramine
#   Chlorpromazine
#   Dronedarone
#   Dosulepin
#   Clotrimazole
# Result 281
# p_value: [1.3826687021834626e-10]
# properties: ['EC_1.14.*_(oxidoreductase_acting_on_paired_donors__with_incorporation_or_reduction_of_molecular_oxygen)_inhibitor']
#   Cinacalcet
#   Diclofenac
#   Flurbiprofen
#   Ampiroxicam
#   Nabumetone
# Result 282
# p_value: [1.7643847182900115e-10]
# properties: ['Dermatologicals']
#   Neomycin
#   Brimonidine
#   Diclofenac
#   Diphenhydramine
#   Tretinoin
# Result 283
# p_value: [1.9398980957683446e-10]
# properties: ['Ethylamines']
#   Methamphetamine
#   Phenoxybenzamine
#   Mephentermine
#   Diclofenac
#   Diphenhydramine
# Result 284
# p_value: [2.403233796688207e-10]
# properties: ['Adrenergic beta-3 Receptor Agonists']
#   Celiprolol
#   Norepinephrine
#   (2S,3R)-2-Azaniumyl-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoate
# ...
#   Loxapine
#   Amoxapine
# Result 426
# p_value: [1.863905485478658e-06]
# properties: ['Dimethylamines']
#   Moxisylyte
#   Tramadol
# Result 427
# p_value: [1.863905485478658e-06]
# properties: ['EC_3.1.4.12_(sphingomyelin_phosphodiesterase)_inhibitor']
#   5-[(Z)-(5-Chloro-2-oxo-1,2-dihydro-3H-indol-3-ylidene)methyl]-N-[2-(diethylamino)ethyl]-2,4-dimethyl-1H-pyrrole-3-carboxamide
#   Desipramine
# Result 428
# p_value: [1.863905485478658e-06]
# properties: ['Imidazoline Derivatives']
#   Tolazoline
#   3-[(4,5-Dihydro-1H-imidazol-3-ium-2-ylmethyl)(4-methylphenyl)amino]phenolate
# Result 429
# p_value: [1.863905485478658e-06]
# properties: ['calcimimetic']
#   Cinacalcet
#   Cinacalcet hydrochloride
# Result 430
# p_value: [2.0392166269700936e-06]
# properties: ['Benzodiazepinones']
#   Lorazepam
#   Pirenzepine
#   Flumazenil
# Result 431
# p_value: [2.0392166269700936e-06]
# properties: ['Phenylacetates']
#   Piperidolate
#   Guanfacine
#   Diclofenac
# Result 432
# p_value: [2.1851201139814648e-06]
# properties: ['Piperidines']
#   Amonafide
#   Paroxetine
#   Miglitol
#   (3R)-1-[4,4-Bis(3-methylthiophen-2-yl)but-3-enyl]piperidin-1-ium-3-carboxylate
# Result 433
# p_value: [2.2002344371455033e-06, 2.3498486296556116e-06]
# properties: ['EC_1.14.99.1_(prostaglandin_endoperoxide_synthase)_inhibitor', 'EC_1.14.99.*_(miscellaneous_oxidoreductase_acting_on_paired_donors__with_incorporation_or_reduction_of_molecular_oxygen)_inhibitor']
#   Nabumetone
#   Diclofenac
#   Flurbiprofen
#   Salicin
#   Ampiroxicam
# Result 434
# p_value: [2.2231873935399226e-06]
# properties: ['plant_metabolite']
#   Menthol
#   Linalool
#   6-Benzylaminopurine
#   Ellipticine
#   (2S,6S,7S,9R,11R,12R,15R,16R)-6-Hydroxy-15-[1-[(2S)-5-(hydroxymethyl)-4-methyl-6-oxo-2,3-dihydropyran-2-yl]ethyl]-2,16-dimethyl-8-oxapentacyclo[9.7.0.02,7.07,9.012,16]octadec-4-en-3-one
# Result 435
# p_value: [2.4191042784216063e-06]
# properties: ['phenothiazine_antipsychotic_drug']
#   Perphenazine
#   Chlorpromazine
#   Levomepromazine
# Result 436
# p_value: [3.3135822671560803e-06]
# properties: ['Antibiotics, Antineoplastic']
#   Mycophenolic acid
#   Dactinomycin
#   Epirubicin
# Result 437
# p_value: [3.3135822671560803e-06, 1.3428106251605668e-05]
# properties: ['Cytochrome P-450 CYP3A7 Inhibitors (strength unknown)', 'Cytochrome P-450 CYP3A7 Inhibitors']
#   Cannabidiol
#   Saquinavir
#   Troglitazone
# Result 438
# p_value: [3.3135822671560803e-06]
# properties: ['Indole Alkaloids']
#   Yohimbine
#   Midostaurin
#   Staurosporine
# Result 439
# p_value: [3.3135822671560803e-06]
# properties: ['Urological Agents']
#   Yohimbine
#   Papaverine
#   Flavoxate
# Result 440
# p_value: [3.4404662774373615e-06, 3.4404662774373615e-06]
# properties: ['food_component', 'physiological_role']
#   INDIGOTINDISULFONATE
#   Pyridoxal phosphate
#   Glutamic acid
#   Copper
#   Adenosine-5'-triphosphate
# Result 441
# p_value: [3.880580815701413e-06, 6.394981133530117e-06]
# properties: ['Benzopyrans', 'Pyrans']
#   Flavoxate
#   Isoquercitrin
#   Troglitazone
#   Taxifolin
# Result 442
# p_value: [4.5394012626011815e-06]
# properties: ['anti_allergic_agent']
#   Methapyrilene
#   Diphenhydramine
#   Tranilast
#   Carbinoxamine
# Result 443
# p_value: [5.0272421038113244e-06, 1.1085469575697202e-05]
# properties: ['Cytochrome P-450 CYP1A2 Inducers (strength unknown)', 'Cytochrome P-450 CYP1A2 Inducers']
#   Phenobarbital
#   Midostaurin
#   Menadione
# Result 444
# p_value: [5.0272421038113244e-06]
# properties: ['OCT2 Substrates']
#   Norepinephrine
#   Prazosin
#   2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate
# Result 445
# p_value: [5.1265028087326835e-06]
# properties: ['volatile_oil_component']
#   Menthol
#   Linalool
#   (+)-Menthol
#   Geraniol
#   l-Menthol
# Result 446
# p_value: [5.542103440476287e-06]
# properties: ['Sulfonamides']
#   Torsemide
#   Bendroflumethiazide
#   Hydroflumethiazide
#   Benzthiazide
# Result 447
# p_value: [5.58664138025281e-06, 6.667559204301312e-05]
# properties: ['Basic Lotions and Liniments', 'Antipruritics and Local Anesthetics']
#   l-Menthol
#   D-Camphor
# Result 448
# p_value: [5.58664138025281e-06, 1.8588355766065373e-05]
# properties: ['EC_4.6.1.2_(guanylate_cyclase)_inhibitor', 'EC_4.6.*_(P_O_lyase)_inhibitor']
#   6-Anilino-5,8-quinolinedione
#   1h-[1,2,4]Oxadiazolo[4,3-a]quinoxalin-1-one
# Result 449
# p_value: [5.58664138025281e-06, 2.7857235773705394e-05, 5.190587230545986e-05]
# properties: ['Nitroimidazole Antimicrobial', 'Nitroimidazoles', 'Nitroimidazole Derivatives']
#   Secnidazole
#   Tinidazole
# Result 450
# p_value: [5.58664138025281e-06]
# properties: ['Sympatholytic (Adrenergic Blocking) Agents']
#   Ergotamine
#   3-[(4,5-Dihydro-1H-imidazol-3-ium-2-ylmethyl)(4-methylphenyl)amino]phenolate
# Result 451
# p_value: [6.444782097344706e-06]
# properties: ['Sodium Channel Blockers']
#   Ethotoin
#   Lamotrigine
#   Oxcarbazepine
# Result 452
# p_value: [6.879847262740153e-06, 1.0726034286824755e-05]
# properties: ['micronutrient', 'nutrient']
#   Pyridoxal phosphate
#   Glutamic acid
#   Copper
#   Adenosine-5'-triphosphate
#   Tryptophan
# Result 453
# p_value: [7.014963551441872e-06]
# properties: ['Hematologic Agents']
#   Relcovaptan
#   Milrinone
#   Tranilast
#   Menadione
# Result 454
# p_value: [7.243001973673417e-06]
# properties: ['UGT1A1 Inhibitors']
#   Flurbiprofen
#   Propofol
#   Amitriptyline
# Result 455
# p_value: [8.026656702802581e-06]
# properties: ['central_nervous_system_stimulant']
#   Methamphetamine
#   (-)-Norephedrine
#   Mephentermine
#   9-Chloro-2-(2-furyl)-(1,2,4)triazolo(1,5-c)quinazolin-5-imine
# Result 456
# p_value: [9.029777516546992e-06]
# properties: ['Cytochrome P-450 CYP2C19 Inducers']
#   Phenobarbital
#   Artemether
#   Midostaurin
# Result 457
# p_value: [9.914759225024748e-06]
# properties: ['receptor_modulator']
#   Olmesartan
#   Zileuton
#   Tomelukast
#   Tretinoin
#   Spironolactone
# Result 458
# p_value: [9.946588241811431e-06]
# properties: ['Antiprotozoals']
#   Artemether
#   Secnidazole
#   Tinidazole
#   Anisomycin
# Result 459
# p_value: [1.0022878628471491e-05]
# properties: ['Phenyl Ethers']
#   Trimebutine
#   Proparacaine
#   Fenofibrate
# Result 460
# p_value: [1.0367831729882269e-05]
# properties: ['Antiparasitic Products, Insecticides and Repellents']
#   Artemether
#   Levamisole
#   Secnidazole
#   Tinidazole
# Result 461
# p_value: [1.1085469575697202e-05]
# properties: ['Topical Products for Joint and Muscular Pain']
#   Flurbiprofen
#   Tolazoline
#   Diclofenac
# Result 462
# p_value: [1.1163142939563512e-05]
# properties: ['Adrenergic alpha-2 Receptor Antagonists']
#   Yohimbine
#   Mirtazapine
# Result 463
# p_value: [1.1163142939563512e-05]
# properties: ['Alpha-and Beta-adrenergic Agonists']
#   Norepinephrine
#   2-Hydroxy-4-[(1R)-1-hydroxy-2-(methylazaniumyl)ethyl]phenolate
# Result 464
# p_value: [1.1163142939563512e-05]
# properties: ['Antivertigo Preparations']
#   Betahistine
#   Flunarizine
# Result 465
# p_value: [1.1163142939563512e-05]
# properties: ['Caproates']
#   Mycophenolic acid
#   L-Norleucine
# Result 466
# p_value: [1.1163142939563512e-05]
# properties: ['Cytochrome P-450 CYP2A6 Inhibitors (weak)']
#   Fenofibrate
#   Amphetamine
# Result 467
# p_value: [1.1163142939563512e-05]
# properties: ['Flavonols']
#   Isoquercitrin
#   Taxifolin
# Result 468
# p_value: [1.1163142939563512e-05]
# properties: ['Miscellaneous Antidepressants']
#   Mirtazapine
#   Tryptophan
# Result 469
# p_value: [1.1163142939563512e-05]
# properties: ['Receptor Tyrosine Kinase Inhibitors']
#   Midostaurin
#   Axitinib
# Result 470
# p_value: [1.1163142939563512e-05]
# properties: ['UGT1A1 substrates with narrow therapeutic index']
#   Mycophenolic acid
#   Amitriptyline
# Result 471
# p_value: [1.1163142939563512e-05]
# properties: ['dopamine_receptor_D2_antagonist']
#   Prochlorperazine
#   Yohimbine
# Result 472
# p_value: [1.1163142939563512e-05]
# properties: ['potassium_channel_opener']
#   Nicorandil
#   2-Aminoethyl diphenylborinate
# Result 473
# p_value: [1.182209130825463e-05]
# properties: ['fundamental_metabolite']
#   2-Ammonio-3-sulfanylpropanoate
#   Glutamic acid
#   Spermine
#   Adenosine-5'-triphosphate
#   d,l-Aspartic acid
# Result 474
# p_value: [1.221979906401131e-05]
# properties: ['GABA Modulators']
#   Phenobarbital
#   Lorazepam
#   Flumazenil
# Result 475
# p_value: [1.221979906401131e-05]
# properties: ['OATP1B3 substrates']
#   4-Chlorophenol
#   Olmesartan
#   Methotrexate
# Result 476
# p_value: [1.3428106251605668e-05]
# properties: ['antitussive']
#   l-Menthol
#   Tramadol
#   Diphenhydramine
# Result 477
# p_value: [1.3428106251605668e-05]
# properties: ['cannabinoid_receptor_agonist']
#   Cannabidiol
#   Anandamide
#   Dronabinol
# Result 478
# p_value: [1.47126207805007e-05, 3.006578674360485e-05]
# properties: ['Flavonoids', 'Chromones']
#   Flavoxate
#   Isoquercitrin
#   Taxifolin
# Result 479
# p_value: [1.7120609100678974e-05, 8.425012215632114e-05]
# properties: ['platelet_aggregation_inhibitor', 'hematologic_agent']
#   Cytochalasin B
#   Milrinone
#   Troglitazone
#   Carmoxirole
# Result 480
# p_value: [1.7747480871121498e-05, 1.839105423576191e-05, 1.839105423576191e-05]
# properties: ['Electrolytes', 'Anions', 'Ions']
#   Nicorandil
#   Artemether
#   Calcium phosphate
#   Calcium hydrogen phosphate dihydrate
# Result 481
# p_value: [1.8588355766065373e-05, 8.32689051707503e-05]
# properties: ['Calcium Compounds', 'Phosphate salts']
#   Calcium phosphate
#   Calcium hydrogen phosphate dihydrate
# Result 482
# p_value: [1.8588355766065373e-05]
# properties: ['Cyclohexanols']
#   l-Menthol
#   Tramadol
# Result 483
# p_value: [1.8588355766065373e-05]
# properties: ['Cytochrome P-450 CYP2B6 Inducers (strong)']
#   Nevirapine
#   Phenobarbital
# Result 484
# p_value: [1.8588355766065373e-05]
# properties: ['Cytochrome P-450 CYP3A7 Inducers (strength unknown)']
#   Phenobarbital
#   Midostaurin
# Result 485
# p_value: [1.8588355766065373e-05]
# properties: ['Glutamates']
#   Pidotimod
#   Glutamic acid
# Result 486
# p_value: [1.904556222149244e-05]
# properties: ['excitatory_amino_acid_antagonist']
#   Phenobarbital
#   Lamotrigine
#   Tramadol
# Result 487
# p_value: [1.904556222149244e-05]
# properties: ['reproductive_control_drug']
#   Nonoxynol-9
#   Methotrexate
#   Nifedipine
# Result 488
# p_value: [2.2355676618545286e-05]
# properties: ['Anti-Allergic Agents']
#   Methapyrilene
#   Diphenhydramine
#   Tranilast
# Result 489
# p_value: [2.2355676618545286e-05]
# properties: ['Topoisomerase II Inhibitors']
#   Etoposide
#   Pefloxacin
#   Epirubicin
# Result 490
# p_value: [2.2355676618545286e-05]
# properties: ['protein_synthesis_inhibitor']
#   Anisomycin
#   Omacetaxine mepesuccinate
#   Clarithromycin
# Result 491
# p_value: [2.4143726985247476e-05]
# properties: ['Drugs Used in Diabetes']
#   Glyburide
#   Miglitol
#   Troglitazone
# Result 492
# p_value: [2.7857235773705394e-05, 5.190587230545986e-05]
# properties: ['Beta blocking agents and calcium channel blockers', 'Calcium Channel Blockers (Dihydropyridine)']
#   Felodipine
#   Nifedipine
# Result 493
# p_value: [2.7857235773705394e-05]
# properties: ['Excitatory Amino Acids']
#   d,l-Aspartic acid
#   Glutamic acid
# Result 494
# p_value: [2.7996632364038304e-05]
# properties: ['Cytochrome P-450 CYP3A5 Inducers (strength unknown)']
#   Midostaurin
#   Cortisone
#   Oxcarbazepine
# Result 495
# p_value: [2.7996632364038304e-05]
# properties: ['Systemic Hormonal Preparations, Excl. Sex Hormones and Insulins']
#   Cinacalcet
#   Cortisone
#   Etelcalcetide
# Result 496
# p_value: [3.006578674360485e-05]
# properties: ['Hydroxybenzoates']
#   Trimebutine
#   Proparacaine
#   Mesalamine
# Result 497
# p_value: [3.686965810757866e-05]
# properties: ['Amino Acids, Cyclic']
#   Tryptophan
#   Pidotimod
#   Methyldopa
# Result 498
# p_value: [3.8964749136373196e-05]
# properties: ['Cannabinoids and similars']
#   Cannabidiol
#   Dronabinol
# Result 499
# p_value: [3.8964749136373196e-05]
# properties: ['Enzyme Inducing Antiepileptic Drugs']
#   Phenobarbital
#   Oxcarbazepine
# Result 500
# p_value: [3.8964749136373196e-05]
# properties: ['Guanidine Derivatives']
#   Debrisoquine
#   Bethanidine
# Result 501
# p_value: [3.8964749136373196e-05]
# properties: ['Increased Sympathetic Activity']
#   Methamphetamine
#   Oxymetazoline
# Result 502
# p_value: [3.8964749136373196e-05]
# properties: ['Phenothiazines With Aliphatic Side-Chain']
#   Chlorpromazine
#   Levomepromazine
# Result 503
# p_value: [3.8964749136373196e-05]
# properties: ['Topoisomerase I Inhibitors']
#   7-Ethyl-10-hydroxycamptothecin
#   Irinotecan
# Result 504
# p_value: [4.7411895122957104e-05]
# properties: ['Pyrimidinones']
#   Phenobarbital
#   Risperidone
#   Capecitabine
# Result 505
# p_value: [5.032395952705738e-05]
# properties: ['Pharmaceutical Preparations']
#   Irinotecan
#   D-Camphor
#   Tetrahydrozoline
# Result 506
# p_value: [5.190587230545986e-05]
# properties: ['Aminoalkyl Ethers']
#   Diphenhydramine
#   Carbinoxamine
# Result 507
# p_value: [5.190587230545986e-05]
# properties: ['Benzofurans']
#   Dronedarone
#   Escitalopram
# Result 508
# p_value: [5.190587230545986e-05]
# properties: ['Central Nervous System Stimulation']
#   Methamphetamine
#   Amphetamine
# Result 509
# p_value: [5.190587230545986e-05]
# properties: ['EENT Drugs, Miscellaneous']
#   l-Menthol
#   Apraclonidine
# Result 510
# p_value: [5.190587230545986e-05]
# properties: ['Hydroxybenzoate Ethers']
#   Trimebutine
#   Proparacaine
# Result 511
# p_value: [5.190587230545986e-05]
# properties: ['Synthetic Anticholinergics, Esters With Tertiary Amino Group']
#   Trimebutine
#   Piperidolate
# Result 512
# p_value: [5.190587230545986e-05]
# properties: ['capsaicin_receptor_antagonist']
#   Tramadol
#   Capsazepine
# Result 513
# p_value: [5.5553043591931105e-05]
# properties: ['Escherichia_coli_metabolite']
#   Glutamic acid
#   Copper
#   Neomycin
#   d,l-Aspartic acid
#   (2S)-2-Azaniumyl-3-phosphonooxypropanoate
# Result 514
# p_value: [5.975680165924407e-05, 8.609120159875914e-05]
# properties: ['anti_asthmatic_drug', 'anti_asthmatic_agent']
#   Zileuton
#   Tomelukast
#   Tranilast
# Result 515
# p_value: [6.279365989106662e-05]
# properties: ['EC_2.7.11.*_(protein_serine/threonine_kinase)_inhibitor']
#   Palbociclib
#   Midostaurin
#   Selumetinib
#   Staurosporine
# Result 516
# p_value: [6.314011364235992e-05]
# properties: ['Cytochrome P-450 CYP2B6 Inhibitors']
#   Paroxetine
#   Desipramine
#   Clotrimazole
# Result 517
# p_value: [6.667559204301312e-05]
# properties: ['Aminopyridines']
#   Methapyrilene
#   Milrinone
# Result 518
# p_value: [6.667559204301312e-05]
# properties: ['Benzothiadiazines']
#   Bendroflumethiazide
#   Hydroflumethiazide
# Result 519
# p_value: [6.667559204301312e-05]
# properties: ['Cytochrome P-450 CYP3A5 Inhibitors (strong)']
#   Saquinavir
#   Clarithromycin
# Result 520
# p_value: [6.667559204301312e-05]
# properties: ['GABA_antagonist']
#   Flumazenil
#   Clozapine
# Result 521
# p_value: [6.667559204301312e-05]
# properties: ['leukotriene_antagonist']
#   Zileuton
#   Tomelukast
# Result 522
# p_value: [7.027745697541228e-05]
# properties: ['Pigments, Biological']
#   Acitretin
#   Tretinoin
#   Methotrexate
# Result 523
# p_value: [7.117911097570087e-05]
# properties: ['Protective Agents']
#   Probucol
#   Flumazenil
#   Milrinone
#   Carvedilol
# Result 524
# p_value: [8.021692554457876e-05]
# properties: ['antibacterial_drug']
#   Pefloxacin
#   Neomycin
#   Clofazimine
#   Tinidazole
#   Clarithromycin
# Result 525
# p_value: [8.194040037483656e-05]
# properties: ['EC_2.7.10.*_(protein_tyrosine_kinase)_inhibitor']
#   5-[(Z)-(5-Chloro-2-oxo-1,2-dihydro-3H-indol-3-ylidene)methyl]-N-[2-(diethylamino)ethyl]-2,4-dimethyl-1H-pyrrole-3-carboxamide
#   Linifanib
#   1-(Tert-butyl)-3-(4-chlorophenyl)-1H-pyrazolo[3,4-d]pyrimidin-4-amine
# Result 526
# p_value: [8.32689051707503e-05]
# properties: ['Adrenergic beta-1 Receptor Antagonists']
#   Celiprolol
#   Carvedilol
# Result 527
# p_value: [8.32689051707503e-05]
# properties: ['Miscellaneous Central Nervous System Agents']
#   Betahistine
#   Flumazenil
# Result 528
# p_value: [8.32689051707503e-05]
# properties: ['Phenothiazines With Piperazine Structure']
#   Prochlorperazine
#   Perphenazine
# Result 529
# p_value: [8.32689051707503e-05]
# properties: ['adenosine_receptor_antagonist']
#   Reversine
#   9-Chloro-2-(2-furyl)-(1,2,4)triazolo(1,5-c)quinazolin-5-imine
# Result 530
# p_value: [8.609120159875914e-05]
# properties: ['Cytochrome P-450 CYP2C8 Inhibitors (strength unknown)']
#   Bosutinib
#   Midostaurin
#   Nifedipine
# Result 531
# p_value: [9.037687539319815e-05]
# properties: ['Antihistamines for Systemic Use']
#   Methapyrilene
#   Diphenhydramine
#   Carbinoxamine
# Result 532
# p_value: [9.936069045592694e-05]
# properties: ['Drugs for Functional Gastrointestinal Disorders']
#   Trimebutine
#   Papaverine
#   Piperidolate
# Result 533
# p_value: [9.936069045592694e-05]
# properties: ['antipyretic']
#   Flurbiprofen
#   Salicin
#   Diclofenac
