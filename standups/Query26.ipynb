# %% [markdown]
# # Setup

# %%
import json
import requests
from datetime import datetime as dt
from collections import defaultdict
import pandas as pd
import copy

# %%
#https://pypi.org/project/gamma-viewer/
from gamma_viewer import GammaViewer
from IPython.display import display, Markdown

# %%
def printjson(j):
    print(json.dumps(j,indent=4))
def print_json(j):
    printjson(j)

# %%
def post(name,url,message,params=None):
    if params is None:
        response = requests.post(url,json=message)
    else:
        response = requests.post(url,json=message,params=params)
    if not response.status_code == 200:
        print(name, 'error:',response.status_code)
        print(response.json())
        return {}
    return response.json()

def automat(db,message):
    automat_url = f'https://automat.renci.org/{db}/query'
    response = requests.post(automat_url,json=message)
    print(response.status_code)
    return response.json()

def strider(message):
    url = 'https://strider.renci.org/1.1/query'
    strider_answer = post(strider,url,message)
    return strider_answer

def aragorn(message, coalesce_type='xnone'):
    if coalesce_type == 'xnone':
        answer = post('aragorn','https://aragorn.renci.org/1.1/query',message)
    else:
        answer = post('aragorn','https://aragorn.renci.org/1.1/query',message, params={'answer_coalesce_type':coalesce_type})
    return answer

##

def bte(message):
    url = 'https://api.bte.ncats.io/v1/query'
    return post(strider,url,message)

def coalesce(message,method='all'):
    url = 'https://answercoalesce.renci.org/coalesce/graph'
    return post('AC'+method,url,message)

def striderandfriends(message):
    strider_answer = strider(message)    
    coalesced_answer = post('coalesce','https://answercoalesce.renci.org/coalesce/all',strider_answer)
    omni_answer = post('omnicorp','https://aragorn-ranker.renci.org/omnicorp_overlay',coalesced_answer)
    weighted_answer = post('weight','https://aragorn-ranker.renci.org/weight_correctness',omni_answer)
    scored_answer = post('score','https://aragorn-ranker.renci.org/score',weighted_answer)
    return strider_answer,coalesced_answer,omni_answer,weighted_answer,scored_answer

# %%
def print_errors(strider_result):
    errorcounts = defaultdict(int)
    for logmessage in strider_result['logs']:
        if logmessage['level'] == 'ERROR':
            #jm = json.loads(logmessage['message'])
            #words = jm['error'].split()
            #e = " ".join(words[:-5])            
            e = logmessage['error']
            errorcounts[e] += 1
    for error,count in errorcounts.items():
        print(f'{error} ({count} times)')
        
def print_queried_sources(strider_result):
    querycounts = defaultdict(int)
    for logmessage in strider_result['logs']:
        if 'step' in logmessage and isinstance(logmessage['step'],list):
            for s in logmessage['step']:
                querycounts[s['url']] += 1
    for url,count in querycounts.items():
        print(f'{url} ({count} times)')
        
def print_query_for_source(strider_result,url):
    for logmessage in strider_result['logs']:
        if 'step' in logmessage and isinstance(logmessage['step'],list):
            for s in logmessage['step']:
                if s['url']==url:
                    print(s)

# %%
def retrieve_ars_results(mid):
    ars='https://ars-dev.transltr.io'
    message_url = f'{ars}/ars/api/messages/{mid}?trace=y'
    response = requests.get(message_url)
    j = response.json()
    results = {}
    for child in j['children']:
        if child['actor']['agent'] in ['ara-aragorn', 'ara-aragorn-exp']:
            childmessage_id = child['message']
            child_url = f'{ars}/ars/api/messages/{childmessage_id}'
            child_response = requests.get(child_url).json()
            try:
                nresults = len(child_response['fields']['data']['message']['results'])
                if nresults > 0:
                    results[child['actor']['agent']] = {'message':child_response['fields']['data']['message']}
            except:
                nresults=0
            print( child['status'], child['actor']['agent'],nresults )
    return results

# %%
def get_provenance(message):
    """Given a message with results, find the source of the edges"""
    prov = defaultdict(lambda: defaultdict(int)) # {qedge->{source->count}}
    results = message['message']['results']
    kg = message['message']['knowledge_graph']['edges']
    edge_bindings = [ r['edge_bindings'] for r in results ]
    for bindings in edge_bindings:
        for qg_e, kg_l in bindings.items():
            for kg_e in kg_l:
                for att in kg[kg_e['id']]['attributes']:
                    if att['attribute_type_id'] == 'MetaInformation:Provenance':
                        source = att['value']
                        prov[qg_e][source]+=1
    qg_edges = []
    sources = []
    counts = []
    for qg_e in prov:
        for source in prov[qg_e]:
            qg_edges.append(qg_e)
            sources.append(source)
            counts.append(prov[qg_e][source])
    prov_table = pd.DataFrame({"QG Edge":qg_edges, "Source":sources, "Count":counts})
    return prov_table

# %%
def ac_to_table(aragorn_result,mnode):
    #scores = []
    answer_node_count = []
    merged_count = []
    method = []
    extra = []
    for res_i, result in enumerate(aragorn_result['message']['results']):
        #scores.append(result['score'])
        answer_node_count.append(len(result['node_bindings']))
        merged_count.append(len(result['node_bindings'][mnode]))
        try:
            method.append(result['node_bindings'][mnode][0]['coalescence_method'])
        except:
            method.append('Original')
    df = pd.DataFrame({'N_Answer_Nodes':answer_node_count, 'N_Merged_Nodes':merged_count, 'Method':method})
    return df

def filter_to_simple(aragorn_result,mnode):
    simple_result = copy.deepcopy(aragorn_result)
    simple_result['message']['results'] = list(
    filter( lambda x: 'coalescence_method' not in x['node_bindings'][mnode][0], 
           aragorn_result['message']['results'])
    )
    print(len(simple_result['message']['results']))
    return simple_result

def print_nodenames(simple_result,qnode):
    #Print the names of the answers
    for result in simple_result['message']['results']:
        #Each answer has an identifier:
        n1_id = result['node_bindings'][qnode][0]['id']
        #The information for that identifier is in the KG:
        node = simple_result['message']['knowledge_graph']['nodes'][n1_id]
        #Each node has a name
        print(node['name'])

def filter_to_coal(aragorn_result,mnode,method):
    #The results that have been coalesced:
    coalesced_results = list(
        filter( lambda x: 'coalescence_method'  in x['node_bindings'][mnode][0], 
               aragorn_result['message']['results'])
    )
    #Those that have been coalesced via a new node (graph coalescence)
    graph_coalesced_results = list(
        filter( lambda x: x['node_bindings'][mnode][0]['coalescence_method'] == method, coalesced_results)
    )
    print(len(graph_coalesced_results))
    simple_result = copy.deepcopy(aragorn_result)
    simple_result['message']['results'] = graph_coalesced_results
    return simple_result

def filter_to_gc(aragorn_result,mnode):
    return filter_to_coal(aragorn_result,mnode,'graph_enrichment')

def filter_to_pc(aragorn_result,mnode):
    return filter_to_coal(aragorn_result,mnode,'property_enrichment')

def print_gc_result(graph,gc_result,node):
    print('p_value:', gc_result['node_bindings'][node][0]['p_value'])
    maxprint=5
    for extra_edge in gc_result['edge_bindings']:
        if not extra_edge.startswith('extra_'):
            continue
        numnodes = len(gc_result['edge_bindings'][extra_edge])
        if numnodes == 0:
            printjson(gc_result)
            return
        print ('Merged',numnodes)
        nprint = min([numnodes,maxprint])
        for eb in gc_result['edge_bindings'][extra_edge][:maxprint]:        
            kge = graph['edges'][eb['id']]
            subject_node = kge['subject']
            object_node = kge['object']
            pred = kge['predicate']
            print( f"  {graph['nodes'][subject_node]['name']} -[{pred}]-> {graph['nodes'][object_node]['name']}")
    print('----')
    
def print_pc_result(knowledge_graph,pc_result,node):
    print('p_value:', pc_result['node_bindings'][node][0]['p_values'])
    print('properties:', pc_result['node_bindings'][node][0]['properties'])
    numnodes = len(pc_result['node_bindings'][node])
    print('node count',numnodes)
    maxprint=5
    nprint = min([numnodes,maxprint])
    for node in pc_result['node_bindings'][node][:nprint]:
        kgn = knowledge_graph['nodes'][node['id']]
        print( f"  {kgn['name']}")
    if numnodes > maxprint:
        print('  ...')
    print('----')

# %% [markdown]
# ## Query Specific

# %%
standup_json='StandupDefinitions/standup_26.json'

# %%
with open(standup_json,'r') as jsonfile:
    standup_info = json.load(jsonfile)

# %%
display(Markdown(f"# {standup_info['Query Title']}"))
display(Markdown(f"{standup_info['Query Description']}"))
print(f'Github Issue: {standup_info["github_issue"]}')
# Out:
# # 25. 2 hop
# Disease Sleep Apnea (MONDO:0005296) - Gene - ChemicalSubstance Valproic acid (PUBCHEM.COMPOUND:3121)
# Github Issue: https://github.com/NCATSTranslator/testing/issues/81

# %% [markdown]
# The query as run through the ARS:

# %%
query = json.loads(requests.get(standup_info['query_location']).content)
printjson(query)
# Out:
# {
#     "message": {
#         "query_graph": {
#             "nodes": {
#                 "n0": {
#                     "ids": [
#                         "MONDO:0005296"
#                     ],
#                     "categories": [
#                         "biolink:Disease"
#                     ]
#                 },
#                 "n1": {
#                     "categories": [
#                         "biolink:Gene"
#                     ]
#                 },
#                 "n2": {
#                     "ids": [
#                         "PUBCHEM.COMPOUND:3121"
#                     ],
#                     "categories": [
#                         "biolink:ChemicalSubstance"
#                     ]
#                 }
#             },
#             "edges": {
#                 "e0": {
#                     "subject": "n0",
#                     "object": "n1"
#                 },
#                 "e1": {
#                     "subject": "n1",
#                     "object": "n2"
#                 }
#             }
#         }
#     }
# }

# %% [markdown]
# ## ARS Assessment

# %%
ARS_Responses = [(dt.strptime(x['ARS_result_date'],'%Y-%m-%d'),x['ARS_result_id']) for x in standup_info['ARS_Results']]
ARS_Responses.sort()

# %%
for ars_date, ars_id in ARS_Responses:
    display(Markdown(f'### {ars_date}'))
    _ = retrieve_ars_results(ars_id)
    print(f'https://arax.ncats.io/?source=ARS&id={ars_id}')
# Out:
# ### 2021-06-24 00:00:00
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-18-0443eb881d0c> in <module>
#       1 for ars_date, ars_id in ARS_Responses:
#       2     display(Markdown(f'### {ars_date}'))
# ----> 3     _ = retrieve_ars_results(ars_id)
#       4     print(f'https://arax.ncats.io/?source=ARS&id={ars_id}')
#
# <ipython-input-6-6468a0479dc2> in retrieve_ars_results(mid)
#       3     message_url = f'{ars}/ars/api/messages/{mid}?trace=y'
#       4     response = requests.get(message_url)
# ----> 5     j = response.json()
#       6     results = {}
#       7     for child in j['children']:
#
# /opt/anaconda3/envs/minihackathons/lib/python3.9/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# /opt/anaconda3/envs/minihackathons/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /opt/anaconda3/envs/minihackathons/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/anaconda3/envs/minihackathons/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Strider Direct

# %%
query['log_level']='DEBUG'
start = dt.now()
strider_result = strider(query)
end = dt.now()
print(f"Strider produced {len(strider_result['message']['results'])} results in {end-start}.")
# Out:
# Strider produced 0 results in 0:04:22.810492.

# %% [markdown]
# ### Provenance

# %%
prov = get_provenance(strider_result)
display(prov)
# Out:
# Empty DataFrame
# Columns: [QG Edge, Source, Count]
# Index: []

# %% [markdown]
# ### Queried sources

# %%
print_queried_sources(strider_result)
# Out:
# https://automat.renci.org/covidkopkg/1.1/query (83 times)
# https://automat.renci.org/cord19-scibite/1.1/query (2 times)
# https://automat.renci.org/cord19-scigraph/1.1/query (4 times)
# https://automat.renci.org/robokopkg/1.1/query (82 times)
# https://automat.renci.org/mychem/1.1/query (14 times)
# https://automat.renci.org/chembio/1.1/query (1 times)
# https://automat.renci.org/pharos/1.1/query (7 times)
# https://automat.renci.org/hmdb/1.1/query (2 times)
# https://automat.renci.org/ctd/1.1/query (75 times)
# https://translator.broadinstitute.org/molepro/trapi/v1.1/query (8 times)
# https://cam-kp-api-dev.renci.org/query (27 times)
# https://spokekp.healthdatascience.cloud/api/v1.1//query (2 times)
# https://arax.ncats.io/api/rtxkg2/v1.1/query (87 times)
# https://automat.renci.org/kegg/1.1/query (2 times)
# https://automat.renci.org/gtopdb/1.1/query (1 times)

# %%
levs=[ l['level'] for l in strider_result['logs']]

# %%
n = defaultdict(int)
for l in levs:
    n[l] += 1
for l,c in n.items():
    print(l,c)
# Out:
# ERROR 62
# DEBUG 11
# INFO 5

# %% [markdown]
# ### Errors

# %%
print_errors(strider_result)
# Out:
# 504 Server Error: Gateway Time-out for url: https://automat.renci.org/robokopkg/1.1/query
# For more information check: https://httpstatuses.com/504 (830 times)
# 400 Client Error: Bad Request for url: https://cam-kp-api-dev.renci.org/query
# For more information check: https://httpstatuses.com/400 (162 times)

# %% [markdown]
# ### Results

# %%
view = GammaViewer(props={"data":strider_result})
display(view)

# %% [markdown]
# ### Strider Assessment

# %% [markdown]
# Enter Assessment Here

# %%
hop1 = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids": [
                        "MONDO:0005296"
                    ],
                    "categories": [
                        "biolink:Disease"
                    ]
                },
                "n1": {
                    "categories": [
                        "biolink:Gene"
                    ]
                }
            },
            "edges": {
                "e0": {
                    "subject": "n0",
                    "object": "n1"
                }
            }
        }
    }
}

# %%
query['log_level']='DEBUG'
start = dt.now()
strider_result = strider(hop1)
end = dt.now()
print(f"Strider produced {len(strider_result['message']['results'])} results in {end-start}.")
# Out:
# Strider produced 88 results in 0:00:07.139656.

# %%
view = GammaViewer(props={"data":strider_result})
display(view)

# %%
hop2 = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids": [
                        "PUBCHEM.COMPOUND:3121"
                    ],
                    "categories": [
                        "biolink:ChemicalSubstance"
                    ]
                },
                "n1": {
                    "categories": [
                        "biolink:Gene"
                    ]
                }
            },
            "edges": {
                "e0": {
                    "subject": "n0",
                    "object": "n1"
                }
            }
        }
    }
}
query['log_level']='DEBUG'
start = dt.now()
strider_result2 = strider(hop2)
end = dt.now()
print(f"Strider produced {len(strider_result2['message']['results'])} results in {end-start}.")
# Out:
# Strider produced 5625 results in 0:01:54.517449.

# %%
names = [ v['name'] for v in strider_result2['message']['knowledge_graph']['nodes'].values()]

# %%
'FGFR3' in names
# Out:
# True

# %%
'BCHE' in names
# Out:
# True

# %%
'GNE' in names
# Out:
# True

# %%
hop1keys = set( strider_result['message']['knowledge_graph']['nodes'].keys() )
hop2keys = set( strider_result2['message']['knowledge_graph']['nodes'].keys() )

# %%
hop1keys.intersection(hop2keys)
# Out:
# {'NCBIGene:10020',
#  'NCBIGene:1026',
#  'NCBIGene:1028',
#  'NCBIGene:10628',
#  'NCBIGene:169026',
#  'NCBIGene:2026',
#  'NCBIGene:2261',
#  'NCBIGene:336',
#  'NCBIGene:4280',
#  'NCBIGene:429',
#  'NCBIGene:5054',
#  'NCBIGene:5660',
#  'NCBIGene:590',
#  'NCBIGene:5979',
#  'NCBIGene:6281',
#  'NCBIGene:64324',
#  'NCBIGene:6647',
#  'NCBIGene:6651',
#  'NCBIGene:6714',
#  'NCBIGene:7099',
#  'NCBIGene:7422',
#  'NCBIGene:761',
#  'NCBIGene:8863'}

# %% [markdown]
# ## ARAGORN

# %%
start = dt.now()
aragorn_result = aragorn(query)
end = dt.now()
if 'results' in aragorn_result['message']:
    print(f"ARAGORN produced {len(aragorn_result['message']['results'])} results in {end-start}.")
else:
    print('Error, no result field')
# Out:
# ARAGORN produced 4 results in 0:01:31.725570.

# %%
view = GammaViewer(props={"data":aragorn_result})
display(view)

# %%
node='n0' #this might need to change based on the query
property_answers = filter_to_pc(aragorn_result,node)
for pc_result in property_answers['message']['results']:
    print_pc_result(aragorn_result['message']['knowledge_graph'],pc_result,node)
# Out:
# 72
# p_value: [5.515487725071365e-06]
# properties: ['molecule_type:Small molecule']
# node count 41
#   Progesterone
#   2-[(4-Benzyltriazol-1-yl)methyl]phenol
#   2-Hydroxy-N-(4-methyl-2-nitrophenyl)benzamide
#   (2-Hydroxyphenyl)(5-methyl-1H-benzotriazole-1-yl) ketone
#   (2-Hydroxyphenyl)(5-chloro-1H-benzotriazole-1-yl) ketone
#   ...
# ----
# p_value: [7.280805894138608e-21]
# properties: ['drugbank.approved']
# node count 10
#   Enflurane
#   Cromolyn
#   Potassium ion
#   Miconazole
#   Hydroflumethiazide
#   ...
# ----
# p_value: [6.562508889245017e-13]
# properties: ['application']
# node count 9
#   Enflurane
#   Cromolyn
#   Hydroflumethiazide
#   Hydron;2,2,2-trifluoroacetate
#   Bendroflumethiazide
#   ...
# ----
# p_value: [6.897912892096567e-07]
# properties: ['biological_role']
# node count 8
#   ferroheme b
#   Carbon monoxide
#   Hydrochlorothiazide
#   Cromolyn
#   Potassium ion
#   ...
# ----
# p_value: [9.721386753620717e-15]
# properties: ['therapeutic_flag']
# node count 8
#   Enflurane
#   Bendroflumethiazide
#   Hydrochlorothiazide
#   Cromolyn
#   Chlorzoxazone
#   ...
# ----
# p_value: [2.2949756493814526e-12, 2.57007352781012e-12]
# properties: ['drug', 'pharmaceutical']
# node count 8
#   Enflurane
#   Bendroflumethiazide
#   Carbon monoxide
#   Hydrochlorothiazide
#   Cromolyn
#   ...
# ----
# p_value: [4.973953814826612e-09, 3.253952725359222e-08]
# properties: ['drugbank.approved', 'therapeutic_flag']
# node count 7
#   Progesterone
#   Hydrochlorothiazide
#   Cromolyn
#   Miconazole
#   Halothane
#   ...
# ----
# p_value: [3.158203894386266e-06, 3.466396107623068e-06, 4.081957952521912e-05]
# properties: ['drug', 'pharmaceutical', 'application']
# node count 7
#   Progesterone
#   Hydrochlorothiazide
#   Cromolyn
#   Toluene
#   Halothane
#   ...
# ----
# p_value: [1.538133315810867e-08, 4.684195150955309e-08, 1.6819428445002239e-07, 3.852266794909273e-07, 3.02193770834427e-06, 3.1540408286920396e-06, 9.98531972766535e-06]
# properties: ['Heterocyclic Compounds, Fused-Ring', 'oral', 'drugbank.approved', 'therapeutic_flag', 'drug', 'pharmaceutical', 'application']
# node count 3
#   Chlorzoxazone
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [1.6819428445002239e-07, 3.852266794909273e-07]
# properties: ['drugbank.approved', 'therapeutic_flag']
# node count 3
#   Miconazole
#   Hydrochlorothiazide
#   Cromolyn
# ----
# p_value: [3.96302115595274e-13, 3.6613538394777114e-12]
# properties: ['Heterocyclic Compounds, Fused-Ring', 'oral']
# node count 6
#   Bendroflumethiazide
#   Hydrochlorothiazide
#   Cromolyn
#   Chlorzoxazone
#   Diazoxide
#   ...
# ----
# p_value: [2.490151067292366e-10, 2.7117059602636154e-10, 2.6869366083974615e-09, 1.1060722067763238e-06, 3.520009055952577e-06]
# properties: ['drug', 'pharmaceutical', 'application', 'biochemical_role', 'biological_role']
# node count 6
#   Norepinephrine
#   Phloretin
#   Paclitaxel
#   Topotecan
#   Acetylcholine
#   ...
# ----
# p_value: [2.038488866386128e-12]
# properties: ['drugbank.vet_approved']
# node count 6
#   Progesterone
#   Hydrochlorothiazide
#   Toluene
#   Miconazole
#   Halothane
#   ...
# ----
# p_value: [1.3408947255340005e-09]
# properties: ['drugbank.investigational']
# node count 5
#   Enflurane
#   Carbon monoxide
#   Potassium ion
#   Miconazole
#   Hydroflumethiazide
# ----
# p_value: [2.1746369139580313e-07]
# properties: ['therapeutic_flag']
# node count 5
#   Bendroflumethiazide
#   Hydroflumethiazide
#   Chlorzoxazone
#   Estradiol
#   Flindokalner
# ----
# p_value: [1.0168800665649664e-16]
# properties: ['Diuretics']
# node count 5
#   Bendroflumethiazide
#   Hydrochlorothiazide
#   Potassium ion
#   Diazoxide
#   Hydroflumethiazide
# ----
# p_value: [1.0441608595853187e-15, 5.1436023587168934e-14]
# properties: ['Gynecological Antiinfectives and Antiseptics', 'Genito Urinary System and Sex Hormones']
# node count 5
#   Bendroflumethiazide
#   Hydrochlorothiazide
#   Miconazole
#   Diazoxide
#   Hydroflumethiazide
# ----
# p_value: [1.9858405319919156e-12]
# properties: ['cardiovascular_drug']
# node count 5
#   Bendroflumethiazide
#   Carbon monoxide
#   Hydrochlorothiazide
#   Diazoxide
#   Hydroflumethiazide
# ----
# p_value: [1.3676499293256683e-06, 2.205127538596047e-05]
# properties: ['eukaryotic_metabolite', 'metabolite']
# node count 5
#   Norepinephrine
#   Phloretin
#   Paclitaxel
#   Acetylcholine
#   CID 22326046
# ----
# p_value: [2.6762786740295016e-07, 1.810176012338286e-06, 2.673904838489784e-06, 2.7649814005418537e-05]
# properties: ['human_metabolite', 'mammalian_metabolite', 'animal_metabolite', 'eukaryotic_metabolite']
# node count 5
#   ferroheme b
#   Carbon monoxide
#   Potassium ion
#   Calcium ion
#   Hydron;2,2,2-trifluoroacetate
# ----
# p_value: [5.5748029044531066e-08]
# properties: ['drugbank.approved']
# node count 5
#   Bendroflumethiazide
#   Chlorzoxazone
#   Estradiol
#   Hydroflumethiazide
#   Ethanol
# ----
# p_value: [2.8240650513686877e-10, 1.1195507566393842e-09]
# properties: ['drugbank.approved', 'therapeutic_flag']
# node count 5
#   Norepinephrine
#   Paclitaxel
#   Topotecan
#   Acetylcholine
#   CID 22326046
# ----
# p_value: [1.7981725149422116e-07, 8.406044111949419e-07, 2.0245310787121444e-06]
# properties: ['Gynecological Antiinfectives and Antiseptics', 'Genito Urinary System and Sex Hormones', 'drugbank.vet_approved']
# node count 2
#   Miconazole
#   Hydrochlorothiazide
# ----
# p_value: [1.8542887608806634e-05, 3.891719344771636e-05]
# properties: ['Heterocyclic Compounds, Fused-Ring', 'oral']
# node count 2
#   Hydrochlorothiazide
#   Cromolyn
# ----
# p_value: [6.259263695051877e-07]
# properties: ['oral']
# node count 4
#   Chlorzoxazone
#   Bendroflumethiazide
#   Estradiol
#   Hydroflumethiazide
# ----
# p_value: [2.14979244212456e-07]
# properties: ['topical']
# node count 4
#   Halothane
#   Progesterone
#   Miconazole
#   Cromolyn
# ----
# p_value: [1.1289412528027133e-06, 1.3114105643615957e-06, 3.9058926802677605e-06]
# properties: ['Cytochrome P-450 CYP3A4 Substrates', 'Cytochrome P-450 CYP3A Substrates', 'Cytochrome P-450 Substrates']
# node count 4
#   Progesterone
#   Miconazole
#   Halothane
#   Pergolide
# ----
# p_value: [9.341621926301377e-17, 3.6697196637091085e-16, 6.094701060557387e-14, 1.2950041737483324e-12, 8.937840438173137e-12, 1.993525689311319e-11, 2.1476823734682156e-11, 5.382799399706657e-11, 4.126950707055083e-10, 6.035274321508555e-10, 2.4231691283760683e-09]
# properties: ['Benzothiadiazines', 'Thiazides', 'diuretic', 'Sulfonamides', 'Sulfones', 'Hypotensive Agents', 'Antihypertensive Agents', 'antihypertensive_agent', 'Amides', 'Cardiovascular Agents', 'Sulfur Compounds']
# node count 4
#   Bendroflumethiazide
#   Diazoxide
#   Hydrochlorothiazide
#   Hydroflumethiazide
# ----
# p_value: [9.765897592910908e-08, 1.2899484903029827e-06, 6.02427022862859e-06, 8.25637389853852e-06]
# properties: ['pharmacological_role', 'human_metabolite', 'mammalian_metabolite', 'animal_metabolite']
# node count 4
#   CID 22326046
#   Acetylcholine
#   Norepinephrine
#   Paclitaxel
# ----
# p_value: [1.0287425003131642e-08]
# properties: ['Genito Urinary System and Sex Hormones']
# node count 4
#   Progesterone
#   Hydrochlorothiazide
#   Miconazole
#   Dequalinium
# ----
# p_value: [4.787102115230931e-06]
# properties: ['Heterocyclic Compounds, Fused-Ring']
# node count 4
#   Hydrochlorothiazide
#   Cromolyn
#   Pergolide
#   Dequalinium
# ----
# p_value: [2.0403006695158507e-05]
# properties: ['oral']
# node count 4
#   Progesterone
#   Hydrochlorothiazide
#   Cromolyn
#   Pergolide
# ----
# p_value: [1.833866515298574e-08, 4.4062988701304977e-07, 1.3789890843106206e-06, 2.0245310787121444e-06, 3.858378348558863e-06]
# properties: ['Antidiarrheals, Intestinal Antiinflammatory/antiinfective Agents', 'Sensory Organs', 'Dermatologicals', 'Alimentary Tract and Metabolism', 'topical']
# node count 2
#   Miconazole
#   Cromolyn
# ----
# p_value: [1.4198210164880847e-09, 2.6029918491330954e-09, 2.6029918491330954e-09, 3.5889613377891098e-09, 2.9223150662589873e-08, 3.730750911147743e-08, 7.2167820056376e-08, 1.3096214565466716e-07, 1.7981725149422116e-07, 3.40921990632363e-07, 4.952722010973931e-07, 5.078484306901876e-07, 5.270083315029566e-07, 8.324840533458494e-07, 8.406044111949419e-07, 2.298446107288386e-06, 2.7787386302036648e-06, 3.601319091793038e-06, 5.565687897605218e-06]
# properties: ['Benzothiadiazines', 'Increased Diuresis', 'Thiazides', 'Sodium Chloride Symporter Inhibitors', 'diuretic', 'Natriuretic Agents', 'Diuretics', 'Sulfonamides', 'Gynecological Antiinfectives and Antiseptics', 'Sulfones', 'Membrane Transport Modulators', 'Hypotensive Agents', 'Antihypertensive Agents', 'antihypertensive_agent', 'Genito Urinary System and Sex Hormones', 'Amides', 'Cardiovascular Agents', 'cardiovascular_drug', 'Sulfur Compounds']
# node count 2
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [5.296181119535818e-05]
# properties: ['therapeutic_flag']
# node count 2
#   Estradiol
#   Flindokalner
# ----
# p_value: [8.855274550283674e-08, 2.5855689099621977e-06, 4.854644479101057e-06, 5.435863503893832e-06, 1.2402289710247026e-05]
# properties: ['Cytochrome P-450 CYP1A2 Substrates', 'Cytochrome P-450 Enzyme Inhibitors', 'Cytochrome P-450 CYP3A4 Substrates', 'Cytochrome P-450 CYP3A Substrates', 'Cytochrome P-450 Substrates']
# node count 3
#   Chlorzoxazone
#   Estradiol
#   Ethanol
# ----
# p_value: [6.084513997099509e-05]
# properties: ['therapeutic_flag']
# node count 3
#   Estradiol
#   Diazoxide
#   Flindokalner
# ----
# p_value: [5.162863158278855e-07]
# properties: ['parenteral']
# node count 3
#   Topotecan
#   Norepinephrine
#   Paclitaxel
# ----
# p_value: [3.842299802637642e-06]
# properties: ['antineoplastic_agent']
# node count 3
#   Topotecan
#   Phloretin
#   Paclitaxel
# ----
# p_value: [1.4186282967954475e-07]
# properties: ['Genito Urinary System and Sex Hormones']
# node count 3
#   Bendroflumethiazide
#   Estradiol
#   Hydroflumethiazide
# ----
# p_value: [1.446716752427261e-05]
# properties: ['Heterocyclic Compounds, Fused-Ring']
# node count 3
#   Chlorzoxazone
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [5.728694474392006e-09]
# properties: ['Hyperglycemia-Associated Agents']
# node count 3
#   Bendroflumethiazide
#   Diazoxide
#   Hydrochlorothiazide
# ----
# p_value: [3.6995275426024607e-06]
# properties: ['Cytochrome P-450 Substrates']
# node count 3
#   Enflurane
#   Chlorzoxazone
#   Miconazole
# ----
# p_value: [1.8994907900566742e-07]
# properties: ['Gynecological Antiinfectives and Antiseptics']
# node count 3
#   Miconazole
#   Hydrochlorothiazide
#   Dequalinium
# ----
# p_value: [4.022876292634458e-06]
# properties: ['Dermatologicals']
# node count 3
#   Miconazole
#   Cromolyn
#   Dequalinium
# ----
# p_value: [4.397018366044429e-06, 3.4431142254581205e-05]
# properties: ['Cytochrome P-450 CYP3A Inhibitors', 'Cytochrome P-450 Enzyme Inhibitors']
# node count 3
#   Progesterone
#   Miconazole
#   Pergolide
# ----
# p_value: [6.361273105724518e-12, 1.0524610728756563e-11, 3.8271306752799074e-10, 1.895379942640866e-08]
# properties: ['Increased Diuresis', 'Sodium Chloride Symporter Inhibitors', 'Natriuretic Agents', 'Membrane Transport Modulators']
# node count 3
#   Bendroflumethiazide
#   Hydrochlorothiazide
#   Hydroflumethiazide
# ----
# p_value: [1.5697662313508262e-07]
# properties: ['drugbank.vet_approved']
# node count 3
#   Enflurane
#   Miconazole
#   Hydrochlorothiazide
# ----
# p_value: [4.1270025802707294e-07]
# properties: ['topical']
# node count 3
#   Enflurane
#   Miconazole
#   Cromolyn
# ----
# p_value: [1.1627335870232626e-06]
# properties: ['cofactor']
# node count 3
#   ferroheme b
#   Calcium ion
#   Potassium ion
# ----
# p_value: [9.68697276701708e-07, 2.2109740054334953e-05]
# properties: ['neurotransmitter_agent', 'mouse_metabolite']
# node count 3
#   Acetylcholine
#   Norepinephrine
#   CID 22326046
# ----
# p_value: [2.4351066401073697e-05, 3.764901972849685e-05, 4.1852137584677285e-05, 6.244195812591984e-05]
# properties: ['Cytochrome P-450 CYP3A4 Inducers (strength unknown)', 'Cytochrome P-450 CYP3A4 Inducers', 'Cytochrome P-450 CYP3A Inducers', 'Cytochrome P-450 Enzyme Inducers']
# node count 2
#   Estradiol
#   Ethanol
# ----
# p_value: [5.2857988866740214e-05]
# properties: ['Cytochrome P-450 CYP2D6 Inhibitors (strength unknown)']
# node count 2
#   Miconazole
#   Pergolide
# ----
# p_value: [4.107346998840335e-06, 3.587605029124872e-05]
# properties: ['Sensory Organs', 'topical']
# node count 2
#   Acetylcholine
#   CID 22326046
# ----
# p_value: [1.8844175810311423e-05]
# properties: ['drugbank.vet_approved']
# node count 2
#   CID 22326046
#   Paclitaxel
# ----
# p_value: [8.365105233103283e-05]
# properties: ['human_xenobiotic_metabolite']
# node count 2
#   Norepinephrine
#   CID 22326046
# ----
# p_value: [2.222817084379647e-06, 3.972395869662428e-06, 6.891532696963129e-05, 8.281206421710943e-05, 8.648392202542116e-05]
# properties: ['Cytochrome P-450 CYP3A4 Inhibitors (weak)', 'Cytochrome P-450 CYP2E1 Substrates', 'Cytochrome P-450 CYP3A4 Inhibitors', 'Cytochrome P-450 CYP3A Inhibitors', 'central_nervous_system_depressant']
# node count 2
#   Chlorzoxazone
#   Ethanol
# ----
# p_value: [8.091430641712834e-08, 1.48329964283483e-07, 1.48329964283483e-07, 2.045036719432946e-07, 1.6640349803069579e-06, 2.1240869277917008e-06, 4.106934028408685e-06, 7.448529360821423e-06, 1.0223270541701228e-05, 1.9363596619562294e-05, 2.8109580726009318e-05, 2.8821778985894128e-05, 2.990670236991801e-05, 4.718764505601706e-05]
# properties: ['Benzothiadiazines', 'Increased Diuresis', 'Thiazides', 'Sodium Chloride Symporter Inhibitors', 'diuretic', 'Natriuretic Agents', 'Diuretics', 'Sulfonamides', 'Gynecological Antiinfectives and Antiseptics', 'Sulfones', 'Membrane Transport Modulators', 'Hypotensive Agents', 'Antihypertensive Agents', 'antihypertensive_agent']
# node count 2
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [2.5751688468187114e-05, 7.807521742481401e-05]
# properties: ['Cytochrome P-450 CYP2C19 inhibitors (strength unknown)', 'Cytochrome P-450 CYP2C19 Inhibitors']
# node count 2
#   Progesterone
#   Miconazole
# ----
# p_value: [6.999923708105896e-05]
# properties: ['Hyperglycemia-Associated Agents']
# node count 2
#   Progesterone
#   Hydrochlorothiazide
# ----
# p_value: [2.870904070657723e-08]
# properties: ['Low-Ceiling Diuretics and Potassium-Sparing Agents']
# node count 2
#   Bendroflumethiazide
#   Hydrochlorothiazide
# ----
# p_value: [1.6932661723681538e-06, 3.1514752264738556e-05, 3.787899688674101e-05]
# properties: ['Cytochrome P-450 CYP2E1 Inhibitors', 'Cytochrome P-450 CYP3A4 Inhibitors', 'Cytochrome P-450 CYP3A Inhibitors']
# node count 2
#   Chlorzoxazone
#   Miconazole
# ----
# p_value: [1.8130480545818397e-06]
# properties: ['Cytochrome P-450 CYP2E1 Substrates']
# node count 2
#   Enflurane
#   Chlorzoxazone
# ----
# p_value: [1.0094662911753687e-05]
# properties: ['vasodilator_agent']
# node count 2
#   Carbon monoxide
#   Diazoxide
# ----
# p_value: [1.4402180676279318e-06, 3.998267309555481e-06, 6.185877736372578e-06, 6.527243286359484e-06, 6.877758363265727e-06, 7.310451830271301e-06, 1.0269674521287355e-05, 1.303633735683665e-05, 1.9198014027154402e-05]
# properties: ['Myelosuppressive Agents', 'Cytochrome P-450 CYP3A4 Inducers (strength unknown)', 'Cytochrome P-450 CYP3A4 Inducers', 'Immunosuppressive Agents', 'Cytochrome P-450 CYP3A Inducers', 'Antineoplastic and Immunomodulating Agents', 'Cytochrome P-450 Enzyme Inducers', 'P-glycoprotein substrates', 'Antineoplastic Agents']
# node count 2
#   Topotecan
#   Paclitaxel
# ----
# p_value: [3.076257833396323e-09, 8.24403093211081e-07, 3.928422830302463e-06, 3.928422830302463e-06]
# properties: ['macronutrient', 'nutrient', 'food_component', 'physiological_role']
# node count 2
#   Calcium
#   Potassium
# ----
# p_value: [1.2710009277837232e-05]
# properties: ['Hyperglycemia-Associated Agents']
# node count 2
#   Bendroflumethiazide
#   Estradiol
# ----
# p_value: [4.0938873284065865e-06, 1.536794230546433e-05]
# properties: ['Hyperglycemia-Associated Agents', 'Genito Urinary System and Sex Hormones']
# node count 2
#   Estradiol
#   Diazoxide
# ----
# p_value: [6.744034553745893e-09, 1.2817456150742807e-08, 2.0823187314116925e-08, 4.081727266229449e-08, 9.111620548329211e-05]
# properties: ['Replacement Preparations', 'Minerals', 'Metals', 'Elements', 'drugbank.approved']
# node count 2
#   potassium hydride
#   Calcium
# ----
# p_value: [5.7710528180400505e-06]
# properties: ['Antidiarrheals, Intestinal Antiinflammatory/antiinfective Agents']
# node count 2
#   Miconazole
#   Cromolyn
# ----
# p_value: [4.765690088040808e-07, 1.1427433820628262e-05, 3.569291651622227e-05, 5.235160897303835e-05]
# properties: ['Antidiarrheals, Intestinal Antiinflammatory/antiinfective Agents', 'Sensory Organs', 'Dermatologicals', 'Alimentary Tract and Metabolism']
# node count 2
#   Miconazole
#   Cromolyn
# ----
# p_value: [1.6008020001879997e-07, 1.9429826482967636e-07, 3.642644140689693e-07, 2.5852124011817738e-05, 3.225109094690438e-05, 3.349015055486641e-05, 4.586991706817948e-05]
# properties: ['neurotransmitter', 'OCT1 substrates', 'Biogenic Amines', 'Cardiovascular Agents', 'Amines', 'cardiovascular_drug', 'Neurotransmitter Agents']
# node count 2
#   Acetylcholine
#   Norepinephrine
# ----

# %%
property_answers['message']['results'][0]
# Out:
# {'node_bindings': {'n1': [{'id': 'NCBIGene:3778'}],
#   'n0': [{'id': 'PUBCHEM.COMPOUND:5994',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11437030',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:3605484',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:10243969',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:10967695',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:2798243',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:3639',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:4552',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:10969679',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:47811',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:10968747',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11065065',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:44570449',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11254734',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:15717694',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:24285063',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:24285062',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11392406',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11818496',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:10064074',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:10356396',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:2882',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:4050379',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:4189',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:2946791',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:3562',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11471747',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:16099762',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:2953683',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11472034',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11109578',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11000844',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:16099761',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:2798242',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11779066',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11335564',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:1140',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11042812',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11782023',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:5073804',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:2993',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']}]},
#  'edge_bindings': {'e0': [{'id': '8835aa3ef86e', 'weight': 1},
#    {'id': '9b9fe0c2173b', 'weight': 1},
#    {'id': '6593dce43a5a', 'weight': 1},
#    {'id': 'f6834a7bd409', 'weight': 1},
#    {'id': '9bcfc71111fb', 'weight': 1},
#    {'id': '2b08ed724613', 'weight': 1},
#    {'id': 'e2bb8031297c', 'weight': 1},
#    {'id': 'e2e73c80e2b1', 'weight': 1},
#    {'id': 'fcd6c243b89a', 'weight': 1},
#    {'id': '93781bc5b720', 'weight': 1},
#    {'id': '13f399d6ef5a', 'weight': 1},
#    {'id': '31d39230b010', 'weight': 1},
#    {'id': '8a8b0505df93', 'weight': 1},
#    {'id': 'e05768c1144f', 'weight': 1},
#    {'id': 'ec7c8bceabe8', 'weight': 1},
#    {'id': 'fa9144751c19', 'weight': 1},
#    {'id': '624dce68f2b6', 'weight': 1},
#    {'id': '50b22b52633a', 'weight': 1},
#    {'id': '90da61c18e2b', 'weight': 1},
#    {'id': '575ba5bf4bde', 'weight': 1},
#    {'id': '813ac630e5a8', 'weight': 1},
#    {'id': '36147eeeb47d', 'weight': 1},
#    {'id': '2b9c630cb328', 'weight': 1},
#    {'id': '0f01c46d3821', 'weight': 1},
#    {'id': '4862631be215', 'weight': 1},
#    {'id': 'a4a6be2e95c8', 'weight': 1},
#    {'id': '053020371140', 'weight': 1},
#    {'id': 'f878fce830ca', 'weight': 1},
#    {'id': '6f16827a043d', 'weight': 1},
#    {'id': '72ac435f8b42', 'weight': 1},
#    {'id': '41ab3cd757b5', 'weight': 1},
#    {'id': '279f77556601', 'weight': 1},
#    {'id': '9c5edb149e48', 'weight': 1},
#    {'id': 'fac70141e1e1', 'weight': 1},
#    {'id': '45ba72cbd553', 'weight': 1},
#    {'id': '70e70b8a9179', 'weight': 1},
#    {'id': '56567f23fa13', 'weight': 1},
#    {'id': 'c019f6c15e5e', 'weight': 1},
#    {'id': 'f1e2af78989f', 'weight': 1},
#    {'id': '1f7ee5fba0f3', 'weight': 1},
#    {'id': '838d30134673', 'weight': 1}]},
#  'score': 40.999999953231885}

# %%
graph_answers=filter_to_gc(aragorn_result,node)
for gc_result in graph_answers['message']['results']:
    print_gc_result(aragorn_result['message']['knowledge_graph'],gc_result,node)
# Out:
# 85
# p_value: 1.488362376405769e-24
# Merged 8
#   Isochamaejasmin -[biolink:directly_interacts_with]-> VEGFA
#   Holo-Lys2 -[biolink:directly_interacts_with]-> VEGFA
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> VEGFA
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> VEGFA
#   6-Bromohexanoic acid -[biolink:directly_interacts_with]-> VEGFA
# ----
# p_value: 1.098744871207281e-18
# Merged 7
#   Holo-Lys2 -[biolink:directly_interacts_with]-> TNF
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> TNF
#   Deoxylimonoic acid D-ring-lactone -[biolink:directly_interacts_with]-> TNF
#   Diazoxide -[biolink:directly_interacts_with]-> TNF
#   Isochamaejasmin -[biolink:directly_interacts_with]-> TNF
# ----
# p_value: 2.5251858514751036e-18
# Merged 6
#   Diazoxide -[biolink:directly_interacts_with]-> CXCL8
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> CXCL8
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> CXCL8
#   Holo-Lys2 -[biolink:directly_interacts_with]-> CXCL8
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> CXCL8
# ----
# p_value: 4.4690012826693734e-12
# Merged 6
#   Hydrochlorothiazide -[biolink:contraindicated_for]-> liver disease
#   Diazoxide -[biolink:contraindicated_for]-> liver disease
#   Cromolyn -[biolink:contraindicated_for]-> liver disease
#   Miconazole -[biolink:contraindicated_for]-> liver disease
#   Bendroflumethiazide -[biolink:contraindicated_for]-> liver disease
# ----
# p_value: 2.857900719790251e-07
# Merged 5
#   Cromolyn -[biolink:contraindicated_for]-> liver disease
#   Progesterone -[biolink:contraindicated_for]-> liver disease
#   Miconazole -[biolink:contraindicated_for]-> liver disease
#   Hydrochlorothiazide -[biolink:contraindicated_for]-> liver disease
#   Halothane -[biolink:contraindicated_for]-> liver disease
# ----
# p_value: 1.1096556736007788e-18
# Merged 5
#   Isochamaejasmin -[biolink:directly_interacts_with]-> CAV1
#   Diazoxide -[biolink:directly_interacts_with]-> CAV1
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> CAV1
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> CAV1
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> CAV1
# ----
# p_value: 7.314555092806038e-11
# Merged 4
#   Ethanol -[biolink:interacts_with]-> CYP1A1
#   Chlorzoxazone -[biolink:interacts_with]-> CYP1A1
#   Estradiol -[biolink:interacts_with]-> CYP1A1
#   poly(vinyl alcohol) macromolecule -[biolink:interacts_with]-> CYP1A1
# ----
# p_value: 4.1929085487571036e-18
# Merged 6
#   Holo-Lys2 -[biolink:directly_interacts_with]-> NR1I2
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> NR1I2
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> NR1I2
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> NR1I2
#   Estradiol -[biolink:directly_interacts_with]-> NR1I2
# ----
# p_value: 5.64600149725104e-18
# Merged 5
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> MMP1
#   6-Bromohexanoic acid -[biolink:directly_interacts_with]-> MMP1
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> MMP1
#   Isochamaejasmin -[biolink:directly_interacts_with]-> MMP1
#   Holo-Lys2 -[biolink:directly_interacts_with]-> MMP1
# ----
# p_value: 2.901724023394722e-21
# Merged 6
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> VCAM1
#   Deoxylimonoic acid D-ring-lactone -[biolink:directly_interacts_with]-> VCAM1
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> VCAM1
#   Isochamaejasmin -[biolink:directly_interacts_with]-> VCAM1
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> VCAM1
# ----
# p_value: 9.727453559742477e-19
# Merged 6
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> CYP19A1
#   Isochamaejasmin -[biolink:directly_interacts_with]-> CYP19A1
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> CYP19A1
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> CYP19A1
#   Holo-Lys2 -[biolink:directly_interacts_with]-> CYP19A1
# ----
# p_value: 1.1733811243450021e-07
# Merged 3
#   Cromolyn -[biolink:contraindicated_for]-> liver disease
#   Hydrochlorothiazide -[biolink:contraindicated_for]-> liver disease
#   Miconazole -[biolink:contraindicated_for]-> liver disease
# ----
# p_value: 5.424485815671622e-11
# Merged 4
#   Chlorzoxazone -[biolink:interacts_with]-> CYP2A6
#   Hydron;2,2,2-trifluoroacetate -[biolink:interacts_with]-> CYP2A6
#   Miconazole -[biolink:interacts_with]-> CYP2A6
#   ferroheme b -[biolink:interacts_with]-> CYP2A6
# ----
# p_value: 6.619891429384633e-10
# Merged 4
#   Norepinephrine -[biolink:increases_degradation_of]-> CASP9
#   CID 22326046 -[biolink:increases_degradation_of]-> CASP9
#   Topotecan -[biolink:increases_degradation_of]-> CASP9
#   Paclitaxel -[biolink:increases_degradation_of]-> CASP9
# ----
# p_value: 4.772714879877331e-10
# Merged 3
#   Estradiol -[biolink:decreases_expression_of]-> PPARG
#   poly(vinyl alcohol) macromolecule -[biolink:decreases_expression_of]-> PPARG
#   Ethanol -[biolink:decreases_expression_of]-> PPARG
# ----
# p_value: 2.291810764092827e-09
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:decreases_expression_of]-> CAT
#   Estradiol -[biolink:decreases_expression_of]-> CAT
#   Ethanol -[biolink:decreases_expression_of]-> CAT
# ----
# p_value: 3.4678226769058036e-09
# Merged 3
#   Estradiol -[biolink:decreases_molecular_modification_of]-> MAPK1
#   poly(vinyl alcohol) macromolecule -[biolink:decreases_molecular_modification_of]-> MAPK1
#   Ethanol -[biolink:decreases_molecular_modification_of]-> MAPK1
# ----
# p_value: 3.4678226769058036e-09
# Merged 3
#   Ethanol -[biolink:decreases_molecular_modification_of]-> MAPK3
#   Estradiol -[biolink:decreases_molecular_modification_of]-> MAPK3
#   poly(vinyl alcohol) macromolecule -[biolink:decreases_molecular_modification_of]-> MAPK3
# ----
# p_value: 2.59993158810574e-09
# Merged 4
#   ferroheme b -[biolink:interacts_with]-> CYP2D6
#   Chlorzoxazone -[biolink:interacts_with]-> CYP2D6
#   Hydron;2,2,2-trifluoroacetate -[biolink:interacts_with]-> CYP2D6
#   Miconazole -[biolink:interacts_with]-> CYP2D6
# ----
# p_value: 8.303202934617915e-15
# Merged 4
#   Diazoxide -[biolink:interacts_with]-> SLC12A3
#   Hydrochlorothiazide -[biolink:interacts_with]-> SLC12A3
#   Bendroflumethiazide -[biolink:interacts_with]-> SLC12A3
#   Calcium ion -[biolink:interacts_with]-> SLC12A3
# ----
# p_value: 2.9583182608342703e-13
# Merged 5
#   ferroheme b -[biolink:interacts_with]-> CYP2E1
#   Enflurane -[biolink:interacts_with]-> CYP2E1
#   Hydron;2,2,2-trifluoroacetate -[biolink:interacts_with]-> CYP2E1
#   Chlorzoxazone -[biolink:interacts_with]-> CYP2E1
#   Miconazole -[biolink:interacts_with]-> CYP2E1
# ----
# p_value: 1.9990197678078563e-10
# Merged 4
#   CID 22326046 -[biolink:increases_activity_of]-> CASP7
#   Topotecan -[biolink:increases_activity_of]-> CASP7
#   Norepinephrine -[biolink:increases_activity_of]-> CASP7
#   Paclitaxel -[biolink:increases_activity_of]-> CASP7
# ----
# p_value: 4.960091226100248e-10
# Merged 4
#   Paclitaxel -[biolink:increases_activity_of]-> MAPK3
#   Norepinephrine -[biolink:increases_activity_of]-> MAPK3
#   Acetylcholine -[biolink:increases_activity_of]-> MAPK3
#   CID 22326046 -[biolink:increases_activity_of]-> MAPK3
# ----
# p_value: 5.103028626884024e-10
# Merged 4
#   Norepinephrine -[biolink:increases_activity_of]-> MAPK1
#   CID 22326046 -[biolink:increases_activity_of]-> MAPK1
#   Paclitaxel -[biolink:increases_activity_of]-> MAPK1
#   Acetylcholine -[biolink:increases_activity_of]-> MAPK1
# ----
# p_value: 4.813623377380656e-19
# Merged 5
#   6-Bromohexanoic acid -[biolink:directly_interacts_with]-> UNG
#   Isochamaejasmin -[biolink:directly_interacts_with]-> UNG
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> UNG
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> UNG
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> UNG
# ----
# p_value: 1.1096556736007788e-18
# Merged 5
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> SERPINB2
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> SERPINB2
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> SERPINB2
#   6-Bromohexanoic acid -[biolink:directly_interacts_with]-> SERPINB2
#   Isochamaejasmin -[biolink:directly_interacts_with]-> SERPINB2
# ----
# p_value: 1.6072855942046885e-18
# Merged 5
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> PDGFA
#   Holo-Lys2 -[biolink:directly_interacts_with]-> PDGFA
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> PDGFA
#   Deoxylimonoic acid D-ring-lactone -[biolink:directly_interacts_with]-> PDGFA
#   Isochamaejasmin -[biolink:directly_interacts_with]-> PDGFA
# ----
# p_value: 2.3907728420560098e-12
# Merged 3
#   Miconazole -[biolink:interacts_with]-> KCNN4
#   Calcium ion -[biolink:interacts_with]-> KCNN4
#   Hydron;2,2,2-trifluoroacetate -[biolink:interacts_with]-> KCNN4
# ----
# p_value: 5.969072369944539e-11
# Merged 3
#   Ethanol -[biolink:increases_expression_of]-> CD14
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> CD14
#   Estradiol -[biolink:increases_expression_of]-> CD14
# ----
# p_value: 3.4678226769058036e-09
# Merged 3
#   Estradiol -[biolink:increases_expression_of]-> MMP9
#   Ethanol -[biolink:increases_expression_of]-> MMP9
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> MMP9
# ----
# p_value: 2.9862884178003977e-10
# Merged 3
#   ferroheme b -[biolink:interacts_with]-> NOS3
#   Miconazole -[biolink:interacts_with]-> NOS3
#   Calcium ion -[biolink:interacts_with]-> NOS3
# ----
# p_value: 5.831266121292244e-10
# Merged 3
#   Hydrochlorothiazide -[biolink:interacts_with]-> CA1
#   Bendroflumethiazide -[biolink:interacts_with]-> CA1
#   Diazoxide -[biolink:interacts_with]-> CA1
# ----
# p_value: 1.0086532462030283e-12
# Merged 3
#   Calcium ion -[biolink:interacts_with]-> KCNMB3
#   Miconazole -[biolink:interacts_with]-> KCNMB3
#   Potassium ion -[biolink:interacts_with]-> KCNMB3
# ----
# p_value: 1.4183974058871814e-07
# Merged 2
#   Cromolyn -[biolink:causes_adverse_event]-> Marchiafava-Bignami disease
#   Hydrochlorothiazide -[biolink:causes_adverse_event]-> Marchiafava-Bignami disease
# ----
# p_value: 2.1772026260476887e-10
# Merged 3
#   Miconazole -[biolink:interacts_with]-> NOS2
#   ferroheme b -[biolink:interacts_with]-> NOS2
#   Calcium ion -[biolink:interacts_with]-> NOS2
# ----
# p_value: 6.110813387633773e-13
# Merged 3
#   TRPC6 -[biolink:increases_transport_of]-> potassium hydride
#   TRPC6 -[biolink:increases_transport_of]-> Potassium
#   TRPC6 -[biolink:increases_transport_of]-> Calcium
# ----
# p_value: 2.291810764092827e-09
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> TIMP1
#   Ethanol -[biolink:increases_expression_of]-> TIMP1
#   Estradiol -[biolink:increases_expression_of]-> TIMP1
# ----
# p_value: 5.969072369944539e-11
# Merged 3
#   CAT -[biolink:affects_response_to]-> Topotecan
#   CAT -[biolink:affects_response_to]-> Paclitaxel
#   CAT -[biolink:affects_response_to]-> CID 22326046
# ----
# p_value: 3.1431454609879794e-09
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> COL1A1
#   Estradiol -[biolink:increases_expression_of]-> COL1A1
#   Ethanol -[biolink:increases_expression_of]-> COL1A1
# ----
# p_value: 3.8141065443520285e-09
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> PPARG
#   Ethanol -[biolink:increases_expression_of]-> PPARG
#   Estradiol -[biolink:increases_expression_of]-> PPARG
# ----
# p_value: 8.268649309420201e-10
# Merged 4
#   Chlorzoxazone -[biolink:interacts_with]-> CYP2E1
#   Estradiol -[biolink:interacts_with]-> CYP2E1
#   poly(vinyl alcohol) macromolecule -[biolink:interacts_with]-> CYP2E1
#   Ethanol -[biolink:interacts_with]-> CYP2E1
# ----
# p_value: 1.1888462455265065e-08
# Merged 2
#   TRPC6 -[biolink:increases_transport_of]-> Rubidium
#   TRPC6 -[biolink:increases_transport_of]-> Cesium
# ----
# p_value: 2.291810764092827e-09
# Merged 3
#   Estradiol -[biolink:increases_molecular_interaction]-> CYP1A1
#   poly(vinyl alcohol) macromolecule -[biolink:increases_molecular_interaction]-> CYP1A1
#   Ethanol -[biolink:increases_molecular_interaction]-> CYP1A1
# ----
# p_value: 2.0466162687245084e-09
# Merged 3
#   Hydrochlorothiazide -[biolink:causes_adverse_event]-> Marchiafava-Bignami disease
#   Cromolyn -[biolink:causes_adverse_event]-> Marchiafava-Bignami disease
#   Chlorzoxazone -[biolink:causes_adverse_event]-> Marchiafava-Bignami disease
# ----
# p_value: 3.9546805706673473e-07
# Merged 4
#   Progesterone -[biolink:prevents]-> Found Dead
#   Cromolyn -[biolink:prevents]-> Found Dead
#   Hydrochlorothiazide -[biolink:prevents]-> Found Dead
#   Pergolide -[biolink:prevents]-> Found Dead
# ----
# p_value: 2.350740151877105e-13
# Merged 3
#   potassium hydride -[biolink:increases_activity_of]-> KLK8
#   Potassium -[biolink:increases_activity_of]-> KLK8
#   Calcium -[biolink:increases_activity_of]-> KLK8
# ----
# p_value: 1.2397132968460726e-14
# Merged 3
#   ADRA1A -[biolink:affects_transport_of]-> potassium hydride
#   ADRA1A -[biolink:affects_transport_of]-> Potassium
#   ADRA1A -[biolink:affects_transport_of]-> Calcium
# ----
# p_value: 9.825267406237279e-09
# Merged 2
#   Dietary Fats -[biolink:increases_expression_of]-> COL1A2
#   Oxygen -[biolink:increases_expression_of]-> COL1A2
# ----
# p_value: 2.5185377860571276e-11
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:increases_molecular_interaction]-> None
#   Estradiol -[biolink:increases_molecular_interaction]-> None
#   Ethanol -[biolink:increases_molecular_interaction]-> None
# ----
# p_value: 7.990603750138681e-10
# Merged 3
#   Estradiol -[biolink:increases_localization_of]-> CTNNB1
#   Ethanol -[biolink:increases_localization_of]-> CTNNB1
#   poly(vinyl alcohol) macromolecule -[biolink:increases_localization_of]-> CTNNB1
# ----
# p_value: 9.319226393727285e-10
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:decreases_activity_of]-> SULT1E1
#   Estradiol -[biolink:decreases_activity_of]-> SULT1E1
#   Ethanol -[biolink:decreases_activity_of]-> SULT1E1
# ----
# p_value: 2.291810764092827e-09
# Merged 3
#   Estradiol -[biolink:increases_expression_of]-> MMP2
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> MMP2
#   Ethanol -[biolink:increases_expression_of]-> MMP2
# ----
# p_value: 2.8393806934826688e-09
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:increases_molecular_interaction]-> NR1I2
#   Ethanol -[biolink:increases_molecular_interaction]-> NR1I2
#   Estradiol -[biolink:increases_molecular_interaction]-> NR1I2
# ----
# p_value: 1.7969161042122528e-07
# Merged 3
#   Hydrochlorothiazide -[biolink:causes_adverse_event]-> Feeling jittery
#   Cromolyn -[biolink:causes_adverse_event]-> Feeling jittery
#   Progesterone -[biolink:causes_adverse_event]-> Feeling jittery
# ----
# p_value: 5.572460752049427e-07
# Merged 3
#   Progesterone -[biolink:causes_adverse_event]-> Dyspepsia
#   Hydrochlorothiazide -[biolink:causes_adverse_event]-> Dyspepsia
#   Cromolyn -[biolink:causes_adverse_event]-> Dyspepsia
# ----
# p_value: 6.452734370829963e-11
# Merged 3
#   Enflurane -[biolink:interacts_with]-> ATP2C1
#   Calcium ion -[biolink:interacts_with]-> ATP2C1
#   Hydron;2,2,2-trifluoroacetate -[biolink:interacts_with]-> ATP2C1
# ----
# p_value: 5.831266121292244e-10
# Merged 3
#   Bendroflumethiazide -[biolink:interacts_with]-> CA2
#   Hydrochlorothiazide -[biolink:interacts_with]-> CA2
#   Diazoxide -[biolink:interacts_with]-> CA2
# ----
# p_value: 1.0868725189495286e-09
# Merged 3
#   Paclitaxel -[biolink:causes_adverse_event]-> Clostridium welchii infection
#   Norepinephrine -[biolink:causes_adverse_event]-> Clostridium welchii infection
#   Topotecan -[biolink:causes_adverse_event]-> Clostridium welchii infection
# ----
# p_value: 1.1656792007971442e-10
# Merged 3
#   Estradiol -[biolink:increases_molecular_interaction]-> CYP1B1
#   Ethanol -[biolink:increases_molecular_interaction]-> CYP1B1
#   poly(vinyl alcohol) macromolecule -[biolink:increases_molecular_interaction]-> CYP1B1
# ----
# p_value: 2.014025431203612e-10
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> TGM2
#   Ethanol -[biolink:increases_expression_of]-> TGM2
#   Estradiol -[biolink:increases_expression_of]-> TGM2
# ----
# p_value: 1.9015674565146053e-07
# Merged 2
#   Halothane -[biolink:decreases_activity_of]-> KCNJ6
#   Toluene -[biolink:decreases_activity_of]-> KCNJ6
# ----
# p_value: 4.772714879877331e-10
# Merged 3
#   Norepinephrine -[biolink:causes_adverse_event]-> None
#   Topotecan -[biolink:causes_adverse_event]-> None
#   Paclitaxel -[biolink:causes_adverse_event]-> None
# ----
# p_value: 5.566347605213264e-10
# Merged 3
#   Paclitaxel -[biolink:causes_adverse_event]-> Colon perforation
#   Norepinephrine -[biolink:causes_adverse_event]-> Colon perforation
#   Topotecan -[biolink:causes_adverse_event]-> Colon perforation
# ----
# p_value: 1.7468556887556165e-10
# Merged 2
#   ABCC9 -[biolink:increases_transport_of]-> Potassium
#   ABCC9 -[biolink:increases_transport_of]-> potassium hydride
# ----
# p_value: 1.7468556887556165e-10
# Merged 2
#   KCNE3 -[biolink:affects_transport_of]-> Potassium
#   KCNE3 -[biolink:affects_transport_of]-> potassium hydride
# ----
# p_value: 1.7468556887556165e-10
# Merged 2
#   SGK2 -[biolink:increases_transport_of]-> potassium hydride
#   SGK2 -[biolink:increases_transport_of]-> Potassium
# ----
# p_value: 7.603142898260044e-07
# Merged 2
#   Hydrochlorothiazide -[biolink:causes_adverse_event]-> Abnormal Mammogram
#   Progesterone -[biolink:causes_adverse_event]-> Abnormal Mammogram
# ----
# p_value: 8.84331917719657e-10
# Merged 2
#   Oxygen -[biolink:increases_expression_of]-> APLN
#   Dietary Fats -[biolink:increases_expression_of]-> APLN
# ----
# p_value: 7.958540976766807e-09
# Merged 2
#   Oxygen -[biolink:increases_activity_of]-> CS
#   Dietary Fats -[biolink:increases_activity_of]-> CS
# ----
# p_value: 3.4624495147262728e-59
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:11820396",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "UMLS:C0059640",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10354434",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10083014",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:9815734",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10038562",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:214350",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:9881289",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "CHEBI:17246",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:702",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2315",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5757",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10263172",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2733",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10035337",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10398337",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_0": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "44fd64f737e2",
#                 "weight": 1
#             },
#             {
#                 "id": "5d367fac900e",
#                 "weight": 1
#             },
#             {
#                 "id": "907bfced6727",
#                 "weight": 1
#             },
#             {
#                 "id": "90d26be31f21",
#                 "weight": 1
#             },
#             {
#                 "id": "74d328710ec9",
#                 "weight": 1
#             },
#             {
#                 "id": "c7f8ac074648",
#                 "weight": 1
#             },
#             {
#                 "id": "d05db24673c1",
#                 "weight": 1
#             },
#             {
#                 "id": "85e056a852c8",
#                 "weight": 1
#             },
#             {
#                 "id": "0c7474acbc5c",
#                 "weight": 1
#             },
#             {
#                 "id": "1194d7ecc312",
#                 "weight": 1
#             },
#             {
#                 "id": "d43131f08c86",
#                 "weight": 1
#             },
#             {
#                 "id": "f33755b08c2b",
#                 "weight": 1
#             },
#             {
#                 "id": "1f9c82188903",
#                 "weight": 1
#             },
#             {
#                 "id": "8dd40182bbda",
#                 "weight": 1
#             },
#             {
#                 "id": "6c77b2217b94",
#                 "weight": 1
#             },
#             {
#                 "id": "32d9ae20c0de",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_0": []
#     },
#     "score": 0
# }
# p_value: 8.220862357437827e-142
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:5994",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11437030",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3605484",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10243969",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10967695",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2798243",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3639",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4552",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10969679",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:47811",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10968747",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11065065",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:44570449",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11254734",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:15717694",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:24285063",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:24285062",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11392406",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11818496",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10064074",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4697",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10356396",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2882",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4050379",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4189",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2946791",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3562",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11471747",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:16099762",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2953683",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11472034",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11109578",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11000844",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:16099761",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2798242",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11779066",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11335564",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:1140",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11042812",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11782023",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "UMLS:C0082965",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5073804",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2993",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_20": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "8835aa3ef86e",
#                 "weight": 1
#             },
#             {
#                 "id": "9b9fe0c2173b",
#                 "weight": 1
#             },
#             {
#                 "id": "6593dce43a5a",
#                 "weight": 1
#             },
#             {
#                 "id": "f6834a7bd409",
#                 "weight": 1
#             },
#             {
#                 "id": "9bcfc71111fb",
#                 "weight": 1
#             },
#             {
#                 "id": "2b08ed724613",
#                 "weight": 1
#             },
#             {
#                 "id": "e2bb8031297c",
#                 "weight": 1
#             },
#             {
#                 "id": "e2e73c80e2b1",
#                 "weight": 1
#             },
#             {
#                 "id": "fcd6c243b89a",
#                 "weight": 1
#             },
#             {
#                 "id": "93781bc5b720",
#                 "weight": 1
#             },
#             {
#                 "id": "13f399d6ef5a",
#                 "weight": 1
#             },
#             {
#                 "id": "31d39230b010",
#                 "weight": 1
#             },
#             {
#                 "id": "8a8b0505df93",
#                 "weight": 1
#             },
#             {
#                 "id": "e05768c1144f",
#                 "weight": 1
#             },
#             {
#                 "id": "ec7c8bceabe8",
#                 "weight": 1
#             },
#             {
#                 "id": "fa9144751c19",
#                 "weight": 1
#             },
#             {
#                 "id": "624dce68f2b6",
#                 "weight": 1
#             },
#             {
#                 "id": "50b22b52633a",
#                 "weight": 1
#             },
#             {
#                 "id": "90da61c18e2b",
#                 "weight": 1
#             },
#             {
#                 "id": "d2980eac332e",
#                 "weight": 1
#             },
#             {
#                 "id": "575ba5bf4bde",
#                 "weight": 1
#             },
#             {
#                 "id": "813ac630e5a8",
#                 "weight": 1
#             },
#             {
#                 "id": "36147eeeb47d",
#                 "weight": 1
#             },
#             {
#                 "id": "2b9c630cb328",
#                 "weight": 1
#             },
#             {
#                 "id": "0f01c46d3821",
#                 "weight": 1
#             },
#             {
#                 "id": "4862631be215",
#                 "weight": 1
#             },
#             {
#                 "id": "a4a6be2e95c8",
#                 "weight": 1
#             },
#             {
#                 "id": "053020371140",
#                 "weight": 1
#             },
#             {
#                 "id": "f878fce830ca",
#                 "weight": 1
#             },
#             {
#                 "id": "6f16827a043d",
#                 "weight": 1
#             },
#             {
#                 "id": "72ac435f8b42",
#                 "weight": 1
#             },
#             {
#                 "id": "41ab3cd757b5",
#                 "weight": 1
#             },
#             {
#                 "id": "279f77556601",
#                 "weight": 1
#             },
#             {
#                 "id": "9c5edb149e48",
#                 "weight": 1
#             },
#             {
#                 "id": "fac70141e1e1",
#                 "weight": 1
#             },
#             {
#                 "id": "45ba72cbd553",
#                 "weight": 1
#             },
#             {
#                 "id": "70e70b8a9179",
#                 "weight": 1
#             },
#             {
#                 "id": "56567f23fa13",
#                 "weight": 1
#             },
#             {
#                 "id": "c019f6c15e5e",
#                 "weight": 1
#             },
#             {
#                 "id": "edeb1132b29a",
#                 "weight": 1
#             },
#             {
#                 "id": "f1e2af78989f",
#                 "weight": 1
#             },
#             {
#                 "id": "1f7ee5fba0f3",
#                 "weight": 1
#             },
#             {
#                 "id": "838d30134673",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_20": [],
#         "s144": [
#             {
#                 "id": "bd3e73c7-4efe-47ff-a770-718d42e1880f",
#                 "weight": 1
#             }
#         ]
#     },
#     "score": 0
# }
# p_value: 3.1763251677139393e-09
# Merged 3
#   Cromolyn -[biolink:interacts_with]-> KCNMA1
#   Miconazole -[biolink:interacts_with]-> KCNMA1
#   Hydrochlorothiazide -[biolink:interacts_with]-> KCNMA1
# ----
# p_value: 4.728318829430971e-44
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:6325242",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:24892745",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:214350",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "CHEBI:36314",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:20210",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "CHEBI:5743",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4479243",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5757",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:54614868",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3019",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:390361",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_28": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "45fc7a1a59a3",
#                 "weight": 1
#             },
#             {
#                 "id": "be7635a0dff8",
#                 "weight": 1
#             },
#             {
#                 "id": "af09ae830a33",
#                 "weight": 1
#             },
#             {
#                 "id": "24dc3c6ff60d",
#                 "weight": 1
#             },
#             {
#                 "id": "def593db50d4",
#                 "weight": 1
#             },
#             {
#                 "id": "752752df6d52",
#                 "weight": 1
#             },
#             {
#                 "id": "7ec1d63c574e",
#                 "weight": 1
#             },
#             {
#                 "id": "7a9e6b1aa9d7",
#                 "weight": 1
#             },
#             {
#                 "id": "4e4e62c17e58",
#                 "weight": 1
#             },
#             {
#                 "id": "ca8d3297f7e7",
#                 "weight": 1
#             },
#             {
#                 "id": "f99dae9682fe",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_28": []
#     },
#     "score": 0
# }
# p_value: 1.0086532462030283e-12
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:4189",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.0086532462030283e-12,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3639",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.0086532462030283e-12,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2882",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.0086532462030283e-12,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_40": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "f9e5dd34101a",
#                 "weight": 1
#             },
#             {
#                 "id": "053020371140",
#                 "weight": 1
#             },
#             {
#                 "id": "e2bb8031297c",
#                 "weight": 1
#             },
#             {
#                 "id": "36147eeeb47d",
#                 "weight": 1
#             },
#             {
#                 "id": "1d0315cadf9f",
#                 "weight": 1
#             },
#             {
#                 "id": "916e4ae87fba",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_40": []
#     },
#     "score": 0
# }
# p_value: 3.649053390131684e-11
# {
# ...
#                 ]
#             }
#         ],
#         "extra_qn_45": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "6c77b2217b94",
#                 "weight": 1
#             },
#             {
#                 "id": "5d367fac900e",
#                 "weight": 1
#             },
#             {
#                 "id": "425ed253744f",
#                 "weight": 1
#             },
#             {
#                 "id": "b10907769d2e",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_45": []
#     },
#     "score": 0
# }
# p_value: 5.283942155856431e-09
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:5757",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 5.283942155856431e-09,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:214350",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 5.283942155856431e-09,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_46": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "8dd40182bbda",
#                 "weight": 1
#             },
#             {
#                 "id": "4e4e62c17e58",
#                 "weight": 1
#             },
#             {
#                 "id": "752752df6d52",
#                 "weight": 1
#             },
#             {
#                 "id": "907bfced6727",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_46": []
#     },
#     "score": 0
# }
# p_value: 1.2619852879368695e-08
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:5757",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2619852879368695e-08,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:214350",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2619852879368695e-08,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_47": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "8dd40182bbda",
#                 "weight": 1
#             },
#             {
#                 "id": "4e4e62c17e58",
#                 "weight": 1
#             },
#             {
#                 "id": "752752df6d52",
#                 "weight": 1
#             },
#             {
#                 "id": "907bfced6727",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_47": []
#     },
#     "score": 0
# }
# p_value: 1.2397132968460726e-14
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:5357696",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2397132968460726e-14,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5354618",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2397132968460726e-14,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5359464",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2397132968460726e-14,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_48": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "45ecf7a215df",
#                 "weight": 1
#             },
#             {
#                 "id": "2724819edcfe",
#                 "weight": 1
#             },
#             {
#                 "id": "1c07fbd17c90",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_48": []
#     },
#     "score": 0
# }
# p_value: 3.9304008111929507e-10
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "NCIT:C2317",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.9304008111929507e-10,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:977",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.9304008111929507e-10,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_49": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "c928a4294bbc",
#                 "weight": 1
#             },
#             {
#                 "id": "44b67b255f8f",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_49": []
#     },
#     "score": 0
# }
# p_value: 1.2275003461865521e-46
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:3226",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "UNII:42VZT0U6YR",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2882",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:813",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:271",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4189",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:23138861",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2315",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:281",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3639",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2733",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3019",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_49": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "b10907769d2e",
#                 "weight": 1
#             },
#             {
#                 "id": "7de639cd6261",
#                 "weight": 1
#             },
#             {
#                 "id": "425ed253744f",
#                 "weight": 1
#             },
#             {
#                 "id": "f63203ccbe33",
#                 "weight": 1
#             },
#             {
#                 "id": "1d0315cadf9f",
#                 "weight": 1
#             },
#             {
#                 "id": "e86c0cf44ef0",
#                 "weight": 1
#             },
#             {
#                 "id": "f9e5dd34101a",
#                 "weight": 1
#             },
#             {
#                 "id": "1b926b87d935",
#                 "weight": 1
#             },
#             {
#                 "id": "4ddfa10ae2fa",
#                 "weight": 1
#             },
#             {
#                 "id": "bc93e064bee3",
#                 "weight": 1
#             },
#             {
#                 "id": "916e4ae87fba",
#                 "weight": 1
#             },
#             {
#                 "id": "df99e009b6c4",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_49": []
#     },
#     "score": 0
# }
# p_value: 1.586695648732096e-33
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:220338",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:439260",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4788",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:36314",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:60700",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:187",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:105008",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:22326046",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_49": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "cb1ede0206cc",
#                 "weight": 1
#             },
#             {
#                 "id": "47dcf3e94481",
#                 "weight": 1
#             },
#             {
#                 "id": "be96f19b170d",
#                 "weight": 1
#             },
#             {
#                 "id": "c4c62f5d9156",
#                 "weight": 1
#             },
#             {
#                 "id": "5ad902b8a8f6",
#                 "weight": 1
#             },
#             {
#                 "id": "0fbf4749d416",
#                 "weight": 1
#             },
#             {
#                 "id": "9dada43f375a",
#                 "weight": 1
#             },
#             {
#                 "id": "914e737e0851",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_49": []
#     },
#     "score": 0
# }
# p_value: 1.7468556887556165e-10
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:5460341",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.7468556887556165e-10,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:9903",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.7468556887556165e-10,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_49": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "bab38a3a09c2",
#                 "weight": 1
#             },
#             {
#                 "id": "0933b06c1f9a",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_49": []
#     },
#     "score": 0
# }
# p_value: 1.2397132968460726e-14
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:5460341",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2397132968460726e-14,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "CHEBI:32589",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2397132968460726e-14,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5462222",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2397132968460726e-14,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_49": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "2fba6157825e",
#                 "weight": 1
#             },
#             {
#                 "id": "55fa14d7ae52",
#                 "weight": 1
#             },
#             {
#                 "id": "a6448ab1b4e5",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_49": []
#     },
#     "score": 0
# }

# %% [markdown]
# ### ARAGORN Assessment

# %% [markdown]
# How did we do?
