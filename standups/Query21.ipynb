# %% [markdown]
# # Setup

# %%
import json
import requests
from datetime import datetime as dt
from collections import defaultdict
import pandas as pd
import copy

# %%
#https://pypi.org/project/gamma-viewer/
from gamma_viewer import GammaViewer
from IPython.display import display, Markdown

# %%
def printjson(j):
    print(json.dumps(j,indent=4))
def print_json(j):
    printjson(j)

# %%
def post(name,url,message,params=None):
    if params is None:
        response = requests.post(url,json=message)
    else:
        response = requests.post(url,json=message,params=params)
    if not response.status_code == 200:
        print(name, 'error:',response.status_code)
        print(response.json())
        return {}
    return response.json()

def automat(db,message):
    automat_url = f'https://automat.renci.org/{db}/query'
    response = requests.post(automat_url,json=message)
    print(response.status_code)
    return response.json()

def strider(message):
    url = 'https://strider.renci.org/1.1/query?log_level=DEBUG'
    strider_answer = post(strider,url,message)
    return strider_answer

def aragorn(message, coalesce_type='xnone'):
    if coalesce_type == 'xnone':
        answer = post('aragorn','https://aragorn.renci.org/1.1/query',message)
    else:
        answer = post('aragorn','https://aragorn.renci.org/1.1/query',message, params={'answer_coalesce_type':coalesce_type})
    return answer

##

def bte(message):
    url = 'https://api.bte.ncats.io/v1/query'
    return post(strider,url,message)

def coalesce(message,method='all'):
    url = 'https://answercoalesce.renci.org/coalesce/graph'
    return post('AC'+method,url,message)

def striderandfriends(message):
    strider_answer = strider(message)    
    coalesced_answer = post('coalesce','https://answercoalesce.renci.org/coalesce/all',strider_answer)
    omni_answer = post('omnicorp','https://aragorn-ranker.renci.org/omnicorp_overlay',coalesced_answer)
    weighted_answer = post('weight','https://aragorn-ranker.renci.org/weight_correctness',omni_answer)
    scored_answer = post('score','https://aragorn-ranker.renci.org/score',weighted_answer)
    return strider_answer,coalesced_answer,omni_answer,weighted_answer,scored_answer

# %%
def print_errors(strider_result):
    errorcounts = defaultdict(int)
    for logmessage in strider_result['logs']:
        if logmessage['level'] == 'ERROR':
            jm = json.loads(logmessage['message'])
            words = jm['error'].split()
            e = " ".join(words[:-5])
            errorcounts[e] += 1
    for error,count in errorcounts.items():
        print(f'{error} ({count} times)')
        
def print_queried_sources(strider_result):
    querycounts = defaultdict(int)
    for logmessage in strider_result['logs']:
        if 'step' in logmessage and isinstance(logmessage['step'],list):
            for s in logmessage['step']:
                querycounts[s['url']] += 1
    for url,count in querycounts.items():
        print(f'{url} ({count} times)')
        
def print_query_for_source(strider_result,url):
    for logmessage in strider_result['logs']:
        if 'step' in logmessage and isinstance(logmessage['step'],list):
            for s in logmessage['step']:
                if s['url']==url:
                    print(s)

# %%
def retrieve_ars_results(mid):
    message_url = f'https://ars.transltr.io/ars/api/messages/{mid}?trace=y'
    response = requests.get(message_url)
    j = response.json()
    results = {}
    for child in j['children']:
        if child['actor']['agent'] in ['ara-aragorn', 'ara-aragorn-exp']:
            childmessage_id = child['message']
            child_url = f'https://ars.transltr.io/ars/api/messages/{childmessage_id}'
            child_response = requests.get(child_url).json()
            try:
                nresults = len(child_response['fields']['data']['message']['results'])
                if nresults > 0:
                    results[child['actor']['agent']] = {'message':child_response['fields']['data']['message']}
            except:
                nresults=0
            print( child['status'], child['actor']['agent'],nresults )
    return results

# %%
def get_provenance(message):
    """Given a message with results, find the source of the edges"""
    prov = defaultdict(lambda: defaultdict(int)) # {qedge->{source->count}}
    results = message['message']['results']
    kg = message['message']['knowledge_graph']['edges']
    edge_bindings = [ r['edge_bindings'] for r in results ]
    for bindings in edge_bindings:
        for qg_e, kg_l in bindings.items():
            for kg_e in kg_l:
                for att in kg[kg_e['id']]['attributes']:
                    if att['attribute_type_id'] == 'MetaInformation:Provenance':
                        source = att['value']
                        prov[qg_e][source]+=1
    qg_edges = []
    sources = []
    counts = []
    for qg_e in prov:
        for source in prov[qg_e]:
            qg_edges.append(qg_e)
            sources.append(source)
            counts.append(prov[qg_e][source])
    prov_table = pd.DataFrame({"QG Edge":qg_edges, "Source":sources, "Count":counts})
    return prov_table

# %%
def ac_to_table(aragorn_result,mnode):
    #scores = []
    answer_node_count = []
    merged_count = []
    method = []
    extra = []
    for res_i, result in enumerate(aragorn_result['message']['results']):
        #scores.append(result['score'])
        answer_node_count.append(len(result['node_bindings']))
        merged_count.append(len(result['node_bindings'][mnode]))
        try:
            method.append(result['node_bindings'][mnode][0]['coalescence_method'])
        except:
            method.append('Original')
    df = pd.DataFrame({'N_Answer_Nodes':answer_node_count, 'N_Merged_Nodes':merged_count, 'Method':method})
    return df

def filter_to_simple(aragorn_result,mnode):
    simple_result = copy.deepcopy(aragorn_result)
    simple_result['message']['results'] = list(
    filter( lambda x: 'coalescence_method' not in x['node_bindings'][mnode][0], 
           aragorn_result['message']['results'])
    )
    print(len(simple_result['message']['results']))
    return simple_result

def print_nodenames(simple_result,qnode):
    #Print the names of the answers
    for result in simple_result['message']['results']:
        #Each answer has an identifier:
        n1_id = result['node_bindings'][qnode][0]['id']
        #The information for that identifier is in the KG:
        node = simple_result['message']['knowledge_graph']['nodes'][n1_id]
        #Each node has a name
        print(node['name'])

def filter_to_coal(aragorn_result,mnode,method):
    #The results that have been coalesced:
    coalesced_results = list(
        filter( lambda x: 'coalescence_method'  in x['node_bindings'][mnode][0], 
               aragorn_result['message']['results'])
    )
    #Those that have been coalesced via a new node (graph coalescence)
    graph_coalesced_results = list(
        filter( lambda x: x['node_bindings'][mnode][0]['coalescence_method'] == method, coalesced_results)
    )
    print(len(graph_coalesced_results))
    simple_result = copy.deepcopy(aragorn_result)
    simple_result['message']['results'] = graph_coalesced_results
    return simple_result

def filter_to_gc(aragorn_result,mnode):
    return filter_to_coal(aragorn_result,mnode,'graph_enrichment')

def filter_to_pc(aragorn_result,mnode):
    return filter_to_coal(aragorn_result,mnode,'property_enrichment')

def print_gc_result(graph,gc_result,node):
    print('p_value:', gc_result['node_bindings'][node][0]['p_value'])
    maxprint=5
    for extra_edge in gc_result['edge_bindings']:
        if not extra_edge.startswith('extra_'):
            continue
        numnodes = len(gc_result['edge_bindings'][extra_edge])
        if numnodes == 0:
            printjson(gc_result)
            return
        print ('Merged',numnodes)
        nprint = min([numnodes,maxprint])
        for eb in gc_result['edge_bindings'][extra_edge][:maxprint]:        
            kge = graph['edges'][eb['id']]
            subject_node = kge['subject']
            object_node = kge['object']
            pred = kge['predicate']
            print( f"  {graph['nodes'][subject_node]['name']} -[{pred}]-> {graph['nodes'][object_node]['name']}")
    print('----')
    
def print_pc_result(knowledge_graph,pc_result,node):
    print('p_value:', pc_result['node_bindings'][node][0]['p_values'])
    print('properties:', pc_result['node_bindings'][node][0]['properties'])
    numnodes = len(pc_result['node_bindings'][node])
    print('node count',numnodes)
    maxprint=5
    nprint = min([numnodes,maxprint])
    for node in pc_result['node_bindings'][node][:nprint]:
        kgn = knowledge_graph['nodes'][node['id']]
        print( f"  {kgn['name']}")
    if numnodes > maxprint:
        print('  ...')
    print('----')

# %% [markdown]
# ## Query Specific

# %%
standup_json='StandupDefinitions/standup_21.json'

# %%
with open(standup_json,'r') as jsonfile:
    standup_info = json.load(jsonfile)

# %%
display(Markdown(f"# {standup_info['Query Title']}"))
display(Markdown(f"{standup_info['Query Description']}"))
print(f'Github Issue: {standup_info["github_issue"]}')
# Out:
# # 21. Script 1c chemical
# Chemical - Gene KCNMA1 (HGNC:6284)
# Github Issue: https://github.com/NCATSTranslator/testing/issues/71

# %% [markdown]
# The query as run through the ARS:

# %%
query = json.loads(requests.get(standup_info['query_location']).content)
printjson(query)
# Out:
# {
#     "message": {
#         "query_graph": {
#             "nodes": {
#                 "n0": {
#                     "categories": [
#                         "biolink:ChemicalSubstance"
#                     ]
#                 },
#                 "n1": {
#                     "ids": [
#                         "HGNC:6284"
#                     ],
#                     "categories": [
#                         "biolink:Gene"
#                     ]
#                 }
#             },
#             "edges": {
#                 "e0": {
#                     "subject": "n0",
#                     "object": "n1"
#                 }
#             }
#         }
#     }
# }

# %% [markdown]
# ## ARS Assessment

# %%
ARS_Responses = [(dt.strptime(x['ARS_result_date'],'%Y-%m-%d'),x['ARS_result_id']) for x in standup_info['ARS_Results']]
ARS_Responses.sort()

# %%
for ars_date, ars_id in ARS_Responses:
    display(Markdown(f'### {ars_date}'))
    _ = retrieve_ars_results(ars_id)
    print(f'https://arax.ncats.io/?source=ARS&id={ars_id}')
# Out:
# ### 2021-06-03 00:00:00
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-14-0443eb881d0c> in <module>
#       1 for ars_date, ars_id in ARS_Responses:
#       2     display(Markdown(f'### {ars_date}'))
# ----> 3     _ = retrieve_ars_results(ars_id)
#       4     print(f'https://arax.ncats.io/?source=ARS&id={ars_id}')
#
# <ipython-input-6-94fc96aaceb4> in retrieve_ars_results(mid)
#       2     message_url = f'https://ars.transltr.io/ars/api/messages/{mid}?trace=y'
#       3     response = requests.get(message_url)
# ----> 4     j = response.json()
#       5     results = {}
#       6     for child in j['children']:
#
# /opt/anaconda3/envs/minihackathons/lib/python3.9/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# /opt/anaconda3/envs/minihackathons/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /opt/anaconda3/envs/minihackathons/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/anaconda3/envs/minihackathons/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Strider Direct

# %%
start = dt.now()
strider_result = strider(query)
end = dt.now()
print(f"Strider produced {len(strider_result['message']['results'])} results in {end-start}.")
# Out:
# Strider produced 123 results in 0:00:41.393737.

# %% [markdown]
# ### Provenance

# %%
prov = get_provenance(strider_result)
display(prov)
# Out:
#   QG Edge                                             Source  Count
# 0      e0         https://automat.renci.org/pharos/1.1/query     52
# 1      e0            https://automat.renci.org/ctd/1.1/query     36
# 2      e0         https://automat.renci.org/mychem/1.1/query     13
# 3      e0      https://automat.renci.org/robokopkg/1.1/query    129
# 4      e0           https://automat.renci.org/hmdb/1.1/query     16
# 5      e0  https://automat.renci.org/cord19-scibite/1.1/q...      2
# 6      e0        https://automat.renci.org/chembio/1.1/query      4

# %% [markdown]
# ### Queried sources

# %%
print_queried_sources(strider_result)

# %% [markdown]
# ### Errors

# %%
print_errors(strider_result)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-28-3d00ec35de1d> in <module>
# ----> 1 print_errors(strider_result)
#
# <ipython-input-5-c22b4cc156f5> in print_errors(strider_result)
#       3     for logmessage in strider_result['logs']:
#       4         if logmessage['level'] == 'ERROR':
# ----> 5             jm = json.loads(logmessage['message'])
#       6             words = jm['error'].split()
#       7             e = " ".join(words[:-5])
#
# /opt/anaconda3/envs/minihackathons/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /opt/anaconda3/envs/minihackathons/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/anaconda3/envs/minihackathons/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ### Results

# %%
view = GammaViewer(props={"data":strider_result})
display(view)

# %% [markdown]
# ### Strider Assessment

# %% [markdown]
# Enter Assessment Here

# %% [markdown]
# ## ARAGORN

# %%
start = dt.now()
aragorn_result = aragorn(query)
end = dt.now()
if 'results' in aragorn_result['message']:
    print(f"ARAGORN produced {len(aragorn_result['message']['results'])} results in {end-start}.")
else:
    print('Error, no result field')
# Out:
# ARAGORN produced 883 results in 0:02:18.201895.

# %%
view = GammaViewer(props={"data":aragorn_result})
display(view)

# %%
node='n0' #this might need to change based on the query
property_answers = filter_to_pc(aragorn_result,node)
for pc_result in property_answers['message']['results']:
    print_pc_result(aragorn_result['message']['knowledge_graph'],pc_result,node)
# Out:
# 275
# p_value: [1.4198210164880847e-09, 2.6029918491330954e-09, 2.6029918491330954e-09, 3.5889613377891098e-09, 2.9223150662589873e-08, 3.730750911147743e-08, 7.2167820056376e-08, 1.3096214565466716e-07, 1.7981725149422116e-07, 3.40921990632363e-07, 4.952722010973931e-07, 5.078484306901876e-07, 5.270083315029566e-07, 8.324840533458494e-07, 8.406044111949419e-07, 2.298446107288386e-06, 2.7787386302036648e-06, 3.601319091793038e-06, 5.565687897605218e-06, 1.8542887608806634e-05, 3.891719344771636e-05, 9.111620548329211e-05]
# properties: ['Benzothiadiazines', 'Increased Diuresis', 'Thiazides', 'Sodium Chloride Symporter Inhibitors', 'diuretic', 'Natriuretic Agents', 'Diuretics', 'Sulfonamides', 'Gynecological Antiinfectives and Antiseptics', 'Sulfones', 'Membrane Transport Modulators', 'Hypotensive Agents', 'Antihypertensive Agents', 'antihypertensive_agent', 'Genito Urinary System and Sex Hormones', 'Amides', 'Cardiovascular Agents', 'cardiovascular_drug', 'Sulfur Compounds', 'Heterocyclic Compounds, Fused-Ring', 'oral', 'drugbank.approved']
# node count 2
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [3.852266794909273e-07]
# properties: ['therapeutic_flag']
# node count 3
#   Flindokalner
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [2.038488866386128e-12]
# properties: ['drugbank.vet_approved']
# node count 6
#   Hydrochlorothiazide
#   Pergolide
#   Halothane
#   Toluene
#   Miconazole
#   ...
# ----
# p_value: [4.973953814826612e-09, 3.253952725359222e-08]
# properties: ['drugbank.approved', 'therapeutic_flag']
# node count 7
#   Hydrochlorothiazide
#   Cromolyn
#   Pergolide
#   Halothane
#   Miconazole
#   ...
# ----
# p_value: [1.0287425003131642e-08]
# properties: ['Genito Urinary System and Sex Hormones']
# node count 4
#   Hydrochlorothiazide
#   Miconazole
#   Dequalinium
#   Progesterone
# ----
# p_value: [1.8994907900566742e-07]
# properties: ['Gynecological Antiinfectives and Antiseptics']
# node count 3
#   Hydrochlorothiazide
#   Miconazole
#   Dequalinium
# ----
# p_value: [2.14979244212456e-07]
# properties: ['topical']
# node count 4
#   Miconazole
#   Cromolyn
#   Progesterone
#   Halothane
# ----
# p_value: [1.1289412528027133e-06, 1.3114105643615957e-06, 3.9058926802677605e-06]
# properties: ['Cytochrome P-450 CYP3A4 Substrates', 'Cytochrome P-450 CYP3A Substrates', 'Cytochrome P-450 Substrates']
# node count 4
#   Miconazole
#   Pergolide
#   Progesterone
#   Halothane
# ----
# p_value: [3.158203894386266e-06, 3.466396107623068e-06, 4.081957952521912e-05]
# properties: ['drug', 'pharmaceutical', 'application']
# node count 7
#   Hydrochlorothiazide
#   Cromolyn
#   Pergolide
#   Halothane
#   Toluene
#   ...
# ----
# p_value: [4.022876292634458e-06]
# properties: ['Dermatologicals']
# node count 3
#   Miconazole
#   Cromolyn
#   Dequalinium
# ----
# p_value: [4.397018366044429e-06, 3.4431142254581205e-05]
# properties: ['Cytochrome P-450 CYP3A Inhibitors', 'Cytochrome P-450 Enzyme Inhibitors']
# node count 3
#   Miconazole
#   Pergolide
#   Progesterone
# ----
# p_value: [4.787102115230931e-06]
# properties: ['Heterocyclic Compounds, Fused-Ring']
# node count 4
#   Hydrochlorothiazide
#   Cromolyn
#   Pergolide
#   Dequalinium
# ----
# p_value: [5.515487725071365e-06]
# properties: ['molecule_type:Small molecule']
# node count 41
#   2-Hydroxy-N-(2-nitrophenyl)benzamide
#   N-(5-Chloro-2-hydroxyphenyl)-2-ethoxybenzamide
#   (2-Hydroxyphenyl)(5-fluoro-1H-benzotriazole-1-yl) ketone
#   5-Chloro-2-hydroxy-N-(2-methoxy-4-nitrophenyl)benzamide
#   5-Chloro-N-(2-hydroxy-5-methylphenyl)-2-methoxybenzamide
#   ...
# ----
# p_value: [5.7710528180400505e-06]
# properties: ['Antidiarrheals, Intestinal Antiinflammatory/antiinfective Agents']
# node count 2
#   Miconazole
#   Cromolyn
# ----
# p_value: [2.0403006695158507e-05]
# properties: ['oral']
# node count 4
#   Hydrochlorothiazide
#   Cromolyn
#   Pergolide
#   Progesterone
# ----
# p_value: [2.5751688468187114e-05, 7.807521742481401e-05]
# properties: ['Cytochrome P-450 CYP2C19 inhibitors (strength unknown)', 'Cytochrome P-450 CYP2C19 Inhibitors']
# node count 2
#   Miconazole
#   Progesterone
# ----
# p_value: [5.2857988866740214e-05]
# properties: ['Cytochrome P-450 CYP2D6 Inhibitors (strength unknown)']
# node count 2
#   Miconazole
#   Pergolide
# ----
# p_value: [6.999923708105896e-05]
# properties: ['Hyperglycemia-Associated Agents']
# node count 2
#   Hydrochlorothiazide
#   Progesterone
# ----
# p_value: [5.5748029044531066e-08]
# properties: ['drugbank.approved']
# node count 5
#   Ethanol
#   Bendroflumethiazide
#   Chlorzoxazone
#   Hydroflumethiazide
#   Estradiol
# ----
# p_value: [8.091430641712834e-08, 1.48329964283483e-07, 1.48329964283483e-07, 2.045036719432946e-07, 1.6640349803069579e-06, 2.1240869277917008e-06, 4.106934028408685e-06, 7.448529360821423e-06, 1.0223270541701228e-05, 1.9363596619562294e-05, 2.8109580726009318e-05, 2.8821778985894128e-05, 2.990670236991801e-05, 4.718764505601706e-05]
# properties: ['Benzothiadiazines', 'Increased Diuresis', 'Thiazides', 'Sodium Chloride Symporter Inhibitors', 'diuretic', 'Natriuretic Agents', 'Diuretics', 'Sulfonamides', 'Gynecological Antiinfectives and Antiseptics', 'Sulfones', 'Membrane Transport Modulators', 'Hypotensive Agents', 'Antihypertensive Agents', 'antihypertensive_agent']
# node count 2
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [8.855274550283674e-08, 2.5855689099621977e-06, 4.854644479101057e-06, 5.435863503893832e-06, 1.2402289710247026e-05]
# properties: ['Cytochrome P-450 CYP1A2 Substrates', 'Cytochrome P-450 Enzyme Inhibitors', 'Cytochrome P-450 CYP3A4 Substrates', 'Cytochrome P-450 CYP3A Substrates', 'Cytochrome P-450 Substrates']
# node count 3
#   Estradiol
#   Ethanol
#   Chlorzoxazone
# ----
# p_value: [1.4186282967954475e-07]
# properties: ['Genito Urinary System and Sex Hormones']
# node count 3
#   Estradiol
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [2.1746369139580313e-07]
# properties: ['therapeutic_flag']
# node count 5
#   Chlorzoxazone
#   Bendroflumethiazide
#   Hydroflumethiazide
#   Flindokalner
#   Estradiol
# ----
# p_value: [6.259263695051877e-07]
# properties: ['oral']
# node count 4
#   Bendroflumethiazide
#   Estradiol
#   Chlorzoxazone
#   Hydroflumethiazide
# ----
# p_value: [2.222817084379647e-06, 3.972395869662428e-06, 6.891532696963129e-05, 8.281206421710943e-05, 8.648392202542116e-05]
# properties: ['Cytochrome P-450 CYP3A4 Inhibitors (weak)', 'Cytochrome P-450 CYP2E1 Substrates', 'Cytochrome P-450 CYP3A4 Inhibitors', 'Cytochrome P-450 CYP3A Inhibitors', 'central_nervous_system_depressant']
# node count 2
#   Ethanol
#   Chlorzoxazone
# ----
# p_value: [1.2710009277837232e-05]
# properties: ['Hyperglycemia-Associated Agents']
# node count 2
#   Estradiol
#   Bendroflumethiazide
# ----
# p_value: [1.446716752427261e-05]
# properties: ['Heterocyclic Compounds, Fused-Ring']
# node count 3
#   Bendroflumethiazide
#   Chlorzoxazone
#   Hydroflumethiazide
# ----
# p_value: [2.4351066401073697e-05, 3.764901972849685e-05, 4.1852137584677285e-05, 6.244195812591984e-05]
# properties: ['Cytochrome P-450 CYP3A4 Inducers (strength unknown)', 'Cytochrome P-450 CYP3A4 Inducers', 'Cytochrome P-450 CYP3A Inducers', 'Cytochrome P-450 Enzyme Inducers']
# node count 2
#   Estradiol
#   Ethanol
# ----
# p_value: [4.0938873284065865e-06, 1.536794230546433e-05]
# properties: ['Hyperglycemia-Associated Agents', 'Genito Urinary System and Sex Hormones']
# node count 2
#   Diazoxide
#   Estradiol
# ----
# p_value: [6.084513997099509e-05]
# properties: ['therapeutic_flag']
# node count 3
#   Diazoxide
#   Estradiol
#   Flindokalner
# ----
# p_value: [1.833866515298574e-08, 4.4062988701304977e-07, 1.3789890843106206e-06, 2.0245310787121444e-06, 3.858378348558863e-06]
# properties: ['Antidiarrheals, Intestinal Antiinflammatory/antiinfective Agents', 'Sensory Organs', 'Dermatologicals', 'Alimentary Tract and Metabolism', 'topical']
# node count 2
#   Miconazole
#   Cromolyn
# ----
# p_value: [1.6819428445002239e-07, 3.852266794909273e-07]
# properties: ['drugbank.approved', 'therapeutic_flag']
# node count 3
#   Hydrochlorothiazide
#   Miconazole
#   Cromolyn
# ----
# p_value: [1.7981725149422116e-07, 8.406044111949419e-07, 2.0245310787121444e-06]
# properties: ['Gynecological Antiinfectives and Antiseptics', 'Genito Urinary System and Sex Hormones', 'drugbank.vet_approved']
# node count 2
#   Hydrochlorothiazide
#   Miconazole
# ----
# p_value: [1.8542887608806634e-05, 3.891719344771636e-05]
# properties: ['Heterocyclic Compounds, Fused-Ring', 'oral']
# node count 2
#   Hydrochlorothiazide
#   Cromolyn
# ----
# p_value: [1.4198210164880847e-09, 2.6029918491330954e-09, 2.6029918491330954e-09, 3.5889613377891098e-09, 2.9223150662589873e-08, 3.730750911147743e-08, 7.2167820056376e-08, 1.3096214565466716e-07, 1.7981725149422116e-07, 3.40921990632363e-07, 4.952722010973931e-07, 5.078484306901876e-07, 5.270083315029566e-07, 8.324840533458494e-07, 8.406044111949419e-07, 2.298446107288386e-06, 2.7787386302036648e-06, 3.601319091793038e-06, 5.565687897605218e-06]
# properties: ['Benzothiadiazines', 'Increased Diuresis', 'Thiazides', 'Sodium Chloride Symporter Inhibitors', 'diuretic', 'Natriuretic Agents', 'Diuretics', 'Sulfonamides', 'Gynecological Antiinfectives and Antiseptics', 'Sulfones', 'Membrane Transport Modulators', 'Hypotensive Agents', 'Antihypertensive Agents', 'antihypertensive_agent', 'Genito Urinary System and Sex Hormones', 'Amides', 'Cardiovascular Agents', 'cardiovascular_drug', 'Sulfur Compounds']
# node count 2
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [1.538133315810867e-08, 4.684195150955309e-08, 1.6819428445002239e-07, 3.852266794909273e-07, 3.02193770834427e-06, 3.1540408286920396e-06, 9.98531972766535e-06]
# properties: ['Heterocyclic Compounds, Fused-Ring', 'oral', 'drugbank.approved', 'therapeutic_flag', 'drug', 'pharmaceutical', 'application']
# node count 3
#   Bendroflumethiazide
#   Chlorzoxazone
#   Hydroflumethiazide
# ----
# p_value: [5.296181119535818e-05]
# properties: ['therapeutic_flag']
# node count 2
#   Flindokalner
#   Estradiol
# ----
# p_value: [9.111620548329211e-05]
# properties: ['drugbank.approved']
# node count 2
#   CID 22326046
#   Linoleic acid
# ----
# p_value: [5.994871568899997e-08, 2.802996857905803e-07, 6.752118503921037e-07, 3.0484198007490766e-05, 5.296181119535818e-05]
# properties: ['Gynecological Antiinfectives and Antiseptics', 'Genito Urinary System and Sex Hormones', 'drugbank.vet_approved', 'drugbank.approved', 'therapeutic_flag']
# node count 2
#   Hydrochlorothiazide
#   Miconazole
# ----
# p_value: [1.072711482296507e-08, 1.656370080772124e-08, 4.7271036527377365e-07, 4.813823042636279e-07, 4.813823042636279e-07, 8.004815422791671e-07, 1.3709327506795327e-06]
# properties: ['Oxides', 'Oxygen Compounds', 'Electrolytes', 'Anions', 'Ions', 'Noxae', 'Toxic Actions']
# node count 2
#   Carbon monoxide
#   Hypochlorous acid
# ----
# p_value: [6.453014782790147e-06, 2.0690634032338777e-05, 2.6271150280704374e-05]
# properties: ['human_metabolite', 'mammalian_metabolite', 'animal_metabolite']
# node count 3
#   Carbon monoxide
#   Hydron;2,2,2-trifluoroacetate
#   Hypochlorous acid
# ----
# p_value: [8.394535793686814e-06, 1.2437018227594604e-05, 2.7331494264924287e-05]
# properties: ['metabolite', 'biochemical_role', 'biological_role']
# node count 4
#   Carbon monoxide
#   Tetrandrine
#   Hydron;2,2,2-trifluoroacetate
#   Hypochlorous acid
# ----
# p_value: [1.3003625791872499e-05, 5.296181119535818e-05]
# properties: ['oral', 'therapeutic_flag']
# node count 2
#   Diazoxide
#   Cromolyn sodium
# ----
# p_value: [9.275705461470757e-10]
# properties: ['drugbank.approved']
# node count 4
#   Procaine
#   Dequalinium
#   Halothane
#   Trimebutine
# ----
# p_value: [1.348767717024092e-08, 2.3074338487517425e-07, 3.9032465575685535e-07, 4.046854559463563e-06, 8.496099843817277e-06, 1.1543322353165687e-05, 1.5644869087909672e-05]
# properties: ['NMDA Receptor Antagonists', 'Anesthetics', 'anaesthetic', 'drugbank.vet_approved', 'Nervous System', 'Central Nervous System Depressants', 'Central Nervous System Agents']
# node count 2
#   Procaine
#   Halothane
# ----
# p_value: [8.345326717474655e-07, 8.928597948309788e-07, 2.130282467782815e-06, 6.223315044570329e-06, 7.606817758206547e-06]
# properties: ['Benzoates', 'Anticholinergic Agents', 'Acids, Carbocyclic', 'Benzene Derivatives', 'Peripheral Nervous System Agents']
# node count 2
#   Procaine
#   Trimebutine
# ----
# p_value: [1.5325036254618058e-06, 1.195672704907236e-05, 1.2477446837383407e-05, 3.9296363532509174e-05]
# properties: ['therapeutic_flag', 'drug', 'pharmaceutical', 'application']
# node count 3
#   Procaine
#   Dequalinium
#   Halothane
# ----
# p_value: [1.7796063507436808e-05, 1.9197008978837797e-05, 3.338566631715035e-05]
# properties: ['Cytochrome P-450 CYP3A4 Substrates', 'Cytochrome P-450 CYP3A Substrates', 'Cytochrome P-450 Substrates']
# node count 2
#   Trimebutine
#   Halothane
# ----
# p_value: [9.737186942834701e-05]
# properties: ['drugbank.investigational']
# node count 2
#   Procaine
#   Dequalinium
# ----
# p_value: [4.732793343868404e-10, 8.676787797092094e-10, 8.676787797092094e-10, 1.196344984144516e-09, 9.741666299462462e-09, 1.2436729175832025e-08, 2.405836616466436e-08, 4.366001859718601e-08, 5.994871568899997e-08, 1.1366592014190619e-07, 1.6513504775647593e-07, 1.6932882852506938e-07, 1.7571809953929336e-07, 2.77591476266036e-07, 2.802996857905803e-07, 7.665942018730103e-07, 9.268386965076685e-07, 1.2013144171552388e-06, 1.856911468465754e-06, 6.191216759432129e-06, 1.3003625791872499e-05, 3.0484198007490766e-05, 5.296181119535818e-05]
# properties: ['Benzothiadiazines', 'Increased Diuresis', 'Thiazides', 'Sodium Chloride Symporter Inhibitors', 'diuretic', 'Natriuretic Agents', 'Diuretics', 'Sulfonamides', 'Gynecological Antiinfectives and Antiseptics', 'Sulfones', 'Membrane Transport Modulators', 'Hypotensive Agents', 'Antihypertensive Agents', 'antihypertensive_agent', 'Genito Urinary System and Sex Hormones', 'Amides', 'Cardiovascular Agents', 'cardiovascular_drug', 'Sulfur Compounds', 'Heterocyclic Compounds, Fused-Ring', 'oral', 'drugbank.approved', 'therapeutic_flag']
# node count 2
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [2.552016545202061e-15, 3.4566348263201605e-13]
# properties: ['oral', 'therapeutic_flag']
# node count 7
#   Ketorolac
#   Phenylephrine
#   Chlorzoxazone
#   Pinacidil
#   Losartan potassium
#   ...
# ----
# p_value: [1.2711157007599106e-11]
# properties: ['drugbank.approved']
# node count 6
#   Phenylephrine
#   Chlorzoxazone
#   Pinacidil
#   Vorinostat
#   Clotrimazole
#   ...
# ----
# p_value: [4.338260421422282e-09, 3.253395012794563e-08, 5.638957781861385e-08, 8.061883033840374e-06, 8.169970547076264e-06, 4.2680916210181235e-05]
# properties: ['Sympathomimetics Excl. Antiglaucoma Preparations', 'Mydriatics and Cycloplegics', 'Mydriatics', 'Sensory Organs', 'Ophthalmologicals', 'Agents that produce hypertension']
# node count 2
#   Phenylephrine
#   Ketorolac
# ----
# p_value: [1.0103088060444722e-08]
# properties: ['Cytochrome P-450 Substrates']
# node count 4
#   Clotrimazole
#   Chlorzoxazone
#   Pinacidil
#   Ketorolac
# ----
# p_value: [2.3849952276226235e-07]
# properties: ['topical']
# node count 3
#   Phenylephrine
#   Clotrimazole
#   Ketorolac
# ----
# p_value: [2.7114596348834224e-07, 2.9088584503683915e-07, 1.9181911625569623e-06]
# properties: ['drug', 'pharmaceutical', 'application']
# node count 5
#   Phenylephrine
#   Chlorzoxazone
#   Vorinostat
#   Clotrimazole
#   Ketorolac
# ----
# p_value: [3.991576683820786e-07, 4.45403846507717e-05]
# properties: ['Enzyme Inhibitors', 'inhibitor']
# node count 3
#   Ketorolac
#   Clotrimazole
#   Vorinostat
# ----
# p_value: [8.352035083314186e-07, 9.355715451611056e-07]
# properties: ['Cytochrome P-450 CYP3A4 Substrates', 'Cytochrome P-450 CYP3A Substrates']
# node count 3
#   Chlorzoxazone
#   Pinacidil
#   Clotrimazole
# ----
# p_value: [1.1941983169880571e-06, 2.224070693234688e-05, 2.67342970682855e-05]
# properties: ['Cytochrome P-450 CYP2E1 Inhibitors', 'Cytochrome P-450 CYP3A4 Inhibitors', 'Cytochrome P-450 CYP3A Inhibitors']
# node count 2
#   Chlorzoxazone
#   Clotrimazole
# ----
# p_value: [6.722105010351201e-06]
# properties: ['Musculo-Skeletal System']
# node count 2
#   Chlorzoxazone
#   Ketorolac
# ----
# p_value: [2.0148284706695425e-05]
# properties: ['Cytochrome P-450 Enzyme Inducers']
# node count 2
#   Phenylephrine
#   Clotrimazole
# ----
# p_value: [5.068368723626811e-05]
# properties: ['Cardiovascular Agents']
# node count 2
#   Phenylephrine
#   Pinacidil
# ----
# p_value: [6.321475293051707e-05]
# properties: ['Amines']
# node count 2
#   Phenylephrine
#   Vorinostat
# ----
# p_value: [6.936473177435439e-05]
# properties: ['Peripheral Nervous System Agents']
# node count 2
#   Phenylephrine
#   Chlorzoxazone
# ----
# p_value: [1.0845317370420608e-08, 4.5529316451944257e-07, 8.497106292635839e-07, 7.325379238889835e-06, 1.2539098792708433e-05, 2.5190713380436417e-05]
# properties: ['Oxidants', 'Antiseptics and Disinfectants', 'Anti-Infective Agents, Local', 'Noxae', 'Toxic Actions', 'Dermatologicals']
# node count 2
#   CID 22326046
#   N-Chloro-p-toluenesulfonamide
# ----
# p_value: [1.9891804879512388e-07]
# properties: ['Compounds used in a research, industrial, or household setting']
# node count 3
#   N-Ethylmaleimide
#   CID 22326046
#   N-Chloro-p-toluenesulfonamide
# ----
# p_value: [2.9757609767340255e-05]
# properties: ['drugbank.experimental']
# node count 3
#   N-Ethylmaleimide
#   N-Chloro-p-toluenesulfonamide
#   Linoleic acid
# ----
# p_value: [2.972745810792925e-13, 7.785583174561709e-13, 3.233530415506796e-11, 1.2731706704119597e-10, 3.1323640435231733e-10, 5.053116276118675e-10, 7.01905735524395e-10, 1.3246614665975873e-09, 2.5512667746779457e-09, 5.073647817362958e-09, 5.148220672207072e-09, 2.332781074427904e-08, 3.1016419308551057e-08, 4.5772894730876356e-08, 8.795519557839466e-08]
# properties: ['Benzothiadiazines', 'Thiazides', 'diuretic', 'Diuretics', 'Sulfonamides', 'Gynecological Antiinfectives and Antiseptics', 'Hyperglycemia-Associated Agents', 'Sulfones', 'Antihypertensive Agents', 'antihypertensive_agent', 'Genito Urinary System and Sex Hormones', 'Amides', 'Cardiovascular Agents', 'cardiovascular_drug', 'Sulfur Compounds']
# node count 3
#   Diazoxide
#   Trichlormethiazide
#   Chlorothiazide
# ----
# p_value: [1.0290832011805648e-12, 6.303402210568319e-11, 6.865468246252186e-11, 6.84353360884122e-10]
# properties: ['therapeutic_flag', 'drug', 'pharmaceutical', 'application']
# node count 6
#   Diazoxide
#   Cromolyn sodium
#   Enflurane
#   Chlorzoxazone
#   Trichlormethiazide
#   ...
# ----
# p_value: [1.2660916817122347e-11]
# properties: ['oral']
# node count 5
#   Diazoxide
#   Cromolyn sodium
#   Chlorzoxazone
#   Trichlormethiazide
#   Chlorothiazide
# ----
# p_value: [1.0639080395081944e-10]
# properties: ['drugbank.approved']
# node count 5
#   Diazoxide
#   Chlorzoxazone
#   Enflurane
#   Trichlormethiazide
#   Chlorothiazide
# ----
# p_value: [1.3281470894745026e-09]
# properties: ['Heterocyclic Compounds, Fused-Ring']
# node count 4
#   Diazoxide
#   Trichlormethiazide
#   Chlorzoxazone
#   Chlorothiazide
# ----
# p_value: [1.928104015261745e-08]
# properties: ['drugbank.vet_approved']
# node count 3
#   Trichlormethiazide
#   Chlorothiazide
#   Enflurane
# ----
# p_value: [2.512066826051319e-08, 2.6107758242353714e-07, 3.4631858114131564e-06]
# properties: ['Sodium Chloride Symporter Inhibitors', 'Natriuretic Agents', 'Membrane Transport Modulators']
# node count 2
#   Trichlormethiazide
#   Chlorothiazide
# ----
# p_value: [4.884187469523172e-07, 4.0289898721894634e-05, 5.458069199351924e-05]
# properties: ['Cytochrome P-450 CYP2E1 Substrates', 'Central Nervous System Depressants', 'Central Nervous System Agents']
# node count 2
#   Chlorzoxazone
#   Enflurane
# ----
# p_value: [3.5510764106823477e-06, 9.228274456401271e-05]
# properties: ['Hypotensive Agents', 'parenteral']
# node count 2
#   Diazoxide
#   Chlorothiazide
# ----
# p_value: [2.6927325469558004e-05]
# properties: ['topical']
# node count 2
#   Cromolyn sodium
#   Enflurane
# ----
# p_value: [2.8171876615686264e-14]
# properties: ['drugbank.approved']
# node count 6
#   Hydrochlorothiazide
#   Halothane
#   Dequalinium
#   Procaine
#   Miconazole
#   ...
# ----
# p_value: [6.7448715713359165e-12]
# properties: ['drugbank.vet_approved']
# node count 4
#   Hydrochlorothiazide
#   Miconazole
#   Procaine
#   Halothane
# ----
# p_value: [1.2141740991227413e-10]
# properties: ['therapeutic_flag']
# node count 5
#   Hydrochlorothiazide
#   Halothane
#   Procaine
#   Miconazole
#   Dequalinium
# ----
# p_value: [2.8880114613862374e-10, 2.9429947532685176e-09]
# properties: ['Gynecological Antiinfectives and Antiseptics', 'Genito Urinary System and Sex Hormones']
# node count 3
#   Hydrochlorothiazide
#   Miconazole
#   Dequalinium
# ----
# p_value: [3.371723337729569e-08, 5.767105785115693e-07, 9.754847741873358e-07, 2.1206652927413467e-05, 2.8805073766561564e-05, 3.9028145880471216e-05]
# properties: ['NMDA Receptor Antagonists', 'Anesthetics', 'anaesthetic', 'Nervous System', 'Central Nervous System Depressants', 'Central Nervous System Agents']
# node count 2
#   Procaine
#   Halothane
# ----
# p_value: [1.01891179376232e-07, 1.1416418882258295e-07, 2.619289240223515e-07]
# properties: ['Cytochrome P-450 CYP3A4 Substrates', 'Cytochrome P-450 CYP3A Substrates', 'Cytochrome P-450 Substrates']
# node count 3
#   Miconazole
#   Trimebutine
#   Halothane
# ----
# p_value: [6.400637124909633e-07, 6.774155963065488e-07, 3.114511595969003e-06]
# properties: ['drug', 'pharmaceutical', 'application']
# node count 4
#   Hydrochlorothiazide
#   Procaine
#   Dequalinium
#   Halothane
# ----
# p_value: [1.3049825160347069e-06]
# properties: ['drugbank.investigational']
# node count 3
#   Procaine
#   Miconazole
#   Dequalinium
# ----
# p_value: [2.0853048572883642e-06, 2.2310127625099463e-06, 5.321501948173301e-06, 1.5537237561139143e-05, 1.898858748195113e-05]
# properties: ['Benzoates', 'Anticholinergic Agents', 'Acids, Carbocyclic', 'Benzene Derivatives', 'Peripheral Nervous System Agents']
# node count 2
#   Procaine
#   Trimebutine
# ----
# p_value: [2.20147797853502e-06, 6.600858519367818e-05]
# properties: ['Sensory Organs', 'parenteral']
# node count 2
#   Miconazole
#   Procaine
# ----
# p_value: [2.5371725838033512e-06]
# properties: ['Hypotensive Agents']
# node count 2
#   Hydrochlorothiazide
#   Halothane
# ----
# p_value: [3.244081436447419e-06, 1.14722091624008e-05]
# properties: ['Potential QTc-Prolonging Agents', 'QTc Prolonging Agents']
# node count 2
#   Hydrochlorothiazide
#   Trimebutine
# ----
# p_value: [6.885652144372743e-06, 2.998499412723667e-05]
# properties: ['Dermatologicals', 'Anti-Infective Agents']
# node count 2
#   Miconazole
#   Dequalinium
# ----
# p_value: [1.0106108539182216e-05]
# properties: ['Alimentary Tract and Metabolism']
# node count 2
#   Miconazole
#   Trimebutine
# ----
# p_value: [1.9248307425752365e-05]
# properties: ['topical']
# node count 2
#   Miconazole
#   Halothane
# ----
# p_value: [9.225471350986952e-05]
# properties: ['Heterocyclic Compounds, Fused-Ring']
# node count 2
#   Hydrochlorothiazide
#   Dequalinium
# ----
# p_value: [3.419847672810566e-22]
# properties: ['drugbank.approved']
# node count 15
#   Diazoxide
#   Chlorpromazine
#   Halothane
#   Masoprocol
#   Linoleic acid
#   ...
# ----
# p_value: [2.0514156506560096e-20]
# properties: ['therapeutic_flag']
# node count 15
#   Diazoxide
#   Chlorpromazine
#   Cromolyn sodium
#   Halothane
#   Masoprocol
#   ...
# ----
# p_value: [3.384063114362462e-15, 3.666949635302836e-13]
# properties: ['Gynecological Antiinfectives and Antiseptics', 'Genito Urinary System and Sex Hormones']
# node count 6
#   Diazoxide
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Hydroflumethiazide
#   Miconazole
#   ...
# ----
# p_value: [7.415757791579472e-15]
# properties: ['application']
# node count 16
#   Diazoxide
#   Chlorpromazine
#   Rottlerin
#   Aminocarb
#   Cromolyn sodium
#   ...
# ----
# p_value: [1.3471391162162934e-14, 1.6332822506091667e-14]
# properties: ['drug', 'pharmaceutical']
# node count 14
#   Diazoxide
#   Chlorpromazine
#   Rottlerin
#   Cromolyn sodium
#   Halothane
#   ...
# ----
# p_value: [2.6875029666848894e-14]
# properties: ['drugbank.vet_approved']
# node count 7
#   Hydrochlorothiazide
#   Chlorpromazine
#   Halothane
#   Miconazole
#   Procaine
#   ...
# ----
# p_value: [3.263722640539901e-14, 1.2818059792751736e-13, 2.1243588023705134e-11, 1.3449789892373538e-10, 4.498743450766179e-10, 3.0928619591473737e-09, 7.413361106468373e-09, 1.4049238799643485e-07, 2.0491354418306642e-07]
# properties: ['Benzothiadiazines', 'Thiazides', 'diuretic', 'Diuretics', 'Sulfonamides', 'Sulfones', 'Antihypertensive Agents', 'Amides', 'Cardiovascular Agents']
# node count 4
#   Diazoxide
#   Bendroflumethiazide
#   Hydrochlorothiazide
#   Hydroflumethiazide
# ----
# p_value: [7.98428551161702e-14]
# properties: ['Hypotensive Agents']
# node count 6
#   Diazoxide
#   Chlorpromazine
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Halothane
#   ...
# ----
# p_value: [2.578249212252794e-13]
# properties: ['topical']
# node count 7
#   Chlorpromazine
#   Benzyl alcohol
#   Halothane
#   Cromolyn sodium
#   Masoprocol
#   ...
# ----
# p_value: [7.333506694490273e-13]
# properties: ['drugbank.investigational']
# node count 9
#   Chlorpromazine
#   Masoprocol
#   Aldosterone
#   Procaine
#   Emodepside
#   ...
# ----
# p_value: [4.2642623471901366e-11]
# properties: ['Cytochrome P-450 Substrates']
# node count 7
#   Chlorpromazine
#   Arachidonic acid
#   Benzyl alcohol
#   Halothane
#   Trimebutine
#   ...
# ----
# p_value: [9.01331365277004e-11, 3.502253112962774e-09]
# properties: ['antihypertensive_agent', 'cardiovascular_drug']
# node count 5
#   Diazoxide
#   Hydrochlorothiazide
#   Rottlerin
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [2.9637777741551786e-10]
# properties: ['Central Nervous System Agents']
# node count 6
#   Chlorpromazine
#   Benzyl alcohol
#   Halothane
#   Masoprocol
#   Procaine
#   ...
# ----
# p_value: [3.1317367324017454e-10]
# properties: ['P-glycoprotein inhibitors']
# node count 5
#   Chlorpromazine
#   Benzyl alcohol
#   Miconazole
#   Cholesterol
#   Ether
# ----
# p_value: [3.482425963764614e-10]
# properties: ['Anesthetics']
# node count 4
#   Procaine
#   Benzyl alcohol
#   Halothane
#   Ether
# ----
# p_value: [4.6288957820733193e-10, 7.657304816422888e-10, 2.7783774372672378e-08, 1.3644780461664452e-06]
# properties: ['Increased Diuresis', 'Sodium Chloride Symporter Inhibitors', 'Natriuretic Agents', 'Membrane Transport Modulators']
# node count 3
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [9.570747602345183e-10, 2.0469809109676297e-06, 2.1152003569366856e-06, 4.805425298235842e-06]
# properties: ['Daphnia_galeata_metabolite', 'Daphnia_metabolite', 'crustacean_metabolite', 'Lipids']
# node count 3
#   Arachidonic acid
#   Cholesterol
#   Linoleic acid
# ----
# p_value: [1.3241616906636422e-09]
# properties: ['Hyperglycemia-Associated Agents']
# node count 4
#   Diazoxide
#   Chlorpromazine
#   Bendroflumethiazide
#   Hydrochlorothiazide
# ----
# p_value: [3.837179826898573e-09]
# properties: ['Heterocyclic Compounds, Fused-Ring']
# node count 6
#   Diazoxide
#   Chlorpromazine
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Hydroflumethiazide
#   ...
# ----
# p_value: [4.01937610417936e-09]
# properties: ['Peripheral Nervous System Agents']
# node count 5
#   Chlorpromazine
#   Benzyl alcohol
#   Masoprocol
#   Trimebutine
#   Procaine
# ----
# p_value: [7.871787099503138e-09]
# properties: ['biological_role']
# node count 18
#   Diazoxide
#   Chlorpromazine
#   Rottlerin
#   Arachidonic acid
#   Cromolyn sodium
#   ...
# ----
# p_value: [1.033344560496385e-08]
# properties: ['Sulfur Compounds']
# node count 5
#   Diazoxide
#   Chlorpromazine
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [1.1334651754731745e-08]
# properties: ['Central Nervous System Depressants']
# node count 5
#   Chlorpromazine
#   Benzyl alcohol
#   Halothane
#   Procaine
#   Ether
# ----
# p_value: [1.6761976426905314e-08]
# properties: ['K_ATP_channel_agonist']
# node count 2
#   Diazoxide
#   Rottlerin
# ----
# p_value: [3.314858156056838e-08, 3.998593466564176e-08]
# properties: ['Cytochrome P-450 CYP3A4 Substrates', 'Cytochrome P-450 CYP3A Substrates']
# node count 5
#   Chlorpromazine
#   Halothane
#   Trimebutine
#   Miconazole
#   Aldosterone
# ----
# p_value: [3.4183547860891466e-08]
# properties: ['oral']
# node count 6
#   Diazoxide
#   Chlorpromazine
#   Hydrochlorothiazide
#   Cromolyn sodium
#   Bendroflumethiazide
#   ...
# ----
# p_value: [1.541827209354095e-07]
# properties: ['chemical_role']
# node count 13
#   Chlorpromazine
#   Arachidonic acid
#   Masoprocol
#   Linoleic acid
#   Bilirubin
#   ...
# ----
# p_value: [2.5693101785550343e-07]
# properties: ['Benzene Derivatives']
# node count 4
#   Procaine
#   Benzyl alcohol
#   Masoprocol
#   Trimebutine
# ----
# p_value: [3.3747208801378066e-07]
# properties: ['anaesthetic']
# node count 3
#   Procaine
#   Halothane
#   Ether
# ----
# p_value: [3.5185412671135807e-07, 1.5084185382487498e-05]
# properties: ['Fatty Acids, Essential', 'Fatty Acids, Unsaturated']
# node count 2
#   Arachidonic acid
#   Linoleic acid
# ----
# p_value: [4.690995453835233e-07]
# properties: ['Low-Ceiling Diuretics and Potassium-Sparing Agents']
# node count 2
#   Hydrochlorothiazide
#   Bendroflumethiazide
# ----
# p_value: [4.766961630050956e-07]
# properties: ['Nervous System']
# node count 4
#   Chlorpromazine
#   Procaine
#   Halothane
#   Ether
# ----
# p_value: [6.398269870012039e-07, 1.09941736579213e-06]
# properties: ['enzyme_inhibitor', 'inhibitor']
# node count 6
#   Chlorpromazine
#   Arachidonic acid
#   Aminocarb
#   Masoprocol
#   Okadaic acid
#   ...
# ----
# p_value: [7.537837118337058e-07, 1.7580923149736354e-06, 1.113080357608784e-05, 1.3700003816245074e-05]
# properties: ['Anesthetics, Inhalation', 'inhalation_anaesthetic', 'Anesthetics, General', 'general_anaesthetic']
# node count 2
#   Halothane
#   Ether
# ----
# p_value: [9.474261327760263e-07]
# properties: ['Anti-Infective Agents']
# node count 4
#   Miconazole
#   Dequalinium
#   Emodepside
#   CID 22326046
# ----
# p_value: [1.1452821430813632e-06]
# properties: ['Sensory Organs']
# node count 3
#   Miconazole
#   Procaine
#   CID 22326046
# ----
# p_value: [1.168389535146699e-06]
# properties: ['Anticholinergic Agents']
# node count 3
#   Chlorpromazine
#   Procaine
#   Trimebutine
# ----
# p_value: [1.523807615071562e-06, 3.865536397654933e-06, 5.018916105974834e-06]
# properties: ['Antiinfectives and Antiseptics for Local Oral Treatment', 'Otologicals', 'Stomatological Preparations']
# node count 2
#   Miconazole
#   CID 22326046
# ----
# p_value: [2.8622199556708496e-06]
# properties: ['NMDA Receptor Antagonists']
# node count 2
#   Procaine
#   Halothane
# ----
# p_value: [3.5144182913152497e-06]
# properties: ['Benzyl Compounds']
# node count 2
#   Benzyl alcohol
#   Masoprocol
# ----
# p_value: [4.401575508510612e-06]
# properties: ['Sensory System Agents']
# node count 3
#   Procaine
#   Benzyl alcohol
#   Masoprocol
# ----
# p_value: [4.5014764344357145e-06]
# properties: ['parenteral']
# node count 4
#   Diazoxide
#   Miconazole
#   Chlorpromazine
#   Procaine
# ----
# p_value: [4.743052295408756e-06]
# properties: ['EC_3.*_(hydrolase)_inhibitor']
# node count 4
#   Aminocarb
#   Chlorpromazine
#   Arachidonic acid
#   Okadaic acid
# ----
# p_value: [6.303368282121573e-06]
# properties: ['Dermatologicals']
# node count 3
#   Miconazole
#   Dequalinium
#   CID 22326046
# ----
# p_value: [6.378800666907536e-06]
# properties: ['biochemical_role']
# node count 13
#   Chlorpromazine
#   Rottlerin
#   Arachidonic acid
#   Aminocarb
#   Masoprocol
#   ...
# ----
# p_value: [7.274381997585244e-06]
# properties: ['Anesthetics, Local']
# node count 2
#   Procaine
#   Benzyl alcohol
# ----
# p_value: [1.0530020184808563e-05, 1.9634654532421778e-05]
# properties: ['Antiseptics and Disinfectants', 'Anti-Infective Agents, Local']
# node count 2
#   Dequalinium
#   CID 22326046
# ----
# p_value: [1.116787759097556e-05]
# properties: ['Alimentary Tract and Metabolism']
# node count 3
#   Miconazole
#   Trimebutine
#   CID 22326046
# ----
# p_value: [1.148249212774949e-05]
# properties: ['drugbank.experimental']
# node count 5
#   Arachidonic acid
#   Okadaic acid
#   Linoleic acid
#   Aldosterone
#   Ether
# ----
# p_value: [1.3487879279108638e-05]
# properties: ['QTc Prolonging Agents']
# node count 3
#   Hydrochlorothiazide
#   Chlorpromazine
#   Trimebutine
# ----
# p_value: [1.3653112005061773e-05]
# properties: ['aetiopathogenetic_role']
# node count 4
#   Cromolyn sodium
#   Procaine
#   CID 22326046
#   Benzidine
# ----
# p_value: [1.3843178978071477e-05]
# properties: ['Agents that produce hypertension']
# node count 3
#   Chlorpromazine
#   Halothane
#   Ether
# ----
# p_value: [1.4696089656776726e-05]
# properties: ['EC_3.1.*_(ester_hydrolase)_inhibitor']
# node count 3
#   Arachidonic acid
#   Aminocarb
#   Okadaic acid
# ----
# p_value: [1.621328297185922e-05]
# properties: ['pharmacological_role']
# node count 5
#   Diazoxide
#   Chlorpromazine
#   Rottlerin
#   Aldosterone
#   CID 22326046
# ----
# p_value: [1.9634654532421778e-05]
# properties: ['Ethers']
# node count 2
#   Trimebutine
#   Ether
# ----
# p_value: [2.2999570237727417e-05, 9.95835775540878e-05]
# properties: ['Cholinesterase Inhibitors', 'Agents that reduce seizure threshold']
# node count 2
#   Chlorpromazine
#   Procaine
# ----
# p_value: [2.431979512116236e-05]
# properties: ['Compounds used in a research, industrial, or household setting']
# node count 3
#   CID 22326046
#   Masoprocol
#   Ether
# ----
# p_value: [2.7577923640453855e-05, 7.116347814498881e-05]
# properties: ['Cytochrome P-450 CYP2E1 Inhibitors', 'Cytochrome P-450 CYP2D6 Inhibitors (strength unknown)']
# node count 2
#   Miconazole
#   Chlorpromazine
# ----
# p_value: [2.952495630559716e-05]
# properties: ['Cytochrome P-450 CYP2E1 Substrates']
# node count 2
#   Benzyl alcohol
#   Halothane
# ----
# p_value: [3.932021223305e-05]
# properties: ['mouse_metabolite']
# node count 5
#   Arachidonic acid
#   Bilirubin
#   Aldosterone
#   Cholesterol
#   CID 22326046
# ----
# p_value: [4.067572811548946e-05]
# properties: ['antioxidant']
# node count 3
#   Bilirubin
#   Benzyl alcohol
#   Masoprocol
# ----
# p_value: [9.24717494708621e-05]
# properties: ['solvent']
# node count 2
#   Benzyl alcohol
#   Ether
# ----
# p_value: [4.4152314519977435e-25]
# properties: ['drugbank.approved']
# node count 14
#   Diazoxide
#   Enflurane
#   Halothane
#   Procaine
#   Trimebutine
#   ...
# ----
# p_value: [5.084245727995787e-24, 5.591896025088302e-23, 1.9720268873036105e-19, 3.3527134926790336e-18, 2.1122864146158016e-17, 3.9404082795891844e-16, 1.4804617673616502e-15, 5.915077731110608e-15, 1.267490301098499e-13, 4.893175545318453e-13, 1.8084682302798462e-12]
# properties: ['Benzothiadiazines', 'Thiazides', 'diuretic', 'Diuretics', 'Sulfonamides', 'Sulfones', 'Antihypertensive Agents', 'antihypertensive_agent', 'Amides', 'cardiovascular_drug', 'Sulfur Compounds']
# node count 6
#   Diazoxide
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Trichlormethiazide
#   Hydroflumethiazide
#   ...
# ----
# p_value: [1.3017340593069618e-23]
# properties: ['Genito Urinary System and Sex Hormones']
# node count 9
#   Diazoxide
#   Chlorothiazide
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Trichlormethiazide
#   ...
# ----
# p_value: [2.0843245068502262e-23]
# properties: ['therapeutic_flag']
# node count 14
#   Diazoxide
#   Enflurane
#   Halothane
#   Flindokalner
#   Procaine
#   ...
# ----
# p_value: [2.207734646704003e-23]
# properties: ['Gynecological Antiinfectives and Antiseptics']
# node count 8
#   Diazoxide
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Trichlormethiazide
#   Hydroflumethiazide
#   ...
# ----
# p_value: [4.2218813100348535e-19]
# properties: ['drugbank.vet_approved']
# node count 8
#   Hydrochlorothiazide
#   Miconazole
#   Enflurane
#   Trichlormethiazide
#   Halothane
#   ...
# ----
# p_value: [2.1476697771774367e-18, 1.1633864922437823e-15]
# properties: ['Sodium Chloride Symporter Inhibitors', 'Natriuretic Agents']
# node count 5
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Trichlormethiazide
#   Hydroflumethiazide
#   Chlorothiazide
# ----
# p_value: [1.088930272153018e-16]
# properties: ['Hyperglycemia-Associated Agents']
# node count 6
#   Diazoxide
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Trichlormethiazide
#   Estradiol
#   ...
# ----
# p_value: [6.388815443123988e-16]
# properties: ['Cardiovascular Agents']
# node count 7
#   Diazoxide
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Trichlormethiazide
#   Hydroflumethiazide
#   ...
# ----
# p_value: [1.2261366180443971e-15]
# properties: ['Membrane Transport Modulators']
# node count 6
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Trichlormethiazide
#   Hydroflumethiazide
#   Chlorothiazide
#   ...
# ----
# p_value: [1.3230985967293632e-15]
# properties: ['Hypotensive Agents']
# node count 6
#   Diazoxide
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Halothane
#   Hydroflumethiazide
#   ...
# ----
# p_value: [3.052158357254944e-15]
# properties: ['Heterocyclic Compounds, Fused-Ring']
# node count 8
#   Diazoxide
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Trichlormethiazide
#   Chlorzoxazone
#   ...
# ----
# p_value: [9.005424662266903e-15]
# properties: ['Increased Diuresis']
# node count 4
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Chlorothiazide
#   Hydroflumethiazide
# ----
# p_value: [5.873368144454852e-14]
# properties: ['oral']
# node count 8
#   Diazoxide
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Trichlormethiazide
#   Chlorzoxazone
#   ...
# ----
# p_value: [6.031632683131203e-14, 7.035215928116619e-14, 4.355949554432199e-12]
# properties: ['drug', 'pharmaceutical', 'application']
# node count 11
#   Diazoxide
#   Enflurane
#   Halothane
#   Procaine
#   Chlorothiazide
#   ...
# ----
# p_value: [1.4360901147724526e-11]
# properties: ['drugbank.investigational']
# node count 7
#   Miconazole
#   Enflurane
#   Dequalinium
#   Estradiol
#   Procaine
#   ...
# ----
# p_value: [1.655938374668154e-11]
# properties: ['Low-Ceiling Diuretics and Potassium-Sparing Agents']
# node count 3
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Trichlormethiazide
# ----
# p_value: [4.8709148575342565e-11]
# properties: ['Cytochrome P-450 Substrates']
# node count 6
#   Miconazole
#   Enflurane
#   Halothane
#   Chlorzoxazone
#   Estradiol
#   ...
# ----
# p_value: [1.1788895135845764e-09, 1.4239464929298118e-09]
# properties: ['Cytochrome P-450 CYP3A4 Substrates', 'Cytochrome P-450 CYP3A Substrates']
# node count 5
#   Miconazole
#   Halothane
#   Chlorzoxazone
#   Estradiol
#   Trimebutine
# ----
# p_value: [1.009471232881126e-08]
# properties: ['Cytochrome P-450 CYP2E1 Substrates']
# node count 3
#   Chlorzoxazone
#   Enflurane
#   Halothane
# ----
# p_value: [2.156192663616255e-08, 4.761264470016167e-08, 4.820581011150054e-06]
# properties: ['Anesthetics', 'anaesthetic', 'Nervous System']
# node count 3
#   Procaine
#   Enflurane
#   Halothane
# ----
# p_value: [2.8221115437003887e-08]
# properties: ['topical']
# node count 4
#   Estradiol
#   Miconazole
#   Enflurane
#   Halothane
# ----
# p_value: [6.309682028278138e-08, 1.1560721873341205e-07]
# properties: ['Central Nervous System Depressants', 'Central Nervous System Agents']
# node count 4
#   Procaine
#   Chlorzoxazone
#   Enflurane
#   Halothane
# ----
# p_value: [2.0758033397642372e-07, 3.0686466700816983e-06, 6.105733535191253e-06]
# properties: ['Anesthetics, Inhalation', 'Anesthetics, General', 'Hydrocarbons, Halogenated']
# node count 2
#   Enflurane
#   Halothane
# ----
# p_value: [3.290832065451646e-07]
# properties: ['parenteral']
# node count 4
#   Diazoxide
#   Miconazole
#   Procaine
#   Chlorothiazide
# ----
# p_value: [7.88501975965436e-07]
# properties: ['NMDA Receptor Antagonists']
# node count 2
#   Procaine
#   Halothane
# ----
# p_value: [4.087329120356154e-06]
# properties: ['Peripheral Nervous System Agents']
# node count 3
#   Procaine
#   Trimebutine
#   Chlorzoxazone
# ----
# p_value: [4.159576079220459e-06]
# properties: ['Cytochrome P-450 CYP2A6 Substrates']
# node count 2
#   Chlorzoxazone
#   Halothane
# ----
# p_value: [4.820581011150054e-06]
# properties: ['Drugs that are Mainly Renally Excreted']
# node count 3
#   Estradiol
#   Trimebutine
#   Chlorzoxazone
# ----
# p_value: [5.415733810417111e-06]
# properties: ['Ethers']
# node count 2
#   Trimebutine
#   Enflurane
# ----
# p_value: [7.60949518987051e-06]
# properties: ['Cytochrome P-450 CYP2E1 Inhibitors']
# node count 2
#   Miconazole
#   Chlorzoxazone
# ----
# p_value: [7.739984500775098e-06]
# properties: ['Cytochrome P-450 Enzyme Inhibitors']
# node count 3
#   Estradiol
#   Miconazole
#   Chlorzoxazone
# ----
# p_value: [9.278167192027431e-06]
# properties: ['OAT3/SLC22A8 Substrates']
# node count 2
#   Hydrochlorothiazide
#   Estradiol
# ----
# p_value: [2.413545534589166e-05]
# properties: ['OAT1/SLC22A6 inhibitors']
# node count 2
#   Hydrochlorothiazide
#   Chlorothiazide
# ----
# p_value: [2.7536416518427064e-05]
# properties: ['Agents that reduce seizure threshold']
# node count 2
#   Procaine
#   Enflurane
# ----
# p_value: [3.6146977008921956e-05]
# properties: ['Bradycardia-Causing Agents']
# node count 2
#   Trimebutine
#   Bendroflumethiazide
# ----
# p_value: [4.854464029812433e-05, 5.192731791479194e-05]
# properties: ['Benzoates', 'Anticholinergic Agents']
# node count 2
#   Procaine
#   Trimebutine
# ----
# p_value: [5.124172734987343e-05]
# properties: ['Sensory Organs']
# node count 2
#   Miconazole
#   Procaine
# ----
# p_value: [7.13397154246435e-05]
# properties: ['Cytochrome P-450 CYP1A2 Substrates']
# node count 2
#   Estradiol
#   Chlorzoxazone
# ----
# p_value: [7.542280262640308e-05]
# properties: ['Potential QTc-Prolonging Agents']
# node count 2
#   Hydrochlorothiazide
#   Trimebutine
# ----
# p_value: [1.581807665250982e-20]
# properties: ['therapeutic_flag']
# node count 16
#   Tinidazole
#   Secnidazole
#   Rimantadine
#   Dosulepin
#   Chlorphenesin carbamate
#   ...
# ----
# p_value: [3.585521358827973e-20, 4.6621484971902495e-20, 5.193337124690774e-17]
# properties: ['drug', 'pharmaceutical', 'application']
# node count 19
#   Etoposide
#   Dosulepin
#   Chlorphenesin carbamate
#   Dibenzoylmethane
#   Dasatinib
#   ...
# ----
# p_value: [6.841683573844944e-19]
# properties: ['drugbank.approved']
# node count 14
#   Tinidazole
#   Secnidazole
#   Rimantadine
#   Dosulepin
#   Chlorphenesin carbamate
#   ...
# ----
# p_value: [1.0445240762003738e-17]
# properties: ['oral']
# node count 12
#   Tinidazole
#   Secnidazole
#   Rimantadine
#   Etoposide
#   Chlorphenesin carbamate
#   ...
# ----
# p_value: [4.681205705434035e-14]
# properties: ['Cytochrome P-450 Substrates']
# node count 9
#   Tinidazole
#   Etoposide
#   Dosulepin
#   Zileuton
#   Dasatinib
#   ...
# ----
# p_value: [4.997109321071027e-14]
# properties: ['Cytochrome P-450 Enzyme Inhibitors']
# node count 8
#   Capecitabine
#   Vemurafenib
#   Dasatinib
#   Etoposide
#   Dosulepin
#   ...
# ----
# p_value: [4.0399275165142085e-12]
# properties: ['Enzyme Inhibitors']
# node count 7
#   Vemurafenib
#   Etoposide
#   Rimantadine
#   Ibuprofen
#   Zileuton
#   ...
# ----
# p_value: [2.2458040109950432e-11, 2.922099374915103e-11]
# properties: ['Cytochrome P-450 CYP3A4 Substrates', 'Cytochrome P-450 CYP3A Substrates']
# node count 7
#   Tinidazole
#   Vemurafenib
#   Etoposide
#   Ibuprofen
#   Zileuton
#   ...
# ----
# p_value: [1.665079894891654e-10, 3.772638660018194e-10]
# properties: ['enzyme_inhibitor', 'inhibitor']
# node count 9
#   Etoposide
#   Zileuton
#   Dasatinib
#   Gefitinib
#   N4-(3-Bromophenyl)-N6-methylpyrido[3,4-d]pyrimidine-4,6-diamine
#   ...
# ----
# p_value: [2.2208193918852822e-10]
# properties: ['drugbank.investigational']
# node count 8
#   Tinidazole
#   Capecitabine
#   Rimantadine
#   Zileuton
#   Dasatinib
#   ...
# ----
# p_value: [2.2364528297290575e-10]
# properties: ['biological_role']
# node count 22
#   Secnidazole
#   Etoposide
#   Dibenzoylmethane
#   Dasatinib
#   N4-(3-Bromophenyl)-N6-methylpyrido[3,4-d]pyrimidine-4,6-diamine
#   ...
# ----
# p_value: [2.3127665799253917e-10, 2.59088491970868e-09]
# properties: ['Antineoplastic and Immunomodulating Agents', 'Antineoplastic Agents']
# node count 5
#   Capecitabine
#   Vemurafenib
#   Etoposide
#   Dasatinib
#   Gefitinib
# ----
# p_value: [2.573578404743099e-10]
# properties: ['antineoplastic_agent']
# node count 8
#   Capecitabine
#   Vemurafenib
#   Dasatinib
#   Etoposide
#   Dibenzoylmethane
#   ...
# ----
# p_value: [9.308775368754817e-10, 9.850420461121866e-10]
# properties: ['P-glycoprotein inhibitors', 'P-glycoprotein substrates']
# node count 5
#   Vemurafenib
#   Etoposide
#   Ibuprofen
#   Dasatinib
#   Gefitinib
# ----
# p_value: [9.68021419879434e-10]
# properties: ['BCRP/ABCG2 Substrates']
# node count 4
#   Dasatinib
#   Vemurafenib
#   Gefitinib
#   Etoposide
# ----
# p_value: [7.876697489221998e-09, 5.440978704522125e-08]
# properties: ['EC_2.7.*_(P_containing_group_transferase)_inhibitor', 'EC_2.*_(transferase)_inhibitor']
# node count 5
#   Vemurafenib
#   Dasatinib
#   Gefitinib
#   N-[(2R)-2,3-Dihydroxypropoxy]-3,4-difluoro-2-[(2-fluoro-4-iodophenyl)amino]benzamide
#   N4-(3-Bromophenyl)-N6-methylpyrido[3,4-d]pyrimidine-4,6-diamine
# ----
# p_value: [1.0144809409597895e-08]
# properties: ['Cytochrome P-450 CYP2C9 Inhibitors']
# node count 4
#   Capecitabine
#   Vemurafenib
#   Gefitinib
#   Dosulepin
# ----
# p_value: [1.6246238591467128e-08]
# properties: ['biochemical_role']
# node count 18
#   Dihydroegotamine
#   Etoposide
#   N-[(2R)-2,3-Dihydroxypropoxy]-3,4-difluoro-2-[(2-fluoro-4-iodophenyl)amino]benzamide
#   Zileuton
#   Dibenzoylmethane
#   ...
# ----
# p_value: [2.5398531545618944e-08, 2.5644910031092393e-08, 2.585778593957691e-08]
# properties: ['Bronsted_base', 'base', 'acceptor']
# node count 11
#   4-[[4-(4-Chlorophenyl)-2-thiazolyl]amino]phenol
#   Rimantadine
#   2-Methyl-5-[(4-phenyl-3,6-dihydro-2H-pyridin-1-yl)methyl]-4-pyrimidinamine
#   Dasatinib
#   Ampiroxicam
#   ...
# ----
# p_value: [2.8561832641712975e-08, 5.2930529622707684e-08, 1.5083665020938336e-07, 2.3758667376631775e-07]
# properties: ['Kinase Inhibitor', 'Tyrosine Kinase Inhibitors', 'Protein Kinase Inhibitors', 'BCRP/ABCG2 Inhibitors']
# node count 3
#   Dasatinib
#   Vemurafenib
#   Gefitinib
# ----
# p_value: [7.701818069095524e-08, 3.849704653850929e-07, 7.184617004508344e-07, 1.6118271902529443e-05, 4.8249486497776965e-05]
# properties: ['Nitroimidazole Antimicrobial', 'Nitroimidazoles', 'Nitroimidazole Derivatives', 'Nitro Compounds', 'Imidazoles']
# node count 2
#   Tinidazole
#   Secnidazole
# ----
# p_value: [8.824265541948224e-08, 7.227718016286435e-07, 5.1555178170910355e-06]
# properties: ['Cytochrome P-450 CYP2D6 Inhibitors (weak)', 'Cytochrome P-450 CYP2C9 Inhibitors (strength unknown)', 'Cytochrome P-450 CYP2D6 Inhibitors']
# node count 3
#   Vemurafenib
#   Gefitinib
#   Dosulepin
# ----
# p_value: [1.3447059221661268e-07]
# properties: ['pharmacological_role']
# node count 7
#   6-Benzylaminopurine
#   11-[[4-[4-(Diethylamino)butyl]-1-piperidinyl]acetyl]-5,11-dihydro-6H-pyrido[2,3-B][1,4]benzodiazepin-6-one
#   3-(17-Hydroxy-10,13-dimethyl-3-oxo-7-propyl-2,6,7,8,9,11,12,14,15,16-decahydro-1H-cyclopenta[a]phenanthren-17-yl)propanoic acid
#   Ibuprofen
#   Zileuton
#   ...
# ----
# p_value: [1.353656071258215e-07]
# properties: ['Cytochrome P-450 CYP3A Inhibitors']
# node count 4
#   Zileuton
#   Dasatinib
#   Gefitinib
#   Etoposide
# ----
# p_value: [2.0782864233257322e-07]
# properties: ['protein_kinase_inhibitor']
# node count 4
#   Dasatinib
#   Vemurafenib
#   Gefitinib
#   N4-(3-Bromophenyl)-N6-methylpyrido[3,4-d]pyrimidine-4,6-diamine
# ----
# p_value: [3.280257194317666e-07]
# properties: ['chemical_role']
# node count 14
#   4-[[4-(4-Chlorophenyl)-2-thiazolyl]amino]phenol
#   Rimantadine
#   2-Methyl-5-[(4-phenyl-3,6-dihydro-2H-pyridin-1-yl)methyl]-4-pyrimidinamine
#   Dasatinib
#   Ampiroxicam
#   ...
# ----
# p_value: [4.515165135652022e-07, 4.352471078239168e-06]
# properties: ['Myelosuppressive Agents', 'Immunosuppressive Agents']
# node count 3
#   Capecitabine
#   Dasatinib
#   Etoposide
# ----
# p_value: [1.4108227048043407e-06, 5.381164624997407e-06, 5.9186640500908405e-06]
# properties: ['Cytochrome P-450 CYP2B6 Substrates with a Narrow Therapeutic Index', 'Non-Selective Monoamine Reuptake Inhibitors', 'Antidepressive Agents, Tricyclic']
# node count 2
#   Lofepramine
#   Dosulepin
# ----
# p_value: [3.058156624565041e-06, 5.470177187025823e-06, 8.562497596756903e-06]
# properties: ['non_steroidal_anti_inflammatory_drug', 'antirheumatic_drug', 'anti_inflammatory_drug']
# node count 3
#   Zileuton
#   Ampiroxicam
#   Ibuprofen
# ----
# p_value: [3.0765544621134504e-06]
# properties: ['Cytochrome P-450 CYP1A2 Inhibitors (moderate)']
# node count 2
#   Vemurafenib
#   Dosulepin
# ----
# p_value: [3.2817017904900177e-06, 9.922468747138573e-06]
# properties: ['Cytochrome P-450 CYP3A5 Substrates', 'Cytochrome P-450 CYP3A4 Inhibitors']
# node count 3
#   Dasatinib
#   Gefitinib
#   Etoposide
# ----
# p_value: [3.57601486458454e-06]
# properties: ['Cytochrome P-450 CYP1A2 Substrates']
# node count 3
#   Zileuton
#   Dasatinib
#   Etoposide
# ----
# p_value: [3.746558758947979e-06]
# properties: ['Central Nervous System Agents']
# node count 4
#   Zileuton
#   Ibuprofen
#   Lofepramine
#   Dosulepin
# ----
# p_value: [1.1903021567043962e-05]
# properties: ['Cardiotoxic antineoplastic agents']
# node count 2
#   Capecitabine
#   Etoposide
# ----
# p_value: [1.5951229683411034e-05]
# properties: ['Antiinfectives for Systemic Use']
# node count 3
#   Tinidazole
#   Secnidazole
#   Rimantadine
# ----
# p_value: [2.0230876788340246e-05]
# properties: ['Heterocyclic Compounds, Fused-Ring']
# node count 4
#   Lofepramine
#   Vemurafenib
#   Gefitinib
#   Dosulepin
# ----
# p_value: [2.418282025036251e-05]
# properties: ['UGT1A9 Substrates']
# node count 2
#   Zileuton
#   Ibuprofen
# ----
# p_value: [2.5519886485307294e-05, 9.427665076448477e-05]
# properties: ['QTc Prolonging Agents', 'Sulfur Compounds']
# node count 3
#   Dasatinib
#   Vemurafenib
#   Dosulepin
# ----
# p_value: [2.61903291809138e-05, 6.339016395151225e-05]
# properties: ['Agents that produce hypertension', 'Nervous System']
# node count 3
#   Ibuprofen
#   Lofepramine
#   Dosulepin
# ----
# p_value: [3.256935596297696e-05]
# properties: ['Nucleic Acid Synthesis Inhibitors']
# node count 2
#   Capecitabine
#   Rimantadine
# ----
# p_value: [5.3055296213499055e-05]
# properties: ['Cytochrome P-450 CYP2C19 inhibitors (strength unknown)']
# node count 2
#   Gefitinib
#   Dosulepin
# ----
# p_value: [5.981531757133749e-05]
# properties: ['UGT1A1 Substrates']
# node count 2
#   Etoposide
#   Ibuprofen
# ----
# p_value: [6.339016395151225e-05]
# properties: ['Drugs that are Mainly Renally Excreted']
# node count 3
#   Tinidazole
#   Capecitabine
#   Ibuprofen
# ----
# p_value: [7.280805894138608e-21]
# properties: ['drugbank.approved']
# node count 10
#   Diazoxide
#   Carbon monoxide
#   Enflurane
#   Hydrochlorothiazide
#   Cromolyn
#   ...
# ----
# p_value: [9.341621926301377e-17, 3.6697196637091085e-16, 6.094701060557387e-14, 1.2950041737483324e-12, 8.937840438173137e-12, 1.993525689311319e-11, 2.1476823734682156e-11, 5.382799399706657e-11, 4.126950707055083e-10, 6.035274321508555e-10, 2.4231691283760683e-09]
# properties: ['Benzothiadiazines', 'Thiazides', 'diuretic', 'Sulfonamides', 'Sulfones', 'Hypotensive Agents', 'Antihypertensive Agents', 'antihypertensive_agent', 'Amides', 'Cardiovascular Agents', 'Sulfur Compounds']
# node count 4
#   Diazoxide
#   Bendroflumethiazide
#   Hydrochlorothiazide
#   Hydroflumethiazide
# ----
# p_value: [1.0168800665649664e-16]
# properties: ['Diuretics']
# node count 5
#   Diazoxide
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Potassium ion
#   Hydroflumethiazide
# ----
# p_value: [1.0441608595853187e-15, 5.1436023587168934e-14]
# properties: ['Gynecological Antiinfectives and Antiseptics', 'Genito Urinary System and Sex Hormones']
# node count 5
#   Diazoxide
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Hydroflumethiazide
#   Miconazole
# ----
# p_value: [9.721386753620717e-15]
# properties: ['therapeutic_flag']
# node count 8
#   Diazoxide
#   Hydrochlorothiazide
#   Cromolyn
#   Chlorzoxazone
#   Enflurane
#   ...
# ----
# p_value: [3.96302115595274e-13, 3.6613538394777114e-12]
# properties: ['Heterocyclic Compounds, Fused-Ring', 'oral']
# node count 6
#   Diazoxide
#   Hydrochlorothiazide
#   Cromolyn
#   Chlorzoxazone
#   Bendroflumethiazide
#   ...
# ----
# p_value: [6.562508889245017e-13]
# properties: ['application']
# node count 9
#   Diazoxide
#   Carbon monoxide
#   Hydron;2,2,2-trifluoroacetate
#   Enflurane
#   Hydrochlorothiazide
#   ...
# ----
# p_value: [1.9858405319919156e-12]
# properties: ['cardiovascular_drug']
# node count 5
#   Diazoxide
#   Hydrochlorothiazide
#   Carbon monoxide
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [2.2949756493814526e-12, 2.57007352781012e-12]
# properties: ['drug', 'pharmaceutical']
# node count 8
#   Diazoxide
#   Carbon monoxide
#   Cromolyn
#   Hydrochlorothiazide
#   Chlorzoxazone
#   ...
# ----
# p_value: [6.361273105724518e-12, 1.0524610728756563e-11, 3.8271306752799074e-10, 1.895379942640866e-08]
# properties: ['Increased Diuresis', 'Sodium Chloride Symporter Inhibitors', 'Natriuretic Agents', 'Membrane Transport Modulators']
# node count 3
#   Hydrochlorothiazide
#   Bendroflumethiazide
#   Hydroflumethiazide
# ----
# p_value: [1.3408947255340005e-09]
# properties: ['drugbank.investigational']
# node count 5
#   Carbon monoxide
#   Enflurane
#   Potassium ion
#   Hydroflumethiazide
#   Miconazole
# ----
# p_value: [5.728694474392006e-09]
# properties: ['Hyperglycemia-Associated Agents']
# node count 3
#   Diazoxide
#   Bendroflumethiazide
#   Hydrochlorothiazide
# ----
# p_value: [2.870904070657723e-08]
# properties: ['Low-Ceiling Diuretics and Potassium-Sparing Agents']
# node count 2
#   Hydrochlorothiazide
#   Bendroflumethiazide
# ----
# p_value: [1.5697662313508262e-07]
# properties: ['drugbank.vet_approved']
# node count 3
#   Hydrochlorothiazide
#   Miconazole
#   Enflurane
# ----
# p_value: [2.6762786740295016e-07, 1.810176012338286e-06, 2.673904838489784e-06, 2.7649814005418537e-05]
# properties: ['human_metabolite', 'mammalian_metabolite', 'animal_metabolite', 'eukaryotic_metabolite']
# node count 5
#   Carbon monoxide
#   Hydron;2,2,2-trifluoroacetate
#   ferroheme b
#   Potassium ion
#   Calcium ion
# ----
# p_value: [4.1270025802707294e-07]
# properties: ['topical']
# node count 3
#   Miconazole
#   Cromolyn
#   Enflurane
# ----
# p_value: [4.765690088040808e-07, 1.1427433820628262e-05, 3.569291651622227e-05, 5.235160897303835e-05]
# properties: ['Antidiarrheals, Intestinal Antiinflammatory/antiinfective Agents', 'Sensory Organs', 'Dermatologicals', 'Alimentary Tract and Metabolism']
# node count 2
#   Miconazole
#   Cromolyn
# ----
# p_value: [6.897912892096567e-07]
# properties: ['biological_role']
# node count 8
#   Diazoxide
#   Carbon monoxide
#   Cromolyn
#   Hydrochlorothiazide
#   ferroheme b
#   ...
# ----
# p_value: [1.1627335870232626e-06]
# properties: ['cofactor']
# node count 3
#   Calcium ion
#   ferroheme b
#   Potassium ion
# ----
# p_value: [1.6932661723681538e-06, 3.1514752264738556e-05, 3.787899688674101e-05]
# properties: ['Cytochrome P-450 CYP2E1 Inhibitors', 'Cytochrome P-450 CYP3A4 Inhibitors', 'Cytochrome P-450 CYP3A Inhibitors']
# node count 2
#   Miconazole
#   Chlorzoxazone
# ----
# p_value: [1.8130480545818397e-06]
# properties: ['Cytochrome P-450 CYP2E1 Substrates']
# node count 2
#   Chlorzoxazone
#   Enflurane
# ----
# p_value: [3.6995275426024607e-06]
# properties: ['Cytochrome P-450 Substrates']
# node count 3
#   Miconazole
#   Chlorzoxazone
#   Enflurane
# ----
# p_value: [1.0094662911753687e-05]
# properties: ['vasodilator_agent']
# node count 2
#   Diazoxide
#   Carbon monoxide
# ----
# p_value: [2.490151067292366e-10, 2.7117059602636154e-10, 2.6869366083974615e-09, 1.1060722067763238e-06, 3.520009055952577e-06]
# properties: ['drug', 'pharmaceutical', 'application', 'biochemical_role', 'biological_role']
# node count 6
#   Norepinephrine
#   Acetylcholine
#   Phloretin
#   Paclitaxel
#   CID 22326046
#   ...
# ----
# p_value: [2.8240650513686877e-10, 1.1195507566393842e-09]
# properties: ['drugbank.approved', 'therapeutic_flag']
# node count 5
#   Norepinephrine
#   Acetylcholine
#   Paclitaxel
#   CID 22326046
#   Topotecan
# ----
# p_value: [9.765897592910908e-08, 1.2899484903029827e-06, 6.02427022862859e-06, 8.25637389853852e-06]
# properties: ['pharmacological_role', 'human_metabolite', 'mammalian_metabolite', 'animal_metabolite']
# node count 4
#   Paclitaxel
#   Norepinephrine
#   Acetylcholine
#   CID 22326046
# ----
# p_value: [1.6008020001879997e-07, 1.9429826482967636e-07, 3.642644140689693e-07, 2.5852124011817738e-05, 3.225109094690438e-05, 3.349015055486641e-05, 4.586991706817948e-05]
# properties: ['neurotransmitter', 'OCT1 substrates', 'Biogenic Amines', 'Cardiovascular Agents', 'Amines', 'cardiovascular_drug', 'Neurotransmitter Agents']
# node count 2
#   Norepinephrine
#   Acetylcholine
# ----
# p_value: [5.162863158278855e-07]
# properties: ['parenteral']
# node count 3
#   Paclitaxel
#   Norepinephrine
#   Topotecan
# ----
# p_value: [9.68697276701708e-07, 2.2109740054334953e-05]
# properties: ['neurotransmitter_agent', 'mouse_metabolite']
# node count 3
#   Norepinephrine
#   Acetylcholine
#   CID 22326046
# ----
# p_value: [1.3676499293256683e-06, 2.205127538596047e-05]
# properties: ['eukaryotic_metabolite', 'metabolite']
# node count 5
#   Norepinephrine
#   Acetylcholine
#   Phloretin
#   Paclitaxel
#   CID 22326046
# ----
# p_value: [1.4402180676279318e-06, 3.998267309555481e-06, 6.185877736372578e-06, 6.527243286359484e-06, 6.877758363265727e-06, 7.310451830271301e-06, 1.0269674521287355e-05, 1.303633735683665e-05, 1.9198014027154402e-05]
# properties: ['Myelosuppressive Agents', 'Cytochrome P-450 CYP3A4 Inducers (strength unknown)', 'Cytochrome P-450 CYP3A4 Inducers', 'Immunosuppressive Agents', 'Cytochrome P-450 CYP3A Inducers', 'Antineoplastic and Immunomodulating Agents', 'Cytochrome P-450 Enzyme Inducers', 'P-glycoprotein substrates', 'Antineoplastic Agents']
# node count 2
#   Paclitaxel
#   Topotecan
# ----
# p_value: [3.842299802637642e-06]
# properties: ['antineoplastic_agent']
# node count 3
#   Phloretin
#   Paclitaxel
#   Topotecan
# ----
# p_value: [4.107346998840335e-06, 3.587605029124872e-05]
# properties: ['Sensory Organs', 'topical']
# node count 2
#   Acetylcholine
#   CID 22326046
# ----
# p_value: [1.8844175810311423e-05]
# properties: ['drugbank.vet_approved']
# node count 2
#   Paclitaxel
#   CID 22326046
# ----
# p_value: [8.365105233103283e-05]
# properties: ['human_xenobiotic_metabolite']
# node count 2
#   Norepinephrine
#   CID 22326046
# ----
# p_value: [3.076257833396323e-09, 8.24403093211081e-07, 3.928422830302463e-06, 3.928422830302463e-06]
# properties: ['macronutrient', 'nutrient', 'food_component', 'physiological_role']
# node count 2
#   Potassium
#   Calcium
# ----
# p_value: [6.744034553745893e-09, 1.2817456150742807e-08, 2.0823187314116925e-08, 4.081727266229449e-08, 9.111620548329211e-05]
# properties: ['Replacement Preparations', 'Minerals', 'Metals', 'Elements', 'drugbank.approved']
# node count 2
#   Calcium
#   potassium hydride
# ----

# %%
property_answers['message']['results'][0]
# Out:
# {'node_bindings': {'n1': [{'id': 'NCBIGene:3778'}],
#   'n0': [{'id': 'PUBCHEM.COMPOUND:5994',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11437030',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:3605484',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:10243969',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:10967695',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:2798243',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:3639',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:4552',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:10969679',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:47811',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:10968747',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11065065',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:44570449',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11254734',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:15717694',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:24285063',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:24285062',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11392406',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11818496',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:10064074',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:10356396',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:2882',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:4050379',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:4189',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:2946791',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:3562',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11471747',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:16099762',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:2953683',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11472034',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11109578',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11000844',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:16099761',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:2798242',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11779066',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11335564',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:1140',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11042812',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:11782023',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:5073804',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']},
#    {'id': 'PUBCHEM.COMPOUND:2993',
#     'coalescence_method': 'property_enrichment',
#     'p_values': [5.515487725071365e-06],
#     'properties': ['molecule_type:Small molecule']}]},
#  'edge_bindings': {'e0': [{'id': '8835aa3ef86e', 'weight': 1},
#    {'id': '9b9fe0c2173b', 'weight': 1},
#    {'id': '6593dce43a5a', 'weight': 1},
#    {'id': 'f6834a7bd409', 'weight': 1},
#    {'id': '9bcfc71111fb', 'weight': 1},
#    {'id': '2b08ed724613', 'weight': 1},
#    {'id': 'e2bb8031297c', 'weight': 1},
#    {'id': 'e2e73c80e2b1', 'weight': 1},
#    {'id': 'fcd6c243b89a', 'weight': 1},
#    {'id': '93781bc5b720', 'weight': 1},
#    {'id': '13f399d6ef5a', 'weight': 1},
#    {'id': '31d39230b010', 'weight': 1},
#    {'id': '8a8b0505df93', 'weight': 1},
#    {'id': 'e05768c1144f', 'weight': 1},
#    {'id': 'ec7c8bceabe8', 'weight': 1},
#    {'id': 'fa9144751c19', 'weight': 1},
#    {'id': '624dce68f2b6', 'weight': 1},
#    {'id': '50b22b52633a', 'weight': 1},
#    {'id': '90da61c18e2b', 'weight': 1},
#    {'id': '575ba5bf4bde', 'weight': 1},
#    {'id': '813ac630e5a8', 'weight': 1},
#    {'id': '36147eeeb47d', 'weight': 1},
#    {'id': '2b9c630cb328', 'weight': 1},
#    {'id': '0f01c46d3821', 'weight': 1},
#    {'id': '4862631be215', 'weight': 1},
#    {'id': 'a4a6be2e95c8', 'weight': 1},
#    {'id': '053020371140', 'weight': 1},
#    {'id': 'f878fce830ca', 'weight': 1},
#    {'id': '6f16827a043d', 'weight': 1},
#    {'id': '72ac435f8b42', 'weight': 1},
#    {'id': '41ab3cd757b5', 'weight': 1},
#    {'id': '279f77556601', 'weight': 1},
#    {'id': '9c5edb149e48', 'weight': 1},
#    {'id': 'fac70141e1e1', 'weight': 1},
#    {'id': '45ba72cbd553', 'weight': 1},
#    {'id': '70e70b8a9179', 'weight': 1},
#    {'id': '56567f23fa13', 'weight': 1},
#    {'id': 'c019f6c15e5e', 'weight': 1},
#    {'id': 'f1e2af78989f', 'weight': 1},
#    {'id': '1f7ee5fba0f3', 'weight': 1},
#    {'id': '838d30134673', 'weight': 1}]},
#  'score': 40.999999953231885}

# %%
graph_answers=filter_to_gc(aragorn_result,node)
for gc_result in graph_answers['message']['results']:
    print_gc_result(aragorn_result['message']['knowledge_graph'],gc_result,node)
# Out:
# 85
# p_value: 1.488362376405769e-24
# Merged 8
#   Isochamaejasmin -[biolink:directly_interacts_with]-> VEGFA
#   Holo-Lys2 -[biolink:directly_interacts_with]-> VEGFA
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> VEGFA
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> VEGFA
#   6-Bromohexanoic acid -[biolink:directly_interacts_with]-> VEGFA
# ----
# p_value: 1.098744871207281e-18
# Merged 7
#   Holo-Lys2 -[biolink:directly_interacts_with]-> TNF
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> TNF
#   Deoxylimonoic acid D-ring-lactone -[biolink:directly_interacts_with]-> TNF
#   Diazoxide -[biolink:directly_interacts_with]-> TNF
#   Isochamaejasmin -[biolink:directly_interacts_with]-> TNF
# ----
# p_value: 2.5251858514751036e-18
# Merged 6
#   Diazoxide -[biolink:directly_interacts_with]-> CXCL8
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> CXCL8
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> CXCL8
#   Holo-Lys2 -[biolink:directly_interacts_with]-> CXCL8
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> CXCL8
# ----
# p_value: 4.4690012826693734e-12
# Merged 6
#   Hydrochlorothiazide -[biolink:contraindicated_for]-> liver disease
#   Diazoxide -[biolink:contraindicated_for]-> liver disease
#   Cromolyn -[biolink:contraindicated_for]-> liver disease
#   Miconazole -[biolink:contraindicated_for]-> liver disease
#   Bendroflumethiazide -[biolink:contraindicated_for]-> liver disease
# ----
# p_value: 2.857900719790251e-07
# Merged 5
#   Cromolyn -[biolink:contraindicated_for]-> liver disease
#   Progesterone -[biolink:contraindicated_for]-> liver disease
#   Miconazole -[biolink:contraindicated_for]-> liver disease
#   Hydrochlorothiazide -[biolink:contraindicated_for]-> liver disease
#   Halothane -[biolink:contraindicated_for]-> liver disease
# ----
# p_value: 1.1096556736007788e-18
# Merged 5
#   Isochamaejasmin -[biolink:directly_interacts_with]-> CAV1
#   Diazoxide -[biolink:directly_interacts_with]-> CAV1
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> CAV1
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> CAV1
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> CAV1
# ----
# p_value: 7.314555092806038e-11
# Merged 4
#   Ethanol -[biolink:interacts_with]-> CYP1A1
#   Chlorzoxazone -[biolink:interacts_with]-> CYP1A1
#   Estradiol -[biolink:interacts_with]-> CYP1A1
#   poly(vinyl alcohol) macromolecule -[biolink:interacts_with]-> CYP1A1
# ----
# p_value: 4.1929085487571036e-18
# Merged 6
#   Holo-Lys2 -[biolink:directly_interacts_with]-> NR1I2
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> NR1I2
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> NR1I2
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> NR1I2
#   Estradiol -[biolink:directly_interacts_with]-> NR1I2
# ----
# p_value: 5.64600149725104e-18
# Merged 5
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> MMP1
#   6-Bromohexanoic acid -[biolink:directly_interacts_with]-> MMP1
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> MMP1
#   Isochamaejasmin -[biolink:directly_interacts_with]-> MMP1
#   Holo-Lys2 -[biolink:directly_interacts_with]-> MMP1
# ----
# p_value: 2.901724023394722e-21
# Merged 6
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> VCAM1
#   Deoxylimonoic acid D-ring-lactone -[biolink:directly_interacts_with]-> VCAM1
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> VCAM1
#   Isochamaejasmin -[biolink:directly_interacts_with]-> VCAM1
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> VCAM1
# ----
# p_value: 9.727453559742477e-19
# Merged 6
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> CYP19A1
#   Isochamaejasmin -[biolink:directly_interacts_with]-> CYP19A1
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> CYP19A1
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> CYP19A1
#   Holo-Lys2 -[biolink:directly_interacts_with]-> CYP19A1
# ----
# p_value: 1.1733811243450021e-07
# Merged 3
#   Cromolyn -[biolink:contraindicated_for]-> liver disease
#   Hydrochlorothiazide -[biolink:contraindicated_for]-> liver disease
#   Miconazole -[biolink:contraindicated_for]-> liver disease
# ----
# p_value: 5.424485815671622e-11
# Merged 4
#   Chlorzoxazone -[biolink:interacts_with]-> CYP2A6
#   Hydron;2,2,2-trifluoroacetate -[biolink:interacts_with]-> CYP2A6
#   Miconazole -[biolink:interacts_with]-> CYP2A6
#   ferroheme b -[biolink:interacts_with]-> CYP2A6
# ----
# p_value: 6.619891429384633e-10
# Merged 4
#   Norepinephrine -[biolink:increases_degradation_of]-> CASP9
#   CID 22326046 -[biolink:increases_degradation_of]-> CASP9
#   Topotecan -[biolink:increases_degradation_of]-> CASP9
#   Paclitaxel -[biolink:increases_degradation_of]-> CASP9
# ----
# p_value: 4.772714879877331e-10
# Merged 3
#   Estradiol -[biolink:decreases_expression_of]-> PPARG
#   poly(vinyl alcohol) macromolecule -[biolink:decreases_expression_of]-> PPARG
#   Ethanol -[biolink:decreases_expression_of]-> PPARG
# ----
# p_value: 2.291810764092827e-09
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:decreases_expression_of]-> CAT
#   Estradiol -[biolink:decreases_expression_of]-> CAT
#   Ethanol -[biolink:decreases_expression_of]-> CAT
# ----
# p_value: 3.4678226769058036e-09
# Merged 3
#   Estradiol -[biolink:decreases_molecular_modification_of]-> MAPK1
#   poly(vinyl alcohol) macromolecule -[biolink:decreases_molecular_modification_of]-> MAPK1
#   Ethanol -[biolink:decreases_molecular_modification_of]-> MAPK1
# ----
# p_value: 3.4678226769058036e-09
# Merged 3
#   Ethanol -[biolink:decreases_molecular_modification_of]-> MAPK3
#   Estradiol -[biolink:decreases_molecular_modification_of]-> MAPK3
#   poly(vinyl alcohol) macromolecule -[biolink:decreases_molecular_modification_of]-> MAPK3
# ----
# p_value: 2.59993158810574e-09
# Merged 4
#   ferroheme b -[biolink:interacts_with]-> CYP2D6
#   Chlorzoxazone -[biolink:interacts_with]-> CYP2D6
#   Hydron;2,2,2-trifluoroacetate -[biolink:interacts_with]-> CYP2D6
#   Miconazole -[biolink:interacts_with]-> CYP2D6
# ----
# p_value: 8.303202934617915e-15
# Merged 4
#   Diazoxide -[biolink:interacts_with]-> SLC12A3
#   Hydrochlorothiazide -[biolink:interacts_with]-> SLC12A3
#   Bendroflumethiazide -[biolink:interacts_with]-> SLC12A3
#   Calcium ion -[biolink:interacts_with]-> SLC12A3
# ----
# p_value: 2.9583182608342703e-13
# Merged 5
#   ferroheme b -[biolink:interacts_with]-> CYP2E1
#   Enflurane -[biolink:interacts_with]-> CYP2E1
#   Hydron;2,2,2-trifluoroacetate -[biolink:interacts_with]-> CYP2E1
#   Chlorzoxazone -[biolink:interacts_with]-> CYP2E1
#   Miconazole -[biolink:interacts_with]-> CYP2E1
# ----
# p_value: 1.9990197678078563e-10
# Merged 4
#   CID 22326046 -[biolink:increases_activity_of]-> CASP7
#   Topotecan -[biolink:increases_activity_of]-> CASP7
#   Norepinephrine -[biolink:increases_activity_of]-> CASP7
#   Paclitaxel -[biolink:increases_activity_of]-> CASP7
# ----
# p_value: 4.960091226100248e-10
# Merged 4
#   Paclitaxel -[biolink:increases_activity_of]-> MAPK3
#   Norepinephrine -[biolink:increases_activity_of]-> MAPK3
#   Acetylcholine -[biolink:increases_activity_of]-> MAPK3
#   CID 22326046 -[biolink:increases_activity_of]-> MAPK3
# ----
# p_value: 5.103028626884024e-10
# Merged 4
#   Norepinephrine -[biolink:increases_activity_of]-> MAPK1
#   CID 22326046 -[biolink:increases_activity_of]-> MAPK1
#   Paclitaxel -[biolink:increases_activity_of]-> MAPK1
#   Acetylcholine -[biolink:increases_activity_of]-> MAPK1
# ----
# p_value: 4.813623377380656e-19
# Merged 5
#   6-Bromohexanoic acid -[biolink:directly_interacts_with]-> UNG
#   Isochamaejasmin -[biolink:directly_interacts_with]-> UNG
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> UNG
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> UNG
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> UNG
# ----
# p_value: 1.1096556736007788e-18
# Merged 5
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> SERPINB2
#   glycerophosphoethanolamine -[biolink:directly_interacts_with]-> SERPINB2
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> SERPINB2
#   6-Bromohexanoic acid -[biolink:directly_interacts_with]-> SERPINB2
#   Isochamaejasmin -[biolink:directly_interacts_with]-> SERPINB2
# ----
# p_value: 1.6072855942046885e-18
# Merged 5
#   1-[(3S,9S,10S)-9-[[Cyclopropylmethyl(methyl)amino]methyl]-12-[(2R)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-16-yl]-3-(4-fluorophenyl)urea -[biolink:directly_interacts_with]-> PDGFA
#   Holo-Lys2 -[biolink:directly_interacts_with]-> PDGFA
#   Pipecolic acid betaine -[biolink:directly_interacts_with]-> PDGFA
#   Deoxylimonoic acid D-ring-lactone -[biolink:directly_interacts_with]-> PDGFA
#   Isochamaejasmin -[biolink:directly_interacts_with]-> PDGFA
# ----
# p_value: 2.3907728420560098e-12
# Merged 3
#   Miconazole -[biolink:interacts_with]-> KCNN4
#   Calcium ion -[biolink:interacts_with]-> KCNN4
#   Hydron;2,2,2-trifluoroacetate -[biolink:interacts_with]-> KCNN4
# ----
# p_value: 5.969072369944539e-11
# Merged 3
#   Ethanol -[biolink:increases_expression_of]-> CD14
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> CD14
#   Estradiol -[biolink:increases_expression_of]-> CD14
# ----
# p_value: 3.4678226769058036e-09
# Merged 3
#   Estradiol -[biolink:increases_expression_of]-> MMP9
#   Ethanol -[biolink:increases_expression_of]-> MMP9
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> MMP9
# ----
# p_value: 2.9862884178003977e-10
# Merged 3
#   ferroheme b -[biolink:interacts_with]-> NOS3
#   Miconazole -[biolink:interacts_with]-> NOS3
#   Calcium ion -[biolink:interacts_with]-> NOS3
# ----
# p_value: 5.831266121292244e-10
# Merged 3
#   Hydrochlorothiazide -[biolink:interacts_with]-> CA1
#   Bendroflumethiazide -[biolink:interacts_with]-> CA1
#   Diazoxide -[biolink:interacts_with]-> CA1
# ----
# p_value: 1.0086532462030283e-12
# Merged 3
#   Calcium ion -[biolink:interacts_with]-> KCNMB3
#   Miconazole -[biolink:interacts_with]-> KCNMB3
#   Potassium ion -[biolink:interacts_with]-> KCNMB3
# ----
# p_value: 1.4183974058871814e-07
# Merged 2
#   Cromolyn -[biolink:causes_adverse_event]-> Marchiafava-Bignami disease
#   Hydrochlorothiazide -[biolink:causes_adverse_event]-> Marchiafava-Bignami disease
# ----
# p_value: 2.1772026260476887e-10
# Merged 3
#   Miconazole -[biolink:interacts_with]-> NOS2
#   ferroheme b -[biolink:interacts_with]-> NOS2
#   Calcium ion -[biolink:interacts_with]-> NOS2
# ----
# p_value: 6.110813387633773e-13
# Merged 3
#   TRPC6 -[biolink:increases_transport_of]-> potassium hydride
#   TRPC6 -[biolink:increases_transport_of]-> Potassium
#   TRPC6 -[biolink:increases_transport_of]-> Calcium
# ----
# p_value: 2.291810764092827e-09
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> TIMP1
#   Ethanol -[biolink:increases_expression_of]-> TIMP1
#   Estradiol -[biolink:increases_expression_of]-> TIMP1
# ----
# p_value: 5.969072369944539e-11
# Merged 3
#   CAT -[biolink:affects_response_to]-> Topotecan
#   CAT -[biolink:affects_response_to]-> Paclitaxel
#   CAT -[biolink:affects_response_to]-> CID 22326046
# ----
# p_value: 3.1431454609879794e-09
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> COL1A1
#   Estradiol -[biolink:increases_expression_of]-> COL1A1
#   Ethanol -[biolink:increases_expression_of]-> COL1A1
# ----
# p_value: 3.8141065443520285e-09
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> PPARG
#   Ethanol -[biolink:increases_expression_of]-> PPARG
#   Estradiol -[biolink:increases_expression_of]-> PPARG
# ----
# p_value: 8.268649309420201e-10
# Merged 4
#   Chlorzoxazone -[biolink:interacts_with]-> CYP2E1
#   Estradiol -[biolink:interacts_with]-> CYP2E1
#   poly(vinyl alcohol) macromolecule -[biolink:interacts_with]-> CYP2E1
#   Ethanol -[biolink:interacts_with]-> CYP2E1
# ----
# p_value: 1.1888462455265065e-08
# Merged 2
#   TRPC6 -[biolink:increases_transport_of]-> Rubidium
#   TRPC6 -[biolink:increases_transport_of]-> Cesium
# ----
# p_value: 2.291810764092827e-09
# Merged 3
#   Estradiol -[biolink:increases_molecular_interaction]-> CYP1A1
#   poly(vinyl alcohol) macromolecule -[biolink:increases_molecular_interaction]-> CYP1A1
#   Ethanol -[biolink:increases_molecular_interaction]-> CYP1A1
# ----
# p_value: 2.0466162687245084e-09
# Merged 3
#   Hydrochlorothiazide -[biolink:causes_adverse_event]-> Marchiafava-Bignami disease
#   Cromolyn -[biolink:causes_adverse_event]-> Marchiafava-Bignami disease
#   Chlorzoxazone -[biolink:causes_adverse_event]-> Marchiafava-Bignami disease
# ----
# p_value: 3.9546805706673473e-07
# Merged 4
#   Progesterone -[biolink:prevents]-> Found Dead
#   Cromolyn -[biolink:prevents]-> Found Dead
#   Hydrochlorothiazide -[biolink:prevents]-> Found Dead
#   Pergolide -[biolink:prevents]-> Found Dead
# ----
# p_value: 2.350740151877105e-13
# Merged 3
#   potassium hydride -[biolink:increases_activity_of]-> KLK8
#   Potassium -[biolink:increases_activity_of]-> KLK8
#   Calcium -[biolink:increases_activity_of]-> KLK8
# ----
# p_value: 1.2397132968460726e-14
# Merged 3
#   ADRA1A -[biolink:affects_transport_of]-> potassium hydride
#   ADRA1A -[biolink:affects_transport_of]-> Potassium
#   ADRA1A -[biolink:affects_transport_of]-> Calcium
# ----
# p_value: 9.825267406237279e-09
# Merged 2
#   Dietary Fats -[biolink:increases_expression_of]-> COL1A2
#   Oxygen -[biolink:increases_expression_of]-> COL1A2
# ----
# p_value: 2.5185377860571276e-11
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:increases_molecular_interaction]-> None
#   Estradiol -[biolink:increases_molecular_interaction]-> None
#   Ethanol -[biolink:increases_molecular_interaction]-> None
# ----
# p_value: 7.990603750138681e-10
# Merged 3
#   Estradiol -[biolink:increases_localization_of]-> CTNNB1
#   Ethanol -[biolink:increases_localization_of]-> CTNNB1
#   poly(vinyl alcohol) macromolecule -[biolink:increases_localization_of]-> CTNNB1
# ----
# p_value: 9.319226393727285e-10
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:decreases_activity_of]-> SULT1E1
#   Estradiol -[biolink:decreases_activity_of]-> SULT1E1
#   Ethanol -[biolink:decreases_activity_of]-> SULT1E1
# ----
# p_value: 2.291810764092827e-09
# Merged 3
#   Estradiol -[biolink:increases_expression_of]-> MMP2
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> MMP2
#   Ethanol -[biolink:increases_expression_of]-> MMP2
# ----
# p_value: 2.8393806934826688e-09
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:increases_molecular_interaction]-> NR1I2
#   Ethanol -[biolink:increases_molecular_interaction]-> NR1I2
#   Estradiol -[biolink:increases_molecular_interaction]-> NR1I2
# ----
# p_value: 1.7969161042122528e-07
# Merged 3
#   Hydrochlorothiazide -[biolink:causes_adverse_event]-> Feeling jittery
#   Cromolyn -[biolink:causes_adverse_event]-> Feeling jittery
#   Progesterone -[biolink:causes_adverse_event]-> Feeling jittery
# ----
# p_value: 5.572460752049427e-07
# Merged 3
#   Progesterone -[biolink:causes_adverse_event]-> Dyspepsia
#   Hydrochlorothiazide -[biolink:causes_adverse_event]-> Dyspepsia
#   Cromolyn -[biolink:causes_adverse_event]-> Dyspepsia
# ----
# p_value: 6.452734370829963e-11
# Merged 3
#   Enflurane -[biolink:interacts_with]-> ATP2C1
#   Calcium ion -[biolink:interacts_with]-> ATP2C1
#   Hydron;2,2,2-trifluoroacetate -[biolink:interacts_with]-> ATP2C1
# ----
# p_value: 5.831266121292244e-10
# Merged 3
#   Bendroflumethiazide -[biolink:interacts_with]-> CA2
#   Hydrochlorothiazide -[biolink:interacts_with]-> CA2
#   Diazoxide -[biolink:interacts_with]-> CA2
# ----
# p_value: 1.0868725189495286e-09
# Merged 3
#   Paclitaxel -[biolink:causes_adverse_event]-> Clostridium welchii infection
#   Norepinephrine -[biolink:causes_adverse_event]-> Clostridium welchii infection
#   Topotecan -[biolink:causes_adverse_event]-> Clostridium welchii infection
# ----
# p_value: 1.1656792007971442e-10
# Merged 3
#   Estradiol -[biolink:increases_molecular_interaction]-> CYP1B1
#   Ethanol -[biolink:increases_molecular_interaction]-> CYP1B1
#   poly(vinyl alcohol) macromolecule -[biolink:increases_molecular_interaction]-> CYP1B1
# ----
# p_value: 2.014025431203612e-10
# Merged 3
#   poly(vinyl alcohol) macromolecule -[biolink:increases_expression_of]-> TGM2
#   Ethanol -[biolink:increases_expression_of]-> TGM2
#   Estradiol -[biolink:increases_expression_of]-> TGM2
# ----
# p_value: 1.9015674565146053e-07
# Merged 2
#   Halothane -[biolink:decreases_activity_of]-> KCNJ6
#   Toluene -[biolink:decreases_activity_of]-> KCNJ6
# ----
# p_value: 4.772714879877331e-10
# Merged 3
#   Norepinephrine -[biolink:causes_adverse_event]-> None
#   Topotecan -[biolink:causes_adverse_event]-> None
#   Paclitaxel -[biolink:causes_adverse_event]-> None
# ----
# p_value: 5.566347605213264e-10
# Merged 3
#   Paclitaxel -[biolink:causes_adverse_event]-> Colon perforation
#   Norepinephrine -[biolink:causes_adverse_event]-> Colon perforation
#   Topotecan -[biolink:causes_adverse_event]-> Colon perforation
# ----
# p_value: 1.7468556887556165e-10
# Merged 2
#   ABCC9 -[biolink:increases_transport_of]-> Potassium
#   ABCC9 -[biolink:increases_transport_of]-> potassium hydride
# ----
# p_value: 1.7468556887556165e-10
# Merged 2
#   KCNE3 -[biolink:affects_transport_of]-> Potassium
#   KCNE3 -[biolink:affects_transport_of]-> potassium hydride
# ----
# p_value: 1.7468556887556165e-10
# Merged 2
#   SGK2 -[biolink:increases_transport_of]-> potassium hydride
#   SGK2 -[biolink:increases_transport_of]-> Potassium
# ----
# p_value: 7.603142898260044e-07
# Merged 2
#   Hydrochlorothiazide -[biolink:causes_adverse_event]-> Abnormal Mammogram
#   Progesterone -[biolink:causes_adverse_event]-> Abnormal Mammogram
# ----
# p_value: 8.84331917719657e-10
# Merged 2
#   Oxygen -[biolink:increases_expression_of]-> APLN
#   Dietary Fats -[biolink:increases_expression_of]-> APLN
# ----
# p_value: 7.958540976766807e-09
# Merged 2
#   Oxygen -[biolink:increases_activity_of]-> CS
#   Dietary Fats -[biolink:increases_activity_of]-> CS
# ----
# p_value: 3.4624495147262728e-59
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:11820396",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "UMLS:C0059640",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10354434",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10083014",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:9815734",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10038562",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:214350",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:9881289",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "CHEBI:17246",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:702",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2315",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5757",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10263172",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2733",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10035337",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10398337",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.4624495147262728e-59,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_0": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "44fd64f737e2",
#                 "weight": 1
#             },
#             {
#                 "id": "5d367fac900e",
#                 "weight": 1
#             },
#             {
#                 "id": "907bfced6727",
#                 "weight": 1
#             },
#             {
#                 "id": "90d26be31f21",
#                 "weight": 1
#             },
#             {
#                 "id": "74d328710ec9",
#                 "weight": 1
#             },
#             {
#                 "id": "c7f8ac074648",
#                 "weight": 1
#             },
#             {
#                 "id": "d05db24673c1",
#                 "weight": 1
#             },
#             {
#                 "id": "85e056a852c8",
#                 "weight": 1
#             },
#             {
#                 "id": "0c7474acbc5c",
#                 "weight": 1
#             },
#             {
#                 "id": "1194d7ecc312",
#                 "weight": 1
#             },
#             {
#                 "id": "d43131f08c86",
#                 "weight": 1
#             },
#             {
#                 "id": "f33755b08c2b",
#                 "weight": 1
#             },
#             {
#                 "id": "1f9c82188903",
#                 "weight": 1
#             },
#             {
#                 "id": "8dd40182bbda",
#                 "weight": 1
#             },
#             {
#                 "id": "6c77b2217b94",
#                 "weight": 1
#             },
#             {
#                 "id": "32d9ae20c0de",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_0": []
#     },
#     "score": 0
# }
# p_value: 8.220862357437827e-142
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:5994",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11437030",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3605484",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10243969",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10967695",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2798243",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3639",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4552",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10969679",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:47811",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10968747",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11065065",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:44570449",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11254734",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:15717694",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:24285063",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:24285062",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11392406",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11818496",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10064074",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4697",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:10356396",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2882",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4050379",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4189",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2946791",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3562",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11471747",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:16099762",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2953683",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11472034",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11109578",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11000844",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:16099761",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2798242",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11779066",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11335564",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:1140",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11042812",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11782023",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "UMLS:C0082965",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5073804",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2993",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 8.220862357437827e-142,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_20": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "8835aa3ef86e",
#                 "weight": 1
#             },
#             {
#                 "id": "9b9fe0c2173b",
#                 "weight": 1
#             },
#             {
#                 "id": "6593dce43a5a",
#                 "weight": 1
#             },
#             {
#                 "id": "f6834a7bd409",
#                 "weight": 1
#             },
#             {
#                 "id": "9bcfc71111fb",
#                 "weight": 1
#             },
#             {
#                 "id": "2b08ed724613",
#                 "weight": 1
#             },
#             {
#                 "id": "e2bb8031297c",
#                 "weight": 1
#             },
#             {
#                 "id": "e2e73c80e2b1",
#                 "weight": 1
#             },
#             {
#                 "id": "fcd6c243b89a",
#                 "weight": 1
#             },
#             {
#                 "id": "93781bc5b720",
#                 "weight": 1
#             },
#             {
#                 "id": "13f399d6ef5a",
#                 "weight": 1
#             },
#             {
#                 "id": "31d39230b010",
#                 "weight": 1
#             },
#             {
#                 "id": "8a8b0505df93",
#                 "weight": 1
#             },
#             {
#                 "id": "e05768c1144f",
#                 "weight": 1
#             },
#             {
#                 "id": "ec7c8bceabe8",
#                 "weight": 1
#             },
#             {
#                 "id": "fa9144751c19",
#                 "weight": 1
#             },
#             {
#                 "id": "624dce68f2b6",
#                 "weight": 1
#             },
#             {
#                 "id": "50b22b52633a",
#                 "weight": 1
#             },
#             {
#                 "id": "90da61c18e2b",
#                 "weight": 1
#             },
#             {
#                 "id": "d2980eac332e",
#                 "weight": 1
#             },
#             {
#                 "id": "575ba5bf4bde",
#                 "weight": 1
#             },
#             {
#                 "id": "813ac630e5a8",
#                 "weight": 1
#             },
#             {
#                 "id": "36147eeeb47d",
#                 "weight": 1
#             },
#             {
#                 "id": "2b9c630cb328",
#                 "weight": 1
#             },
#             {
#                 "id": "0f01c46d3821",
#                 "weight": 1
#             },
#             {
#                 "id": "4862631be215",
#                 "weight": 1
#             },
#             {
#                 "id": "a4a6be2e95c8",
#                 "weight": 1
#             },
#             {
#                 "id": "053020371140",
#                 "weight": 1
#             },
#             {
#                 "id": "f878fce830ca",
#                 "weight": 1
#             },
#             {
#                 "id": "6f16827a043d",
#                 "weight": 1
#             },
#             {
#                 "id": "72ac435f8b42",
#                 "weight": 1
#             },
#             {
#                 "id": "41ab3cd757b5",
#                 "weight": 1
#             },
#             {
#                 "id": "279f77556601",
#                 "weight": 1
#             },
#             {
#                 "id": "9c5edb149e48",
#                 "weight": 1
#             },
#             {
#                 "id": "fac70141e1e1",
#                 "weight": 1
#             },
#             {
#                 "id": "45ba72cbd553",
#                 "weight": 1
#             },
#             {
#                 "id": "70e70b8a9179",
#                 "weight": 1
#             },
#             {
#                 "id": "56567f23fa13",
#                 "weight": 1
#             },
#             {
#                 "id": "c019f6c15e5e",
#                 "weight": 1
#             },
#             {
#                 "id": "edeb1132b29a",
#                 "weight": 1
#             },
#             {
#                 "id": "f1e2af78989f",
#                 "weight": 1
#             },
#             {
#                 "id": "1f7ee5fba0f3",
#                 "weight": 1
#             },
#             {
#                 "id": "838d30134673",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_20": [],
#         "s144": [
#             {
#                 "id": "bd3e73c7-4efe-47ff-a770-718d42e1880f",
#                 "weight": 1
#             }
#         ]
#     },
#     "score": 0
# }
# p_value: 3.1763251677139393e-09
# Merged 3
#   Cromolyn -[biolink:interacts_with]-> KCNMA1
#   Miconazole -[biolink:interacts_with]-> KCNMA1
#   Hydrochlorothiazide -[biolink:interacts_with]-> KCNMA1
# ----
# p_value: 4.728318829430971e-44
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:6325242",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:24892745",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:214350",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "CHEBI:36314",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:20210",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "CHEBI:5743",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4479243",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5757",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:54614868",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3019",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:390361",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 4.728318829430971e-44,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_28": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "45fc7a1a59a3",
#                 "weight": 1
#             },
#             {
#                 "id": "be7635a0dff8",
#                 "weight": 1
#             },
#             {
#                 "id": "af09ae830a33",
#                 "weight": 1
#             },
#             {
#                 "id": "24dc3c6ff60d",
#                 "weight": 1
#             },
#             {
#                 "id": "def593db50d4",
#                 "weight": 1
#             },
#             {
#                 "id": "752752df6d52",
#                 "weight": 1
#             },
#             {
#                 "id": "7ec1d63c574e",
#                 "weight": 1
#             },
#             {
#                 "id": "7a9e6b1aa9d7",
#                 "weight": 1
#             },
#             {
#                 "id": "4e4e62c17e58",
#                 "weight": 1
#             },
#             {
#                 "id": "ca8d3297f7e7",
#                 "weight": 1
#             },
#             {
#                 "id": "f99dae9682fe",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_28": []
#     },
#     "score": 0
# }
# p_value: 1.0086532462030283e-12
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:4189",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.0086532462030283e-12,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3639",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.0086532462030283e-12,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2882",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.0086532462030283e-12,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_40": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "f9e5dd34101a",
#                 "weight": 1
#             },
#             {
#                 "id": "053020371140",
#                 "weight": 1
#             },
#             {
#                 "id": "e2bb8031297c",
#                 "weight": 1
#             },
#             {
#                 "id": "36147eeeb47d",
#                 "weight": 1
#             },
#             {
#                 "id": "1d0315cadf9f",
#                 "weight": 1
#             },
#             {
#                 "id": "916e4ae87fba",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_40": []
#     },
#     "score": 0
# }
# p_value: 3.649053390131684e-11
# {
# ...
#                 ]
#             }
#         ],
#         "extra_qn_45": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "6c77b2217b94",
#                 "weight": 1
#             },
#             {
#                 "id": "5d367fac900e",
#                 "weight": 1
#             },
#             {
#                 "id": "425ed253744f",
#                 "weight": 1
#             },
#             {
#                 "id": "b10907769d2e",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_45": []
#     },
#     "score": 0
# }
# p_value: 5.283942155856431e-09
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:5757",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 5.283942155856431e-09,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:214350",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 5.283942155856431e-09,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_46": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "8dd40182bbda",
#                 "weight": 1
#             },
#             {
#                 "id": "4e4e62c17e58",
#                 "weight": 1
#             },
#             {
#                 "id": "752752df6d52",
#                 "weight": 1
#             },
#             {
#                 "id": "907bfced6727",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_46": []
#     },
#     "score": 0
# }
# p_value: 1.2619852879368695e-08
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:5757",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2619852879368695e-08,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:214350",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2619852879368695e-08,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_47": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "8dd40182bbda",
#                 "weight": 1
#             },
#             {
#                 "id": "4e4e62c17e58",
#                 "weight": 1
#             },
#             {
#                 "id": "752752df6d52",
#                 "weight": 1
#             },
#             {
#                 "id": "907bfced6727",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_47": []
#     },
#     "score": 0
# }
# p_value: 1.2397132968460726e-14
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:5357696",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2397132968460726e-14,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5354618",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2397132968460726e-14,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5359464",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2397132968460726e-14,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_48": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "45ecf7a215df",
#                 "weight": 1
#             },
#             {
#                 "id": "2724819edcfe",
#                 "weight": 1
#             },
#             {
#                 "id": "1c07fbd17c90",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_48": []
#     },
#     "score": 0
# }
# p_value: 3.9304008111929507e-10
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "NCIT:C2317",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.9304008111929507e-10,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:977",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 3.9304008111929507e-10,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_49": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "c928a4294bbc",
#                 "weight": 1
#             },
#             {
#                 "id": "44b67b255f8f",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_49": []
#     },
#     "score": 0
# }
# p_value: 1.2275003461865521e-46
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:3226",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "UNII:42VZT0U6YR",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2882",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:813",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:271",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4189",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:23138861",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2315",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:281",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3639",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:2733",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3019",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2275003461865521e-46,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_49": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "b10907769d2e",
#                 "weight": 1
#             },
#             {
#                 "id": "7de639cd6261",
#                 "weight": 1
#             },
#             {
#                 "id": "425ed253744f",
#                 "weight": 1
#             },
#             {
#                 "id": "f63203ccbe33",
#                 "weight": 1
#             },
#             {
#                 "id": "1d0315cadf9f",
#                 "weight": 1
#             },
#             {
#                 "id": "e86c0cf44ef0",
#                 "weight": 1
#             },
#             {
#                 "id": "f9e5dd34101a",
#                 "weight": 1
#             },
#             {
#                 "id": "1b926b87d935",
#                 "weight": 1
#             },
#             {
#                 "id": "4ddfa10ae2fa",
#                 "weight": 1
#             },
#             {
#                 "id": "bc93e064bee3",
#                 "weight": 1
#             },
#             {
#                 "id": "916e4ae87fba",
#                 "weight": 1
#             },
#             {
#                 "id": "df99e009b6c4",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_49": []
#     },
#     "score": 0
# }
# p_value: 1.586695648732096e-33
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:220338",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:439260",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4788",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:36314",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:60700",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:187",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:105008",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:22326046",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.586695648732096e-33,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_49": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "cb1ede0206cc",
#                 "weight": 1
#             },
#             {
#                 "id": "47dcf3e94481",
#                 "weight": 1
#             },
#             {
#                 "id": "be96f19b170d",
#                 "weight": 1
#             },
#             {
#                 "id": "c4c62f5d9156",
#                 "weight": 1
#             },
#             {
#                 "id": "5ad902b8a8f6",
#                 "weight": 1
#             },
#             {
#                 "id": "0fbf4749d416",
#                 "weight": 1
#             },
#             {
#                 "id": "9dada43f375a",
#                 "weight": 1
#             },
#             {
#                 "id": "914e737e0851",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_49": []
#     },
#     "score": 0
# }
# p_value: 1.7468556887556165e-10
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:5460341",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.7468556887556165e-10,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:9903",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.7468556887556165e-10,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_49": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "bab38a3a09c2",
#                 "weight": 1
#             },
#             {
#                 "id": "0933b06c1f9a",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_49": []
#     },
#     "score": 0
# }
# p_value: 1.2397132968460726e-14
# {
#     "node_bindings": {
#         "n1": [
#             {
#                 "id": "NCBIGene:3778"
#             }
#         ],
#         "n0": [
#             {
#                 "id": "PUBCHEM.COMPOUND:5460341",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2397132968460726e-14,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "CHEBI:32589",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2397132968460726e-14,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5462222",
#                 "coalescence_method": "graph_enrichment",
#                 "p_value": 1.2397132968460726e-14,
#                 "enriched_nodes": [
#                     "NCBIGene:3778"
#                 ]
#             }
#         ],
#         "extra_qn_49": []
#     },
#     "edge_bindings": {
#         "e0": [
#             {
#                 "id": "2fba6157825e",
#                 "weight": 1
#             },
#             {
#                 "id": "55fa14d7ae52",
#                 "weight": 1
#             },
#             {
#                 "id": "a6448ab1b4e5",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_49": []
#     },
#     "score": 0
# }

# %% [markdown]
# ### ARAGORN Assessment

# %% [markdown]
# How did we do?
