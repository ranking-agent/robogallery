# %% [markdown]
# # Setup

# %%
import json
import requests
from datetime import datetime as dt
from collections import defaultdict
import pandas as pd

# %%
#https://pypi.org/project/gamma-viewer/
from gamma_viewer import GammaViewer
from IPython.display import display, Markdown

# %%
def printjson(j):
    print(json.dumps(j,indent=4))
def print_json(j):
    printjson(j)

# %%
def post(name,url,message,params=None):
    if params is None:
        response = requests.post(url,json=message)
    else:
        response = requests.post(url,json=message,params=params)
    if not response.status_code == 200:
        print(name, 'error:',response.status_code)
        print(response.json())
        return {}
    return response.json()

def automat(db,message):
    automat_url = f'https://automat.renci.org/{db}/query'
    response = requests.post(automat_url,json=message)
    print(response.status_code)
    return response.json()

def strider(message):
    url = 'https://strider.renci.org/query?log_level=DEBUG'
    strider_answer = post(strider,url,message)
    return strider_answer

def aragorn(message, coalesce_type='xnone'):
    if coalesce_type == 'xnone':
        answer = post('aragorn','https://aragorn.renci.org/query',message)
    else:
        answer = post('aragorn','https://aragorn.renci.org/query',message, params={'answer_coalesce_type':coalesce_type})
    return answer

##

def bte(message):
    url = 'https://api.bte.ncats.io/v1/query'
    return post(strider,url,message)

def coalesce(message,method='all'):
    url = 'https://answercoalesce.renci.org/coalesce/graph'
    return post('AC'+method,url,message)

def striderandfriends(message):
    strider_answer = strider(message)    
    coalesced_answer = post('coalesce','https://answercoalesce.renci.org/coalesce/all',strider_answer)
    omni_answer = post('omnicorp','https://aragorn-ranker.renci.org/omnicorp_overlay',coalesced_answer)
    weighted_answer = post('weight','https://aragorn-ranker.renci.org/weight_correctness',omni_answer)
    scored_answer = post('score','https://aragorn-ranker.renci.org/score',weighted_answer)
    return strider_answer,coalesced_answer,omni_answer,weighted_answer,scored_answer

# %%
def print_errors(strider_result):
    errorcounts = defaultdict(int)
    for logmessage in strider_result['logs']:
        if logmessage['level'] == 'ERROR':
            jm = json.loads(logmessage['message'])
            words = jm['error'].split()
            e = " ".join(words[:-5])
            errorcounts[e] += 1
    for error,count in errorcounts.items():
        print(f'{error} ({count} times)')
        
def print_queried_sources(strider_result):
    querycounts = defaultdict(int)
    for logmessage in strider_result['logs']:
        if 'step' in logmessage and isinstance(logmessage['step'],list):
            for s in logmessage['step']:
                querycounts[s['url']] += 1
    for url,count in querycounts.items():
        print(f'{url} ({count} times)')
        
def print_query_for_source(strider_result,url):
    for logmessage in strider_result['logs']:
        if 'step' in logmessage and isinstance(logmessage['step'],list):
            for s in logmessage['step']:
                if s['url']==url:
                    print(s)

# %%
def retrieve_ars_results(mid):
    message_url = f'https://ars.transltr.io/ars/api/messages/{mid}?trace=y'
    response = requests.get(message_url)
    j = response.json()
    results = {}
    for child in j['children']:
        if child['actor']['agent'] in ['ara-aragorn', 'ara-aragorn-exp']:
            childmessage_id = child['message']
            child_url = f'https://ars.transltr.io/ars/api/messages/{childmessage_id}'
            child_response = requests.get(child_url).json()
            try:
                nresults = len(child_response['fields']['data']['message']['results'])
                if nresults > 0:
                    results[child['actor']['agent']] = {'message':child_response['fields']['data']['message']}
            except:
                nresults=0
            print( child['status'], child['actor']['agent'],nresults )
    return results

# %%
def get_provenance(message):
    """Given a message with results, find the source of the edges"""
    prov = defaultdict(lambda: defaultdict(int)) # {qedge->{source->count}}
    results = message['message']['results']
    kg = message['message']['knowledge_graph']['edges']
    edge_bindings = [ r['edge_bindings'] for r in results ]
    for bindings in edge_bindings:
        for qg_e, kg_l in bindings.items():
            for kg_e in kg_l:
                for att in kg[kg_e['id']]['attributes']:
                    if att['name'] == 'provenance':
                        source = att['value']
                        prov[qg_e][source]+=1
    qg_edges = []
    sources = []
    counts = []
    for qg_e in prov:
        for source in prov[qg_e]:
            qg_edges.append(qg_e)
            sources.append(source)
            counts.append(prov[qg_e][source])
    prov_table = pd.DataFrame({"QG Edge":qg_edges, "Source":sources, "Count":counts})
    return prov_table

# %% [markdown]
# ## Query Specific

# %%
pwd
# Out:
# '/Users/priyash/Documents/GitHub/robogallery/user_queries'

# %%
standup_json='/Users/priyash/Documents/GitHub/robogallery/standups/StandupDefinitions/standup_3.json'

# %%
with open(standup_json,'r') as jsonfile:
    standup_info = json.load(jsonfile)

# %%
display(Markdown(f"# {standup_info['Query Title']}"))
display(Markdown(f"{standup_info['Query Description']}"))
print(f'Github Issue: {standup_info["github_issue"]}')
# Out:
# # 3. Named Thing
# What things are related to Acrocyanosis (UMLS:C0221347)
# Github Issue: https://github.com/NCATSTranslator/testing/issues/12

# %% [markdown]
# The query as run through the ARS:

# %%
query = json.loads(requests.get(standup_info['query_location']).content)
printjson(query)
# Out:
# {
#     "message": {
#         "query_graph": {
#             "nodes": {
#                 "n0": {
#                     "id": "UMLS:C0221347",
#                     "category": "biolink:PhenotypicFeature"
#                 },
#                 "n1": {
#                     "category": "biolink:NamedThing"
#                 }
#             },
#             "edges": {
#                 "e01": {
#                     "subject": "n0",
#                     "object": "n1"
#                 }
#             }
#         }
#     }
# }

# %% [markdown]
# ## ARS Assessment

# %%
ARS_Responses = [(dt.strptime(x['ARS_result_date'],'%Y-%m-%d'),x['ARS_result_id']) for x in standup_info['ARS_Results']]
ARS_Responses.sort()

# %%
for ars_date, ars_id in ARS_Responses:
    display(Markdown(f'### {ars_date}'))
    _ = retrieve_ars_results(ars_id)
    print(f'https://arax.ncats.io/?source=ARS&id={ars_id}')
# Out:
# ### 2021-03-16 00:00:00
# Done ara-aragorn 340
# Done ara-aragorn-exp 0
# https://arax.ncats.io/?source=ARS&id=8c6ae8db-1af9-49ae-a9f5-99181bd3dd4b
# ### 2021-03-17 00:00:00
# Error ara-aragorn 0
# Done ara-aragorn-exp 0
# https://arax.ncats.io/?source=ARS&id=58846701-a542-487c-8602-ef7ff04fb7fa

# %% [markdown]
# ## Strider Direct

# %%
start = dt.now()
strider_result = strider(query)
end = dt.now()
print(f"Strider produced {len(strider_result['message']['results'])} results in {end-start}.")
# Out:
# Strider produced 0 results in 0:00:28.245458.

# %% [markdown]
# ### Provenance

# %%
prov = get_provenance(strider_result)
display(prov)
# Out:
# Empty DataFrame
# Columns: [QG Edge, Source, Count]
# Index: []

# %% [markdown]
# ### Queried sources

# %%
print_queried_sources(strider_result)
# Out:
# https://automat.renci.org/covidkopkg/reasonerapi (99 times)
# https://automat.renci.org/robokopkg/reasonerapi (81 times)
# https://automat.renci.org/ctd/reasonerapi (11 times)
# https://automat.renci.org/cord19-scibite/reasonerapi (18 times)
# https://automat.renci.org/covid-phenotypes/reasonerapi (3 times)
# https://automat.renci.org/cord19-scigraph/reasonerapi (30 times)
# https://automat.renci.org/mychem/reasonerapi (6 times)
# https://automat.renci.org/ontological-hierarchy/reasonerapi (8 times)
# https://automat.renci.org/uberongraph/reasonerapi (99 times)
# https://automat.renci.org/pharos/reasonerapi (2 times)
# https://automat.renci.org/biolink/reasonerapi (11 times)
# https://automat.renci.org/hmdb/reasonerapi (2 times)
# https://automat.renci.org/hetio/reasonerapi (5 times)
# http://chp.thayer.dartmouth.edu/query/ (2 times)
# https://trapi.monarchinitiative.org/query (47 times)
# https://translator.broadinstitute.org/molepro/trapi/v1.0/query (1 times)
# https://stars-app.renci.org/sparql-kp/query (57 times)
# https://translator.broadinstitute.org/genetics_provider/trapi/v1.0/query (2 times)
# https://icees.renci.org:16340/knowledge_graph_one_hop?reasoner=true (2 times)

# %% [markdown]
# ### Errors

# %%
print_errors(strider_result)

# %%
strider_result
# Out:
# {'message': {'query_graph': {'nodes': {'n1': {'id': None,
#      'category': ['biolink:NamedThing'],
#      'is_set': False},
#     'n0': {'id': ['UMLS:C0221347'],
#      'category': ['biolink:PhenotypicFeature'],
#      'is_set': False}},
#    'edges': {'e01': {'subject': 'n0',
#      'object': 'n1',
#      'predicate': None,
#      'relation': None}}},
#   'knowledge_graph': {'nodes': {}, 'edges': {}},
#   'results': []},
#  'logs': [{'timestamp': '2021-05-20T17:41:58.705298',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.687693',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.663859',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.646373',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.630436',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.613755',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.596411',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.578471',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.560439',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.543516',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.526242',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.504188',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.484954',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.467113',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.449338',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.430139',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.400871',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.376228',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.350945',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.327535',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.311209',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.293768',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.274540',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.256478',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.236582',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.217131',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.199062',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.180986',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.163538',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.145460',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.128167',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.109334',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.091615',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.073065',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.055082',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:58.023366',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.999000',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.972203',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.954437',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.931420',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.911535',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.891485',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.873058',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.853949',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.830229',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.788840',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.766888',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.748399',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.730342',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.706909',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.689033',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.671228',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.630759',
#    'level': 'WARNING',
#    'code': None,
#    'message': 'Cannot find identifier with a preferred prefix'},
#   {'timestamp': '2021-05-20T17:41:57.605474',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.577669',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.558655',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.542017',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.512174',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.494640',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.476410',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.458536',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.441175',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.423022',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.405385',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.386351',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.366477',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.347238',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.328642',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.311519',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.293922',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.275888',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.256954',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.238548',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.198020',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.179981',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.162758',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.144002',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.126592',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.109049',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.092019',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.074491',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.056870',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.038709',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:57.017422',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.999158',
#    'level': 'WARNING',
#    'code': None,
#    'message': 'Cannot find identifier with a preferred prefix'},
#   {'timestamp': '2021-05-20T17:41:56.982322',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.966439',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.949803',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.932717',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.911798',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.895033',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.868008',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.851653',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.834111',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.817303',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.799793',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.782601',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.764183',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.747159',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.731117',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.714207',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.697800',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.681628',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.664869',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.635155',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.616535',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.597028',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.580614',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.564572',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.548066',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.531115',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.505949',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.490683',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.474481',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.457589',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.440004',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.412295',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.391717',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.372697',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.353660',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.319494',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.301365',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.283999',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.265391',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.247700',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.229348',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.211054',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.191607',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.173898',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.157081',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.135517',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.114776',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.098185',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.080935',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.056662',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.039263',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.022013',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:56.004454',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.986870',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.967962',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.951160',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.934645',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.909915',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.890241',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.870162',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.851903',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.833819',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.816635',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.799280',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.772778',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.754964',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.736743',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.718964',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.701328',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.684357',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.667651',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.650256',
#    'level': 'WARNING',
#    'code': None,
#    'message': "Could not find preferred prefixes for at least one of: ['biolink:Disease', 'biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:NamedThing', 'biolink:Entity']"},
#   {'timestamp': '2021-05-20T17:41:55.632120',
#    'level': 'WARNING',
#    'code': None,
# ...
#        '<-biolink:process_positively_regulates_process-']},
#      'e01.symmetric': {'qg_edge_id': 'e01',
#       'edge_reverse': False,
#       'source': 'n0',
#       'target': 'n1',
#       'predicate': ['<-biolink:related_to-',
#        '<-biolink:develops_from-',
#        '<-biolink:affects_risk_for-',
#        '<-biolink:predisposes-',
#        '<-biolink:prevents-',
#        '<-biolink:prevented_by-',
#        '<-biolink:has_sequence_location-',
#        '<-biolink:has_phenotype-',
#        '<-biolink:has_participant-',
#        '<-biolink:enabled_by-',
#        '<-biolink:has_output-',
#        '<-biolink:has_input-',
#        '<-biolink:contributes_to-',
#        '<-biolink:causes-',
#        '<-biolink:causes_adverse_event-',
#        '<-biolink:treated_by-',
#        '<-biolink:approved_for_treatment_by-',
#        '<-biolink:genetic_association-',
#        '<-biolink:condition_associated_with_gene-',
#        '<-biolink:gene_associated_with_condition-',
#        '<-biolink:located_in-',
#        '<-biolink:contributor-',
#        '<-biolink:publisher-',
#        '<-biolink:author-',
#        '<-biolink:editor-',
#        '<-biolink:provider-',
#        '<-biolink:manifestation_of-',
#        '<-biolink:contraindicated_for-',
#        '<-biolink:similar_to-',
#        '<-biolink:homologous_to-',
#        '<-biolink:orthologous_to-',
#        '<-biolink:xenologous_to-',
#        '<-biolink:paralogous_to-',
#        '<-biolink:model_of-',
#        '<-biolink:chemically_similar_to-',
#        '<-biolink:has_gene_product-',
#        '<-biolink:transcribed_to-',
#        '<-biolink:narrow_match-',
#        '<-biolink:translates_to-',
#        '<-biolink:coexists_with-',
#        '<-biolink:in_pathway_with-',
#        '<-biolink:in_cell_population_with-',
#        '<-biolink:in_complex_with-',
#        '<-biolink:colocalizes_with-',
#        '<-biolink:derives_into-',
#        '<-biolink:has_metabolite-',
#        '<-biolink:has_not_completed-',
#        '<-biolink:location_of-',
#        '<-biolink:translation_of-',
#        '<-biolink:produces-',
#        '<-biolink:close_match-',
#        '<-biolink:exact_match-',
#        '<-biolink:same_as-',
#        '<-biolink:superclass_of-',
#        '<-biolink:transcribed_from-',
#        '<-biolink:expresses-',
#        '<-biolink:is_sequence_variant_of-',
#        '<-biolink:is_splice_site_variant_of-',
#        '<-biolink:is_missense_variant_of-',
#        '<-biolink:is_frameshift_variant_of-',
#        '<-biolink:is_synonymous_variant_of-',
#        '<-biolink:is_non_coding_variant_of-',
#        '<-biolink:is_nonsense_variant_of-',
#        '<-biolink:is_nearby_variant_of-',
#        '<-biolink:in_linkage_disequilibrium_with-',
#        '<-biolink:expressed_in-',
#        '<-biolink:affected_by-',
#        '<-biolink:entity_regulated_by_entity-',
#        '<-biolink:entity_negatively_regulated_by_entity-',
#        '<-biolink:entity_positively_regulated_by_entity-',
#        '<-biolink:disrupted_by-',
#        '<-biolink:process_regulated_by_process-',
#        '<-biolink:process_negatively_regulated_by_process-',
#        '<-biolink:process_positively_regulated_by_process-',
#        '<-biolink:has_increased_amount-',
#        '<-biolink:overlaps-',
#        '<-biolink:has_part-',
#        '<-biolink:has_active_ingredient-',
#        '<-biolink:has_food_component-',
#        '<-biolink:has_nutrient-',
#        '<-biolink:has_excipient-',
#        '<-biolink:has_variant_part-',
#        '<-biolink:part_of-',
#        '<-biolink:food_component_of-',
#        '<-biolink:nutrient_of-',
#        '<-biolink:is_excipient_of-',
#        '<-biolink:is_active_ingredient_of-',
#        '<-biolink:interacts_with-',
#        '<-biolink:directly_interacts_with-',
#        '<-biolink:physically_interacts_with-',
#        '<-biolink:molecularly_interacts_with-',
#        '<-biolink:increases_molecular_interaction-',
#        '<-biolink:decreases_molecular_interaction-',
#        '<-biolink:genetically_interacts_with-',
#        '<-biolink:has_decreased_amount-',
#        '<-biolink:has_completed-',
#        '<-biolink:caused_by-',
#        '<-biolink:derives_from-',
#        '<-biolink:is_metabolite_of-',
#        '<-biolink:related_condition-',
#        '<-biolink:opposite_of-',
#        '<-biolink:disease_has_basis_in-',
#        '<-biolink:in_taxon-',
#        '<-biolink:participates_in-',
#        '<-biolink:enables-',
#        '<-biolink:actively_involved_in-',
#        '<-biolink:capable_of-',
#        '<-biolink:phenotype_of-',
#        '<-biolink:temporally_related_to-',
#        '<-biolink:preceded_by-',
#        '<-biolink:precedes-',
#        '<-biolink:broad_match-',
#        '<-biolink:gene_product_of-',
#        '<-biolink:correlated_with-',
#        '<-biolink:positively_correlated_with-',
#        '<-biolink:coexpressed_with-',
#        '<-biolink:has_biomarker-',
#        '<-biolink:biomarker_for-',
#        '<-biolink:negatively_correlated_with-',
#        '<-biolink:produced_by-',
#        '<-biolink:subclass_of-',
#        '<-biolink:lacks_part-',
#        '<-biolink:has_molecular_consequence-',
#        '<-biolink:occurs_in-',
#        '<-biolink:affects-',
#        '<-biolink:affects_localization_of-',
#        '<-biolink:increases_localization_of-',
#        '<-biolink:decreases_localization_of-',
#        '<-biolink:affects_response_to-',
#        '<-biolink:increases_response_to-',
#        '<-biolink:decreases_response_to-',
#        '<-biolink:affects_expression_in-',
#        '<-biolink:affects_synthesis_of-',
#        '<-biolink:increases_synthesis_of-',
#        '<-biolink:decreases_synthesis_of-',
#        '<-biolink:affects_expression_of-',
#        '<-biolink:increases_expression_of-',
#        '<-biolink:decreases_expression_of-',
#        '<-biolink:ameliorates-',
#        '<-biolink:treats-',
#        '<-biolink:approved_to_treat-',
#        '<-biolink:exacerbates-',
#        '<-biolink:affects_folding_of-',
#        '<-biolink:decreases_folding_of-',
#        '<-biolink:increases_folding_of-',
#        '<-biolink:affects_abundance_of-',
#        '<-biolink:increases_abundance_of-',
#        '<-biolink:decreases_abundance_of-',
#        '<-biolink:affects_molecular_modification_of-',
#        '<-biolink:increases_molecular_modification_of-',
#        '<-biolink:decreases_molecular_modification_of-',
#        '<-biolink:affects_secretion_of-',
#        '<-biolink:decreases_secretion_of-',
#        '<-biolink:increases_secretion_of-',
#        '<-biolink:affects_metabolic_processing_of-',
#        '<-biolink:increases_metabolic_processing_of-',
#        '<-biolink:decreases_metabolic_processing_of-',
#        '<-biolink:affects_activity_of-',
#        '<-biolink:increases_activity_of-',
#        '<-biolink:decreases_activity_of-',
#        '<-biolink:affects_transport_of-',
#        '<-biolink:increases_transport_of-',
#        '<-biolink:decreases_transport_of-',
#        '<-biolink:affects_mutation_rate_of-',
#        '<-biolink:decreases_mutation_rate_of-',
#        '<-biolink:increases_mutation_rate_of-',
#        '<-biolink:entity_regulates_entity-',
#        '<-biolink:entity_negatively_regulates_entity-',
#        '<-biolink:entity_positively_regulates_entity-',
#        '<-biolink:affects_splicing_of-',
#        '<-biolink:decreases_splicing_of-',
#        '<-biolink:increases_splicing_of-',
#        '<-biolink:affects_uptake_of-',
#        '<-biolink:decreases_uptake_of-',
#        '<-biolink:increases_uptake_of-',
#        '<-biolink:disrupts-',
#        '<-biolink:affects_degradation_of-',
#        '<-biolink:decreases_degradation_of-',
#        '<-biolink:increases_degradation_of-',
#        '<-biolink:affects_stability_of-',
#        '<-biolink:decreases_stability_of-',
#        '<-biolink:increases_stability_of-',
#        '<-biolink:process_regulates_process-',
#        '<-biolink:process_negatively_regulates_process-',
#        '<-biolink:process_positively_regulates_process-']},
#      'e01.reverse.symmetric': {'qg_edge_id': 'e01',
#       'edge_reverse': True,
#       'source': 'n1',
#       'target': 'n0',
#       'predicate': ['-biolink:related_to->',
#        '-biolink:develops_from->',
#        '-biolink:affects_risk_for->',
#        '-biolink:predisposes->',
#        '-biolink:prevents->',
#        '-biolink:prevented_by->',
#        '-biolink:has_sequence_location->',
#        '-biolink:has_phenotype->',
#        '-biolink:has_participant->',
#        '-biolink:enabled_by->',
#        '-biolink:has_output->',
#        '-biolink:has_input->',
#        '-biolink:contributes_to->',
#        '-biolink:causes->',
#        '-biolink:causes_adverse_event->',
#        '-biolink:treated_by->',
#        '-biolink:approved_for_treatment_by->',
#        '-biolink:genetic_association->',
#        '-biolink:condition_associated_with_gene->',
#        '-biolink:gene_associated_with_condition->',
#        '-biolink:located_in->',
#        '-biolink:contributor->',
#        '-biolink:publisher->',
#        '-biolink:author->',
#        '-biolink:editor->',
#        '-biolink:provider->',
#        '-biolink:manifestation_of->',
#        '-biolink:contraindicated_for->',
#        '-biolink:similar_to->',
#        '-biolink:homologous_to->',
#        '-biolink:orthologous_to->',
#        '-biolink:xenologous_to->',
#        '-biolink:paralogous_to->',
#        '-biolink:model_of->',
#        '-biolink:chemically_similar_to->',
#        '-biolink:has_gene_product->',
#        '-biolink:transcribed_to->',
#        '-biolink:narrow_match->',
#        '-biolink:translates_to->',
#        '-biolink:coexists_with->',
#        '-biolink:in_pathway_with->',
#        '-biolink:in_cell_population_with->',
#        '-biolink:in_complex_with->',
#        '-biolink:colocalizes_with->',
#        '-biolink:derives_into->',
#        '-biolink:has_metabolite->',
#        '-biolink:has_not_completed->',
#        '-biolink:location_of->',
#        '-biolink:translation_of->',
#        '-biolink:produces->',
#        '-biolink:close_match->',
#        '-biolink:exact_match->',
#        '-biolink:same_as->',
#        '-biolink:superclass_of->',
#        '-biolink:transcribed_from->',
#        '-biolink:expresses->',
#        '-biolink:is_sequence_variant_of->',
#        '-biolink:is_splice_site_variant_of->',
#        '-biolink:is_missense_variant_of->',
#        '-biolink:is_frameshift_variant_of->',
#        '-biolink:is_synonymous_variant_of->',
#        '-biolink:is_non_coding_variant_of->',
#        '-biolink:is_nonsense_variant_of->',
#        '-biolink:is_nearby_variant_of->',
#        '-biolink:in_linkage_disequilibrium_with->',
#        '-biolink:expressed_in->',
#        '-biolink:affected_by->',
#        '-biolink:entity_regulated_by_entity->',
#        '-biolink:entity_negatively_regulated_by_entity->',
#        '-biolink:entity_positively_regulated_by_entity->',
#        '-biolink:disrupted_by->',
#        '-biolink:process_regulated_by_process->',
#        '-biolink:process_negatively_regulated_by_process->',
#        '-biolink:process_positively_regulated_by_process->',
#        '-biolink:has_increased_amount->',
#        '-biolink:overlaps->',
#        '-biolink:has_part->',
#        '-biolink:has_active_ingredient->',
#        '-biolink:has_food_component->',
#        '-biolink:has_nutrient->',
#        '-biolink:has_excipient->',
#        '-biolink:has_variant_part->',
#        '-biolink:part_of->',
#        '-biolink:food_component_of->',
#        '-biolink:nutrient_of->',
#        '-biolink:is_excipient_of->',
#        '-biolink:is_active_ingredient_of->',
#        '-biolink:interacts_with->',
#        '-biolink:directly_interacts_with->',
#        '-biolink:physically_interacts_with->',
#        '-biolink:molecularly_interacts_with->',
#        '-biolink:increases_molecular_interaction->',
#        '-biolink:decreases_molecular_interaction->',
#        '-biolink:genetically_interacts_with->',
#        '-biolink:has_decreased_amount->',
#        '-biolink:has_completed->',
#        '-biolink:caused_by->',
#        '-biolink:derives_from->',
#        '-biolink:is_metabolite_of->',
#        '-biolink:related_condition->',
#        '-biolink:opposite_of->',
#        '-biolink:disease_has_basis_in->',
#        '-biolink:in_taxon->',
#        '-biolink:participates_in->',
#        '-biolink:enables->',
#        '-biolink:actively_involved_in->',
#        '-biolink:capable_of->',
#        '-biolink:phenotype_of->',
#        '-biolink:temporally_related_to->',
#        '-biolink:preceded_by->',
#        '-biolink:precedes->',
#        '-biolink:broad_match->',
#        '-biolink:gene_product_of->',
#        '-biolink:correlated_with->',
#        '-biolink:positively_correlated_with->',
#        '-biolink:coexpressed_with->',
#        '-biolink:has_biomarker->',
#        '-biolink:biomarker_for->',
#        '-biolink:negatively_correlated_with->',
#        '-biolink:produced_by->',
#        '-biolink:subclass_of->',
#        '-biolink:lacks_part->',
#        '-biolink:has_molecular_consequence->',
#        '-biolink:occurs_in->',
#        '-biolink:affects->',
#        '-biolink:affects_localization_of->',
#        '-biolink:increases_localization_of->',
#        '-biolink:decreases_localization_of->',
#        '-biolink:affects_response_to->',
#        '-biolink:increases_response_to->',
#        '-biolink:decreases_response_to->',
#        '-biolink:affects_expression_in->',
#        '-biolink:affects_synthesis_of->',
#        '-biolink:increases_synthesis_of->',
#        '-biolink:decreases_synthesis_of->',
#        '-biolink:affects_expression_of->',
#        '-biolink:increases_expression_of->',
#        '-biolink:decreases_expression_of->',
#        '-biolink:ameliorates->',
#        '-biolink:treats->',
#        '-biolink:approved_to_treat->',
#        '-biolink:exacerbates->',
#        '-biolink:affects_folding_of->',
#        '-biolink:decreases_folding_of->',
#        '-biolink:increases_folding_of->',
#        '-biolink:affects_abundance_of->',
#        '-biolink:increases_abundance_of->',
#        '-biolink:decreases_abundance_of->',
#        '-biolink:affects_molecular_modification_of->',
#        '-biolink:increases_molecular_modification_of->',
#        '-biolink:decreases_molecular_modification_of->',
#        '-biolink:affects_secretion_of->',
#        '-biolink:decreases_secretion_of->',
#        '-biolink:increases_secretion_of->',
#        '-biolink:affects_metabolic_processing_of->',
#        '-biolink:increases_metabolic_processing_of->',
#        '-biolink:decreases_metabolic_processing_of->',
#        '-biolink:affects_activity_of->',
#        '-biolink:increases_activity_of->',
#        '-biolink:decreases_activity_of->',
#        '-biolink:affects_transport_of->',
#        '-biolink:increases_transport_of->',
#        '-biolink:decreases_transport_of->',
#        '-biolink:affects_mutation_rate_of->',
#        '-biolink:decreases_mutation_rate_of->',
#        '-biolink:increases_mutation_rate_of->',
#        '-biolink:entity_regulates_entity->',
#        '-biolink:entity_negatively_regulates_entity->',
#        '-biolink:entity_positively_regulates_entity->',
#        '-biolink:affects_splicing_of->',
#        '-biolink:decreases_splicing_of->',
#        '-biolink:increases_splicing_of->',
#        '-biolink:affects_uptake_of->',
#        '-biolink:decreases_uptake_of->',
#        '-biolink:increases_uptake_of->',
#        '-biolink:disrupts->',
#        '-biolink:affects_degradation_of->',
#        '-biolink:decreases_degradation_of->',
#        '-biolink:increases_degradation_of->',
#        '-biolink:affects_stability_of->',
#        '-biolink:decreases_stability_of->',
#        '-biolink:increases_stability_of->',
#        '-biolink:process_regulates_process->',
#        '-biolink:process_negatively_regulates_process->',
#        '-biolink:process_positively_regulates_process->']}}}},
#   {'timestamp': '2021-05-20T17:41:41.099722',
#    'level': 'DEBUG',
#    'code': None,
#    'message': 'Using BMT to get descendants of node and edge types'},
#   {'timestamp': '2021-05-20T17:41:41.089117',
#    'level': 'INFO',
#    'code': None,
#    'message': 'Generating plan for query graph'},
#   {'timestamp': '2021-05-20T17:41:41.078347',
#    'level': 'DEBUG',
#    'code': None,
#    'message': 'Generating plan'},
#   {'timestamp': '2021-05-20T17:41:41.040083',
#    'level': 'DEBUG',
#    'code': None,
#    'message': 'Contacting node normalizer to get categorys for curies'},
#   {'timestamp': '2021-05-20T17:41:40.978206',
#    'level': 'DEBUG',
#    'code': None,
#    'message': 'Initialized strider worker'}],
#  'status': None}

# %% [markdown]
# ### Results

# %%
view = GammaViewer(props={"data":strider_result})
display(view)

# %% [markdown]
# ### Strider Assessment

# %% [markdown]
# Enter Assessment Here

# %% [markdown]
# ## ARAGORN

# %%
start = dt.now()
aragorn_result = aragorn(query)
end = dt.now()
if 'results' in aragorn_result['message']:
    print(f"ARAGORN produced {len(aragorn_result['message']['results'])} results in {end-start}.")
else:
    print('Error, no result field')
# Out:
# Error, no result field

# %%
view = GammaViewer(props={"data":aragorn_result})
display(view)

# %%
tq={
    "message": {
        "query_graph": {
            "nodes": {
                "n1": {
                    "id": "HP:0033127",
                    "category": "biolink:PhenotypicFeature"
                },
                "n2": {
                    "category": "biolink:Disease"
                }
            },
            "edges": {
                "e02": {
                    "subject": "n1",
                    "object": "n2",
                    "predicate": "biolink:affected_by"
                }
            }
        }
    }
}

# %%
r = automat('uberongraph',tq)
# Out:
# 200

# %% [markdown]
# ### ARAGORN Assessment

# %% [markdown]
# How did we do?
