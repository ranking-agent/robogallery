# %% [markdown]
# ## Workflow C1: Drugs related to multiple sclerosis.
#
#
# <br>
# <br>

# %%
#Loading the functions from a notebook
# %run /Users/priyash/Documents/GitHub/robogallery/user_queries/proj_tools/template.ipynb

# %%
query = {
    "message": {
        "query_graph": {
            "edges": {
                "e00": {
                    "subject": "n00",
                    "object": "n01",
                    "predicates": ["biolink:related_to"]
                }
            },
            "nodes": {
                "n00": {
                    "categories": ["biolink:ChemicalSubstance"]
                },
                "n01": {
                    "categories": ["biolink:Disease"],
                    "ids": ["MONDO:0005301"]
                }
            }
        }
    }
}

# %%
start = dt.now()
strider_result = strider(query)
end = dt.now()
print(f"Strider produced {len(strider_result['message']['results'])} results in {end-start}.")
# Out:
# Strider produced 2044 results in 0:00:51.909225.

# %%
prov = get_provenance(strider_result)
display(prov)
# Out:
# Empty DataFrame
# Columns: [QG Edge, Source, Count]
# Index: []

# %%
for logmessage in strider_result['logs']:
    if logmessage['level'] == 'ERROR':
            print(logmessage['message'])
# Out:
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP

# %%
strider_result['logs']
# Out:
# [{'timestamp': '2021-07-30T14:15:21.462292',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:21 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '369',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:18625", "ENSEMBL:ENSG00000106080", "NCBIGene:55033"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL1201585"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:15:20.817538',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:20 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '322',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["UniProtKB:Q08116"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["PUBCHEM.COMPOUND:5291"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:15:20.094178',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:20 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '322',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["UniProtKB:Q08116"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["PUBCHEM.COMPOUND:5291"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:15:18.618018',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:18 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '362',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:930", "ENSEMBL:ENSG00000027847", "NCBIGene:11285"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL31"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:15:18.412695',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:17 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '369',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:18625", "ENSEMBL:ENSG00000106080", "NCBIGene:55033"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL1201585"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:15:14.931888',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:14 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '362',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:930", "ENSEMBL:ENSG00000027847", "NCBIGene:11285"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL31"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:15:10.800663',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:10 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '369',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:18625", "ENSEMBL:ENSG00000106080", "NCBIGene:55033"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL1201585"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:15:09.389466',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:08 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '322',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["UniProtKB:Q08116"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["PUBCHEM.COMPOUND:5291"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:15:09.252517',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:08 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '349',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["UniProtKB:Q00266", "ENSEMBL:ENSP00000361287"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["PUBCHEM.COMPOUND:5291"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:15:07.937942',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:07 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '369',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:18625", "ENSEMBL:ENSG00000106080", "NCBIGene:55033"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL1201585"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:15:07.308873',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:07 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '362',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:930", "ENSEMBL:ENSG00000027847", "NCBIGene:11285"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL31"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:15:03.576339',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:03 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '455',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n00": {"categories": ["biolink:ChemicalSubstance"], "is_set": false}, "n01": {"ids": ["DOID:2377", "MONDO:0005301", "SNOMEDCT:155023009", "SNOMEDCT:192928003", "SNOMEDCT:24700007", "UMLS:C0026769", "UMLS:C0751324", "UMLS:C2675476", "UMLS:C2675477", "UMLS:C2675478"], "categories": ["biolink:Disease"], "is_set": false}}, "edges": {"e00": {"subject": "n01", "object": "n00", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:15:01.011225',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:15:00 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '362',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:930", "ENSEMBL:ENSG00000027847", "NCBIGene:11285"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL31"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:14:59.787865',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:14:59 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '369',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:18625", "ENSEMBL:ENSG00000106080", "NCBIGene:55033"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL1201585"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:14:58.856183',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:14:57 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '349',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["UniProtKB:Q00266", "ENSEMBL:ENSP00000361287"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["PUBCHEM.COMPOUND:5291"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:14:58.361392',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:14:57 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '349',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["UniProtKB:Q00266", "ENSEMBL:ENSP00000361287"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["PUBCHEM.COMPOUND:5291"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:14:56.809419',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:14:56 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '369',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:18625", "ENSEMBL:ENSG00000106080", "NCBIGene:55033"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL1201585"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:14:55.606541',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:14:55 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '362',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:930", "ENSEMBL:ENSG00000027847", "NCBIGene:11285"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL31"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:14:50.535074',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:14:50 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '362',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:930", "ENSEMBL:ENSG00000027847", "NCBIGene:11285"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL31"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:14:49.783412',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:14:49 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '369',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:18625", "ENSEMBL:ENSG00000106080", "NCBIGene:55033"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL1201585"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:14:48.065830',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:14:47 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '349',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["UniProtKB:Q00266", "ENSEMBL:ENSP00000361287"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["PUBCHEM.COMPOUND:5291"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:14:47.503147',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:14:47 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '349',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["UniProtKB:Q00266", "ENSEMBL:ENSP00000361287"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["PUBCHEM.COMPOUND:5291"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}},
#  {'timestamp': '2021-07-30T14:14:46.468639',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx',
#     'date': 'Fri, 30 Jul 2021 14:14:46 GMT',
#     'content-type': 'application/problem+json',
#     'content-length': '251',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*',
#     'access-control-allow-methods': 'GET, POST, OPTIONS',
#     'access-control-allow-headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range',
#     'access-control-expose-headers': 'Content-Length,Content-Range'},
#    'data': '{\n  "detail": "The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.",\n  "status": 500,\n  "title": "Internal Server Error",\n  "type": "about:blank"\n}\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://translator.broadinstitute.org/molepro/trapi/v1.1/query\nFor more information check: https://httpstatuses.com/500',
#   'request': {'method': 'POST',
#    'url': 'https://translator.broadinstitute.org/molepro/trapi/v1.1/query',
#    'headers': {'host': 'translator.broadinstitute.org',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '369',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n0": {"ids": ["HGNC:18625", "ENSEMBL:ENSG00000106080", "NCBIGene:55033"], "categories": ["biolink:Gene"], "is_set": false}, "n1": {"ids": ["CHEMBL.COMPOUND:CHEMBL1201585"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicates": ["biolink:related_to"]}}}}}'}}]

# %%
view = GammaViewer(props={"data":strider_result})
display(view)

# %%
pred = get_predicate(strider_result)
display(pred)
# Out:
#    QG Edge                                   Predicate  Count
# 0      e00                     biolink:correlated_with    592
# 1      e00                          biolink:related_to    479
# 2      e00                              biolink:treats    816
# 3      e00                             biolink:affects    152
# 4      e00                      biolink:contributes_to      5
# 5      e00                 biolink:contraindicated_for      5
# 6      e00                            biolink:prevents    185
# 7      e00                biolink:causes_adverse_event     19
# 8      e00                      biolink:interacts_with      8
# 9      e00                            biolink:disrupts     25
# 10     e00                              biolink:causes     75
# 11     e00  biolink:entity_positively_regulates_entity     24
# 12     e00      biolink:gene_associated_with_condition     53
# 13     e00                         biolink:predisposes     55
# 14     e00                            biolink:produces      9
# 15     e00                          biolink:located_in      1
# 16     e00                       biolink:coexists_with      3
# 17     e00                       biolink:biomarker_for      1
# 18     e00           biolink:physically_interacts_with      2
