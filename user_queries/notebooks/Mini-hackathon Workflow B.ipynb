# %% [markdown]
# ## Workflow B: DILI Drug Repurposing
#
# <br>
# <br>

# %%
#Loading the functions from a notebook
# %run /Users/priyash/Documents/GitHub/robogallery/user_queries/proj_tools/template.ipynb

# %%
with open('/Users/priyash/Documents/GitHub/robogallery/user_queries/json_queries/workflowb_multihop.json', 'r') as myfile:
    query = make_message(json.loads(myfile.read()))

# %%
printjson(query)
# Out:
# {
#     "message": {
#         "query_graph": {
#             "nodes": {
#                 "n0": {
#                     "name": "drug-induced liver injury",
#                     "ids": [
#                         "NCIT:C26991"
#                     ]
#                 },
#                 "n1": {
#                     "categories": [
#                         "biolink:DiseaseOrPhenotypicFeature"
#                     ],
#                     "name": "Disease Or Phenotypic Feature"
#                 },
#                 "n2": {
#                     "categories": [
#                         "biolink:Gene"
#                     ],
#                     "name": "Gene"
#                 },
#                 "n3": {
#                     "categories": [
#                         "biolink:ChemicalSubstance"
#                     ],
#                     "name": "Chemical Substance"
#                 }
#             },
#             "edges": {
#                 "e0": {
#                     "subject": "n0",
#                     "object": "n1",
#                     "predicates": [
#                         "biolink:correlated_with"
#                     ]
#                 },
#                 "e1": {
#                     "subject": "n1",
#                     "object": "n2",
#                     "predicates": [
#                         "biolink:condition_associated_with_gene"
#                     ]
#                 },
#                 "e2": {
#                     "subject": "n2",
#                     "object": "n3",
#                     "predicates": [
#                         "biolink:related_to"
#                     ]
#                 }
#             }
#         }
#     }
# }

# %% [markdown]
# <br>
#
# ## Strider Direct
#
# <br>

# %%
start = dt.now()
strider_result = strider(query)
end = dt.now()
print(f"Strider produced {len(strider_result['message']['results'])} results in {end-start}.")
# Out:
# Strider produced 0 results in 0:07:30.712903.

# %%
prov = get_provenance(strider_result)
display(prov)
# Out:
# Empty DataFrame
# Columns: [QG Edge, Source, Count]
# Index: []

# %%
for logmessage in strider_result['logs']:
    if logmessage['level'] == 'ERROR':
            print(logmessage['message'])
# Out:
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Request Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP

# %%
strider_result['logs']
# Out:
# [{'timestamp': '2021-07-22T21:02:31.785405',
#   'level': 'ERROR',
#   'code': None,
#   'message': "No KPs for qedge 'e01'"},
#  {'timestamp': '2021-07-22T21:01:43.456912',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'request': {'method': 'POST',
#    'url': 'https://cohd.io/api//query',
#    'headers': {'host': 'cohd.io',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '382',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n2": {"ids": ["PUBCHEM.COMPOUND:155819519", "PUBCHEM.COMPOUND:656852", "PUBCHEM.COMPOUND:73415794"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}, "n0": {"ids": ["MONDO:0010161"], "categories": ["biolink:Disease"], "is_set": false}}, "edges": {"e2": {"subject": "n0", "object": "n2", "predicates": ["biolink:related_to"]}}}}}'},
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx/1.16.1',
#     'date': 'Thu, 22 Jul 2021 21:01:43 GMT',
#     'content-type': 'text/html; charset=utf-8',
#     'content-length': '290',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*'},
#    'data': '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">\n<title>500 Internal Server Error</title>\n<h1>Internal Server Error</h1>\n<p>The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.</p>\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://cohd.io/api//query\nFor more information check: https://httpstatuses.com/500'},
#  {'timestamp': '2021-07-22T21:01:43.374981',
#   'level': 'ERROR',
#   'code': None,
#   'message': 'Response Error contacting KP',
#   'request': {'method': 'POST',
#    'url': 'https://cohd.io/api//query',
#    'headers': {'host': 'cohd.io',
#     'accept': '*/*',
#     'accept-encoding': 'gzip, deflate',
#     'connection': 'keep-alive',
#     'user-agent': 'python-httpx/0.18.2',
#     'content-length': '382',
#     'content-type': 'application/json'},
#    'data': '{"message": {"query_graph": {"nodes": {"n2": {"ids": ["PUBCHEM.COMPOUND:155819519", "PUBCHEM.COMPOUND:656852", "PUBCHEM.COMPOUND:73415794"], "categories": ["biolink:ChemicalSubstance"], "is_set": false}, "n0": {"ids": ["MONDO:0010161"], "categories": ["biolink:Disease"], "is_set": false}}, "edges": {"e2": {"subject": "n2", "object": "n0", "predicates": ["biolink:related_to"]}}}}}'},
#   'response': {'status_code': 500,
#    'headers': {'server': 'nginx/1.16.1',
#     'date': 'Thu, 22 Jul 2021 21:01:42 GMT',
#     'content-type': 'text/html; charset=utf-8',
#     'content-length': '290',
#     'connection': 'keep-alive',
#     'access-control-allow-origin': '*'},
#    'data': '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">\n<title>500 Internal Server Error</title>\n<h1>Internal Server Error</h1>\n<p>The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.</p>\n'},
#   'error': '500 Server Error: INTERNAL SERVER ERROR for url: https://cohd.io/api//query\nFor more information check: https://httpstatuses.com/500'}]

# %%
view = GammaViewer(props={"data":strider_result})
display(view)

# %%
pred = get_predicate(strider_result)
display(pred)
# Out:
# Empty DataFrame
# Columns: [QG Edge, Predicate, Count]
# Index: []

# %%
node =which_nodes(strider_result, 'biolink:decreases_expression_of')
display(node)
# Out:
# Empty DataFrame
# Columns: [Node ID, Name, Source]
# Index: []
