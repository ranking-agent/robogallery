# %%
#Loading the functions from a notebook
# %run /Users/priyash/Documents/GitHub/robogallery/user_queries/proj_tools/template.ipynb

# %% [markdown]
# <br>
#
#
# **These are all causes of hangover.  So in a hangover there is an increase of lactate.  The question that we want to answer then, is do we have a way to decrease lactate or lactates.  And the same for aldehydes etc...
# So what I would like you to do is to try to run either some chemical-(lactate) and chemical-gene-lactate queries through strider and aragorn and let's see if we can get results.  And also do it for aldehyes, and etc.**
#
# <br>

# %% [markdown]
# ### 1. Chemical to Aldehydes
#
# Do we have a way to decrease Aldehydes

# %%
with open('/Users/priyash/Documents/GitHub/robogallery/user_queries/json_queries/hangover_three.json', 'r') as myfile:
    query = make_message(json.loads(myfile.read()))

# %%
printjson(query)
# Out:
# {
#     "message": {
#         "query_graph": {
#             "nodes": {
#                 "n0": {
#                     "name": "Chemical Substance",
#                     "categories": [
#                         "biolink:ChemicalSubstance"
#                     ]
#                 },
#                 "n1": {
#                     "name": "aldehyde",
#                     "ids": [
#                         "CHEBI:17478"
#                     ],
#                     "categories": [
#                         "biolink:ChemicalSubstance",
#                         "biolink:MolecularEntity",
#                         "biolink:BiologicalEntity",
#                         "biolink:NamedThing",
#                         "biolink:Entity"
#                     ]
#                 }
#             },
#             "edges": {
#                 "e0": {
#                     "subject": "n0",
#                     "object": "n1"
#                 }
#             }
#         },
#         "knowledge_graph": {
#             "nodes": {},
#             "edges": {}
#         },
#         "results": []
#     }
# }

# %%
query['message']['knowledge_graph'] = {'nodes':{}, 'edges':{}}
query['message']['results'] = []

# %% [markdown]
# ## Strider Direct
#
# <br>

# %%
start = dt.now()
strider_result = strider(query)
end = dt.now()
print(f"Strider produced {len(strider_result['message']['results'])} results in {end-start}.")

# %%
prov = get_provenance(strider_result)
display(prov)
# Out:
#   QG Edge                                             Source  Count
# 0      e0   https://automat.renci.org/textminingkp/1.1/query   2547
# 1      e0    https://automat.renci.org/uberongraph/1.1/query    280
# 2      e0     https://automat.renci.org/covidkopkg/1.1/query    510
# 3      e0      https://automat.renci.org/robokopkg/1.1/query    510
# 4      e0  https://automat.renci.org/cord19-scigraph/1.1/...    404

# %%
print_queried_sources(strider_result)

# %%
for logmessage in strider_result['logs']:
        if logmessage['level'] == 'ERROR':
            print(logmessage['message'])
# Out:
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting Node Normalizer

# %%
for logmessage in strider_result['logs'][:2]:
    printjson(logmessage)
# Out:
# {
#     "timestamp": "2021-06-16T15:31:36.881270",
#     "level": "ERROR",
#     "code": null,
#     "message": "Response Error contacting KP",
#     "request": {
#         "method": "POST",
#         "url": "https://spokekp.healthdatascience.cloud/api/v1.1/query",
#         "headers": {
#             "host": "spokekp.healthdatascience.cloud",
#             "accept": "*/*",
#             "accept-encoding": "gzip, deflate",
#             "connection": "keep-alive",
#             "user-agent": "python-httpx/0.16.1",
#             "content-length": "485",
#             "content-type": "application/json"
#         },
#         "data": "{\"message\": {\"query_graph\": {\"nodes\": {\"n1\": {\"ids\": [\"CHEBI:17478\"], \"categories\": [\"biolink:Food\"], \"is_set\": false, \"constraints\": null, \"name\": \"aldehyde\"}, \"n0\": {\"ids\": null, \"categories\": [\"biolink:ChemicalSubstance\"], \"is_set\": false, \"constraints\": null, \"name\": \"Chemical Substance\"}}, \"edges\": {\"e0\": {\"subject\": \"n1\", \"object\": \"n0\", \"predicates\": [\"biolink:has_part\"], \"relation\": null, \"constraints\": null}}}, \"knowledge_graph\": null, \"results\": null}, \"log_level\": null}"
#     },
#     "error": "400 Client Error: BAD REQUEST for url: https://spokekp.healthdatascience.cloud/api/v1.1/query\nFor more information check: https://httpstatuses.com/400",
#     "response": {
#         "status_code": 400,
#         "headers": {
#             "server": "nginx/1.16.1",
#             "date": "Wed, 16 Jun 2021 15:31:29 GMT",
#             "content-type": "application/problem+json",
#             "content-length": "143",
#             "connection": "keep-alive"
#         },
#         "data": "{\n  \"detail\": \"None is not of type 'object' - 'message.knowledge_graph'\",\n  \"status\": 400,\n  \"title\": \"Bad Request\",\n  \"type\": \"about:blank\"\n}\n"
#     }
# }
# {
#     "timestamp": "2021-06-16T15:31:36.862227",
#     "level": "ERROR",
#     "code": null,
#     "message": "Response Error contacting KP",
#     "request": {
#         "method": "POST",
#         "url": "https://spokekp.healthdatascience.cloud/api/v1.1/query",
#         "headers": {
#             "host": "spokekp.healthdatascience.cloud",
#             "accept": "*/*",
#             "accept-encoding": "gzip, deflate",
#             "connection": "keep-alive",
#             "user-agent": "python-httpx/0.16.1",
#             "content-length": "499",
#             "content-type": "application/json"
#         },
#         "data": "{\"message\": {\"query_graph\": {\"nodes\": {\"n1\": {\"ids\": [\"CHEBI:17478\"], \"categories\": [\"biolink:MolecularActivity\"], \"is_set\": false, \"constraints\": null, \"name\": \"aldehyde\"}, \"n0\": {\"ids\": null, \"categories\": [\"biolink:ChemicalSubstance\"], \"is_set\": false, \"constraints\": null, \"name\": \"Chemical Substance\"}}, \"edges\": {\"e0\": {\"subject\": \"n1\", \"object\": \"n0\", \"predicates\": [\"biolink:has_input\"], \"relation\": null, \"constraints\": null}}}, \"knowledge_graph\": null, \"results\": null}, \"log_level\": null}"
#     },
#     "error": "400 Client Error: BAD REQUEST for url: https://spokekp.healthdatascience.cloud/api/v1.1/query\nFor more information check: https://httpstatuses.com/400",
#     "response": {
#         "status_code": 400,
#         "headers": {
#             "server": "nginx/1.16.1",
#             "date": "Wed, 16 Jun 2021 15:31:29 GMT",
#             "content-type": "application/problem+json",
#             "content-length": "143",
#             "connection": "keep-alive"
#         },
#         "data": "{\n  \"detail\": \"None is not of type 'object' - 'message.knowledge_graph'\",\n  \"status\": 400,\n  \"title\": \"Bad Request\",\n  \"type\": \"about:blank\"\n}\n"
#     }
# }

# %%
view = GammaViewer(props={"data":strider_result})
display(view)

# %%
pred = get_predicate(strider_result)
display(pred)
# Out:
#   QG Edge            Predicate  Count
# 0      e0   biolink:related_to   3041
# 1      e0     biolink:has_part     18
# 2      e0     biolink:overlaps     12
# 3      e0  biolink:subclass_of    497

# %%
node =which_nodes(strider_result, 'biolink:overlaps')
display(node)
# Out:
#         Node ID                       Name  \
# 0   CHEBI:22221                 acyl group
# 1   CHEBI:37838            carboacyl group
# 2   CHEBI:27207  univalent carboacyl group
# 3   CHEBI:17478                   aldehyde
# 4   CHEBI:17478                   aldehyde
# 5   CHEBI:22221                 acyl group
# 6   CHEBI:37838            carboacyl group
# 7   CHEBI:27207  univalent carboacyl group
# 8   CHEBI:17478                   aldehyde
# 9   CHEBI:17478                   aldehyde
# 10  CHEBI:42485               formyl group
# 11  CHEBI:42485               formyl group
#
#                                              Source
# 0   https://automat.renci.org/uberongraph/1.1/query
# 1   https://automat.renci.org/uberongraph/1.1/query
# 2   https://automat.renci.org/uberongraph/1.1/query
# 3   https://automat.renci.org/uberongraph/1.1/query
# 4   https://automat.renci.org/uberongraph/1.1/query
# 5   https://automat.renci.org/uberongraph/1.1/query
# 6   https://automat.renci.org/uberongraph/1.1/query
# 7   https://automat.renci.org/uberongraph/1.1/query
# 8   https://automat.renci.org/uberongraph/1.1/query
# 9   https://automat.renci.org/uberongraph/1.1/query
# 10  https://automat.renci.org/uberongraph/1.1/query
# 11  https://automat.renci.org/uberongraph/1.1/query

# %% [markdown]
# <br>
#
# ## Aragorn
#
# <br>

# %%
start = dt.now()
aragorn_result = aragorn(query)
end = dt.now()
if 'results' in aragorn_result['message']:
    print(f"ARAGORN produced {len(aragorn_result['message']['results'])} results in {end-start}.")
else:
    print('Error, no result field')
# Out:
# ARAGORN produced 4970 results in 0:07:57.067180.

# %%
prov = get_provenance(strider_result)
display(prov)
# Out:
#   QG Edge                                             Source  Count
# 0      e0   https://automat.renci.org/textminingkp/1.1/query   2547
# 1      e0    https://automat.renci.org/uberongraph/1.1/query    280
# 2      e0     https://automat.renci.org/covidkopkg/1.1/query    510
# 3      e0      https://automat.renci.org/robokopkg/1.1/query    510
# 4      e0  https://automat.renci.org/cord19-scigraph/1.1/...    404

# %%
for logmessage in strider_result['logs']:
        if logmessage['level'] == 'ERROR':
            print(logmessage['message'])
# Out:
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting KP
# Response Error contacting Node Normalizer

# %%
for logmessage in aragorn_result['logs']:
    printjson(logmessage)
# Out:
# {
#     "timestamp": "2021-06-15T18:28:02.541996",
#     "level": "WARNING",
#     "code": null,
#     "message": "Answer coalesce error: HTML error status code 500 returned."
# }

# %%
view = GammaViewer(props={"data":aragorn_result})
display(view)

# %%
pred = get_predicate(aragorn_result)
display(pred)
# Out:
#      QG Edge                         Predicate  Count
# 0         e0                  biolink:overlaps     36
# 1         e0                  biolink:has_part     36
# 2         e0                biolink:related_to   3097
# 3         e0               biolink:subclass_of    818
# 4         e0           biolink:correlated_with   1001
# ...      ...                               ...    ...
# 1267    s657  biolink:literature_co_occurrence      2
# 1268    s671  biolink:literature_co_occurrence      4
# 1269    s697  biolink:literature_co_occurrence      2
# 1270    s713  biolink:literature_co_occurrence      2
# 1271    s715  biolink:literature_co_occurrence      2
#
# [1272 rows x 3 columns]

# %%
node =which_nodes(aragorn_result, 'biolink:overlaps')
display(node)
# Out:
#                      Node ID                       Name  Source
# 0                CHEBI:22221                 acyl group       1
# 1                CHEBI:17478                   aldehyde       1
# 2                CHEBI:42485               formyl group       1
# 3                CHEBI:22221                 acyl group       1
# 4                CHEBI:17478                   aldehyde       1
# 5                CHEBI:22221                 acyl group       1
# 6                CHEBI:42485               formyl group       1
# 7                CHEBI:37838            carboacyl group       1
# 8                CHEBI:27207  univalent carboacyl group       1
# 9                CHEBI:17478                   aldehyde       1
# 10               CHEBI:17478                   aldehyde       1
# 11               CHEBI:42485               formyl group       1
# 12               CHEBI:25585              nonmetal atom       1
# 13               CHEBI:24431            chemical entity       1
# 14               CHEBI:23019             carbonyl group       1
# 15               CHEBI:46629                  oxo group       1
# 16               CHEBI:33303                  chalcogen       1
# 17               CHEBI:33247              organic group       1
# 18               CHEBI:17478                   aldehyde       1
# 19               CHEBI:37838            carboacyl group       1
# 20               CHEBI:27207  univalent carboacyl group       1
# 21               CHEBI:37838            carboacyl group       1
# 22               CHEBI:27207  univalent carboacyl group       1
# 23               CHEBI:17478                   aldehyde       1
# 24               CHEBI:33318    main group element atom       1
# 25               CHEBI:33306  carbon group element atom       1
# 26               CHEBI:17478                   aldehyde       1
# 27               CHEBI:17478                   aldehyde       1
# 28               CHEBI:33246            inorganic group       1
# 29  PUBCHEM.COMPOUND:5462310                carbon atom       1
# 30   PUBCHEM.COMPOUND:159832                 monooxygen       1
# 31               CHEBI:33560       p-block element atom       1
# 32               CHEBI:51446     organic divalent group       1
# 33               CHEBI:24433                      group       1
# 34               CHEBI:33250                       atom       1
# 35               CHEBI:51422           organodiyl group       1
