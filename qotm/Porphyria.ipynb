# %%
from use_translator import *

# %%
query={
    "message": {
        "query_graph": {
            "edges": {
                "e00": {
                    "subject": "n01",
                    "object": "porphyria"
                }
            },
            "nodes": {
                "porphyria": {
                    "categories":
                    [ "biolink:Disease" ],
                    "ids": [
                        "MONDO:0037939"
                    ]
                },
                "n01": {
                    "categories": [
                        "biolink:NamedThing"
                    ]
                }
            }
        }
    }
}

# %%
porphyria_pk = submit_to_ars(query)
# Out:
# https://ars.transltr.io/ars/api/submit
# 201
# https://arax.ncats.io/?source=ARS&id=1d0ca389-bc18-4922-a311-7e0a1ca25109

# %%
aragorn_result = aragorn(query)
# Out:
# aragorn returned in 0:04:40.829050s
# Num Results: 4498

# %%
for r in aragorn_result['message']['results']:
    keys = r['node_bindings'].keys()
    extras = list(filter(lambda k: k.startswith('_'), keys))
    values = []
    for e in extras:
        values += [x['id'] for x in r['node_bindings'][e]]
    names = [aragorn_result['message']['knowledge_graph']['nodes'][i]['name'] for i in values]
    print(names, r['score'])
# Out:
# ['inherited porphyria'] 22.06684419493036
# ['liver disease'] 19.498771416756203
# ['organic molecule'] 18.064354165881287
# ['molecule'] 18.064354165881277
# ['organic cyclic compound'] 16.45665901129455
# ['cyclic compound'] 16.45665901129455
# ['kidney disease'] 16.144101099236085
# ['disease or disorder'] 15.630566385847853
# ['disease by anatomical system'] 12.485530099110578
# ['depressive disorder'] 12.398793767549847
# ['Nausea'] 11.507747558812216
# ['exanthem (disease)'] 11.349740891667025
# ['Non-Neoplastic Disorder'] 11.016642236945518
# ['Vomiting'] 10.820574660299476
# ['dermatitis'] 10.703285418346255
# ['Headache'] 10.695638597875655
# ['peripheral vertigo'] 10.522757147370484
# ['Phenotypic abnormality'] 10.483628949873639
# ['liver failure'] 9.995463164737838
# ['Disorder by Site'] 9.71915761791725
# ['allergic disease'] 9.63934007358535
# ['hypertensive disorder'] 9.181466053610139
# ['Suicidal ideation'] 9.177259840765968
# ...

# %%
query={
    "message": {
        "query_graph": {
            "edges": {
                "e00": {
                    "subject": "n01",
                    "object": "porphyria",
                    "predicates": ["biolink:correlated_with"]
                }
            },
            "nodes": {
                "porphyria": {
                    "categories":
                    [ "biolink:Disease" ],
                    "ids": [
                        "MONDO:0037939"
                    ]
                },
                "n01": {
                    "categories": [
                        "biolink:ChemicalEntity"
                    ]
                }
            }
        }
    }
}

# %%
porphyria_chem_pk = submit_to_ars(query)
# Out:
# https://ars.transltr.io/ars/api/submit
# 201
# https://arax.ncats.io/?source=ARS&id=1d8a1a8a-6961-4114-bed5-24474df601eb

# %%
query={
    "message": {
        "query_graph": {
            "edges": {
                "e00": {
                    "subject": "n01",
                    "object": "porphyria",
                    "predicates": ["biolink:correlated_with"]
                },
                "e01": {
                    "subject": "n01",
                    "object": "alas1qnode"
                }
            },
            "nodes": {
                "porphyria": {
                    "categories":
                    [ "biolink:Disease" ],
                    "ids": [
                        "MONDO:0037939"
                    ]
                },
                "n01": {
                    "categories": [
                        "biolink:ChemicalEntity"
                    ]
                },
                "alas1qnode": {
                    "categories": ["biolink:Gene"],
                    "ids": ["NCBIGene:211"]
                }
            }
        }
    }
}

# %%
porphyria_chemq_pk = submit_to_ars(query)
# Out:
# https://ars.transltr.io/ars/api/submit
# 201
# https://arax.ncats.io/?source=ARS&id=b7555415-f2fb-4c00-a044-d28d6e4499cc

# %%
query={
    "message": {
        "query_graph": {
            "edges": {
                "e00": {
                    "subject": "n01",
                    "object": "porphyria",
                    "predicates": ["biolink:correlated_with"]
                },
                "e01": {
                    "subject": "n01",
                    "object": "alas1qnode"
                }
            },
            "nodes": {
                "porphyria": {
                    "categories":
                    [ "biolink:Disease" ],
                    "ids": [
                        "MONDO:0037939"
                    ]
                },
                "n01": {
                    "categories": [
                        "biolink:BiologicalProcessOrActivity"
                    ]
                },
                "alas1qnode": {
                    "categories": ["biolink:Gene"],
                    "ids": ["NCBIGene:211"]
                }
            }
        }
    }
}

# %%
porphyria_procq_pk = submit_to_ars(query)
# Out:
# https://ars.transltr.io/ars/api/submit
# 201
# https://arax.ncats.io/?source=ARS&id=dc161f97-79e2-4d86-9823-b482fbd87f8b
