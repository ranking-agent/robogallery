# %% [markdown]
# # Setup

# %%
import json
import requests
from datetime import datetime as dt
from collections import defaultdict
import pandas as pd

# %%
def printjson(j):
    print(json.dumps(j,indent=4))
def print_json(j):
    printjson(j)

# %%
def post(name,url,message,params=None):
    if params is None:
        response = requests.post(url,json=message)
    else:
        response = requests.post(url,json=message,params=params)
    if not response.status_code == 200:
        print(name, 'error:',response.status_code)
        print(response.json())
        return {}
    return response.json()

def automat(db,message):
    automat_url = f'https://automat.renci.org/{db}/query'
    response = requests.post(automat_url,json=message)
    print(response.status_code)
    return response.json()

def strider(message):
    url = 'https://strider.renci.org/query?log_level=DEBUG'
    strider_answer = post(strider,url,message)
    return strider_answer

def aragorn(message, coalesce_type='xnone'):
    if coalesce_type == 'xnone':
        answer = post('aragorn','https://aragorn.renci.org/query',message)
    else:
        answer = post('aragorn','https://aragorn.renci.org/query',message, params={'answer_coalesce_type':coalesce_type})
    return answer

##

def bte(message):
    url = 'https://api.bte.ncats.io/v1/query'
    return post(strider,url,message)
 
def striderandfriends(message):
    strider_answer = strider(message)    
    coalesced_answer = post('coalesce','https://answercoalesce.renci.org/coalesce/graph',{'message':strider_answer})
    omni_answer = post('omnicorp','https://aragorn-ranker.renci.org/omnicorp_overlay',{'message': coalesced_answer})
    weighted_answer = post('weight','https://aragorn-ranker.renci.org/weight_correctness',{'message': omni_answer})
    scored_answer = post('score','https://aragorn-ranker.renci.org/score',{'message': weighted_answer})
    return scored_answer

# %%
def retrieve_ars_results(mid):
    message_url = f'https://ars.transltr.io/ars/api/messages/{mid}?trace=y'
    response = requests.get(message_url)
    j = response.json()
    results = {}
    for child in j['children']:
        if child['actor']['agent'] in ['ara-aragorn', 'ara-aragorn-exp']:
            childmessage_id = child['message']
            child_url = f'https://ars.transltr.io/ars/api/messages/{childmessage_id}'
            child_response = requests.get(child_url).json()
            try:
                nresults = len(child_response['fields']['data']['message']['results'])
                if nresults > 0:
                    results[child['actor']['agent']] = {'message':child_response['fields']['data']['message']}
            except:
                nresults=0
            print( child['status'], child['actor']['agent'],nresults )
    return results

# %%
def get_provenance(message):
    """Given a message with results, find the source of the edges"""
    prov = defaultdict(lambda: defaultdict(int)) # {qedge->{source->count}}
    results = message['message']['results']
    kg = message['message']['knowledge_graph']['edges']
    edge_bindings = [ r['edge_bindings'] for r in results ]
    for bindings in edge_bindings:
        for qg_e, kg_l in bindings.items():
            for kg_e in kg_l:
                for att in kg[kg_e['id']]['attributes']:
                    if att['name'] == 'provenance':
                        source = att['value']
                        prov[qg_e][source]+=1
    qg_edges = []
    sources = []
    counts = []
    for qg_e in prov:
        for source in prov[qg_e]:
            qg_edges.append(qg_e)
            sources.append(source)
            counts.append(prov[qg_e][source])
    prov_table = pd.DataFrame({"QG Edge":qg_edges, "Source":sources, "Count":counts})
    return prov_table

# %% [markdown]
# ## Query Specific

# %%
query = {'message':{'query_graph':{
  "nodes": {
    "n0": {
      "categories": [
        "biolink:PhenotypicFeature"
      ],
      "ids": ["HP:0100543"]
    },
    "n1": {
      "ids": ["NCBIGene:351"],
      "categories":[ "biolink:Gene"]
    }
  },
  "edges": {
    "e0": {
      "subject": "n0",
      "object": "n1",
      "predicate": [
        "biolink:related_to"
      ]
    }
  }
}}}

# %% [markdown]
# ## Strider Direct

# %%
start = dt.now()
strider_result = strider(query)
end = dt.now()
print(f"Strider produced {len(strider_result['message']['results'])} results in {end-start}.")
# Out:
# Strider produced 1 results in 0:00:12.924755.

# %%
edges = strider_result["message"]["knowledge_graph"]["edges"]
nodes = strider_result["message"]["knowledge_graph"]["nodes"]
len(edges)
# Out:
# 29

# %%
for nid, node in nodes.items():
    print(nid, node['name'])
# Out:
# NCBIGene:351 APP
# MONDO:0010857 Semantic dementia
# HP:0100543 Cognitive impairment
# MONDO:0001627 dementia
# MONDO:0001152 amnestic disorder
# MONDO:0008119 spinocerebellar ataxia type 1
# HP:0001289 Confusion
# MONDO:0004975 Alzheimer disease
# MONDO:0004648 vascular dementia
# MONDO:0007088 Alzheimer disease type 1

# %%
subjects=[]
objects = []
predicates=[]
pks_s = []
aggs_s = []
for eid, edge in edges.items():
    if edge["subject"] not in ["NCBIGene:351", "HP:0100543"]:
        continue
    if edge["object"] not in ["NCBIGene:351", "HP:0100543"]:
        continue
    aggs = []
    for source in edge["sources"]:
        if source["resource_role"] == "primary_knowledge_source":
            pks = source["resource_id"]
        else:
            aggs.append(source["resource_id"])
    aggs.remove('infores:aragorn')
    subjects.append(edge["subject"])
    objects.append(edge["object"])
    predicates.append(edge["predicate"])
    pks_s.append(pks)
    aggs_s.append(aggs)
    #print(edge["subject"], edge["object"], edge["predicate"], pks, aggs )
df = pd.DataFrame( {"subject": subjects, "predicate": predicates, "object": objects, "PKS": pks_s, "AKS": aggs_s} )

# %%
df.sort_values(by="PKS")
# Out:
#          subject                               predicate        object  \
# 3   NCBIGene:351     biolink:genetically_associated_with    HP:0100543
# 5   NCBIGene:351  biolink:gene_associated_with_condition    HP:0100543
# 2   NCBIGene:351     biolink:genetically_associated_with    HP:0100543
# 6   NCBIGene:351  biolink:gene_associated_with_condition    HP:0100543
# 4     HP:0100543                 biolink:has_participant  NCBIGene:351
# 0   NCBIGene:351                   biolink:has_phenotype    HP:0100543
# 1   NCBIGene:351     biolink:genetically_associated_with    HP:0100543
# 7   NCBIGene:351                         biolink:affects    HP:0100543
# 8   NCBIGene:351                         biolink:affects    HP:0100543
# 9   NCBIGene:351                 biolink:associated_with    HP:0100543
# 10  NCBIGene:351                          biolink:causes    HP:0100543
#
#                           PKS  \
# 3                 infores:ctd
# 5            infores:diseases
# 2            infores:disgenet
# 6            infores:disgenet
# 4                 infores:hpo
# 0     infores:hpo-annotations
# 1   infores:monarchinitiative
# 7            infores:semmeddb
# 8            infores:semmeddb
# 9            infores:semmeddb
# 10            infores:uniprot
#
#                                                   AKS
# 3           [infores:pharos, infores:automat-robokop]
# 5                                   [infores:rtx-kg2]
# 2           [infores:pharos, infores:automat-robokop]
# 6                                   [infores:rtx-kg2]
# 4                                   [infores:molepro]
# 0   [infores:automat-robokop, infores:monarchiniti...
# 1           [infores:pharos, infores:automat-robokop]
# 7                                   [infores:rtx-kg2]
# 8                                   [infores:rtx-kg2]
# 9                                   [infores:rtx-kg2]
# 10                                  [infores:rtx-kg2]

# %%
query = {'message':{'query_graph':{
  "nodes": {
    "n0": {
      "ids": ["GO:0016310"]
    },
    "n1": {
      "ids": ["NCBIGene:351"],
      "categories":[ "biolink:Gene"]
    }
  },
  "edges": {
    "e0": {
      "subject": "n0",
      "object": "n1",
      "predicate": [
        "biolink:related_to"
      ]
    }
  }
}}}

# %%
start = dt.now()
strider_result = strider(query)
end = dt.now()
print(f"Strider produced {len(strider_result['message']['results'])} results in {end-start}.")
# Out:
# Strider produced 1 results in 0:00:16.748422.

# %%
edges = strider_result["message"]["knowledge_graph"]["edges"]
nodes = strider_result["message"]["knowledge_graph"]["nodes"]
len(edges)
# Out:
# 18

# %%
for nid, node in nodes.items():
    print(nid, node['name'])
# Out:
# NCBIGene:351 A4_HUMAN Amyloid-beta precursor protein (sprot)
# GO:0006468 protein phosphorylation
# GO:0016310 phosphorylation

# %%
subjects=[]
objects = []
predicates=[]
pks_s = []
aggs_s = []
for eid, edge in edges.items():
    if edge["subject"] not in ["NCBIGene:351", "GO:0016310"]:
        continue
    if edge["object"] not in ["NCBIGene:351", "GO:0016310"]:
        continue
    aggs = []
    for source in edge["sources"]:
        if source["resource_role"] == "primary_knowledge_source":
            pks = source["resource_id"]
        else:
            aggs.append(source["resource_id"])
    aggs.remove('infores:aragorn')
    subjects.append(edge["subject"])
    objects.append(edge["object"])
    predicates.append(edge["predicate"])
    pks_s.append(pks)
    aggs_s.append(aggs)
    #print(edge["subject"], edge["object"], edge["predicate"], pks, aggs )
df = pd.DataFrame( {"subject": subjects, "predicate": predicates, "object": objects, "PKS": pks_s, "AKS": aggs_s} )

# %%
df
# Out:
#          subject                                          predicate  \
# 0   NCBIGene:351                       biolink:actively_involved_in
# 1   NCBIGene:351                                 biolink:related_to
# 2   NCBIGene:351                       biolink:actively_involved_in
# 3   NCBIGene:351           biolink:acts_upstream_of_positive_effect
# 4   NCBIGene:351  biolink:acts_upstream_of_or_within_negative_ef...
# 5   NCBIGene:351                                     biolink:causes
# 6     GO:0016310                            biolink:has_participant
# 7   NCBIGene:351                                  biolink:regulates
# 8   NCBIGene:351  biolink:acts_upstream_of_or_within_positive_ef...
# 9   NCBIGene:351           biolink:acts_upstream_of_negative_effect
# 10  NCBIGene:351                       biolink:actively_involved_in
#
#           object                   PKS  \
# 0     GO:0016310           infores:goa
# 1     GO:0016310  infores:ensembl-gene
# 2     GO:0016310      infores:hetionet
# 3     GO:0016310           infores:ctd
# 4     GO:0016310           infores:ctd
# 5     GO:0016310           infores:ctd
# 6   NCBIGene:351           infores:ctd
# 7     GO:0016310           infores:ctd
# 8     GO:0016310           infores:ctd
# 9     GO:0016310           infores:ctd
# 10    GO:0016310           infores:ctd
#
#                                                   AKS
# 0   [infores:automat-robokop, infores:automat-huma...
# 1                                   [infores:rtx-kg2]
# 2                          [infores:automat-hetionet]
# 3            [infores:automat-cam-kp, infores:cam-kp]
# 4            [infores:automat-cam-kp, infores:cam-kp]
# 5            [infores:automat-cam-kp, infores:cam-kp]
# 6            [infores:automat-cam-kp, infores:cam-kp]
# 7            [infores:automat-cam-kp, infores:cam-kp]
# 8            [infores:automat-cam-kp, infores:cam-kp]
# 9            [infores:automat-cam-kp, infores:cam-kp]
# 10           [infores:automat-cam-kp, infores:cam-kp]

# %%
query = {'message':{'query_graph':{
  "nodes": {
    "n0": {
      "ids": ["HP:0100639"]
    },
    "n1": {
      "ids": ["MONDO:0019065"]
    }
  },
  "edges": {
    "e0": {
      "subject": "n0",
      "object": "n1",
      "predicate": [
        "biolink:related_to"
      ]
    }
  }
}}}

# %%
start = dt.now()
strider_result = strider(query)
end = dt.now()
print(f"Strider produced {len(strider_result['message']['results'])} results in {end-start}.")
# Out:
# Strider produced 2 results in 0:00:11.962492.

# %%
for eid, edge in strider_result["message"]["knowledge_graph"]["edges"].items():
    printjson(edge)
# Out:
# {
#     "subject": "MONDO:0019065",
#     "object": "HP:0100639",
#     "predicate": "biolink:has_phenotype",
#     "sources": [
#         {
#             "resource_id": "infores:automat-robokop",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:monarchinitiative"
#             ]
#         },
#         {
#             "resource_id": "infores:monarchinitiative",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:hpo-annotations"
#             ]
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:automat-robokop"
#             ]
#         },
#         {
#             "resource_id": "infores:hpo-annotations",
#             "resource_role": "primary_knowledge_source"
#         }
#     ],
#     "qualifiers": [
#         {
#             "qualifier_type_id": "biolink:frequency_qualifier",
#             "qualifier_value": "HP:0040282"
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "not_provided",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "agent_type"
#         },
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "logical_entailment",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "knowledge_level",
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:support_graphs",
#             "value": [
#                 "77d17043",
#                 "b34e3bec"
#             ],
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "MONDO:0005362",
#     "object": "HP:0100639",
#     "predicate": "biolink:subclass_of",
#     "sources": [
#         {
#             "resource_id": "infores:automat-robokop",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:automat-robokop"
#             ]
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "not_provided",
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "automated_agent",
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "MONDO:0007100",
#     "object": "MONDO:0005362",
#     "predicate": "biolink:has_phenotype",
#     "sources": [
#         {
#             "resource_id": "infores:automat-robokop",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:monarchinitiative"
#             ]
#         },
#         {
#             "resource_id": "infores:monarchinitiative",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:hpo-annotations"
#             ]
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:automat-robokop"
#             ]
#         },
#         {
#             "resource_id": "infores:hpo-annotations",
#             "resource_role": "primary_knowledge_source"
#         }
#     ],
#     "qualifiers": [
#         {
#             "qualifier_type_id": "biolink:frequency_qualifier",
#             "qualifier_value": "HP:0040282"
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "not_provided",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "agent_type"
#         },
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "not_provided",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "knowledge_level"
#         }
#     ]
# }
# {
#     "subject": "MONDO:0007100",
#     "object": "HP:0100639",
#     "predicate": "biolink:has_phenotype",
#     "sources": [
#         {
#             "resource_id": "infores:automat-robokop",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:monarchinitiative"
#             ]
#         },
#         {
#             "resource_id": "infores:monarchinitiative",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:hpo-annotations"
#             ]
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:automat-robokop"
#             ]
#         },
#         {
#             "resource_id": "infores:hpo-annotations",
#             "resource_role": "primary_knowledge_source"
#         }
#     ],
#     "qualifiers": [
#         {
#             "qualifier_type_id": "biolink:frequency_qualifier",
#             "qualifier_value": "HP:0040282"
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "not_provided",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "agent_type"
#         },
#         {
#             "attribute_type_id": "biolink:support_graphs",
#             "value": [
#                 "77d17043"
#             ],
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "logical_entailment",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "knowledge_level",
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "MONDO:0007100",
#     "object": "MONDO:0019065",
#     "predicate": "biolink:subclass_of",
#     "sources": [
#         {
#             "resource_id": "infores:automat-robokop",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:automat-robokop"
#             ]
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "not_provided",
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "automated_agent",
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "MONDO:0019065",
#     "object": "HP:0100639",
#     "predicate": "biolink:has_phenotype",
#     "sources": [
#         {
#             "resource_id": "infores:automat-monarchinitiative",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:monarchinitiative"
#             ]
#         },
#         {
#             "resource_id": "infores:hpo-annotations",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:automat-monarchinitiative",
#                 "infores:automat-robokop"
#             ]
#         },
#         {
#             "resource_id": "infores:automat-robokop",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:monarchinitiative"
#             ]
#         },
#         {
#             "resource_id": "infores:monarchinitiative",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:hpo-annotations"
#             ]
#         }
#     ],
#     "qualifiers": [
#         {
#             "qualifier_type_id": "biolink:frequency_qualifier",
#             "qualifier_value": "HP:0040283"
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:original_subject",
#             "value": "Orphanet:85443",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "original_subject"
#         },
#         {
#             "attribute_type_id": "biolink:support_graphs",
#             "value": [
#                 "e26b23b8",
#                 "69ad9388"
#             ],
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:category",
#             "value": [
#                 "biolink:DiseaseToPhenotypicFeatureAssociation",
#                 "biolink:FrequencyQuantifier",
#                 "biolink:EntityToPhenotypicFeatureAssociationMixin",
#                 "biolink:DiseaseToEntityAssociationMixin",
#                 "biolink:Association",
#                 "biolink:Entity",
#                 "biolink:EntityToFeatureOrDiseaseQualifiersMixin",
#                 "biolink:FrequencyQualifierMixin",
#                 "biolink:RelationshipQuantifier"
#             ],
#             "value_type_id": "xsd:anyURI",
#             "original_attribute_name": "category"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "not_provided",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "agent_type"
#         },
#         {
#             "attribute_type_id": "biolink:support_graphs",
#             "value": [
#                 "4342739a",
#                 "49dea95f"
#             ],
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:has_evidence",
#             "value": [
#                 "ECO:0000304"
#             ],
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "has_evidence"
#         },
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "logical_entailment",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "knowledge_level",
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "HP:0008652",
#     "object": "HP:0100639",
#     "predicate": "biolink:subclass_of",
#     "sources": [
#         {
#             "resource_id": "infores:automat-robokop",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:automat-robokop"
#             ]
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "not_provided",
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "automated_agent",
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "MONDO:0019438",
#     "object": "HP:0008652",
#     "predicate": "biolink:has_phenotype",
#     "sources": [
#         {
#             "resource_id": "infores:automat-monarchinitiative",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:monarchinitiative"
#             ]
#         },
#         {
#             "resource_id": "infores:hpo-annotations",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:automat-monarchinitiative",
#                 "infores:automat-robokop"
#             ]
#         },
#         {
#             "resource_id": "infores:automat-robokop",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:monarchinitiative"
#             ]
#         },
#         {
#             "resource_id": "infores:monarchinitiative",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:hpo-annotations"
#             ]
#         }
#     ],
#     "qualifiers": [
#         {
#             "qualifier_type_id": "biolink:frequency_qualifier",
#             "qualifier_value": "HP:0040283"
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "not_provided",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "knowledge_level"
#         },
#         {
#             "attribute_type_id": "biolink:original_subject",
#             "value": "Orphanet:85443",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "original_subject"
#         },
#         {
#             "attribute_type_id": "biolink:category",
#             "value": [
#                 "biolink:DiseaseToPhenotypicFeatureAssociation",
#                 "biolink:FrequencyQuantifier",
#                 "biolink:EntityToPhenotypicFeatureAssociationMixin",
#                 "biolink:DiseaseToEntityAssociationMixin",
#                 "biolink:Association",
#                 "biolink:Entity",
#                 "biolink:EntityToFeatureOrDiseaseQualifiersMixin",
#                 "biolink:FrequencyQualifierMixin",
#                 "biolink:RelationshipQuantifier"
#             ],
#             "value_type_id": "xsd:anyURI",
#             "original_attribute_name": "category"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "not_provided",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "agent_type"
#         },
#         {
#             "attribute_type_id": "biolink:has_evidence",
#             "value": [
#                 "ECO:0000304"
#             ],
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "has_evidence"
#         }
#     ]
# }
# {
#     "subject": "MONDO:0019438",
#     "object": "MONDO:0019065",
#     "predicate": "biolink:subclass_of",
#     "sources": [
#         {
#             "resource_id": "infores:automat-robokop",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:automat-robokop"
#             ]
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "not_provided",
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "automated_agent",
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "MONDO:0019438",
#     "object": "HP:0100639",
#     "predicate": "biolink:has_phenotype",
#     "sources": [
#         {
#             "resource_id": "infores:automat-monarchinitiative",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:monarchinitiative"
#             ]
#         },
#         {
#             "resource_id": "infores:hpo-annotations",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:automat-monarchinitiative",
#                 "infores:automat-robokop"
#             ]
#         },
#         {
#             "resource_id": "infores:automat-robokop",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:monarchinitiative"
#             ]
#         },
#         {
#             "resource_id": "infores:monarchinitiative",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:hpo-annotations"
#             ]
#         }
#     ],
#     "qualifiers": [
#         {
#             "qualifier_type_id": "biolink:frequency_qualifier",
#             "qualifier_value": "HP:0040283"
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:support_graphs",
#             "value": [
#                 "e26b23b8"
#             ],
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:original_subject",
#             "value": "Orphanet:85443",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "original_subject"
#         },
#         {
#             "attribute_type_id": "biolink:category",
#             "value": [
#                 "biolink:DiseaseToPhenotypicFeatureAssociation",
#                 "biolink:FrequencyQuantifier",
#                 "biolink:EntityToPhenotypicFeatureAssociationMixin",
#                 "biolink:DiseaseToEntityAssociationMixin",
#                 "biolink:Association",
#                 "biolink:Entity",
#                 "biolink:EntityToFeatureOrDiseaseQualifiersMixin",
#                 "biolink:FrequencyQualifierMixin",
#                 "biolink:RelationshipQuantifier"
#             ],
#             "value_type_id": "xsd:anyURI",
#             "original_attribute_name": "category"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "not_provided",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "agent_type"
#         },
#         {
#             "attribute_type_id": "biolink:has_evidence",
#             "value": [
#                 "ECO:0000304"
#             ],
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "has_evidence"
#         },
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "logical_entailment",
#             "value_type_id": "EDAM:data_0006",
#             "original_attribute_name": "knowledge_level",
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:support_graphs",
#             "value": [
#                 "4342739a"
#             ],
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "HP:0008652",
#     "object": "HP:0100639",
#     "predicate": "biolink:subclass_of",
#     "sources": [
#         {
#             "resource_id": "infores:automat-monarchinitiative",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:automat-monarchinitiative"
#             ]
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "not_provided",
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "automated_agent",
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "MONDO:0019438",
#     "object": "MONDO:0019065",
#     "predicate": "biolink:subclass_of",
#     "sources": [
#         {
#             "resource_id": "infores:automat-monarchinitiative",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:automat-monarchinitiative"
#             ]
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "not_provided",
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "automated_agent",
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "HP:0100639",
#     "object": "MONDO:0019065",
#     "predicate": "biolink:manifestation_of",
#     "sources": [
#         {
#             "resource_id": "infores:omim",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:rtx-kg2"
#             ]
#         },
#         {
#             "resource_id": "infores:rtx-kg2",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:omim"
#             ]
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "logical_entailment",
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "manual_agent",
#             "attribute_source": "infores:rtx-kg2"
#         },
#         {
#             "attribute_type_id": "biolink:original_predicate",
#             "value": [
#                 "UMLS:C2751492---OMIM:has_manifestation---None---None---None---UMLS:C0242350---umls_source:OMIM",
#                 "UMLS:C0242350---OMIM:manifestation_of---None---None---None---UMLS:C2751492---umls_source:OMIM"
#             ],
#             "value_type_id": "metatype:String",
#             "description": "The IDs of the original RTX-KG2pre edge(s) corresponding to this edge prior to any synonymization or remapping."
#         },
#         {
#             "attribute_type_id": "biolink:support_graphs",
#             "value": [
#                 "0f1135f2",
#                 "dc224065"
#             ],
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "MONDO:0005362",
#     "object": "MONDO:0007100",
#     "predicate": "biolink:manifestation_of",
#     "sources": [
#         {
#             "resource_id": "infores:omim",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:rtx-kg2"
#             ]
#         },
#         {
#             "resource_id": "infores:rtx-kg2",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:omim"
#             ]
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "knowledge_assertion",
#             "attribute_source": "infores:rtx-kg2"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "manual_agent",
#             "attribute_source": "infores:rtx-kg2"
#         },
#         {
#             "attribute_type_id": "biolink:original_predicate",
#             "value": [
#                 "UMLS:C2751492---OMIM:has_manifestation---None---None---None---UMLS:C0242350---umls_source:OMIM",
#                 "UMLS:C0242350---OMIM:manifestation_of---None---None---None---UMLS:C2751492---umls_source:OMIM"
#             ],
#             "value_type_id": "metatype:String",
#             "description": "The IDs of the original RTX-KG2pre edge(s) corresponding to this edge prior to any synonymization or remapping."
#         }
#     ]
# }
# {
#     "subject": "MONDO:0007100",
#     "object": "MONDO:0019065",
#     "predicate": "biolink:subclass_of",
#     "sources": [
#         {
#             "resource_id": "infores:rtx-kg2",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:rtx-kg2"
#             ]
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "not_provided",
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "automated_agent",
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "MONDO:0005362",
#     "object": "HP:0100639",
#     "predicate": "biolink:subclass_of",
#     "sources": [
#         {
#             "resource_id": "infores:rtx-kg2",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:rtx-kg2"
#             ]
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "not_provided",
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "automated_agent",
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
# {
#     "subject": "MONDO:0005362",
#     "object": "MONDO:0019065",
#     "predicate": "biolink:manifestation_of",
#     "sources": [
#         {
#             "resource_id": "infores:omim",
#             "resource_role": "primary_knowledge_source"
#         },
#         {
#             "resource_id": "infores:aragorn",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:rtx-kg2"
#             ]
#         },
#         {
#             "resource_id": "infores:rtx-kg2",
#             "resource_role": "aggregator_knowledge_source",
#             "upstream_resource_ids": [
#                 "infores:omim"
#             ]
#         }
#     ],
#     "attributes": [
#         {
#             "attribute_type_id": "biolink:support_graphs",
#             "value": [
#                 "0f1135f2"
#             ],
#             "attribute_source": "infores:aragorn"
#         },
#         {
#             "attribute_type_id": "biolink:agent_type",
#             "value": "manual_agent",
#             "attribute_source": "infores:rtx-kg2"
#         },
#         {
#             "attribute_type_id": "biolink:original_predicate",
#             "value": [
#                 "UMLS:C2751492---OMIM:has_manifestation---None---None---None---UMLS:C0242350---umls_source:OMIM",
#                 "UMLS:C0242350---OMIM:manifestation_of---None---None---None---UMLS:C2751492---umls_source:OMIM"
#             ],
#             "value_type_id": "metatype:String",
#             "description": "The IDs of the original RTX-KG2pre edge(s) corresponding to this edge prior to any synonymization or remapping."
#         },
#         {
#             "attribute_type_id": "biolink:knowledge_level",
#             "value": "logical_entailment",
#             "attribute_source": "infores:aragorn"
#         }
#     ]
# }
