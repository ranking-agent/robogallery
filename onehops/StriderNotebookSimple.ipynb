# %%
import requests
import json

# %%
def automat(db,message):
    automat_url = f'https://automat.renci.org/{db}/query'
    #response = requests.post(automat_url,json=message['message'])
    response = requests.post(automat_url,json=message)
    print(response.status_code)
    return response.json()

def post(name,url,message,params=None):
    if params is None:
        response = requests.post(url,json=message)
    else:
        response = requests.post(url,json=message,params=params)
    if not response.status_code == 200:
        print(name, 'error:',response.status_code)
        return {}
    #print(response.json())
    return response.json()

def strider(message):
    #url = 'http://robokop.renci.org:5781/query'
    url = 'http://robokop.renci.org:5781/query?log_level=DEBUG'
    strider_answer = post(strider,url,message)
    #numanswers = len(strider_answer['results'])
    #if (numanswers == 0) or ((numanswers == 1) and (len(strider_answer['results'][0]['node_bindings'])==0)):
    #    print('no answers')
    #    return {}
    #Strider for some reason doesn't return the query graph
    #strider_answer['query_graph'] = message['message']['query_graph']
    return strider_answer
 
def striderandfriends(message):
    strider_answer = strider(message)    
    coalesced_answer = post('coalesce','https://answercoalesce.renci.org/coalesce/graph',{'message':strider_answer})
    omni_answer = post('omnicorp','https://aragorn-ranker.renci.org/omnicorp_overlay',{'message': coalesced_answer})
    weighted_answer = post('weight','https://aragorn-ranker.renci.org/weight_correctness',{'message': omni_answer})
    scored_answer = post('score','https://aragorn-ranker.renci.org/score',{'message': weighted_answer})
    return scored_answer

def aragorn(message, coalesce_type):
    if coalesce_type == 'xnone':
        answer = post('aragorn','https://aragorn.renci.org/query',message)
    else:
        answer = post('aragorn','https://aragorn.renci.org/query',message, params={'answer_coalesce_type':coalesce_type})
    return answer

# %% [markdown]
# # Drugs that Treat Schizophrenia

# %% [markdown]
# Send this message directly to aragorn without coalesence

# %%
#message = one_hop_message('MONDO:0005090','disease','chemical_substance','treats',reverse=True)
message = {
  "message": {
    "query_graph": {
      "nodes": {
        "n00": {
          "id": "MONDO:0005784",
          "category": "biolink:Disease"
        },
        "n01": {
          "category": "biolink:Disease"
        }
      },
      "edges": {
        "e00": {
          "subject": "n00",
          "object": "n01",
          "predicate":"biolink:subclass_of"
        }
      }
    }
  }
}

# %%
message={
  "message": {
    "query_graph": {
      "nodes": {
        "n00": {
          "id": "MONDO:0002715"
        },
        "n01": {
          "category": "biolink:ChemicalSubstance"
        },
        "n02": {
          "category": "biolink:Gene"
        }
      },
      "edges": {
        "e00": {
          "predicate": "biolink:correlated_with",
          "subject": "n00",
          "object": "n01"
        },
        "e01": {
          "predicate": "biolink:related_to",
          "subject": "n01",
          "object": "n02"
        }
      }
    }
  }
}

# %%
pregmess={"message": {
    "query_graph": {
        "nodes": {
            "n0": {
                "category": "biolink:ChemicalSubstance"
            },
            "n1": {
                "id": "UMLS:C0032961",
                "category":"biolink:PhenotypicFeature"
            }
        },
        "edges": {
            "e00": {
                "subject": "n0",
                "object": "n1",
                "predicate":"biolink:contraindicated_for"
                }
            }
        }
    }
}

# %%
pm={
"message": {
"query_graph": {
"nodes": {
"n0": {
"id": "MONDO:0005132",
"category":"biolink:Disease"
},
"n1": {
"category": "biolink:ChemicalSubstance"
},
"n2": {
"id": "NCIT:C92933",
"category":"biolink:PhenotypicFeature"
}
},
"edges": {
"e01": {
"subject": "n1",
"object": "n0",
"predicate":"biolink:treats"
},
"e02": {
"subject": "n1",
"object": "n2",
"predicate": "biolink:contraindicated_for"
}
}
}
}
}

# %%
bcq={
  "message": {
    "query_graph": {
      "edges": {
        "e0": {
          "predicate": "biolink:gene_associated_with_condition",
          "subject": "n0",
          "object": "n1"
        }
      },
      "nodes": {
        "n0": {
          "category": "biolink:Gene"
        },
        "n1": {
          "category": "biolink:Disease",
          "id": "MONDO:0007254"
        }
      }
    }
  }
}

# %%
adq = {
        "message": {
            "query_graph": {
                "edges": {
                    "e00": {
                        "subject": "n01",
                        "object": "n00",
                        "predicate": "biolink:treats"
                    }
                },
                "nodes": {
                    "n00": {
                        "id": "MONDO:0004975",
                        "category": "biolink:Disease"
                    },
                    "n01": {
                        "category": "biolink:ChemicalSubstance"
                    }
                }
            }
        }
    }

# %%
corr={
        "message": {
            "query_graph": {
                "edges": {
                    "e00": {
                        "subject": "n00",
                        "object": "n01",
                        "predicate": "biolink:correlated_with"
                    }
                },
                "nodes": {
                    "n00": {
                        "id": "MONDO:0001627",
                        "category": "biolink:Disease"
                    },
                    "n01": {
                        "category": "biolink:ChemicalSubstance"
                    }
                }
            }
        }
    }

# %%
x={
  "message": {
    "query_graph": {
      "nodes": {
        "n0": {
          "id": "MONDO:0004979",
          "category": "biolink:Disease"
        },
        "n1": {
          "category": "biolink:ChemicalSubstance"
        }
      },
      "edges": {
        "e01": {
          "subject": "n1",
          "object": "n0",
          "predicate": "biolink:correlated_with"
        }
      }
    }
  }
}

# %%
x={
  "message": {
    "query_graph": {
      "nodes": {
        "n0": {
          "id": "MONDO:0004979",
          "category": "biolink:Disease"
        },
        "n1": {
          "category": "biolink:ChemicalSubstance"
        }
      },
      "edges": {
        "e01": {
          "subject": "n1",
          "object": "n0",
          "predicate": "biolink:correlated_with"
        }
      }
    }
  }
}

# %%
test_query_1 = {
    "message": {
    "query_graph": {
      "nodes": {
        "n0": {
          "id": "MONDO:0015681",
          "category": "biolink:Disease"
        },
        "n1": {
          "category": "biolink:ChemicalSubstance"
        },
        "n2": {
          "category": "biolink:Gene"
        }
      },
      "edges": {
        "e01": {
          "subject": "n1",
          "object": "n0",
          "predicate": "biolink:treats"
        },
        "e02": {
          "subject": "n1",
          "object": "n2",
          "predicate": "biolink:decreases_activity_of"
        },
        "e03": {
          "subject": "n0",
          "object": "n2",
          "predicate": "biolink:gene_associated_with_condition"
        }
      }
    }
  }
}

# %%
test_query_1a = {
    "message": {
    "query_graph": {
      "nodes": {
        "n0": {
          "id": "MONDO:0015681",
          "category": "biolink:Disease"
        },
        "n1": {
          "category": "biolink:ChemicalSubstance"
        }
      },
      "edges": {
        "e01": {
          "subject": "n1",
          "object": "n0",
          "predicate": "biolink:treats"
        }
      }
    }
  }
}

# %%
test_query_1b = {
    "message": {
    "query_graph": {
      "nodes": {
        "n1": {
          "category": "biolink:ChemicalSubstance",
            "id": "CHEBI:45906"
        },
        "n2": {
          "category": "biolink:Gene"
        }
      },
      "edges": {
        "e02": {
          "subject": "n1",
          "object": "n2",
          "predicate": "biolink:decreases_activity_of"
        }
      }
    }
  }
}

# %%
test_query_1c = {
    "message": {
    "query_graph": {
      "nodes": {
        "n0": {
          "id": "MONDO:0015681",
          "category": "biolink:Disease"
        },
        "n2": {
          "category": "biolink:Gene"
        }
      },
      "edges": {
        "e03": {
          "subject": "n2",
          "object": "n0",
          "predicate": "biolink:gene_associated_with_condition"
        }
      }
    }
  }
}

# %%
test_query_2 = {
    "message": {
    "query_graph": {
      "nodes": {
        "n0": {
          "id": "MONDO:0010130",
          "category": "biolink:Disease"
        },
        "n1": {
          "category": "biolink:BiologicalProcessOrActivity"
        },
        "n2": {
          "category": "biolink:Gene"
        }
      },
      "edges": {
        "e01": {
          "subject": "n0",
          "object": "n1",
          "predicate": "biolink:affects"
        },
        "e02": {
          "subject": "n2",
          "object": "n1",
          "predicate": "biolink:actively_involved_in"
        },
        "e03": {
          "subject": "n2",
          "object": "n0",
          "predicate": "biolink:gene_associated_with_condition"
        }
      }
    }
  }
}

# %%
test_query_2a = {
    "message": {
    "query_graph": {
      "nodes": {
        "n0": {
          "id": "MONDO:0010130",
          "category": "biolink:Disease"
        },
        "n1": {
          "category": "biolink:BiologicalProcess"
        }
      },
      "edges": {
        "e01": {
          "subject": "n0",
          "object": "n1",
          "predicate": "biolink:affects"
        }
      }
    }
  }
}

# %%
test_query_3 = {
    "message": {
    "query_graph": {
      "nodes": {
        "n0": {
          "id": "MONDO:0008114",
          "category": "biolink:Disease"
        },
        "n1": {
          "category": "biolink:PhenotypicFeature"
        },
        "n2": {
          "category": "biolink:ChemicalSubstance"
        }
      },
      "edges": {
        "e01": {
          "subject": "n0",
          "object": "n1",
          "predicate": "biolink:has_phenotype"
        },
        "e02": {
          "subject": "n2",
          "object": "n1",
          "predicate": "biolink:treats"
        },
        "e03": {
          "subject": "n2",
          "object": "n0",
          "predicate": "biolink:treats"
        }
      }
    }
  }
}

# %%
strider(test_query_3)
# Out:
# {'message': {'query_graph': {'nodes': {'n2': {'id': None, 'category': 'biolink:ChemicalSubstance', 'is_set': False}, 'n0': {'id': 'MONDO:0008114', 'category': 'biolink:Disease', 'is_set': False}, 'n1': {'id': None, 'category': 'biolink:PhenotypicFeature', 'is_set': False}}, 'edges': {'e03': {'subject': 'n2', 'object': 'n0', 'predicate': 'biolink:treats', 'relation': None}, 'e02': {'subject': 'n2', 'object': 'n1', 'predicate': 'biolink:treats', 'relation': None}, 'e01': {'subject': 'n0', 'object': 'n1', 'predicate': 'biolink:has_phenotype', 'relation': None}}}, 'knowledge_graph': {'nodes': {'HP:0011675': {'category': ['biolink:NamedThing', 'biolink:BiologicalEntity', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:PhenotypicFeature'], 'name': 'Arrhythmia', 'attributes': [{'type': 'NA', 'value': ['Abnormal heart rate', 'Abnormality of cardiac conduction', 'Arrhythmias', 'Cardiac arrhythmia', 'Cardiac arrhythmias', 'Cardiac conduction abnormalities', 'Cardiac conduction defects', 'Cardiac rhythm disturbances', 'Heart rhythm disorders', 'Irregular heart beat', 'Irregular heartbeat'], 'name': 'synonyms', 'url': None, 'source': None}, {'type': 'NA', 'value': 'Arrhythmia', 'name': 'name', 'url': None, 'source': None}, {'type': 'NA', 'value': ['UMLS:C1832603', 'UMLS:C2938958', 'MEDDRA:10061116', 'HP:0011675', 'UMLS:C2363928', 'UMLS:C0861149', 'UMLS:C0861148', 'MEDDRA:10003119', 'UMLS:C0264886', 'MESH:C562490', 'UMLS:C1842820', 'MEDDRA:10007521', 'MESH:D001145', 'UMLS:C0003811', 'UMLS:C0855329'], 'name': 'equivalent_identifiers', 'url': None, 'source': None}]}, 'MESH:C035133': {'category': ['biolink:NamedThing', 'biolink:MolecularEntity', 'biolink:BiologicalEntity', 'biolink:ChemicalSubstance', 'biolink:Entity'], 'name': '[OBSOLETE] mirtazapine', 'attributes': [{'type': 'NA', 'value': [], 'name': 'synonyms', 'url': None, 'source': None}, {'type': 'NA', 'value': '[OBSOLETE] mirtazapine', 'name': 'name', 'url': None, 'source': None}, {'type': 'NA', 'value': ['UNII:A051Q2099Q', 'MESH:C035133', 'MESH:D000078785'], 'name': 'equivalent_identifiers', 'url': None, 'source': None}]}, 'HP:0003124': {'category': ['biolink:NamedThing', 'biolink:BiologicalEntity', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:PhenotypicFeature'], 'name': 'Hypercholesterolemia', 'attributes': [{'type': 'NA', 'value': [], 'name': 'synonyms', 'url': None, 'source': None}, {'type': 'NA', 'value': 'Hypercholesterolemia', 'name': 'name', 'url': None, 'source': None}, {'type': 'NA', 'value': ['UMLS:C0020443', 'UMLS:C0595929', 'MESH:D006937', 'SNOMEDCT:166830008', 'HP:0003124', 'UMLS:C2721593', 'UMLS:C0856108', 'UMLS:C2242712', 'SNOMEDCT:13644009', 'MEDDRA:10020603'], 'name': 'equivalent_identifiers', 'url': None, 'source': None}]}, 'HP:0000118': {'category': ['biolink:NamedThing', 'biolink:BiologicalEntity', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:PhenotypicFeature'], 'name': 'Phenotypic abnormality', 'attributes': [{'type': 'NA', 'value': ['Organ abnormality'], 'name': 'synonyms', 'url': None, 'source': None}, {'type': 'NA', 'value': 'Phenotypic abnormality', 'name': 'name', 'url': None, 'source': None}, {'type': 'NA', 'value': ['UMLS:C4021819', 'HP:0000118'], 'name': 'equivalent_identifiers', 'url': None, 'source': None}]}, 'HP:0100851': {'category': ['biolink:NamedThing', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:PhenotypicFeature'], 'name': 'Abnormal emotion/affect behavior', 'attributes': [{'type': 'NA', 'value': ['Abnormal emotion/affect behaviour'], 'name': 'synonyms', 'url': None, 'source': None}, {'type': 'NA', 'value': 'Abnormal emotion/affect behavior', 'name': 'name', 'url': None, 'source': None}, {'type': 'NA', 'value': ['UMLS:C4020949', 'HP:0100851'], 'name': 'equivalent_identifiers', 'url': None, 'source': None}]}, 'MESH:D014191': {'category': ['biolink:NamedThing', 'biolink:MolecularEntity', 'biolink:BiologicalEntity', 'biolink:ChemicalSubstance', 'biolink:Entity'], 'name': 'Tranylcypromine', 'attributes': [{'type': 'NA', 'value': [], 'name': ' ...
# {'message': {'query_graph': {'nodes': {'n2': {'id': None,
#      'category': 'biolink:ChemicalSubstance',
#      'is_set': False},
#     'n0': {'id': 'MONDO:0008114',
#      'category': 'biolink:Disease',
#      'is_set': False},
#     'n1': {'id': None,
#      'category': 'biolink:PhenotypicFeature',
#      'is_set': False}},
#    'edges': {'e03': {'subject': 'n2',
#      'object': 'n0',
#      'predicate': 'biolink:treats',
#      'relation': None},
#     'e02': {'subject': 'n2',
#      'object': 'n1',
#      'predicate': 'biolink:treats',
#      'relation': None},
#     'e01': {'subject': 'n0',
#      'object': 'n1',
#      'predicate': 'biolink:has_phenotype',
#      'relation': None}}},
#   'knowledge_graph': {'nodes': {'HP:0011675': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Arrhythmia',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormal heart rate',
#         'Abnormality of cardiac conduction',
#         'Arrhythmias',
#         'Cardiac arrhythmia',
#         'Cardiac arrhythmias',
#         'Cardiac conduction abnormalities',
#         'Cardiac conduction defects',
#         'Cardiac rhythm disturbances',
#         'Heart rhythm disorders',
#         'Irregular heart beat',
#         'Irregular heartbeat'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Arrhythmia',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C1832603',
#         'UMLS:C2938958',
#         'MEDDRA:10061116',
#         'HP:0011675',
#         'UMLS:C2363928',
#         'UMLS:C0861149',
#         'UMLS:C0861148',
#         'MEDDRA:10003119',
#         'UMLS:C0264886',
#         'MESH:C562490',
#         'UMLS:C1842820',
#         'MEDDRA:10007521',
#         'MESH:D001145',
#         'UMLS:C0003811',
#         'UMLS:C0855329'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'MESH:C035133': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': '[OBSOLETE] mirtazapine',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': '[OBSOLETE] mirtazapine',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UNII:A051Q2099Q', 'MESH:C035133', 'MESH:D000078785'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0003124': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Hypercholesterolemia',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Hypercholesterolemia',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C0020443',
#         'UMLS:C0595929',
#         'MESH:D006937',
#         'SNOMEDCT:166830008',
#         'HP:0003124',
#         'UMLS:C2721593',
#         'UMLS:C0856108',
#         'UMLS:C2242712',
#         'SNOMEDCT:13644009',
#         'MEDDRA:10020603'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000118': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Phenotypic abnormality',
#      'attributes': [{'type': 'NA',
#        'value': ['Organ abnormality'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Phenotypic abnormality',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4021819', 'HP:0000118'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0100851': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal emotion/affect behavior',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormal emotion/affect behaviour'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormal emotion/affect behavior',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4020949', 'HP:0100851'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'MESH:D014191': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'Tranylcypromine',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Tranylcypromine',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UNII:3E3V44J4Z9', 'MESH:D014191'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'UMLS:C1696701': {'category': 'biolink:PhenotypicFeature',
#      'name': 'Skin-picking',
#      'attributes': [{'name': 'equivalent_identifiers',
#        'value': {'id': {'label': 'Skin-picking',
#          'identifier': 'UMLS:C1696701'},
#         'db_ids': {'UMLS': ['C1696701'],
#          'HP': ['HP:0012166'],
#          'name': ['Skin-picking']},
#         'type': 'PhenotypicFeature',
#         'curies': ['UMLS:C1696701', 'HP:0012166']},
#        'type': 'biolink:id'}]},
#     'HP:0000716': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Depressivity',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Depressivity',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C0011570',
#         'HP:0000716',
#         'UMLS:C0011581',
#         'UMLS:C0856923',
#         'UMLS:C0154437',
#         'SNOMEDCT:712823008',
#         'UMLS:C0541869',
#         'UMLS:C0235876',
#         'UMLS:C0541868',
#         'MEDDRA:10012378',
#         'UMLS:C1868899',
#         'SNOMEDCT:21061000119107',
#         'UMLS:C0859997',
#         'MEDDRA:10012401',
#         'UMLS:C1386135',
#         'SNOMEDCT:192080009',
#         'UMLS:C0581391',
#         'UMLS:C0349218'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'CHEBI:7640': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'nortriptyline',
#      'attributes': [{'type': 'NA',
#        'value': ['3-(10,11-dihydro-5H-dibenzo[a,d][7]annulen-5-ylidene)-N-methylpropan-1-amine',
#         'Nortriptyline',
#         '10,11-dihydro-N-methyl-5H-dibenzo[a,d]cycloheptene-Delta(5,gamma)-propylamine',
#         '3-(10,11-dihydro-5H-dibenzo[a,d]cyclohepten-5-ylidene)-N-methyl-1-propanamine',
#         'Ateben',
#         'Avantyl',
#         'Aventyl',
#         'demethylamitriptyline',
#         'desmethylamitriptyline',
#         'Noritren',
#         'nortriptylina',
#         'nortriptyline',
#         'nortriptylinum',
#         'Psychostyl',
#         'Sensaval'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'nortriptyline',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['INCHIKEY:JWYGOLDHYLLVDK-WDGOXLLCSA-N',
#         'HMDB:HMDB0014680',
#         'CHEMBL.COMPOUND:CHEMBL445',
#         'UNII:BL03SY4LXB',
#         'CHEBI:7640',
#         'KEGG:C07274',
#         'gtpo:2404',
#         'MESH:D009661',
#         'DRUGBANK:DB00540',
#         'PUBCHEM.COMPOUND:4543'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'UMLS:C0424290': {'category': 'biolink:PhenotypicFeature',
#      'name': 'Collectionism',
#      'attributes': [{'name': 'equivalent_identifiers',
#        'value': {'id': {'label': 'Collectionism',
#          'identifier': 'UMLS:C0424290'},
#         'db_ids': {'UMLS': ['C0424290'],
#          'HP': ['HP:0030212'],
#          'name': ['Collectionism']},
#         'type': 'PhenotypicFeature',
#         'curies': ['UMLS:C0424290', 'HP:0030212']},
#        'type': 'biolink:id'}]},
#     'HP:0012592': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Albuminuria',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Albuminuria',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C0001925',
#         'MEDDRA:10001580',
#         'MESH:D000419',
#         'HP:0012592',
#         'SNOMEDCT:274769005'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'CHEBI:8060': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'Phenelzine',
#      'attributes': [{'type': 'NA',
#        'value': ['Phenelzine',
#         '1-hydrazino-2-phenylethane',
#         '2-phenylethylhydrazine',
#         'phenalzine',
#         'phenelzine sulfate',
#         'phenethylhydrazine'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Phenelzine',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['MESH:D010624',
#         'INCHIKEY:ZKOYCMCWNDWXSA-UHFFFAOYSA-N',
#         'UNII:O408N561GF',
#         'CHEMBL.COMPOUND:CHEMBL1089',
#         'KEGG:C07430',
#         'CHEBI:8060',
#         'PUBCHEM.COMPOUND:3675',
#         'HMDB:HMDB0014918',
#         'DRUGBANK:DB00780',
#         'gtpo:7266'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'CHEBI:17268': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'myo-inositol',
#      'attributes': [{'type': 'NA',
#        'value': ['myo-inositol',
#         'myo-Inositol',
#         '(1r,2R,3S,4s,5R,6S)-cyclohexane-1,2,3,4,5,6-hexol',
#         '1,2,3,4,5,6-HEXAHYDROXY-CYCLOHEXANE',
#         '1,2,3,5/4,6-cyclohexanehexol',
#         '1D-myo-Inositol',
#         '1L-myo-Inositol',
#         'Bios I',
#         'cis-1,2,3,5-trans-4,6-cyclohexanehexol',
#         'Cyclohexitol',
#         'D-myo-Inositol',
#         'Dambose',
#         'i-inositol',
#         'inosite',
#         'Inositol',
#         'Ins',
#         'L-myo-Inositol',
#         'Meat sugar',
#         'meso-Inositol',
#         'Myoinositol'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'myo-inositol',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UNII:4L6452S749',
#         'KEGG:C00137',
#         'DRUGBANK:DB13178',
#         'CHEBI:17268',
#         'INCHIKEY:ZVLFKQXYWNYYOJ-UHFFFAOYSA-N',
#         'HMDB:HMDB0000211',
#         'gtpo:4495',
#         'CHEMBL.COMPOUND:CHEMBL1222251',
#         'MESH:D007294'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'CHEBI:3757': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'clonidine (imino form)',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'clonidine (imino form)',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['MESH:D003000',
#         'CHEBI:3757',
#         'PUBCHEM.COMPOUND:2803',
#         'gtpo:516',
#         'DRUGBANK:DB00575',
#         'INCHIKEY:YEIPELYZWHCLIZ-UHFFFAOYSA-N',
#         'CHEMBL.COMPOUND:CHEMBL134',
#         'UNII:MN3L5RMN02',
#         'CHEBI:46632',
#         'HMDB:HMDB0014714'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0002067': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Bradykinesia',
#      'attributes': [{'type': 'NA',
#        'value': ['Slow movements',
#         'Slowness of movements',
#         'Decreased muscle movement',
#         'Decreased spontaneous movement',
#         'Decreased spontaneous movements'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Bradykinesia',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['MEDDRA:10006100',
#         'UMLS:C0233565',
#         'HP:0002067',
#         'UMLS:C0242684',
#         'MEDDRA:10021021',
#         'MESH:D018476',
#         'SNOMEDCT:399317006',
#         'NCIT:C116707',
#         'NCIT:C116576',
#         'HP:0002375',
#         'UMLS:C0751701',
#         'SNOMEDCT:255385008',
#         'UMLS:C0235020',
#         'SNOMEDCT:43994002',
#         'UMLS:C0235019',
#         'UMLS:C0086439',
#         'MEDDRA:10041052',
#         'UMLS:C0920289'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0001640': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Cardiomegaly',
#      'attributes': [{'type': 'NA',
#        'value': ['Enlarged heart', 'Increased heart size'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Cardiomegaly',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C0264732',
#         'MEDDRA:10007632',
#         'UMLS:C0856198',
#         'UMLS:C0018800',
#         'HP:0001640',
#         'MESH:D006332',
#         'MEDDRA:10007572',
#         'SNOMEDCT:71932004',
#         'SNOMEDCT:8186001',
#         'UMLS:C3495916',
#         'NCIT:C61453',
#         'UMLS:C1383860'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0100739': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Bulimia',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Bulimia',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C2267227',
#         'UMLS:C0541728',
#         'HP:0100739',
#         'MEDDRA:10006550',
#         'UMLS:C0006370'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'CHEBI:9123': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'sertraline',
#      'attributes': [{'type': 'NA',
#        'value': ['(1S,4S)-4-(3,4-dichlorophenyl)-N-methyl-1,2,3,4-tetrahydronaphthalen-1-amine',
#         'Sertraline',
#         '(+)-sertraline',
#         '(1S-cis)-1,2,3,4-tetrahydro-4-(3,4-dichlorophenyl)-N-methyl-1-naphthalenamine',
#         '(1S,4S)-sertraline',
#         'cis-(+)-sertraline',
#         'CP 51974',
#         'sertralina',
#         'sertraline',
#         'sertralinum'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'sertraline',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['PUBCHEM.COMPOUND:68617',
#         'CHEMBL.COMPOUND:CHEMBL809',
#         'DRUGBANK:DB01104',
#         'UNII:QUC7NX6WMB',
#         'MESH:D020280',
#         'CHEBI:9123',
#         'INCHIKEY:HYYANCGBOQXVGM-UHFFFAOYSA-N',
#         'KEGG:C07246',
#         'HMDB:HMDB0005010',
#         'gtpo:4798'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'CHEMBL.COMPOUND:CHEMBL1201178': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'LISDEXAMFETAMINE DIMESYLATE',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'LISDEXAMFETAMINE DIMESYLATE',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['PUBCHEM.COMPOUND:11597697',
#         'MESH:C514020',
#         'INCHIKEY:PAWBWEZPURMGQC-UHFFFAOYSA-N',
#         'CHEMBL.COMPOUND:CHEMBL1201178',
#         'MESH:D000069478',
#         'UNII:SJT761GEGS'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'CHEBI:47780': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'clomipramine',
#      'attributes': [{'type': 'NA',
#        'value': ['3-(3-chloro-10,11-dihydro-5H-dibenzo[b,f]azepin-5-yl)-N,N-dimethylpropan-1-amine',
#         'Clomipramine',
#         '3-(3-chloro-10,11-dihydro-5H-dibenzo[b,f]azepin-5-yl)-N,N-dimethyl-1-propanamine',
#         '3-(3-CHLORO-5H-DIBENZO[B,F]AZEPIN-5-YL)-N,N-DIMETHYLPROPAN-1-AMINE',
#         '3-chloroimipramine',
#         'chlorimipramine',
#         'G 34586',
#         'monochlorimipramine'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'clomipramine',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['gtpo:2398',
#         'CHEMBL.COMPOUND:CHEMBL415',
#         'PUBCHEM.COMPOUND:2801',
#         'DRUGBANK:DB01242',
#         'HMDB:HMDB0015372',
#         'CHEBI:47780',
#         'INCHIKEY:FYPRIKVHHVQETD-COJSNBRMSA-N',
#         'KEGG:C06918',
#         'MESH:D002997',
#         'UNII:NUV44L116D'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0004325': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Decreased body weight',
#      'attributes': [{'type': 'NA',
#        'value': ['Decreased body weight',
#         'Decreased weight',
#         'Low body weight',
#         'Low weight',
#         'Weight less than 3rd percentile'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Decreased body weight',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['SNOMEDCT:161832001',
#         'SNOMEDCT:262285001',
#         'UMLS:C1844806',
#         'UMLS:C0039870',
#         'UMLS:C1112280',
#         'HP:0004325',
#         'SNOMEDCT:248342006',
#         'MEDDRA:10047895',
#         'UMLS:C1262477',
#         'UMLS:C0041667',
#         'MESH:D013851',
#         'MEDDRA:10048828'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0100716': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Self-injurious behavior',
#      'attributes': [{'type': 'NA',
#        'value': ['Deliberate self-harm',
#         'Self mutilation',
#         'Self-mutilation',
#         'Self injury',
#         'Self-harm',
#         'Autoagression',
#         'Self-injurious behavior',
#         'Self-injurious behaviour',
#         'Self-injurious behaviors'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Self-injurious behavior',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C0036601',
#         'UMLS:C0595861',
#         'UMLS:C0858208',
#         'NCIT:C80111',
#         'SNOMEDCT:130968006',
#         'UMLS:C3267152',
#         'UMLS:C0038663',
#         'SNOMEDCT:55554002',
#         'UMLS:C0085271',
#         'UMLS:C2242537',
#         'UMLS:C0856306',
#         'NCIT:C118206',
#         'MESH:D016728',
#         'SNOMEDCT:248062006',
#         'HP:0000742',
#         'UMLS:C0424366',
#         'UMLS:C0856974',
#         'MESH:D013406',
#         'HP:0100716',
#         'MEDDRA:10022524',
#         'MEDDRA:10042464',
#         'SNOMEDCT:82313006',
#         'UMLS:C0853089',
#         'MESH:D012652'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0002045': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Hypothermia',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormally low body temperature', 'Hypothermia'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Hypothermia',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['SNOMEDCT:386689009',
#         'UMLS:C0274285',
#         'HP:0002045',
#         'MESH:D007035',
#         'SNOMEDCT:212916004',
#         'UMLS:C0020672'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'CHEBI:7936': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'paroxetine',
#      'attributes': [{'type': 'NA',
#        'value': ['(3S,4R)-3-[(1,3-benzodioxol-5-yloxy)methyl]-4-(4-fluorophenyl)piperidine',
#         'Paroxetine',
#         '(-)-(3S,4R)-4-(p-fluorophenyl)-3-((3,4-(methylenedioxy)phenoxy)methyl)piperidine',
#         '(3S-trans)-3-((1,3-benzodioxol-5-yloxy)methyl)-4-(4-fluorophenyl)piperidine',
#         'paroxetina',
#         'paroxetinum'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'paroxetine',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['DRUGBANK:DB00715',
#         'UNII:41VRH5220H',
#         'PUBCHEM.COMPOUND:43815',
#         'MESH:D017374',
#         'INCHIKEY:YFKGJTUEXCPANI-GSSGUZCNSA-N',
#         'CHEMBL.COMPOUND:CHEMBL490',
#         'gtpo:4790',
#         'KEGG:C07415',
#         'HMDB:HMDB0014853',
#         'CHEBI:7936'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'MESH:D015283': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'Citalopram',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Citalopram',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UNII:0DHU5B8D6V', 'MESH:D015283'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'CHEBI:5138': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'fluvoxamine',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'fluvoxamine',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['DRUGBANK:DB00176',
#         'UNII:O4L1XPO44W',
#         'gtpo:7189',
#         'PUBCHEM.COMPOUND:5324346',
#         'CHEMBL.COMPOUND:CHEMBL814',
#         'KEGG:C07571',
#         'CHEBI:5138',
#         'MESH:D016666',
#         'INCHIKEY:GGTZVYWJQYDYPG-UHFFFAOYSA-N'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0012228': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Tension-type headache',
#      'attributes': [{'type': 'NA',
#        'value': ['Tension-type headache'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Tension-type headache',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['MESH:D018781',
#         'HP:0012228',
#         'UMLS:C0751705',
#         'NCIT:C117070',
#         'MEDDRA:10043269',
#         'UMLS:C0856311',
#         'UMLS:C0235005',
#         'UMLS:C0857278',
#         'SNOMEDCT:66551002',
#         'UMLS:C0033893',
#         'SNOMEDCT:398057008'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0031466': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Impairment in personality functioning',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Impairment in personality functioning',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0031466'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'UMLS:C0011581': {'category': 'biolink:PhenotypicFeature',
#      'name': 'Depressivity',
#      'attributes': [{'name': 'equivalent_identifiers',
#        'value': {'id': {'label': 'Depressivity',
#          'identifier': 'UMLS:C0011581'},
#         'db_ids': {'UMLS': ['C0011581'],
#          'HP': ['HP:0000716'],
#          'MESH': ['D003866'],
#          'name': ['Depressivity']},
#         'type': 'PhenotypicFeature',
#         'curies': ['UMLS:C0011581', 'HP:0000716', 'MESH:D003866']},
#        'type': 'biolink:id'}]},
#     'CHEBI:3756': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'clonazepam',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'clonazepam',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['CHEBI:3756',
#         'gtpo:6963',
#         'CHEMBL.COMPOUND:CHEMBL452',
#         'DRUGBANK:DB01068',
#         'MESH:D002998',
#         'PUBCHEM.COMPOUND:2802',
#         'HMDB:HMDB0015201',
#         'UNII:5PE9FDE8GB',
#         'INCHIKEY:RXIBUXSIXJCRDP-NDEPHWFRSA-N'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000739': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Anxiety',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Anxiety',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C0700031',
#         'HP:0000739',
#         'UMLS:C0857102',
#         'UMLS:C0549259',
#         'UMLS:C0860604',
#         'UMLS:C0003467',
#         'UMLS:C4020884',
#         'UMLS:C0857126',
#         'SNOMEDCT:198288003',
#         'NCIT:C74532',
#         'SNOMEDCT:300895004',
#         'UMLS:C0235107',
#         'UMLS:C0235013',
#         'SNOMEDCT:191708009',
#         'UMLS:C0027769',
#         'UMLS:C0860603',
#         'SNOMEDCT:48694002',
#         'UMLS:C0857217',
#         'MESH:D001007',
#         'UMLS:C0853241',
#         'MEDDRA:10029216',
#         'NCIT:C26696',
#         'MEDDRA:10002855',
#         'SNOMEDCT:49971008',
#         'UMLS:C0235111',
#         'UMLS:C0424166',
#         'UMLS:C0581386',
#         'UMLS:C0262377',
#         'UMLS:C0563270',
#         'UMLS:C0233485',
#         'MEDDRA:10048533',
#         'UMLS:C0233481',
#         'UMLS:C0700613',
#         'UMLS:C0857480',
#         'UMLS:C0549258',
#         'UMLS:C0542180',
#         'SNOMEDCT:79015004',
#         'NCIT:C86941',
#         'MEDDRA:10002869',
#         'UMLS:C2239195'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0007430': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Generalized edema',
#      'attributes': [{'type': 'NA',
#        'value': ['Generalized tissue edema',
#         'Dropsy',
#         'Fluid retention',
#         'Water retention',
#         'Hydrops',
#         'Oedema',
#         'Extreme generalized edema'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Generalized edema',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['MESH:D004487',
#         'SNOMEDCT:79654002',
#         'SNOMEDCT:20741006',
#         'SNOMEDCT:271808008',
#         'SNOMEDCT:112647008',
#         'UMLS:C0151603',
#         'UMLS:C1850534',
#         'UMLS:C2938876',
#         'HP:0007430',
#         'SNOMEDCT:16740003',
#         'UMLS:C0333243',
#         'UMLS:C0333241',
#         'SNOMEDCT:267038008',
#         'NCIT:C80098',
#         'UMLS:C0858531',
#         'UMLS:C0013604',
#         'UMLS:C0857441',
#         'SNOMEDCT:56977002',
#         'SNOMEDCT:423666004',
#         'UMLS:C0238094',
#         'SNOMEDCT:85628007',
#         'SNOMEDCT:442433009',
#         'SNOMEDCT:284521000',
#         'UMLS:C0856110',
#         'MEDDRA:10018092',
#         'HP:0000969',
#         'UMLS:C0234940',
#         'MEDDRA:10030095',
#         'NCIT:C98811',
#         'NCIT:C3002',
#         'SNOMEDCT:5008001',
#         'UMLS:C0333244',
#         'HP:0012050'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'CHEBI:30145': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'lithium atom',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'lithium atom',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['MESH:D008094',
#         'INCHIKEY:QVFBXCMBAOLLPS-NRFANRHFSA-N',
#         'PUBCHEM.COMPOUND:3028194',
#         'UNII:9FN79X2M3F',
#         'CHEBI:30145'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0031217': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Hot flashes',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Hot flashes',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0031217'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'MONDO:0008114': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:Disease'],
#      'name': 'obsessive-compulsive disorder',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'obsessive-compulsive disorder',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['MESH:D009771',
#         'SNOMEDCT:191736004',
#         'NCIT:C88411',
#         'HP:0000722',
#         'MESH:D003192',
#         'UMLS:C0028768',
#         'DOID:10933',
#         'UMLS:C0600104',
#         'SNOMEDCT:12479006',
#         'EFO:0004242',
#         'OMIM:164230',
#         'MONDO:0008114'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0001686': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Loss of voice',
#      'attributes': [{'type': 'NA',
#        'value': ['Aphonia'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Loss of voice',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['SNOMEDCT:610000',
#         'UMLS:C0264598',
#         'NCIT:C79539',
#         'HP:0001686',
#         'UMLS:C0003564',
#         'UMLS:C1168304',
#         'SNOMEDCT:23187009',
#         'UMLS:C0750924',
#         'MEDDRA:10002953',
#         'SNOMEDCT:44564008',
#         'SNOMEDCT:441913003',
#         'UMLS:C0264599',
#         'MESH:D001044'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0030212': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Collectionism',
#      'attributes': [{'type': 'NA',
#        'value': 'Collectionism',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['SNOMEDCT:247968005',
#         'SNOMEDCT:277850002',
#         'UMLS:C0855230',
#         'HP:0030212',
#         'UMLS:C0424290',
#         'UMLS:C0424291',
#         'MEDDRA:10068007'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0100852': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal fear/anxiety-related behavior',
#      'attributes': [{'type': 'NA',
#        'value': 'Abnormal fear/anxiety-related behavior',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0100852', 'UMLS:C4018849'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'UMLS:C0443147': {'category': 'biolink:PhenotypicFeature',
#      'name': 'Autosomal dominant inheritance',
#      'attributes': [{'name': 'equivalent_identifiers',
#        'value': {'id': {'label': 'Autosomal dominant inheritance',
#          'identifier': 'UMLS:C0443147'},
#         'db_ids': {'UMLS': ['C0443147'],
#          'HP': ['HP:0000006'],
#          'name': ['Autosomal dominant inheritance']},
#         'type': 'PhenotypicFeature',
#         'curies': ['UMLS:C0443147', 'HP:0000006']},
#        'type': 'biolink:id'}]},
#     'CHEBI:86990': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'N-methyl-3-phenyl-3-[4-(trifluoromethyl)phenoxy]propan-1-amine',
#      'attributes': [{'type': 'NA',
#        'value': ['N-methyl-3-phenyl-3-[4-(trifluoromethyl)phenoxy]propan-1-amine'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'N-methyl-3-phenyl-3-[4-(trifluoromethyl)phenoxy]propan-1-amine',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['PUBCHEM.COMPOUND:3386',
#         'CHEMBL.COMPOUND:CHEMBL41',
#         'HMDB:HMDB0014615',
#         'CHEBI:86990',
#         'gtpo:203',
#         'INCHIKEY:ZJLJMTSAOVZZFU-BHEVMNPHSA-N',
#         'DRUGBANK:DB00472'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0200128': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Biventricular hypertrophy',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Biventricular hypertrophy',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0001714',
#         'UMLS:C0281788',
#         'UMLS:C0948228',
#         'MEDDRA:10047295',
#         'UMLS:C0340279',
#         'SNOMEDCT:266249003',
#         'HP:0200128'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0008765': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Auditory hallucinations',
#      'attributes': [{'type': 'NA',
#        'value': ['Sensory hallucination',
#         'Hallucination',
#         'Hallucinations',
#         'Gustatory aura',
#         'Gustatory auras',
#         'Taste hallucinations',
#         'Hallucinations of sound',
#         'Hearing sounds',
#         'Visual hallucinations'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Auditory hallucinations',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C0544668',
#         'MEDDRA:10019072',
#         'UMLS:C0233773',
#         'HP:0000738',
#         'UMLS:C0424083',
#         'UMLS:C0424068',
#         'MEDDRA:10019071',
#         'UMLS:C0424072',
#         'UMLS:C0424071',
#         'UMLS:C0751175',
#         'UMLS:C1456732',
#         'MEDDRA:10019070',
#         'SNOMEDCT:29139005',
#         'MEDDRA:10062684',
#         'SNOMEDCT:247734005',
#         'SNOMEDCT:66609003',
#         'SNOMEDCT:57095008',
#         'MEDDRA:10019063',
#         'MEDDRA:10019075',
#         'MEDDRA:10020927',
#         'SNOMEDCT:762620006',
#         'SNOMEDCT:57553009',
#         'SNOMEDCT:44780000',
#         'SNOMEDCT:191486006',
#         'SNOMEDCT:247733004',
#         'UMLS:C0235153',
#         'UMLS:C0563661',
#         'UMLS:C0853944',
#         'SNOMEDCT:39672001',
#         'SNOMEDCT:26433004',
#         'NCIT:C37961',
#         'UMLS:C0858844',
#         'UMLS:C3897819',
#         'UMLS:C2721589',
#         'NCIT:C118176',
#         'UMLS:C0233766',
#         'UMLS:C0233775',
#         'SNOMEDCT:69690008',
#         'SNOMEDCT:61199005',
#         'NCIT:C118175',
#         'MEDDRA:10019074',
#         'UMLS:C0233758',
#         'UMLS:C0233767',
#         'UMLS:C0233774',
#         'SNOMEDCT:247730001',
#         'SNOMEDCT:247744007',
#         'NCIT:C118179',
#         'HP:0002519',
#         'UMLS:C0029226',
#         'SNOMEDCT:285799000',
#         'UMLS:C0563608',
#         'MESH:D006212',
#         'UMLS:C0233763',
#         'UMLS:C0233762',
#         'UMLS:C0424082',
#         'UMLS:C0751176',
#         'SNOMEDCT:285744009',
#         'UMLS:C0233765',
#         'UMLS:C0233759',
#         'NCIT:C118178',
#         'NCIT:C118174',
#         'UMLS:C0018524',
#         'HP:0011160',
#         'HP:0008765',
#         'HP:0006896',
#         'UMLS:C0233776',
#         'SNOMEDCT:7011001',
#         'HP:0002367',
#         'NCIT:C118177',
#         'SNOMEDCT:64269007',
#         'SNOMEDCT:45150006'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'UMLS:C0003467': {'category': 'biolink:PhenotypicFeature',
#      'name': 'Anxiety',
#      'attributes': [{'name': 'equivalent_identifiers',
#        'value': {'id': {'label': 'Anxiety', 'identifier': 'UMLS:C0003467'},
#         'db_ids': {'UMLS': ['C0003467', 'C4020884'],
#          'HP': ['HP:0000739'],
#          'MESH': ['D001007'],
#          'name': ['Anxiety']},
#         'type': 'PhenotypicFeature',
#         'curies': ['UMLS:C0003467',
#          'UMLS:C4020884',
#          'HP:0000739',
#          'MESH:D001007']},
#        'type': 'biolink:id'}]},
#     'CHEBI:9654': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'trazodone',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'trazodone',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['KEGG:C07156',
#         'HMDB:HMDB0014794',
#         'DRUGBANK:DB00656',
#         'MESH:D014196',
#         'PUBCHEM.COMPOUND:5533',
#         'UNII:YBK48BXK30',
#         'CHEMBL.COMPOUND:CHEMBL621',
#         'gtpo:213',
#         'CHEBI:9654',
#         'INCHIKEY:RUYZJEIKQYLEGZ-UHFFFAOYSA-N'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0012638': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of nervous system physiology',
#      'attributes': [{'type': 'NA',
#        'value': 'Abnormality of nervous system physiology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0012638', 'UMLS:C4022811'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'MESH:D000069470': {'category': ['biolink:NamedThing',
#       'biolink:MolecularEntity',
#       'biolink:BiologicalEntity',
#       'biolink:ChemicalSubstance',
#       'biolink:Entity'],
#      'name': 'Venlafaxine Hydrochloride',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Venlafaxine Hydrochloride',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UNII:7D7RX5A8MO', 'MESH:D000069470'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]}},
#    'edges': {'55bff55c2003e9ce502363539bd5d6b7': {'subject': 'MESH:D015283',
#      'object': 'MONDO:0008114',
#      'predicate': 'biolink:treats',
#      'relation': None,
#      'attributes': [{'name': 'provenance',
#        'type': 'MetaInformation',
#        'value': 'https://automat.renci.org/ctd/reasonerapi'}]},
#     '79ffde9f480990646832ba02d4aee10d': {'subject': 'CHEBI:17268',
#      'object': 'HP:0012592',
#      'predicate': 'biolink:treats',
#      'relation': None,
#      'attributes': [{'name': 'provenance',
#        'type': 'MetaInformation',
#        'value': 'https://automat.renci.org/ctd/reasonerapi'}]},
#     '2c138b484a72c7f81540ec81a134346c': {'subject': 'CHEBI:7640',
#      'object': 'HP:0008765',
#      'predicate': 'biolink:treats',
#      'relation': None,
#      'attributes': [{'name': 'provenance',
#        'type': 'MetaInformation',
#        'value': 'https://automat.renci.org/ctd/reasonerapi'}]},
#     '81438c01891cbc7fda00e48b8d1a1e53': {'subject': 'CHEMBL.COMPOUND:CHEMBL1201178',
#      'object': 'MONDO:0008114',
#      'predicate': 'biolink:treats',
#      'relation': None,
#      'attributes': [{'name': 'provenance',
#        'type': 'MetaInformation',
#        'value': 'https://automat.renci.org/ctd/reasonerapi'}]},
#     'd8865ae15126595ebbe6de5fca4557d4': {'subject': 'CHEBI:8060',
#      'object': 'HP:0200128',
#      'predicate': 'biolink:treats',
#      'relation': None,
#      'attributes': [{'name': 'provenance',
#        'type': 'MetaInformation',
# ...
#      'n2': [{'id': 'CHEBI:9123'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '7526e910f9a2cf0379c6646068d7514c'}],
#      'e02': [{'id': '9a18c9a34c81dd6a07546cfcf4834ee0'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0000739'}],
#      'n2': [{'id': 'CHEBI:9123'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '7526e910f9a2cf0379c6646068d7514c'}],
#      'e02': [{'id': 'f7db9fee6b7067089162a29d6314c692'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0100716'}],
#      'n2': [{'id': 'CHEBI:9123'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '7526e910f9a2cf0379c6646068d7514c'}],
#      'e02': [{'id': '965a0176fc99fca89b9374f4b017e472'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0031217'}],
#      'n2': [{'id': 'CHEBI:7936'}, {'id': 'MESH:D000069470'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'c0ddfe44d4d3c172779b02c0eecfbf80'}],
#      'e02': [{'id': 'ad56d9c606d229acfd3c079bf7758b0e'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0012228'}],
#      'n2': [{'id': 'CHEBI:7936'}, {'id': 'MESH:D000069470'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'c0ddfe44d4d3c172779b02c0eecfbf80'}],
#      'e02': [{'id': '8f787c1cb6c9792426719296b4159f77'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0002045'}],
#      'n2': [{'id': 'CHEBI:7936'}, {'id': 'MESH:D000069470'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'c0ddfe44d4d3c172779b02c0eecfbf80'}],
#      'e02': [{'id': 'fb604ba769ef6f7a28451eb3a0318e34'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0004325'}],
#      'n2': [{'id': 'CHEBI:7936'}, {'id': 'MESH:D000069470'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'c0ddfe44d4d3c172779b02c0eecfbf80'}],
#      'e02': [{'id': 'aff6be8d02d20bc657c01b2d04b04be3'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0000716'}],
#      'n2': [{'id': 'CHEBI:7640'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '00f978f1889b471aa31d69b017400e77'}],
#      'e02': [{'id': '4758a2e0d828ab0a9c129405da0042cd'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0011675'}],
#      'n2': [{'id': 'CHEBI:7640'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '00f978f1889b471aa31d69b017400e77'}],
#      'e02': [{'id': 'b3ea49a7a045071bdfff8c376ced736b'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0001686'}],
#      'n2': [{'id': 'CHEBI:7640'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '00f978f1889b471aa31d69b017400e77'}],
#      'e02': [{'id': 'bd6a3aa36c29c88601004ae837916728'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0008765'}],
#      'n2': [{'id': 'CHEBI:7640'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '00f978f1889b471aa31d69b017400e77'}],
#      'e02': [{'id': '2c138b484a72c7f81540ec81a134346c'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0000716'}],
#      'n2': [{'id': 'CHEBI:30145'}, {'id': 'CHEBI:7640'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'a35e00be3f63c9381692f97ff0a04749'}],
#      'e02': [{'id': '4758a2e0d828ab0a9c129405da0042cd'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0011675'}],
#      'n2': [{'id': 'CHEBI:30145'}, {'id': 'CHEBI:7640'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'a35e00be3f63c9381692f97ff0a04749'}],
#      'e02': [{'id': 'b3ea49a7a045071bdfff8c376ced736b'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0001686'}],
#      'n2': [{'id': 'CHEBI:30145'}, {'id': 'CHEBI:7640'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'a35e00be3f63c9381692f97ff0a04749'}],
#      'e02': [{'id': 'bd6a3aa36c29c88601004ae837916728'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0008765'}],
#      'n2': [{'id': 'CHEBI:30145'}, {'id': 'CHEBI:7640'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'a35e00be3f63c9381692f97ff0a04749'}],
#      'e02': [{'id': '2c138b484a72c7f81540ec81a134346c'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0007430'}],
#      'n2': [{'id': 'CHEBI:5138'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '008da1672be731549b3312a8da44255a'}],
#      'e02': [{'id': 'd731cd4b433984b5294ae6fb8c5f9d02'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0007430'}],
#      'n2': [{'id': 'MESH:C035133'}, {'id': 'CHEBI:5138'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '96ffd1b8ecf497febe1b18b5064ac550'}],
#      'e02': [{'id': 'd731cd4b433984b5294ae6fb8c5f9d02'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0003124'}],
#      'n2': [{'id': 'CHEBI:17268'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'dafaf68fb9dc22d35d88782c10a98a68'}],
#      'e02': [{'id': '1774f36382f3e6f195dc7c0f0997d501'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0012592'}],
#      'n2': [{'id': 'CHEBI:17268'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'dafaf68fb9dc22d35d88782c10a98a68'}],
#      'e02': [{'id': '79ffde9f480990646832ba02d4aee10d'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0003124'}],
#      'n2': [{'id': 'CHEBI:3757'}, {'id': 'CHEBI:17268'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '29af75cec9286d1f37fa3fa8c663b972'}],
#      'e02': [{'id': '1774f36382f3e6f195dc7c0f0997d501'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0012592'}],
#      'n2': [{'id': 'CHEBI:3757'}, {'id': 'CHEBI:17268'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '29af75cec9286d1f37fa3fa8c663b972'}],
#      'e02': [{'id': '79ffde9f480990646832ba02d4aee10d'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0000716'}],
#      'n2': [{'id': 'CHEBI:9654'}, {'id': 'CHEBI:8060'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '85267a775940dcc7fd58e99766337d51'}],
#      'e02': [{'id': 'ffa8a786c78ed764841226d25872ec98'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0012228'}],
#      'n2': [{'id': 'CHEBI:9654'}, {'id': 'CHEBI:8060'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '85267a775940dcc7fd58e99766337d51'}],
#      'e02': [{'id': '2251e40933d2ecd70b3b4256ab2a2d52'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0200128'}],
#      'n2': [{'id': 'CHEBI:9654'}, {'id': 'CHEBI:8060'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '85267a775940dcc7fd58e99766337d51'}],
#      'e02': [{'id': 'd8865ae15126595ebbe6de5fca4557d4'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0001640'}],
#      'n2': [{'id': 'CHEBI:9654'}, {'id': 'CHEBI:8060'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '85267a775940dcc7fd58e99766337d51'}],
#      'e02': [{'id': '2c39467b50e29c840870f314ab785e25'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0000716'}],
#      'n2': [{'id': 'CHEBI:8060'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '811bf08b6574c29bedb0c5b2acdb73df'}],
#      'e02': [{'id': 'ffa8a786c78ed764841226d25872ec98'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0012228'}],
#      'n2': [{'id': 'CHEBI:8060'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '811bf08b6574c29bedb0c5b2acdb73df'}],
#      'e02': [{'id': '2251e40933d2ecd70b3b4256ab2a2d52'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0200128'}],
#      'n2': [{'id': 'CHEBI:8060'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '811bf08b6574c29bedb0c5b2acdb73df'}],
#      'e02': [{'id': 'd8865ae15126595ebbe6de5fca4557d4'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0001640'}],
#      'n2': [{'id': 'CHEBI:8060'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '811bf08b6574c29bedb0c5b2acdb73df'}],
#      'e02': [{'id': '2c39467b50e29c840870f314ab785e25'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0000716'}],
#      'n2': [{'id': 'CHEBI:9123'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '7526e910f9a2cf0379c6646068d7514c'}],
#      'e02': [{'id': '9a18c9a34c81dd6a07546cfcf4834ee0'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0000739'}],
#      'n2': [{'id': 'CHEBI:9123'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '7526e910f9a2cf0379c6646068d7514c'}],
#      'e02': [{'id': 'f7db9fee6b7067089162a29d6314c692'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0100716'}],
#      'n2': [{'id': 'CHEBI:9123'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '7526e910f9a2cf0379c6646068d7514c'}],
#      'e02': [{'id': '965a0176fc99fca89b9374f4b017e472'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0000716'}],
#      'n2': [{'id': 'CHEBI:3756'}, {'id': 'CHEBI:9123'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '1d1582dfe30df1c2baec6f6fb692f89c'}],
#      'e02': [{'id': '9a18c9a34c81dd6a07546cfcf4834ee0'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0000739'}],
#      'n2': [{'id': 'CHEBI:3756'}, {'id': 'CHEBI:9123'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '1d1582dfe30df1c2baec6f6fb692f89c'}],
#      'e02': [{'id': 'f7db9fee6b7067089162a29d6314c692'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0100716'}],
#      'n2': [{'id': 'CHEBI:3756'}, {'id': 'CHEBI:9123'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '1d1582dfe30df1c2baec6f6fb692f89c'}],
#      'e02': [{'id': '965a0176fc99fca89b9374f4b017e472'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0002067'}],
#      'n2': [{'id': 'MESH:D015283'}, {'id': 'MESH:D014191'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '55bff55c2003e9ce502363539bd5d6b7'}],
#      'e02': [{'id': '35d98481e7baae2ab386374bcc84c1d1'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0002067'}],
#      'n2': [{'id': 'MESH:D014191'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': '75debbef25f3e0e8650ede8a676f1080'}],
#      'e02': [{'id': '35d98481e7baae2ab386374bcc84c1d1'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0031217'}],
#      'n2': [{'id': 'CHEBI:7936'}, {'id': 'MESH:D000069470'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'c0ddfe44d4d3c172779b02c0eecfbf80'}],
#      'e02': [{'id': 'ad56d9c606d229acfd3c079bf7758b0e'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0012228'}],
#      'n2': [{'id': 'CHEBI:7936'}, {'id': 'MESH:D000069470'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'c0ddfe44d4d3c172779b02c0eecfbf80'}],
#      'e02': [{'id': '8f787c1cb6c9792426719296b4159f77'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0002045'}],
#      'n2': [{'id': 'CHEBI:7936'}, {'id': 'MESH:D000069470'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'c0ddfe44d4d3c172779b02c0eecfbf80'}],
#      'e02': [{'id': 'fb604ba769ef6f7a28451eb3a0318e34'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0004325'}],
#      'n2': [{'id': 'CHEBI:7936'}, {'id': 'MESH:D000069470'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'c0ddfe44d4d3c172779b02c0eecfbf80'}],
#      'e02': [{'id': 'aff6be8d02d20bc657c01b2d04b04be3'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0031217'}],
#      'n2': [{'id': 'MESH:D000069470'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'acd671d7a1545b479c5e7949df0cc336'}],
#      'e02': [{'id': 'ad56d9c606d229acfd3c079bf7758b0e'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0012228'}],
#      'n2': [{'id': 'MESH:D000069470'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'acd671d7a1545b479c5e7949df0cc336'}],
#      'e02': [{'id': '8f787c1cb6c9792426719296b4159f77'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0002045'}],
#      'n2': [{'id': 'MESH:D000069470'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'acd671d7a1545b479c5e7949df0cc336'}],
#      'e02': [{'id': 'fb604ba769ef6f7a28451eb3a0318e34'}]}},
#    {'node_bindings': {'n0': [{'id': 'MONDO:0008114'}],
#      'n1': [{'id': 'UMLS:C1696701'}, {'id': 'HP:0004325'}],
#      'n2': [{'id': 'MESH:D000069470'}]},
#     'edge_bindings': {'e01': [{'id': 'b22418689be35550499ffda5b9cf1c55'}],
#      'e03': [{'id': 'acd671d7a1545b479c5e7949df0cc336'}],
#      'e02': [{'id': 'aff6be8d02d20bc657c01b2d04b04be3'}]}}]},
#  'logs': []}

# %%
test={
  "message": {
    "query_graph": {
      "nodes": {
        "n0": {
          "id": "MONDO:0004979",
          "category": "biolink:Disease"
        },
        "n1": {
          "category": "biolink:ChemicalSubstance"
        }
      },
      "edges": {
        "e01": {
          "subject": "n0",
          "object": "n1",
          "predicate": "biolink:correlated_with"
        }
      }
    }
  }}

# %%
sout = strider(test)

# %%
kevin={
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "category": "biolink:ChemicalSubstance",
                    "id": "CHEBI:3215"               
                },
                "n3": {
                    "id": "PR:000031567",
                    "category": "biolink:GeneOrGeneProduct"
                 }
            },
            "edges": {
                "e03": {
                    "subject": "n0",
                    "object": "n3"
                }
            }
        }
    }
}
kout = strider(kevin)

# %%
kout
# Out:
# {'message': {'query_graph': {'nodes': {'n3': {'id': 'PR:000031567',
#      'category': 'biolink:GeneOrGeneProduct',
#      'is_set': False},
#     'n0': {'id': 'CHEBI:3215',
#      'category': 'biolink:ChemicalSubstance',
#      'is_set': False}},
#    'edges': {'e03': {'subject': 'n0',
#      'object': 'n3',
#      'predicate': None,
#      'relation': None}}},
#   'knowledge_graph': {'nodes': {}, 'edges': {}},
#   'results': []},
#  'logs': [{'code': None,
#    'message': '{"message": "Cannot find preferred prefixes for categories", "line_number": 193}',
#    'level': 'WARNING',
#    'timestamp': '2021-02-02T16:47:35.745333'},
#   {'code': None,
#    'message': '{"description": "Executing step: ", "step": [{"source_category": "biolink:Protein", "edge_predicate": "<-biolink:interacts_with-", "target_category": "biolink:ChemicalSubstance", "url": "https://stars-app.renci.org/cam-kp/query", "preferred_prefixes": {"biolink:Gene": "UniProtKB", "biolink:BiologicalProcess": "GO"}, "in_transformers": {}, "out_transformers": {}, "name": "cam"}], "line_number": 185}',
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:35.628356'},
#   {'code': None,
#    'message': '{"description": "Recieved results from KPs", "data": {"node_bindings": {"n3": [{"id": "PR:000031567"}]}, "edge_bindings": {}}, "step": {"py/object": "strider.query_planner.Step", "py/newargs": {"py/tuple": ["n3", "e03", "n0"]}, "py/seq": ["n3", "e03", "n0"]}, "line_number": 225}',
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:35.522337'},
#   {'code': None,
#    'message': '{"plan": {"py/object": "collections.defaultdict", "Step(source=\'n3\', edge=\'e03\', target=\'n0\')": [{"source_category": "biolink:Protein", "edge_predicate": "<-biolink:interacts_with-", "target_category": "biolink:ChemicalSubstance", "url": "https://stars-app.renci.org/cam-kp/query", "preferred_prefixes": {"biolink:Gene": "UniProtKB", "biolink:BiologicalProcess": "GO"}, "in_transformers": {}, "out_transformers": {}, "name": "cam"}], "Step(source=\'n0\', edge=\'e03\', target=\'n3\')": [{"source_category": "biolink:ChemicalSubstance", "edge_predicate": "-biolink:affects->", "target_category": "biolink:Protein", "url": "https://stars-app.renci.org/cam-kp/query", "preferred_prefixes": {"biolink:Gene": "UniProtKB", "biolink:BiologicalProcess": "GO"}, "in_transformers": {}, "out_transformers": {}, "name": "cam"}], "default_factory": {"py/type": "builtins.list"}}, "line_number": 151}',
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:35.387990'},
#   {'code': None,
#    'message': '{"message": "Iterating over QGs to find ones that are solvable", "line_number": 307}',
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:34.082634'},
#   {'code': None,
#    'message': '{"message": "Found 170 possible KP operations we can use", "line_number": 304}',
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:34.021996'},
#   {'code': None,
#    'message': '{"message": "Contacting KP registry to ask for KPs to solve this query graph", "line_number": 236}',
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:33.911695'},
#   {'code': None,
#    'message': '{"description": "Query graph with categorys added to curies", "expanded_qg": {"nodes": {"n3": {"id": ["PR:000031567"], "category": ["biolink:GeneOrGeneProduct", "biolink:Gene", "biolink:GeneProduct", "biolink:Transcript", "biolink:RnaProduct", "biolink:NoncodingRnaProduct", "biolink:Microrna", "biolink:RnaProductIsoform", "biolink:Protein", "biolink:ProteinIsoform"], "is_set": false}, "n0": {"id": ["CHEBI:3215"], "category": ["biolink:ChemicalSubstance"], "is_set": false}}, "edges": {"e03": {"subject": "n0", "object": "n3", "predicate": ["-biolink:related_to->", "-biolink:is_sequence_variant_of->", "-biolink:is_frameshift_variant_of->", "-biolink:is_nearby_variant_of->", "-biolink:is_synonymous_variant_of->", "-biolink:is_missense_variant_of->", "-biolink:is_nonsense_variant_of->", "-biolink:is_splice_site_variant_of->", "-biolink:is_non_coding_variant_of->", "-biolink:location_of->", "-biolink:temporally_related_to->", "-biolink:preceded_by->", "-biolink:precedes->", "-biolink:expressed_in->", "-biolink:similar_to->", "-biolink:homologous_to->", "-biolink:xenologous_to->", "-biolink:orthologous_to->", "-biolink:paralogous_to->", "-biolink:chemically_similar_to->", "-biolink:model_of->", "-biolink:coexists_with->", "-biolink:in_pathway_with->", "-biolink:in_cell_population_with->", "-biolink:colocalizes_with->", "-biolink:in_complex_with->", "-biolink:has_sequence_location->", "-biolink:subclass_of->", "-biolink:interacts_with->", "-biolink:physically_interacts_with->", "-biolink:molecularly_interacts_with->", "-biolink:decreases_molecular_interaction->", "-biolink:increases_molecular_interaction->", "-biolink:directly_interacts_with->", "-biolink:genetically_interacts_with->", "-biolink:has_gene_product->", "-biolink:correlated_with->", "-biolink:has_biomarker->", "-biolink:biomarker_for->", "-biolink:positively_correlated_with->", "-biolink:coexpressed_with->", "-biolink:negatively_correlated_with->", "-biolink:has_not_completed->", "-biolink:affects_risk_for->", "-biolink:predisposes->", "-biolink:prevents->", "-biolink:contraindicated_for->", "-biolink:affects->", "-biolink:affects_localization_of->", "-biolink:increases_localization_of->", "-biolink:decreases_localization_of->", "-biolink:regulates,_process_to_process->", "-biolink:positively_regulates,_process_to_process->", "-biolink:negatively_regulates,_process_to_process->", "-biolink:affects_degradation_of->", "-biolink:increases_degradation_of->", "-biolink:decreases_degradation_of->", "-biolink:disrupts->", "-biolink:affects_mutation_rate_of->", "-biolink:decreases_mutation_rate_of->", "-biolink:increases_mutation_rate_of->", "-biolink:affects_activity_of->", "-biolink:increases_activity_of->", "-biolink:decreases_activity_of->", "-biolink:affects_splicing_of->", "-biolink:increases_splicing_of->", "-biolink:decreases_splicing_of->", "-biolink:affects_secretion_of->", "-biolink:decreases_secretion_of->", "-biolink:increases_secretion_of->", "-biolink:affects_response_to->", "-biolink:decreases_response_to->", "-biolink:increases_response_to->", "-biolink:exacerbates->", "-biolink:affects_molecular_modification_of->", "-biolink:increases_molecular_modification_of->", "-biolink:decreases_molecular_modification_of->", "-biolink:affects_metabolic_processing_of->", "-biolink:decreases_metabolic_processing_of->", "-biolink:increases_metabolic_processing_of->", "-biolink:ameliorates->", "-biolink:treats->", "-biolink:affects_synthesis_of->", "-biolink:increases_synthesis_of->", "-biolink:decreases_synthesis_of->", "-biolink:affects_expression_in->", "-biolink:regulates,_entity_to_entity->", "-biolink:negatively_regulates,_entity_to_entity->", "-biolink:positively_regulates,_entity_to_entity->", "-biolink:affects_folding_of->", "-biolink:decreases_folding_of->", "-biolink:increases_folding_of->", "-biolink:affects_uptake_of->", "-biolink:increases_uptake_of->", "-biolink:decreases_uptake_of->", "-biolink:affects_transport_of->", "-biolink:decreases_transpor ...
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:33.710058'},
#   {'code': None,
#    'message': '{"message": "Contacting node normalizer to get categorys for curies", "line_number": 208}',
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:33.602202'},
#   {'code': None,
#    'message': '{"description": "Expanded query graph with descendants", "qg": {"nodes": {"n3": {"id": "PR:000031567", "category": ["biolink:GeneOrGeneProduct", "biolink:Gene", "biolink:GeneProduct", "biolink:Transcript", "biolink:RnaProduct", "biolink:NoncodingRnaProduct", "biolink:Microrna", "biolink:RnaProductIsoform", "biolink:Protein", "biolink:ProteinIsoform"], "is_set": false}, "n0": {"id": "CHEBI:3215", "category": ["biolink:ChemicalSubstance", "biolink:Metabolite", "biolink:Carbohydrate", "biolink:ProcessedMaterial"], "is_set": false}}, "edges": {"e03": {"subject": "n0", "object": "n3", "predicate": ["biolink:related_to", "biolink:is_sequence_variant_of", "biolink:is_frameshift_variant_of", "biolink:is_nearby_variant_of", "biolink:is_synonymous_variant_of", "biolink:is_missense_variant_of", "biolink:is_nonsense_variant_of", "biolink:is_splice_site_variant_of", "biolink:is_non_coding_variant_of", "biolink:location_of", "biolink:temporally_related_to", "biolink:preceded_by", "biolink:precedes", "biolink:expressed_in", "biolink:similar_to", "biolink:homologous_to", "biolink:xenologous_to", "biolink:orthologous_to", "biolink:paralogous_to", "biolink:chemically_similar_to", "biolink:model_of", "biolink:coexists_with", "biolink:in_pathway_with", "biolink:in_cell_population_with", "biolink:colocalizes_with", "biolink:in_complex_with", "biolink:has_sequence_location", "biolink:subclass_of", "biolink:interacts_with", "biolink:physically_interacts_with", "biolink:molecularly_interacts_with", "biolink:decreases_molecular_interaction", "biolink:increases_molecular_interaction", "biolink:directly_interacts_with", "biolink:genetically_interacts_with", "biolink:has_gene_product", "biolink:correlated_with", "biolink:has_biomarker", "biolink:biomarker_for", "biolink:positively_correlated_with", "biolink:coexpressed_with", "biolink:negatively_correlated_with", "biolink:has_not_completed", "biolink:affects_risk_for", "biolink:predisposes", "biolink:prevents", "biolink:contraindicated_for", "biolink:affects", "biolink:affects_localization_of", "biolink:increases_localization_of", "biolink:decreases_localization_of", "biolink:regulates,_process_to_process", "biolink:positively_regulates,_process_to_process", "biolink:negatively_regulates,_process_to_process", "biolink:affects_degradation_of", "biolink:increases_degradation_of", "biolink:decreases_degradation_of", "biolink:disrupts", "biolink:affects_mutation_rate_of", "biolink:decreases_mutation_rate_of", "biolink:increases_mutation_rate_of", "biolink:affects_activity_of", "biolink:increases_activity_of", "biolink:decreases_activity_of", "biolink:affects_splicing_of", "biolink:increases_splicing_of", "biolink:decreases_splicing_of", "biolink:affects_secretion_of", "biolink:decreases_secretion_of", "biolink:increases_secretion_of", "biolink:affects_response_to", "biolink:decreases_response_to", "biolink:increases_response_to", "biolink:exacerbates", "biolink:affects_molecular_modification_of", "biolink:increases_molecular_modification_of", "biolink:decreases_molecular_modification_of", "biolink:affects_metabolic_processing_of", "biolink:decreases_metabolic_processing_of", "biolink:increases_metabolic_processing_of", "biolink:ameliorates", "biolink:treats", "biolink:affects_synthesis_of", "biolink:increases_synthesis_of", "biolink:decreases_synthesis_of", "biolink:affects_expression_in", "biolink:regulates,_entity_to_entity", "biolink:negatively_regulates,_entity_to_entity", "biolink:positively_regulates,_entity_to_entity", "biolink:affects_folding_of", "biolink:decreases_folding_of", "biolink:increases_folding_of", "biolink:affects_uptake_of", "biolink:increases_uptake_of", "biolink:decreases_uptake_of", "biolink:affects_transport_of", "biolink:decreases_transport_of", "biolink:increases_transport_of", "biolink:affects_abundance_of", "biolink:decreases_abundance_of", "biolink:increases_abundance_of", "biolink:affects_stability_of", "biolink:increases_stability_of", "biolink:decreases_stabil ...
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:33.456297'},
#   {'code': None,
#    'message': '{"message": "Using BMT to get descendants of node and edge types", "line_number": 139}',
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:33.388545'},
#   {'code': None,
#    'message': '{"message": "Generating plan for query graph", "line_number": 368}',
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:33.308213'},
#   {'code': None,
#    'message': '{"message": "Generating plan", "line_number": 138}',
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:33.228941'},
#   {'code': None,
#    'message': '{"message": "Initialized strider worker", "line_number": 102}',
#    'level': 'DEBUG',
#    'timestamp': '2021-02-02T16:47:33.109065'}]}

# %%
sout['logs']
# Out:
# [{'code': None,
#   'message': '{"description": "Executing step: ", "step": [{"source_category": "biolink:Disease", "edge_predicate": "-biolink:positively_correlated_with->", "target_category": "biolink:ChemicalSubstance", "url": "https://automat.renci.org/ctd/reasonerapi", "preferred_prefixes": {"biolink:Disease": "MONDO"}, "in_transformers": {}, "out_transformers": {}, "name": "automat_ctd"}], "line_number": 185}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:30.859525'},
#  {'code': None,
#   'message': '{"description": "Recieved results from KPs", "data": {"node_bindings": {"n0": [{"id": "MONDO:0004979"}]}, "edge_bindings": {}}, "step": {"py/object": "strider.query_planner.Step", "py/newargs": {"py/tuple": ["n0", "e01", "n1"]}, "py/seq": ["n0", "e01", "n1"]}, "line_number": 225}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:30.781137'},
#  {'code': None,
#   'message': '{"plan": {"py/object": "collections.defaultdict", "Step(source=\'n0\', edge=\'e01\', target=\'n1\')": [{"source_category": "biolink:Disease", "edge_predicate": "-biolink:positively_correlated_with->", "target_category": "biolink:ChemicalSubstance", "url": "https://automat.renci.org/ctd/reasonerapi", "preferred_prefixes": {"biolink:Disease": "MONDO"}, "in_transformers": {}, "out_transformers": {}, "name": "automat_ctd"}], "Step(source=\'n1\', edge=\'e01\', target=\'n0\')": [{"source_category": "biolink:ChemicalSubstance", "edge_predicate": "<-biolink:positively_correlated_with-", "target_category": "biolink:Disease", "url": "https://automat.renci.org/ctd/reasonerapi", "preferred_prefixes": {"biolink:Disease": "MONDO"}, "in_transformers": {}, "out_transformers": {}, "name": "automat_ctd"}], "default_factory": {"py/type": "builtins.list"}}, "line_number": 151}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:30.685437'},
#  {'code': None,
#   'message': '{"message": "Iterating over QGs to find ones that are solvable", "line_number": 307}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:30.629845'},
#  {'code': None,
#   'message': '{"message": "Found 5 possible KP operations we can use", "line_number": 304}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:30.571365'},
#  {'code': None,
#   'message': '{"message": "Contacting KP registry to ask for KPs to solve this query graph", "line_number": 236}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:30.470383'},
#  {'code': None,
#   'message': '{"description": "Query graph with categorys added to curies", "expanded_qg": {"nodes": {"n0": {"id": ["MONDO:0004979"], "category": ["biolink:Disease"], "is_set": false}, "n1": {"id": null, "category": ["biolink:ChemicalSubstance", "biolink:Metabolite", "biolink:Carbohydrate", "biolink:ProcessedMaterial"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicate": ["-biolink:correlated_with->", "-biolink:has_biomarker->", "-biolink:biomarker_for->", "-biolink:positively_correlated_with->", "-biolink:coexpressed_with->", "-biolink:negatively_correlated_with->"], "relation": null}, "e01.reverse": {"subject": "n1", "object": "n0", "predicate": ["<-biolink:correlated_with-", "<-biolink:has_biomarker-", "<-biolink:biomarker_for-", "<-biolink:positively_correlated_with-", "<-biolink:coexpressed_with-", "<-biolink:negatively_correlated_with-"], "relation": null}}}, "line_number": 228}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:30.379044'},
#  {'code': None,
#   'message': '{"message": "Contacting node normalizer to get categorys for curies", "line_number": 208}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:30.299284'},
#  {'code': None,
#   'message': '{"description": "Expanded query graph with descendants", "qg": {"nodes": {"n0": {"id": "MONDO:0004979", "category": ["biolink:Disease"], "is_set": false}, "n1": {"id": null, "category": ["biolink:ChemicalSubstance", "biolink:Metabolite", "biolink:Carbohydrate", "biolink:ProcessedMaterial"], "is_set": false}}, "edges": {"e01": {"subject": "n0", "object": "n1", "predicate": ["biolink:correlated_with", "biolink:has_biomarker", "biolink:biomarker_for", "biolink:positively_correlated_with", "biolink:coexpressed_with", "biolink:negatively_correlated_with"], "relation": null}}}, "line_number": 164}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:30.218613'},
#  {'code': None,
#   'message': '{"message": "Using BMT to get descendants of node and edge types", "line_number": 139}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:30.163977'},
#  {'code': None,
#   'message': '{"message": "Generating plan for query graph", "line_number": 368}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:30.110315'},
#  {'code': None,
#   'message': '{"message": "Generating plan", "line_number": 138}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:30.056468'},
#  {'code': None,
#   'message': '{"message": "Initialized strider worker", "line_number": 102}',
#   'level': 'DEBUG',
#   'timestamp': '2021-02-02T13:42:29.978352'}]

# %%
aragorn_results=automat('uberongraph',test_query_2a)
# Out:
# 200

# %%
aragorn_results
# Out:
# {'message': {'query_graph': {'nodes': {'n0': {'id': 'MONDO:0010130',
#      'category': 'biolink:Disease',
#      'is_set': False},
#     'n1': {'id': None,
#      'category': 'biolink:BiologicalProcess',
#      'is_set': False}},
#    'edges': {'e01': {'subject': 'n0',
#      'object': 'n1',
#      'predicate': 'biolink:affects',
#      'relation': None}}},
#   'knowledge_graph': {'nodes': {}, 'edges': {}},
#   'results': []}}

# %% [markdown]
# The answer looks fine, but the first result "Thioridazine" has been recalled.  This is coming from CTD, and will be fixed in the next version, when we move CTD:Treats to CTD:Ameliorates...

# %%
GammaViewer(props={"data":aragorn_results})

# %% [markdown]
# Now do the same query, but coalesce on properties

# %%
message = one_hop_message('MONDO:0005090','disease','chemical_substance','treats',reverse=True)
aragorn_results_property=aragorn(message,'property')

# %% [markdown]
# Here we are printing the properties that are found in common across the answers.  Further parsing (not shown) can also pull out which of the results had each property.

# %%
props = []
for result in aragorn_results_property['results']:
    for pr,pv in zip(result['node_bindings'][1]['properties'],result['node_bindings'][1]['p_values']):
        props.append( (pv,pr) )
props.sort()
for pv,pr in props:
    print( pr, pv)
# Out:
# animal_metabolite 6.1604327618471825e-75
# mammalian_metabolite 6.937977255750666e-72
# metabolite 2.258575137625518e-67
# eukaryotic_metabolite 7.480816272708632e-67
# biological_role 4.1253752457842365e-66
# human_metabolite 4.769104271088552e-66
# biochemical_role 1.5928265013041155e-65
# mouse_metabolite 6.806876244474352e-55
# drugbank.approved 2.491922493462403e-45
# chemical_role 4.8569098954635195e-45
# Bronsted_acid 9.547125485999662e-42
# acid 1.0031395011128767e-41
# donor 5.131209350080362e-40
# drugbank.nutraceutical 1.1792034713339206e-39
# algal_metabolite 3.763944179487339e-38
# Daphnia_metabolite 3.9690653243595796e-36
# crustacean_metabolite 5.162694402043632e-36
# Dietary Supplements 3.8362311954412027e-32
# Supplements 4.6265572523507294e-32
# application 1.7064000257342788e-29
# Escherichia_coli_metabolite 5.160085874833554e-29
# Daphnia_magna_metabolite 5.68151216905462e-29
# Amino Acids, Peptides, and Proteins 8.764259786663723e-29
# pharmaceutical 1.0052292107905075e-25
# Amino Acids 8.457383669533408e-25
# drug 1.3516694908193193e-24
# fundamental_metabolite 1.3590901625407988e-24
# bacterial_metabolite 1.7881983218645923e-24
# prokaryotic_metabolite 2.025206909867279e-24
# Antipsychotic Agents (Second Generation [Atypical]) 1.0035555242296353e-23
# drugbank.experimental 7.851765802640238e-23
# Antipsychotic Agents 8.136431852721843e-23
# drugbank.investigational 1.1127675858680962e-22
# Neurotoxic agents 2.6468149896076045e-21
# Bronsted_base 5.285689258906532e-21
# base 5.4115337662609816e-21
# acceptor 5.540247748745373e-21
# Serotonin 5-HT1 Receptor Antagonists 5.170332048226842e-20
# Dopamine Antagonists 7.798105608529677e-20
# Adrenergic alpha-Antagonists 1.4095031742301727e-19
# antipsychotic_agent 2.8913269641787425e-19
# nutraceutical 3.3945432176343165e-19
# food_component 8.621339079784646e-19
# physiological_role 8.621339079784646e-19
# Adrenergic Antagonists 3.913339033306659e-18
# Psycholeptics 6.8801529125363056e-18
# tranquilizing_drug 1.2814105580837338e-17
# Alimentary Tract and Metabolism 1.872759903027161e-17
# Dopamine D2 Receptor Antagonists 4.2475124108644306e-17
# Adrenergic alpha-1 Receptor Antagonists 4.6942772906646067e-17
# serotonergic_drug 7.062539450998473e-17
# Serotonin 5-HT2 Receptor Antagonists 7.559253095949185e-17
# second_generation_antipsychotic 1.6103441857036266e-16
# pharmacological_role 2.1785401078907232e-16
# serotonergic_antagonist 4.59583658436968e-16
# Serotonin Receptor Antagonists 4.916118495974537e-16
# Central Nervous System Depressants 7.710560017727774e-16
# psychotropic_drug 1.1092112048963335e-15
# Hyperglycemia-Associated Agents 1.4747267189029369e-15
# central_nervous_system_depressant 1.6244971733315203e-15
# Agents that produce hypertension 6.769119643784645e-15
# Serotonin Agents 2.102065802377508e-14
# Nervous System 2.5717622094168313e-14
# dopaminergic_antagonist 5.5453462205439386e-14
# central_nervous_system_drug 8.21489126187464e-14
# nutrient 1.148022539233178e-13
# neurotransmitter_agent 1.1977078852313394e-13
# Antidepressive Agents 1.314047340392872e-13
# Serotonergic Drugs Shown to Increase Risk of Serotonin Syndrome 1.314047340392872e-13
# molecular_messenger 1.7586107786270888e-13
# plant_metabolite 2.7388040588996295e-13
# Saccharomyces_cerevisiae_metabolite 3.1330468846906477e-13
# Histamine H1 Antagonists 4.560503652947241e-13
# Tranquilizing Agents 5.627950311407807e-13
# Cytochrome P-450 CYP3A7 Substrates 1.0076084456350478e-12
# Histamine Antagonists 1.0076084456350478e-12
# fungal_metabolite 1.988686188954495e-12
# QTc Prolonging Agents 2.2010054171764296e-12
# dopaminergic_agent 2.428090236380038e-12
# micronutrient 3.4598832409169472e-12
# Psychotropic Drugs 8.990793888134335e-12
# Lipids 9.703964505989182e-12
# Cytochrome P-450 CYP3A5 Substrates 1.2313667825238363e-11
# Neurotransmitter Agents 1.5222920151436775e-11
# Daphnia_galeata_metabolite 1.5694163225458747e-11
# Biogenic Amines 1.992529598357752e-11
# agonist 4.492023073046882e-11
# neurotransmitter_agent 8.113204840512263e-11
# Amino Acids, Essential 9.896610959693412e-11
# pharmacological_role 1.0821374965116767e-10
# Fatty Acids 1.272181853065015e-10
# oral 1.340254774819494e-10
# Cytochrome P-450 CYP3A4 Substrates (strength unknown) 1.4000311024193627e-10
# Acid Preparations 1.4243497463237243e-10
# Digestives, Incl. Enzymes 1.4243497463237243e-10
# Cytochrome P-450 CYP3A4 Substrates 1.434523530810835e-10
# Cytochrome P-450 CYP3A Substrates 1.5056277089464102e-10
# Steroids 3.5221518112038536e-10
# neurotransmitter 5.306148849007473e-10
# therapeutic_flag 6.367565854851391e-10
# adrenergic_antagonist 9.581567433241416e-10
# histamine_antagonist 9.885030744011303e-10
# histaminergic_drug 1.4115798598221684e-09
# Amino Acids, Neutral 2.2183134794967923e-09
# EC_3.1.*_(ester_hydrolase)_inhibitor 2.7170128873200934e-09
# Biogenic Monoamines 3.599875678080783e-09
# drugbank.approved 3.94060589833218e-09
# hormone 4.64804161446002e-09
# Central Nervous System Agents 5.465942268313836e-09
# therapeutic_flag 6.526416665276725e-09
# Amines 6.6235012414534054e-09
# Hormones 7.853979750905847e-09
# Keto Acids 1.2930149989577482e-08
# osmolyte 1.6158763945504494e-08
# Cytochrome P-450 CYP2D6 Substrates 1.8108387484497853e-08
# adrenergic_agent 1.865544591546212e-08
# parenteral 2.113931258794928e-08
# EC_3.1.1.1_(carboxylesterase)_inhibitor 2.4137638482249412e-08
# Hormones, Hormone Substitutes, and Hormone Antagonists 2.8214025031276597e-08
# Highest Risk QTc-Prolonging Agents 3.0621241280924864e-08
# Amino Acids, Acidic 4.043658007474809e-08
# Acids, Acyclic 4.761820743324027e-08
# Indole Derivatives 5.938776319553747e-08
# Amino Acids, Dicarboxylic 6.277284928306055e-08
# Hyperglycemia-Associated Agents 6.477800450843717e-08
# Cytochrome P-450 CYP3A7 Substrates 6.718236721795309e-08
# drug 8.531671092933082e-08
# Gastrointestinal Agents 8.889360674184032e-08
# pharmaceutical 9.477588641456775e-08
# Dopamine Agents 9.96454977188345e-08
# drugbank.investigational 1.0301724840349872e-07
# enzyme_inhibitor 1.187943436024309e-07
# dopaminergic_agent 1.3481156591130436e-07
# antagonist 1.4720907507372655e-07
# Amino Acids, Basic 1.754228568579842e-07
# Muscarinic Antagonists 1.9705602588627019e-07
# OCT1 substrates 2.115364753676069e-07
# Amino Acids, Diamino 2.5227898430018435e-07
# inhibitor 2.5316839066851564e-07
# Compounds used in a research, industrial, or household setting 3.246929517282986e-07
# Sulfur Compounds 4.04003210957645e-07
# EC_3.*_(hydrolase)_inhibitor 4.2363433525448013e-07
# Anticholinergic Agents 5.057214242696074e-07
# Autonomic Agents 5.31234052024384e-07
# Autacoids 5.714002509349929e-07
# Inflammation Mediators 6.093457130961337e-07
# Fatty Acids, Unsaturated 7.778373835698236e-07
# Gonadal Hormones 1.0844359113212776e-06
# Gonadal Steroid Hormones 1.0844359113212776e-06
# Potential QTc-Prolonging Agents 1.1180097376571235e-06
# EC_3.1.1.*_(carboxylic_ester_hydrolase)_inhibitor 1.3010132024993036e-06
# Dopamine D2 Receptor Antagonists 1.3278967372364564e-06
# Amino Acids, Cyclic 1.3939533364223423e-06
# dopaminergic_antagonist 1.3939533364223423e-06
# Glutamates 1.635538093676659e-06
# application 1.7083464608086503e-06
# Dopamine Antagonists 2.00239039145345e-06
# Fatty Acids, Essential 2.289255170984054e-06
# Antipsychotic Agents 2.3634025978008177e-06
# Cytochrome P-450 CYP3A4 Inhibitors 2.9682318771318514e-06
# P-glycoprotein/ABCB1 Inhibitors 3.0507201426868415e-06
# Basic Ointments and Protectants 3.051676178327677e-06
# antipsychotic_agent 3.448615322890704e-06
# Cytochrome P-450 CYP3A Inhibitors 3.535127743276911e-06
# Dopamine Agents 3.6990858780202798e-06
# COMT Substrates 3.922730083092795e-06
# Excitatory Amino Acids 3.922730083092795e-06
# Tryptamines 3.922730083092795e-06
# serotonergic_antagonist 4.2355555282061096e-06
# Pregnanes 5.132998291471528e-06
# Tranquilizing Agents 5.457916940737376e-06
# protective_agent 5.7864831849789105e-06
# CYP3A Substrates (Sensitive) 9.773431821369826e-06
# Biological Factors 1.0216415727692348e-05
# Cytochrome P-450 CYP3A4 Inhibitors (moderate) 1.2582188161840417e-05
# Peptides 1.2642385205495612e-05
# Psycholeptics 1.2933259010358229e-05
# Peripheral Nervous System Agents 1.5190654348099409e-05
# Adrenal Cortex Hormones 1.5420528404343072e-05
# tranquilizing_drug 1.677425385309772e-05
# antagonist 1.7793075112290662e-05
# Adrenergic and Dopaminergic Agents 1.8592477278372498e-05
# Androstenols 1.8592477278372498e-05
# food_acidity_regulator 1.8592477278372498e-05
# Hydroxycorticosteroids 2.0653815128675024e-05
# Ophthalmologicals 2.2124037175724898e-05
# Neurotransmitter Agents 2.2743214953011352e-05
# Antipsychotic Agents (First Generation [Typical]) 2.2822936255374843e-05
# Cytochrome P-450 CYP2D6 Inhibitors (weak) 2.380333498021585e-05
# antioxidant 2.6533407867761827e-05
# Psychotropic Drugs 2.7999287608687755e-05
# Cytochrome P-450 CYP3A5 Substrates 3.370393008159795e-05
# serotonergic_drug 3.42573639252474e-05
# Central Nervous System Depressants 3.4710254946234816e-05
# OCT2 Substrates 3.52828215659713e-05
# OCT2 substrates with narrow therapeutic index 3.52828215659713e-05
# Cytochrome P-450 CYP1A2 Substrates 3.595338864524679e-05
# Catecholamines 3.809716125201571e-05
# H1_receptor_antagonist 3.855121747764854e-05
# Cardiac Stimulants Excl. Cardiac Glycosides 4.101879089189786e-05
# Cytochrome P-450 Enzyme Inhibitors 4.399738552789521e-05
# Anti-Dyskinesia Agents 4.404763998970191e-05
# Stomatological Preparations 4.404763998970191e-05
# Testosterone Congeners 4.404763998970191e-05
# Cytochrome P-450 CYP3A4 Substrates with a Narrow Therapeutic Index 4.487110419490044e-05
# cholinergic_drug 4.593376278963682e-05
# Sugar Alcohols 5.0426715917029043e-05
# Dicarboxylic Acids 5.377680211625141e-05
# Central Nervous System Agents 5.819561983401618e-05
# Antiglaucoma Preparations and Miotics 6.0797720004380126e-05
# Pregnenes 6.0797720004380126e-05
# Agents producing tachycardia 6.239464650090357e-05
# Androstenes 6.446841144798786e-05
# Antiemetics 6.446841144798786e-05
# first_generation_antipsychotic 6.446841144798786e-05
# food_additive 7.280744595664197e-05
# Nasal Preparations 8.442138987851395e-05
# Antidotes 8.873139981131722e-05
# Dermatologicals 9.364539340894273e-05
# parenteral 9.671199637454753e-05
# Osmotic Laxative 9.767027474172386e-05

# %% [markdown]
# Again, the same query but coalescing on ontology subclasses

# %%
message = one_hop_message('MONDO:0005090','disease','chemical_substance','treats',reverse=True)
aragorn_results_ontology=aragorn(message,'ontology')

# %%
#Extract the new nodes
nb = [r['node_bindings'] for r in aragorn_results_ontology['results'] ]
parents = [ [xi['kg_id'][0] for xi in x if (xi['qg_id']=='extra_qn_0')][0] for x in nb ]

#AC isn't returning labels (in process to be fixed) so get the labels from NN
result = requests.get('https://nodenormalization-sri.renci.org/get_normalized_nodes',
                     params={'curie':parents})
x = result.json()

#And print out the superclasses
for xid, xv in x.items():
    print(xid, xv['id']['label'])
# Out:
# CHEBI:72695 organic molecule
# CHEBI:37577 heteroatomic molecular entity
# CHEBI:24651 hydroxides
# CHEBI:36586 carbonyl compound
# CHEBI:64709 organic acid
# CHEBI:33575 carboxylic acid
# CHEBI:25384 monocarboxylic acid
# CHEBI:27369 zwitterion
# CHEBI:33704 alpha-amino acid
# CHEBI:35366 fatty acid
# CHEBI:15705 L-alpha-amino acid
# CHEBI:38166 organic heteropolycyclic compound
# CHEBI:35350 hydroxy steroid
# CHEBI:25693 organic heteromonocyclic compound
# CHEBI:35238 amino acid zwitterion
# CHEBI:15904 long-chain fatty acid
# CHEBI:83813 proteinogenic amino acid
# CHEBI:35789 oxo steroid
# CHEBI:26167 polar amino acid
# CHEBI:59202 straight-chain fatty acid
# CHEBI:61313 C21-steroid
# CHEBI:39418 straight-chain saturated fatty acid
# CHEBI:26144 piperazines
# CHEBI:36885 20-oxo steroid
# CHEBI:58168 1-O-acyl-sn-glycero-3-phosphocholine
# CHEBI:22658 aspartate family amino acid
# CHEBI:46848 N-arylpiperazine
# CHEBI:55505 1,2-benzisothiazole
# CHEBI:51545 1,2-benzoxazoles
# CHEBI:145810 insulin

# %% [markdown]
# Finally, the same query but with graph coalescence

# %%
message = one_hop_message('MONDO:0005090','disease','chemical_substance','treats',reverse=True)
aragorn_results_graph=aragorn(message,'graph')

# %%
nb = [r['node_bindings'] for r in aragorn_results_graph['results'] ]
eb = [r['edge_bindings'] for r in aragorn_results_graph['results']]
extra_nodes = [ [xi['kg_id'][0] for xi in x if (xi['qg_id']=='extra_qn_0')][0] for x in nb ]
extra_edges = [ [xi['kg_id'] for xi in x if (xi['qg_id']=='extra_qe_0')] for x in eb ]

# %%
result = requests.get('https://nodenormalization-sri.renci.org/get_normalized_nodes',
                     params={'curie':extra_nodes})
x = result.json()

# %%
from collections import defaultdict
edges = {e['id']:e['type'] for e in aragorn_results_graph['knowledge_graph']['edges']}
groupy = defaultdict(list)
for extra_node, extra_edge in zip(extra_nodes, extra_edges):
    nn = x[extra_node]
    if nn is None or 'label' not in nn['id']:
        label = extra_node
    else:
        label = nn['id']
    #print(extra_edge)
    #print(label,edges[extra_edge[0]])
    groupy[edges[extra_edge[0]]].append(label)
    #print(extra_node, aragorn_results_graph['knowledge_graph']['edges'][extra_edge])
    
for etype,labels in groupy.items():
    print(etype)
    print('---------------------')
    for l in labels:
        print(l)
    print('')
# Out:
# related_to
# ---------------------
# {'identifier': 'MONDO:0005090', 'label': 'schizophrenia (disease)'}
# {'identifier': 'MONDO:0005335', 'label': 'colorectal neoplasm'}
# UMLS:C0009402
# {'identifier': 'MONDO:0005361', 'label': 'eosinophilic esophagitis'}
# {'identifier': 'MONDO:0005101', 'label': 'ulcerative colitis (disease)'}
# {'identifier': 'MONDO:0009960', 'label': 'inflammatory bowel disease 1'}
# {'identifier': 'MONDO:0004975', 'label': 'Alzheimer disease'}
# UMLS:C0032961
# {'identifier': 'MONDO:0017276', 'label': 'frontotemporal dementia'}
# {'identifier': 'MONDO:0007488', 'label': 'Lewy body dementia'}
# {'identifier': 'MONDO:0005052', 'label': 'irritable bowel syndrome'}
# UMLS:C3871280
# {'identifier': 'MONDO:0005192', 'label': 'exocrine pancreatic carcinoma'}
# {'identifier': 'MONDO:0011122', 'label': 'obesity disorder'}
# {'identifier': 'MONDO:0005027', 'label': 'epilepsy'}
# {'identifier': 'MONDO:0002635', 'label': 'periodontal disease'}
# {'identifier': 'MONDO:0005059', 'label': 'leukemia (disease)'}
# {'identifier': 'MONDO:0015681', 'label': 'childhood disintegrative disorder'}
# {'identifier': 'MONDO:0011730', 'label': 'fumaric aciduria'}
# {'identifier': 'MONDO:0005138', 'label': 'lung carcinoma'}
# {'identifier': 'MONDO:0009563', 'label': 'maple syrup urine disease'}
# {'identifier': 'MONDO:0011628', 'label': 'propionic acidemia'}
# {'identifier': 'MONDO:0009861', 'label': 'phenylketonuria'}
# {'identifier': 'MONDO:0008383', 'label': 'rheumatoid arthritis'}
# {'identifier': 'MONDO:0015268', 'label': 'medullary sponge kidney'}
# {'identifier': 'MONDO:0020642', 'label': 'polycystic kidney disease'}
# {'identifier': 'CHEBI:59869', 'label': 'L-alpha-amino acid zwitterion'}
# UMLS:C0268491
# {'identifier': 'MONDO:0014576', 'label': 'lipoyl transferase 1 deficiency'}
# {'identifier': 'MONDO:0008815', 'label': 'argininosuccinic aciduria'}
# {'identifier': 'MONDO:0005393', 'label': 'gout'}
# {'identifier': 'MONDO:0005009', 'label': 'congestive heart failure'}
# {'identifier': 'MONDO:0007008', 'label': 'uremia'}
# {'identifier': 'MONDO:0005147', 'label': 'type 1 diabetes mellitus'}
# {'identifier': 'MONDO:0005420', 'label': 'hypothyroidism'}
# {'identifier': 'MONDO:0011614', 'label': '3-hydroxy-3-methylglutaryl-CoA synthase deficiency'}
# {'identifier': 'MONDO:0009529', 'label': 'pyruvate dehydrogenase E3 deficiency'}
# {'identifier': 'MONDO:0012084', 'label': 'aromatic L-amino acid decarboxylase deficiency'}
# {'identifier': 'MONDO:0011601', 'label': 'neonatal intrahepatic cholestasis due to citrin deficiency'}
# UMLS:C0238343
# {'identifier': 'MONDO:0009377', 'label': 'hyperammonemia due to N-acetylglutamate synthase deficiency'}
# UMLS:C0268543
# {'identifier': 'MONDO:0005300', 'label': 'chronic kidney disease'}
# {'identifier': 'MONDO:0012407', 'label': 'pyridoxal phosphate-responsive seizures'}
# {'identifier': 'CHEBI:73379', 'label': 'Ala-Phe-Trp-Asn'}
#
# treats
# ---------------------
# {'identifier': 'MONDO:0005090', 'label': 'schizophrenia (disease)'}
# {'identifier': 'MONDO:0004985', 'label': 'bipolar disorder'}
# {'identifier': 'MONDO:0001220', 'label': 'hypoparathyroidism'}
# {'identifier': 'MONDO:0002050', 'label': 'depressive disorder'}
# {'identifier': 'MONDO:0005485', 'label': 'psychotic disorder'}
# {'identifier': 'MONDO:0002025', 'label': 'psychiatric disorder'}
# {'identifier': 'MONDO:0011552', 'label': 'SCZD10'}
# {'identifier': 'MONDO:0005146', 'label': 'post-traumatic stress disorder'}
# {'identifier': 'MONDO:0003996', 'label': 'basal ganglia disease'}
#
# subclass_of
# ---------------------
# {'identifier': 'CHEBI:33608', 'label': 'hydrogen molecular entity'}
# {'identifier': 'CHEBI:33674', 'label': 's-block molecular entity'}
# {'identifier': 'CHEBI:24651', 'label': 'hydroxides'}
# {'identifier': 'CHEBI:36586', 'label': 'carbonyl compound'}
# {'identifier': 'CHEBI:36587', 'label': 'organic oxo compound'}
# {'identifier': 'CHEBI:64709', 'label': 'organic acid'}
# {'identifier': 'CHEBI:33575', 'label': 'carboxylic acid'}
# {'identifier': 'CHEBI:24833', 'label': 'oxoacid'}
# {'identifier': 'CHEBI:35605', 'label': 'carbon oxoacid'}
# {'identifier': 'CHEBI:50047', 'label': 'organic amino compound'}
# {'identifier': 'CHEBI:27369', 'label': 'zwitterion'}
# {'identifier': 'CHEBI:51151', 'label': 'dipolar compound'}
# {'identifier': 'CHEBI:25384', 'label': 'monocarboxylic acid'}
# {'identifier': 'CHEBI:35238', 'label': 'amino acid zwitterion'}
# {'identifier': 'CHEBI:33704', 'label': 'alpha-amino acid'}
# {'identifier': 'CHEBI:15705', 'label': 'L-alpha-amino acid'}
# {'identifier': 'CHEBI:33709', 'label': 'amino acid'}
# {'identifier': 'CHEBI:83813', 'label': 'proteinogenic amino acid'}
# {'identifier': 'CHEBI:26167', 'label': 'polar amino acid'}
# {'identifier': 'CHEBI:39418', 'label': 'straight-chain saturated fatty acid'}
#
# decreases_activity_of
# ---------------------
# {'identifier': 'NCBIGene:117247', 'label': 'SLC16A10'}
# {'identifier': 'NCBIGene:5444', 'label': 'PON1'}
#
# contraindicated_for
# ---------------------
# {'identifier': 'MONDO:0005240', 'label': 'kidney disease'}
# {'identifier': 'MONDO:0019259', 'label': 'classic phenylketonuria'}
# {'identifier': 'HP:0002150', 'label': 'Hypercalciuria'}
# UMLS:C0022650
# {'identifier': 'MONDO:0001566', 'label': 'hypercalcemia disease'}
# {'identifier': 'MONDO:0000190', 'label': 'ventricular fibrillation (disease)'}
# {'identifier': 'MONDO:0019338', 'label': 'sarcoidosis'}
# {'identifier': 'MONDO:0005267', 'label': 'heart disease'}
# {'identifier': 'MONDO:0017863', 'label': 'digitalis poisoning'}
# {'identifier': 'MONDO:0005300', 'label': 'chronic kidney disease'}
# {'identifier': 'MONDO:0043455', 'label': 'humoral hypercalcemia of malignancy'}
# {'identifier': 'MONDO:0010096', 'label': 'tardive dyskinesia (disease)'}
# {'identifier': 'MONDO:0019790', 'label': 'neuroleptic malignant syndrome'}
# {'identifier': 'MONDO:0005469', 'label': 'orthostatic hypotension (disease)'}
#
# contributes_to
# ---------------------
# {'identifier': 'HP:0002354', 'label': 'Memory impairment'}
# {'identifier': 'MONDO:0045057', 'label': 'delirium'}
# {'identifier': 'MONDO:0005359', 'label': 'drug-induced liver injury'}
# {'identifier': 'MONDO:0019790', 'label': 'neuroleptic malignant syndrome'}
# {'identifier': 'MONDO:0002039', 'label': 'cognitive disorder'}
# {'identifier': 'MONDO:0003996', 'label': 'basal ganglia disease'}
# {'identifier': 'MONDO:0016058', 'label': 'paroxysmal dystonia'}
# {'identifier': 'MONDO:0005478', 'label': 'torsades de pointes'}
# {'identifier': 'MONDO:0005395', 'label': 'movement disorder'}
# {'identifier': 'MONDO:0006731', 'label': 'drug-induced akathisia'}
# {'identifier': 'MONDO:0001442', 'label': 'dysthymic disorder'}
# {'identifier': 'MONDO:0005466', 'label': 'hypersomnia (disease)'}
# {'identifier': 'MONDO:0005044', 'label': 'hypertensive disorder'}
# {'identifier': 'MONDO:0011728', 'label': 'blepharospasm'}
# {'identifier': 'HP:0001662', 'label': 'Bradycardia'}
# {'identifier': 'MONDO:0005804', 'label': 'hyperprolactinemia (disease)'}
# {'identifier': 'MONDO:0004790', 'label': 'fatty liver disease'}
# {'identifier': 'MONDO:0000947', 'label': 'psychosexual disorder'}
# {'identifier': 'MONDO:0002442', 'label': 'long QT syndrome'}
# {'identifier': 'MONDO:0001821', 'label': 'hypoactive sexual desire disorder'}
# {'identifier': 'MONDO:0006732', 'label': 'drug-induced dyskinesia'}
# {'identifier': 'MONDO:0006966', 'label': 'secondary Parkinson disease'}
# {'identifier': 'HP:0005986', 'label': 'Limitation of neck motion'}
# {'identifier': 'MONDO:0001152', 'label': 'amnestic disorder'}
# {'identifier': 'MONDO:0005362', 'label': 'erectile dysfunction (disease)'}
# {'identifier': 'HP:0000855', 'label': 'Insulin resistance'}
# {'identifier': 'MONDO:0002125', 'label': 'status epilepticus'}
# {'identifier': 'MONDO:0006802', 'label': 'inappropriate ADH syndrome'}
# {'identifier': 'MONDO:0003969', 'label': 'amphetamine abuse'}
# {'identifier': 'MONDO:0015681', 'label': 'childhood disintegrative disorder'}
# {'identifier': 'MONDO:0005689', 'label': 'cannabis dependence'}
#
# increases_activity_of
# ---------------------
# {'identifier': 'NCBIGene:836', 'label': 'CASP3'}
# {'identifier': 'NCBIGene:5595', 'label': 'MAPK3'}
# IUPHAR:55
#
# interacts_with
# ---------------------
# {'identifier': 'NCBIGene:117247', 'label': 'SLC16A10'}
# {'identifier': 'NCBIGene:374569', 'label': 'ASPG'}
# {'identifier': 'NCBIGene:443', 'label': 'ASPA'}
# {'identifier': 'NCBIGene:95', 'label': 'ACY1'}
# {'identifier': 'NCBIGene:91703', 'label': 'ACY3'}
# {'identifier': 'NCBIGene:97', 'label': 'ACYP1'}
# {'identifier': 'NCBIGene:98', 'label': 'ACYP2'}
# {'identifier': 'NCBIGene:590', 'label': 'BCHE'}
# {'identifier': 'NCBIGene:2194', 'label': 'FASN'}
# {'identifier': 'NCBIGene:570', 'label': 'BAAT'}
# {'identifier': 'NCBIGene:221223', 'label': 'CES5A'}
# {'identifier': 'NCBIGene:8824', 'label': 'CES2'}
# {'identifier': 'NCBIGene:2628', 'label': 'GATM'}
# {'identifier': 'NCBIGene:1644', 'label': 'DDC'}
# {'identifier': 'NCBIGene:23491', 'label': 'CES3'}
# {'identifier': 'NCBIGene:259307', 'label': 'IL4I1'}
# {'identifier': 'NCBIGene:10999', 'label': 'SLC27A4'}
# UniProtKB:Q53FV7
# UniProtKB:Q6FHZ7
# UniProtKB:Q6L9M1
# UniProtKB:Q9UEF6
# {'identifier': 'NCBIGene:883', 'label': 'KYAT1'}
# {'identifier': 'NCBIGene:28965', 'label': 'SLC27A6'}
# UniProtKB:A2RRE8
# UniProtKB:A5PLL0
# UniProtKB:Q53EW1
# UniProtKB:Q86WD1
# {'identifier': 'NCBIGene:204851', 'label': 'HIPK1'}
# {'identifier': 'NCBIGene:29124', 'label': 'LGALS13'}
# {'identifier': 'NCBIGene:50640', 'label': 'PNPLA8'}
# {'identifier': 'NCBIGene:11000', 'label': 'SLC27A3'}
# {'identifier': 'NCBIGene:189', 'label': 'AGXT'}
# {'identifier': 'NCBIGene:56267', 'label': 'KYAT3'}
#
# causes_adverse_event
# ---------------------
# {'identifier': 'MONDO:0003233', 'label': 'essential tremor'}
# {'identifier': 'MONDO:0004901', 'label': 'lingual-facial-buccal dyskinesia'}
# {'identifier': 'MONDO:0019790', 'label': 'neuroleptic malignant syndrome'}
# {'identifier': 'MONDO:0004745', 'label': 'priapism'}
# {'identifier': 'MONDO:0010096', 'label': 'tardive dyskinesia (disease)'}
# {'identifier': 'MONDO:0016812', 'label': 'dopa-responsive dystonia'}
#
# directly_interacts_with
# ---------------------
# {'identifier': 'NCBIGene:222545', 'label': 'GPRC6A'}
#
# increases_degradation_of
# ---------------------
# {'identifier': 'NCBIGene:259307', 'label': 'IL4I1'}

# %%
with open('treatsSchizophrenia_nc.json','w') as outf:
    json.dump(aragorn_results,outf,indent=2)

# %% [markdown]
# Fin.

# %%
#Target for aspirin
message= one_hop_message('CHEBI:15365','chemical_substance','gene','related_to')
results = striderandfriends(message)

# %%
print(json.dumps(results,indent=4))
# Out:
# {
#     "query_graph": {
#         "nodes": [
#             {
#                 "id": "a",
#                 "curie": "CHEBI:15365",
#                 "type": "chemical_substance"
#             },
#             {
#                 "id": "b",
#                 "type": "gene",
#                 "set": true
#             },
#             {
#                 "id": "extra_qn_0",
#                 "type": [
#                     "named_thing",
#                     "ontology_class",
#                     "organism_taxon"
#                 ]
#             }
#         ],
#         "edges": [
#             {
#                 "id": "ab",
#                 "source_id": "a",
#                 "target_id": "b",
#                 "type": "related_to"
#             },
#             {
#                 "id": "extra_qe_0",
#                 "source_id": "b",
#                 "target_id": "extra_qn_0"
#             }
#         ]
#     },
#     "knowledge_graph": {
#         "nodes": [
#             {
#                 "id": "CHEBI:15365",
#                 "type": "chemical_substance",
#                 "name": "CHEBI:15365",
#                 "omnicorp_article_count": 87627,
#                 "equivalent_identifiers": [
#                     "HMDB:HMDB0001879",
#                     "INCHIKEY:TWUMMOVNTDJLHR-UHFFFAOYSA-N",
#                     "PUBCHEM:2244",
#                     "CHEBI:15365",
#                     "GTOPDB:4139",
#                     "MESH:D001241",
#                     "DRUGBANK:DB00945",
#                     "KEGG.COMPOUND:C01405",
#                     "CHEMBL.COMPOUND:CHEMBL25",
#                     "UNII:R16CO5Y76E"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:9536",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "molecular_entity",
#                     "genomic_entity",
#                     "gene_or_gene_product",
#                     "gene",
#                     "macromolecular_machine"
#                 ],
#                 "name": "PTGES",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "HGNC:9599",
#                     "ENSEMBL:ENSG00000148344",
#                     "IUPHAR:1377",
#                     "NCBIGene:9536",
#                     "UniProtKB:O14684",
#                     "NCBIGene:9536"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:101180976",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "molecular_entity",
#                     "genomic_entity",
#                     "gene_or_gene_product",
#                     "gene",
#                     "macromolecular_machine"
#                 ],
#                 "name": "IFNL4",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:101180976",
#                     "ENSEMBL:ENSG00000272395",
#                     "UniProtKB:K9M1U5",
#                     "NCBIGene:101180976",
#                     "HGNC:44480"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:11251",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "molecular_entity",
#                     "genomic_entity",
#                     "gene_or_gene_product",
#                     "gene",
#                     "macromolecular_machine"
#                 ],
#                 "name": "PTGDR2",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:Q9Y5Y4",
#                     "IUPHAR:339",
#                     "HGNC:4502",
#                     "NCBIGene:11251",
#                     "NCBIGene:11251",
#                     "ENSEMBL:ENSG00000183134"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:5914",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "RARA",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:5914",
#                     "UniProtKB:P10276",
#                     "HGNC:9864",
#                     "ENSEMBL:ENSG00000131759",
#                     "NCBIGene:5914",
#                     "IUPHAR:590"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:4056",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "molecular_entity",
#                     "genomic_entity",
#                     "gene_or_gene_product",
#                     "gene",
#                     "macromolecular_machine"
#                 ],
#                 "name": "LTC4S",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:4056",
#                     "HGNC:6719",
#                     "NCBIGene:4056",
#                     "UniProtKB:Q16873",
#                     "ENSEMBL:ENSG00000213316",
#                     "IUPHAR:1391"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:65057",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "ACD",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:65057",
#                     "NCBIGene:65057",
#                     "HGNC:25070",
#                     "UniProtKB:Q96AP0",
#                     "ENSEMBL:ENSG00000102977"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:929",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "CD14",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "ENSEMBL:ENSG00000170458",
#                     "HGNC:1628",
#                     "NCBIGene:929",
#                     "UniProtKB:P08571",
#                     "NCBIGene:929"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:462",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "molecular_entity",
#                     "genomic_entity",
#                     "gene_or_gene_product",
#                     "gene",
#                     "macromolecular_machine"
#                 ],
#                 "name": "SERPINC1",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "ENSEMBL:ENSG00000117601",
#                     "HGNC:775",
#                     "NCBIGene:462",
#                     "NCBIGene:462",
#                     "UniProtKB:P01008",
#                     "IUPHAR:2632"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:3266",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "ERAS",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:3266",
#                     "HGNC:5174",
#                     "UniProtKB:Q7Z444",
#                     "NCBIGene:3266",
#                     "ENSEMBL:ENSG00000187682"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:160622",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "GRASP",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:160622",
#                     "UniProtKB:Q7Z6J2",
#                     "NCBIGene:160622",
#                     "HGNC:18707",
#                     "ENSEMBL:ENSG00000161835"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:5091",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "PC",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "ENSEMBL:ENSG00000173599",
#                     "UniProtKB:P11498",
#                     "HGNC:8636",
#                     "IUPHAR:1262",
#                     "NCBIGene:5091",
#                     "NCBIGene:5091"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:326",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "AIRE",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:O43918",
#                     "HGNC:360",
#                     "NCBIGene:326",
#                     "NCBIGene:326",
#                     "ENSEMBL:ENSG00000160224"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:640",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "BLK",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:640",
#                     "NCBIGene:640",
#                     "IUPHAR:1940",
#                     "UniProtKB:P51451",
#                     "ENSEMBL:ENSG00000136573",
#                     "HGNC:1057"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:22858",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "CILK1",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "IUPHAR:2038",
#                     "HGNC:21219",
#                     "ENSEMBL:ENSG00000112144",
#                     "NCBIGene:22858",
#                     "NCBIGene:22858",
#                     "UniProtKB:Q9UPZ9"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:790",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "CAD",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "HGNC:1424",
#                     "ENSEMBL:ENSG00000084774",
#                     "NCBIGene:790",
#                     "UniProtKB:P27708",
#                     "NCBIGene:790"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:80271",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "ITPKC",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:Q96DU7",
#                     "ENSEMBL:ENSG00000086544",
#                     "NCBIGene:80271",
#                     "HGNC:14897",
#                     "NCBIGene:80271",
#                     "IUPHAR:1449"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:5447",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "POR",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:5447",
#                     "UniProtKB:P16435",
#                     "NCBIGene:5447",
#                     "ENSEMBL:ENSG00000127948",
#                     "HGNC:9208"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:5805",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "PTS",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:5805",
#                     "UniProtKB:Q03393",
#                     "HGNC:9689",
#                     "ENSEMBL:ENSG00000150787",
#                     "NCBIGene:5805"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:50943",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "FOXP3",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:Q9BZS1",
#                     "NCBIGene:50943",
#                     "HGNC:6106",
#                     "ENSEMBL:ENSG00000049768",
#                     "NCBIGene:50943"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:367",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "AR",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:367",
#                     "NCBIGene:367",
#                     "IUPHAR:628",
#                     "UniProtKB:P10275",
#                     "ENSEMBL:ENSG00000169083",
#                     "HGNC:644"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:6476",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "SI",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:P14410",
#                     "NCBIGene:6476",
#                     "ENSEMBL:ENSG00000090402",
#                     "NCBIGene:6476",
#                     "HGNC:10856"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:4118",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "MAL",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:P21145",
#                     "NCBIGene:4118",
#                     "ENSEMBL:ENSG00000172005",
#                     "NCBIGene:4118",
#                     "HGNC:6817"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:2056",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "EPO",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "ENSEMBL:ENSG00000130427",
#                     "NCBIGene:2056",
#                     "NCBIGene:2056",
#                     "HGNC:3415",
#                     "UniProtKB:P01588"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:958",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "CD40",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "IUPHAR:1874",
#                     "HGNC:11919",
#                     "ENSEMBL:ENSG00000101017",
#                     "UniProtKB:P25942",
#                     "NCBIGene:958",
#                     "NCBIGene:958"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:10129",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "FRY",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:10129",
#                     "HGNC:20367",
#                     "ENSEMBL:ENSG00000073910",
#                     "NCBIGene:10129",
#                     "UniProtKB:Q5TBA9"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:355",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "FAS",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:P25445",
#                     "ENSEMBL:ENSG00000026103",
#                     "NCBIGene:355",
#                     "IUPHAR:1875",
#                     "NCBIGene:355",
#                     "HGNC:11920"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:196",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "AHR",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "HGNC:348",
#                     "IUPHAR:2951",
#                     "UniProtKB:P35869",
#                     "ENSEMBL:ENSG00000106546",
#                     "NCBIGene:196",
#                     "NCBIGene:196"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:340451",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "CPP",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "HGNC:2322",
#                     "NCBIGene:340451",
#                     "NCBIGene:340451"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:5741",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "PTH",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:P01270",
#                     "ENSEMBL:ENSG00000152266",
#                     "HGNC:9606",
#                     "NCBIGene:5741",
#                     "NCBIGene:5741"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:26762",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "molecular_entity",
#                     "genomic_entity",
#                     "gene_or_gene_product",
#                     "gene",
#                     "macromolecular_machine"
#                 ],
#                 "name": "HAVCR1",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:Q96D42",
#                     "NCBIGene:26762",
#                     "NCBIGene:26762",
#                     "ENSEMBL:ENSG00000113249",
#                     "HGNC:17866"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:7173",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "TPO",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:7173",
#                     "ENSEMBL:ENSG00000115705",
#                     "NCBIGene:7173",
#                     "HGNC:12015",
#                     "UniProtKB:P07202",
#                     "IUPHAR:2526"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:7200",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "TRH",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:P20396",
#                     "HGNC:12298",
#                     "NCBIGene:7200",
#                     "ENSEMBL:ENSG00000170893",
#                     "NCBIGene:7200"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:8161",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "COIL",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:8161",
#                     "UniProtKB:P38432",
#                     "ENSEMBL:ENSG00000121058",
#                     "HGNC:2184",
#                     "NCBIGene:8161"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:54738",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "FEV",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "ENSEMBL:ENSG00000163497",
#                     "UniProtKB:Q99581",
#                     "NCBIGene:54738",
#                     "NCBIGene:54738",
#                     "HGNC:18562"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:5742",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "molecular_entity",
#                     "genomic_entity",
#                     "gene_or_gene_product",
#                     "gene",
#                     "macromolecular_machine"
#                 ],
#                 "name": "PTGS1",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "HGNC:9604",
#                     "NCBIGene:5742",
#                     "NCBIGene:5742",
#                     "ENSEMBL:ENSG00000095303",
#                     "UniProtKB:P23219",
#                     "IUPHAR:1375"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:7450",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "VWF",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "HGNC:12726",
#                     "NCBIGene:7450",
#                     "NCBIGene:7450",
#                     "UniProtKB:P04275",
#                     "ENSEMBL:ENSG00000110799"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:7124",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "TNF",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:7124",
#                     "HGNC:11892",
#                     "ENSEMBL:ENSG00000232810",
#                     "NCBIGene:7124",
#                     "UniProtKB:P01375"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:3630",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "INS",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:P01308",
#                     "ENSEMBL:ENSG00000254647",
#                     "HGNC:6081",
#                     "NCBIGene:3630",
#                     "NCBIGene:3630"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:11113",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "CIT",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:11113",
#                     "IUPHAR:1509",
#                     "ENSEMBL:ENSG00000122966",
#                     "HGNC:1985",
#                     "UniProtKB:O14578",
#                     "NCBIGene:11113"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:847",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "CAT",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:P04040",
#                     "NCBIGene:847",
#                     "ENSEMBL:ENSG00000121691",
#                     "HGNC:1516",
#                     "IUPHAR:2979",
#                     "NCBIGene:847"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:6010",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "RHO",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "ENSEMBL:ENSG00000163914",
#                     "NCBIGene:6010",
#                     "HGNC:10012",
#                     "UniProtKB:P08100",
#                     "NCBIGene:6010",
#                     "IUPHAR:2963"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:6651",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "SON",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "NCBIGene:6651",
#                     "NCBIGene:6651",
#                     "UniProtKB:P18583",
#                     "ENSEMBL:ENSG00000159140",
#                     "HGNC:11183"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:126669",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "SHE",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "UniProtKB:Q5VZ18",
#                     "ENSEMBL:ENSG00000169291",
#                     "HGNC:27004",
#                     "NCBIGene:126669",
#                     "NCBIGene:126669"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:637",
#                 "type": [
#                     "named_thing",
#                     "molecular_entity",
#                     "biological_entity",
#                     "gene_or_gene_product",
#                     "macromolecular_machine",
#                     "genomic_entity",
#                     "gene"
#                 ],
#                 "name": "BID",
#                 "omnicorp_article_count": 0,
#                 "equivalent_identifiers": [
#                     "ENSEMBL:ENSG00000015475",
#                     "UniProtKB:P55957",
#                     "NCBIGene:637",
#                     "HGNC:1050",
#                     "NCBIGene:637"
#                 ]
#             },
#             {
#                 "id": "NCBIGene:9235",
#                 "type": "gene",
#                 "name": "interleukin 32",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:1956",
#                 "type": "gene",
#                 "name": "epidermal growth factor receptor",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:9104",
#                 "type": "gene",
#                 "name": "regucalcin",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:55806",
#                 "type": "gene",
#                 "name": "HR lysine demethylase and nuclear receptor corepressor",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:83985",
#                 "type": "gene",
#                 "name": "sphingolipid transporter 1 (putative)",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:12",
#                 "type": "gene",
#                 "name": "serpin family A member 3",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:4712",
#                 "type": "gene",
#                 "name": "NADH:ubiquinone oxidoreductase subunit B6",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:1674",
#                 "type": "gene",
#                 "name": "desmin",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:51324",
#                 "type": "gene",
#                 "name": "SPG21 abhydrolase domain containing, maspardin",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:56005",
#                 "type": "gene",
#                 "name": "myeloid derived growth factor",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:1825",
#                 "type": "gene",
#                 "name": "desmocollin 3",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:10603",
#                 "type": "gene",
#                 "name": "SH2B adaptor protein 2",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:7099",
#                 "type": "gene",
#                 "name": "toll like receptor 4",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:572",
#                 "type": "gene",
#                 "name": "BCL2 associated agonist of cell death",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:6430",
#                 "type": "gene",
#                 "name": "serine and arginine rich splicing factor 5",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:85480",
#                 "type": "gene",
#                 "name": "thymic stromal lymphopoietin",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:54440",
#                 "type": "gene",
#                 "name": "SAM and SH3 domain containing 3",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:1401",
#                 "type": "gene",
#                 "name": "C-reactive protein",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:4810",
#                 "type": "gene",
#                 "name": "NHS actin remodeling regulator",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:920",
#                 "type": "gene",
#                 "name": "CD4 molecule",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:2022",
#                 "type": "gene",
#                 "name": "endoglin",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:6955",
#                 "type": "gene",
#                 "name": "T cell receptor alpha locus",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:641455",
#                 "type": "gene",
#                 "name": "POTE ankyrin domain family member M",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:1636",
#                 "type": "gene",
#                 "name": "angiotensin I converting enzyme",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:5743",
#                 "type": "gene",
#                 "name": "prostaglandin-endoperoxide synthase 2",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:240",
#                 "type": "gene",
#                 "name": "arachidonate 5-lipoxygenase",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:730249",
#                 "type": "gene",
#                 "name": "aconitate decarboxylase 1",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:9457",
#                 "type": "gene",
#                 "name": "four and a half LIM domains 5",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:1431",
#                 "type": "gene",
#                 "name": "citrate synthase",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:3274",
#                 "type": "gene",
#                 "name": "histamine receptor H2",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:9311",
#                 "type": "gene",
#                 "name": "acid sensing ion channel subunit 3",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:54478",
#                 "type": "gene",
#                 "name": "PICALM interacting mitotic regulator",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:124872",
#                 "type": "gene",
#                 "name": "beta-1,4-N-acetyl-galactosaminyltransferase 2",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:25759",
#                 "type": "gene",
#                 "name": "SHC adaptor protein 2",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:2232",
#                 "type": "gene",
#                 "name": "ferredoxin reductase",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:831",
#                 "type": "gene",
#                 "name": "calpastatin",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:1611",
#                 "type": "gene",
#                 "name": "death associated protein",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:1677",
#                 "type": "gene",
#                 "name": "DNA fragmentation factor subunit beta",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:7054",
#                 "type": "gene",
#                 "name": "tyrosine hydroxylase",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:828",
#                 "type": "gene",
#                 "name": "calcyphosine",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:8685",
#                 "type": "gene",
#                 "name": "macrophage receptor with collagenous structure",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:4141",
#                 "type": "gene",
#                 "name": "methionyl-tRNA synthetase 1",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:5978",
#                 "type": "gene",
#                 "name": "RE1 silencing transcription factor",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "HGNC:8817",
#                 "type": "gene",
#                 "name": "HGNC:8817",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:10439",
#                 "type": "gene",
#                 "name": "olfactomedin 1",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:9146",
#                 "type": "gene",
#                 "name": "hepatocyte growth factor-regulated tyrosine kinase substrate",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:4149",
#                 "type": "gene",
#                 "name": "MYC associated factor X",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:1154",
#                 "type": "gene",
#                 "name": "cytokine inducible SH2 containing protein",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBIGene:11092",
#                 "type": "gene",
#                 "name": "sperm acrosome associated 9",
#                 "omnicorp_article_count": 0
#             },
#             {
#                 "id": "NCBITaxon:9606",
#                 "type": [
#                     "named_thing",
#                     "ontology_class",
#                     "organism_taxon"
#                 ]
#             },
#             {
#                 "id": "GO:0005515",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "biological_process_or_activity",
#                     "molecular_activity"
#                 ]
#             },
#             {
#                 "id": "UBERON:0001893",
#                 "type": [
#                     "named_thing",
#                     "organismal_entity",
#                     "biological_entity",
#                     "anatomical_entity"
#                 ]
#             },
#             {
#                 "id": "MONDO:0004993",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "disease",
#                     "disease_or_phenotypic_feature"
#                 ]
#             },
#             {
#                 "id": "MONDO:0004992",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "disease",
#                     "disease_or_phenotypic_feature"
#                 ]
#             },
#             {
#                 "id": "MONDO:0005044",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "disease",
#                     "disease_or_phenotypic_feature"
#                 ]
#             },
#             {
#                 "id": "UBERON:0006856",
#                 "type": [
#                     "named_thing",
#                     "organismal_entity",
#                     "biological_entity",
#                     "anatomical_entity"
#                 ]
#             },
#             {
#                 "id": "UBERON:0000029",
#                 "type": [
#                     "named_thing",
#                     "organismal_entity",
#                     "biological_entity",
#                     "anatomical_entity"
#                 ]
#             },
#             {
#                 "id": "MONDO:0005015",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "disease",
#                     "disease_or_phenotypic_feature"
#                 ]
#             },
#             {
#                 "id": "UBERON:0004534",
#                 "type": [
#                     "named_thing",
#                     "organismal_entity",
#                     "biological_entity",
#                     "anatomical_entity"
#                 ]
#             },
#             {
#                 "id": "MONDO:0005154",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "disease",
#                     "disease_or_phenotypic_feature"
#                 ]
#             },
#             {
#                 "id": "MONDO:0004979",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "disease",
#                     "disease_or_phenotypic_feature"
#                 ]
#             },
#             {
#                 "id": "UBERON:0000057",
#                 "type": [
#                     "named_thing",
#                     "organismal_entity",
#                     "biological_entity",
#                     "anatomical_entity"
#                 ]
#             },
#             {
#                 "id": "UBERON:0002240",
#                 "type": [
#                     "named_thing",
#                     "organismal_entity",
#                     "biological_entity",
#                     "anatomical_entity"
#                 ]
#             },
#             {
#                 "id": "UBERON:0002107",
#                 "type": [
#                     "named_thing",
#                     "organismal_entity",
#                     "biological_entity",
#                     "anatomical_entity"
#                 ]
#             },
#             {
#                 "id": "UBERON:0000178",
#                 "type": [
#                     "named_thing",
#                     "organismal_entity",
#                     "biological_entity",
#                     "anatomical_entity"
#                 ]
#             },
#             {
#                 "id": "HP:0000007",
#                 "type": [
#                     "named_thing",
#                     "biological_entity",
#                     "disease_or_phenotypic_feature",
#                     "phenotypic_feature"
#                 ]
#             },
# ...
#                         "NCBIGene:1611",
#                         "NCBIGene:929",
#                         "NCBIGene:5743",
#                         "NCBIGene:7099"
#                     ],
#                     "p_value": 3.219465404353066e-17,
#                     "coalescence_method": "graph_enrichment",
#                     "enriched_nodes": [
#                         "MONDO:0005101"
#                     ]
#                 },
#                 {
#                     "qg_id": "extra_qn_0",
#                     "kg_id": [
#                         "MONDO:0005101"
#                     ]
#                 }
#             ],
#             "edge_bindings": [
#                 {
#                     "qg_id": "ab",
#                     "kg_id": [
#                         "47015fd7aa66206943eb93f033747561",
#                         "CHEBI:15365--related_to--NCBIGene:920",
#                         "CHEBI:15365--related_to--NCBIGene:7099",
#                         "CHEBI:15365--related_to--NCBIGene:1401",
#                         "8ad126c94e42906bbdde570c3f5c86f0",
#                         "CHEBI:15365--related_to--NCBIGene:5743",
#                         "CHEBI:15365--related_to--NCBIGene:1611",
#                         "c22418a49616b0f02dacb6de79be6372"
#                     ]
#                 },
#                 {
#                     "qg_id": "extra_qe_0",
#                     "kg_id": [
#                         "3266198437834771869",
#                         "3511732416747634711",
#                         "-3728204328061458615",
#                         "-3471431107839816663",
#                         "1513559560760407720",
#                         "-3915687505927773559",
#                         "4032399299853659671",
#                         "1574501357973317667"
#                     ]
#                 }
#             ],
#             "score": 0.9858453291928586
#         },
#         {
#             "node_bindings": [
#                 {
#                     "qg_id": "a",
#                     "kg_id": [
#                         "CHEBI:15365"
#                     ]
#                 },
#                 {
#                     "qg_id": "b",
#                     "kg_id": [
#                         "NCBIGene:958",
#                         "NCBIGene:55806",
#                         "NCBIGene:1674",
#                         "NCBIGene:4149",
#                         "NCBIGene:5914",
#                         "NCBIGene:831",
#                         "NCBIGene:9146",
#                         "NCBIGene:367",
#                         "NCBIGene:8161",
#                         "NCBIGene:1956",
#                         "NCBIGene:1154",
#                         "NCBIGene:2232",
#                         "NCBIGene:5742",
#                         "NCBIGene:196",
#                         "NCBIGene:80271",
#                         "NCBIGene:51324",
#                         "NCBIGene:1825"
#                     ],
#                     "p_value": 3.260062376158648e-17,
#                     "coalescence_method": "graph_enrichment",
#                     "enriched_nodes": [
#                         "UBERON:0002030"
#                     ]
#                 },
#                 {
#                     "qg_id": "extra_qn_0",
#                     "kg_id": [
#                         "UBERON:0002030"
#                     ]
#                 }
#             ],
#             "edge_bindings": [
#                 {
#                     "qg_id": "ab",
#                     "kg_id": [
#                         "7be068e47c1b37b1aeb3997fa8609250",
#                         "CHEBI:15365--related_to--NCBIGene:1825",
#                         "a405d77376c8b53594071d4de63b2b7f",
#                         "CHEBI:15365--related_to--NCBIGene:4149",
#                         "CHEBI:15365--related_to--NCBIGene:55806",
#                         "CHEBI:15365--related_to--NCBIGene:1154",
#                         "CHEBI:15365--related_to--NCBIGene:831",
#                         "1b70a37b306e1f81f55189c8cf17415e",
#                         "c22418a49616b0f02dacb6de79be6372",
#                         "99b9a62c72b408658a39319d9a1c43c4",
#                         "f83cdff47e4140eb2d28f9d93a469949",
#                         "CHEBI:15365--related_to--NCBIGene:1956",
#                         "CHEBI:15365--related_to--NCBIGene:51324",
#                         "CHEBI:15365--related_to--NCBIGene:1674",
#                         "CHEBI:15365--related_to--NCBIGene:9146",
#                         "0e384537b65c634a2d64ff7f3de1c090",
#                         "CHEBI:15365--related_to--NCBIGene:2232"
#                     ]
#                 },
#                 {
#                     "qg_id": "extra_qe_0",
#                     "kg_id": [
#                         "5414869968476226063",
#                         "8874595048257366442",
#                         "-8201278290646214071",
#                         "-6492872693715500206",
#                         "1278180681608012088",
#                         "1598453610062512161",
#                         "5003148466536351931",
#                         "2387884268950916455",
#                         "-3282215903071915589",
#                         "-9046795221398856936",
#                         "7844436110935214551",
#                         "1040626596092749108",
#                         "-1041880729315416347",
#                         "1465981049268943495",
#                         "4986343582125154877",
#                         "-7161342795617680655",
#                         "-2003301985357881358"
#                     ]
#                 }
#             ],
#             "score": 0.5
#         },
#         {
#             "node_bindings": [
#                 {
#                     "qg_id": "a",
#                     "kg_id": [
#                         "CHEBI:15365"
#                     ]
#                 },
#                 {
#                     "qg_id": "b",
#                     "kg_id": [
#                         "NCBIGene:462",
#                         "NCBIGene:7200",
#                         "NCBIGene:5741",
#                         "NCBIGene:2056",
#                         "NCBIGene:929",
#                         "NCBIGene:7450",
#                         "NCBIGene:85480",
#                         "NCBIGene:7124",
#                         "NCBIGene:847",
#                         "NCBIGene:12",
#                         "NCBIGene:1636",
#                         "NCBIGene:3630",
#                         "NCBIGene:1401",
#                         "NCBIGene:1825",
#                         "NCBIGene:240"
#                     ],
#                     "p_value": 3.302098845841598e-17,
#                     "coalescence_method": "graph_enrichment",
#                     "enriched_nodes": [
#                         "GO:0005576"
#                     ]
#                 },
#                 {
#                     "qg_id": "extra_qn_0",
#                     "kg_id": [
#                         "GO:0005576"
#                     ]
#                 }
#             ],
#             "edge_bindings": [
#                 {
#                     "qg_id": "ab",
#                     "kg_id": [
#                         "CHEBI:15365--related_to--NCBIGene:1825",
#                         "CHEBI:15365--related_to--NCBIGene:1636",
#                         "c84af6eff46773688d551f4bf9ca301e",
#                         "47015fd7aa66206943eb93f033747561",
#                         "bd70c7edae1d7388ce04773fd81470df",
#                         "63174bdea1e913253373c9b65ca50147",
#                         "CHEBI:15365--related_to--NCBIGene:85480",
#                         "8ad126c94e42906bbdde570c3f5c86f0",
#                         "d979da1a72df017fe7dd4cd008baf79b",
#                         "CHEBI:15365--related_to--NCBIGene:1401",
#                         "CHEBI:15365--related_to--NCBIGene:240",
#                         "7c45f741559dd46760ccbe870d73756d",
#                         "20068e0e1be874c920fd49325f2a2a7d",
#                         "CHEBI:15365--related_to--NCBIGene:12",
#                         "70abbf9116890eb51fb3ae669b4ca235"
#                     ]
#                 },
#                 {
#                     "qg_id": "extra_qe_0",
#                     "kg_id": [
#                         "-7097437562776058551",
#                         "-583977572581343120",
#                         "9031843788292372088",
#                         "-8528081833969982954",
#                         "2367432139273777092",
#                         "-501293360991882844",
#                         "-5590629624700068174",
#                         "-625362427778551829",
#                         "4196988174524174267",
#                         "3015158440620228507",
#                         "-8977602146234246139",
#                         "4844613850941728772",
#                         "1946790256133693995",
#                         "-6777940784293352607",
#                         "486933964497039343"
#                     ]
#                 }
#             ],
#             "score": 0.6772190444071825
#         },
#         {
#             "node_bindings": [
#                 {
#                     "qg_id": "a",
#                     "kg_id": [
#                         "CHEBI:15365"
#                     ]
#                 },
#                 {
#                     "qg_id": "b",
#                     "kg_id": [
#                         "NCBIGene:355",
#                         "NCBIGene:929",
#                         "NCBIGene:5447",
#                         "NCBIGene:637",
#                         "NCBIGene:1956",
#                         "NCBIGene:572",
#                         "NCBIGene:7124",
#                         "NCBIGene:847",
#                         "NCBIGene:7099",
#                         "NCBIGene:5743"
#                     ],
#                     "p_value": 3.338208485051658e-17,
#                     "coalescence_method": "graph_enrichment",
#                     "enriched_nodes": [
#                         "CHEBI:36314"
#                     ]
#                 },
#                 {
#                     "qg_id": "extra_qn_0",
#                     "kg_id": [
#                         "CHEBI:36314"
#                     ]
#                 }
#             ],
#             "edge_bindings": [
#                 {
#                     "qg_id": "ab",
#                     "kg_id": [
#                         "47015fd7aa66206943eb93f033747561",
#                         "7026ae84ef2681e44addf4fbe7f54ac8",
#                         "CHEBI:15365--related_to--NCBIGene:7099",
#                         "8ad126c94e42906bbdde570c3f5c86f0",
#                         "d979da1a72df017fe7dd4cd008baf79b",
#                         "CHEBI:15365--related_to--NCBIGene:1956",
#                         "103f3d35ff61dcb93063c41bae6cfec2",
#                         "504ba324ddbbcbc9a10bcc08b0c885fe",
#                         "CHEBI:15365--related_to--NCBIGene:572",
#                         "CHEBI:15365--related_to--NCBIGene:5743"
#                     ]
#                 },
#                 {
#                     "qg_id": "extra_qe_0",
#                     "kg_id": [
#                         "5619250380661360769",
#                         "-4418953545795721225",
#                         "5986323579880116264",
#                         "-596224104566822890",
#                         "-8862634145122715132",
#                         "1734869462877766997",
#                         "6560038596374059377",
#                         "-4481938553881705564",
#                         "-4024618717638337702",
#                         "6222652602194756899"
#                     ]
#                 }
#             ],
#             "score": 0.9858453291928586
#         },
#         {
#             "node_bindings": [
#                 {
#                     "qg_id": "a",
#                     "kg_id": [
#                         "CHEBI:15365"
#                     ]
#                 },
#                 {
#                     "qg_id": "b",
#                     "kg_id": [
#                         "NCBIGene:1956",
#                         "NCBIGene:7124",
#                         "NCBIGene:355",
#                         "NCBIGene:1674",
#                         "NCBIGene:3630",
#                         "NCBIGene:5743",
#                         "NCBIGene:1431",
#                         "NCBIGene:637"
#                     ],
#                     "p_value": 3.9461018482500385e-17,
#                     "coalescence_method": "graph_enrichment",
#                     "enriched_nodes": [
#                         "CHEBI:7847"
#                     ]
#                 },
#                 {
#                     "qg_id": "extra_qn_0",
#                     "kg_id": [
#                         "CHEBI:7847"
#                     ]
#                 }
#             ],
#             "edge_bindings": [
#                 {
#                     "qg_id": "ab",
#                     "kg_id": [
#                         "70abbf9116890eb51fb3ae669b4ca235",
#                         "CHEBI:15365--related_to--NCBIGene:1956",
#                         "7026ae84ef2681e44addf4fbe7f54ac8",
#                         "103f3d35ff61dcb93063c41bae6cfec2",
#                         "8ad126c94e42906bbdde570c3f5c86f0",
#                         "CHEBI:15365--related_to--NCBIGene:1674",
#                         "CHEBI:15365--related_to--NCBIGene:5743",
#                         "CHEBI:15365--related_to--NCBIGene:1431"
#                     ]
#                 },
#                 {
#                     "qg_id": "extra_qe_0",
#                     "kg_id": [
#                         "-8955173487596001014",
#                         "-7515273935605603844",
#                         "2467518278167837405",
#                         "8169048771817469897",
#                         "-5730076894566437973",
#                         "3148458871737944896",
#                         "7770471146059513269",
#                         "8682310248598430000"
#                     ]
#                 }
#             ],
#             "score": 0.9858453291928586
#         },
#         {
#             "node_bindings": [
#                 {
#                     "qg_id": "a",
#                     "kg_id": [
#                         "CHEBI:15365"
#                     ]
#                 },
#                 {
#                     "qg_id": "b",
#                     "kg_id": [
#                         "NCBIGene:7200",
#                         "NCBIGene:5741",
#                         "NCBIGene:4141",
#                         "NCBIGene:3630",
#                         "NCBIGene:7173",
#                         "NCBIGene:1401",
#                         "NCBIGene:50943",
#                         "NCBIGene:7450"
#                     ],
#                     "p_value": 3.9461018482500385e-17,
#                     "coalescence_method": "graph_enrichment",
#                     "enriched_nodes": [
#                         "MONDO:0005420"
#                     ]
#                 },
#                 {
#                     "qg_id": "extra_qn_0",
#                     "kg_id": [
#                         "MONDO:0005420"
#                     ]
#                 }
#             ],
#             "edge_bindings": [
#                 {
#                     "qg_id": "ab",
#                     "kg_id": [
#                         "7c45f741559dd46760ccbe870d73756d",
#                         "c84af6eff46773688d551f4bf9ca301e",
#                         "bd70c7edae1d7388ce04773fd81470df",
#                         "CHEBI:15365--related_to--NCBIGene:4141",
#                         "CHEBI:15365--related_to--NCBIGene:1401",
#                         "0d45723cdf7f11b7e6c4a31a769c1306",
#                         "70abbf9116890eb51fb3ae669b4ca235",
#                         "f53418e9216582ab082387695d24773b"
#                     ]
#                 },
#                 {
#                     "qg_id": "extra_qe_0",
#                     "kg_id": [
#                         "8141394119864290412",
#                         "-1593510167211066380",
#                         "-3127360889902072160",
#                         "6417218351026219715",
#                         "3107424130821334487",
#                         "-5764216872079059441",
#                         "-3741055613023861602",
#                         "-1002647499610893690"
#                     ]
#                 }
#             ],
#             "score": 0.283916542352791
#         }
#     ]
# }

# %%
#genes that cause cystic fibrosis
message= one_hop_message('MONDO:0009061','disease','gene','causes',reverse=True)
results = striderandfriends(message)

# %%
print(results['results'])
# Out:
# [{'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0009061']}, {'qg_id': 'b', 'kg_id': ['NCBIGene:57491', 'NCBIGene:186', 'NCBIGene:4585', 'NCBIGene:22802', 'NCBIGene:6550', 'NCBIGene:6804', 'NCBIGene:51164', 'NCBIGene:6547', 'NCBIGene:1080'], 'p_value': 2.3634670232224677e-38, 'coalescence_method': 'graph_enrichment', 'enriched_nodes': ['MONDO:0009061']}, {'qg_id': 'extra_qn_0', 'kg_id': ['MONDO:0009061']}], 'edge_bindings': [{'qg_id': 'ab', 'kg_id': ['8ff819b0bf8041f7ffd624f954bd536a', 'fb317c29ae24e5886f22d3c7d6867081', '5bf84ae94cc85b1eb7f0da0d09a9428d', 'a0ddb3a5b0c5c536a14003a8a0786186', 'a8c45616851f027d6d630b42f28b919d', 'a9eac7fa54140a5bafc6b9d471479d46', '3db0c85b8e74b8510fc6fc076d104648', '7c5ad568fed616b223634fbff6860fb2', 'e123a21f4e0bab8e7c4266eddf18f43d']}, {'qg_id': 'extra_qe_0', 'kg_id': ['fb317c29ae24e5886f22d3c7d6867081', '8ff819b0bf8041f7ffd624f954bd536a', '5bf84ae94cc85b1eb7f0da0d09a9428d', 'a0ddb3a5b0c5c536a14003a8a0786186', 'a8c45616851f027d6d630b42f28b919d', 'a9eac7fa54140a5bafc6b9d471479d46', '3db0c85b8e74b8510fc6fc076d104648', '7c5ad568fed616b223634fbff6860fb2', 'e123a21f4e0bab8e7c4266eddf18f43d']}], 'score': 1.0000000000000002}, {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0009061']}, {'qg_id': 'b', 'kg_id': ['NCBIGene:57491', 'NCBIGene:186', 'NCBIGene:4585', 'NCBIGene:22802', 'NCBIGene:6550', 'NCBIGene:6804', 'NCBIGene:51164', 'NCBIGene:6547', 'NCBIGene:1080'], 'p_value': 2.1326844535634116e-29, 'coalescence_method': 'graph_enrichment', 'enriched_nodes': ['MONDO:0009061']}, {'qg_id': 'extra_qn_0', 'kg_id': ['MONDO:0009061']}], 'edge_bindings': [{'qg_id': 'ab', 'kg_id': ['8ff819b0bf8041f7ffd624f954bd536a', 'fb317c29ae24e5886f22d3c7d6867081', '5bf84ae94cc85b1eb7f0da0d09a9428d', 'a0ddb3a5b0c5c536a14003a8a0786186', 'a8c45616851f027d6d630b42f28b919d', 'a9eac7fa54140a5bafc6b9d471479d46', '3db0c85b8e74b8510fc6fc076d104648', '7c5ad568fed616b223634fbff6860fb2', 'e123a21f4e0bab8e7c4266eddf18f43d']}, {'qg_id': 'extra_qe_0', 'kg_id': ['-2198756245166415419', '6580482909483273728', '4932890742590912261', '2259811648577669391', '-2836696923401477419', '8664906454566060983', '-886388267001220529', '-2488449996259033606', '-7002822587629154007']}], 'score': 1.0000000000000002}, {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0009061']}, {'qg_id': 'b', 'kg_id': ['NCBIGene:51164', 'NCBIGene:22802', 'NCBIGene:1080', 'NCBIGene:6804'], 'p_value': 3.7262085153553745e-14, 'coalescence_method': 'graph_enrichment', 'enriched_nodes': ['MONDO:0001684']}, {'qg_id': 'extra_qn_0', 'kg_id': ['MONDO:0001684']}], 'edge_bindings': [{'qg_id': 'ab', 'kg_id': ['8ff819b0bf8041f7ffd624f954bd536a', 'a8c45616851f027d6d630b42f28b919d', 'a9eac7fa54140a5bafc6b9d471479d46', '3db0c85b8e74b8510fc6fc076d104648']}, {'qg_id': 'extra_qe_0', 'kg_id': ['-7162155821629554008', '6787078948292808413', '-9140966043561428897', '8339046744795118183']}], 'score': 1.0000000000000002}, {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0009061']}, {'qg_id': 'b', 'kg_id': ['NCBIGene:51164', 'NCBIGene:22802', 'NCBIGene:1080', 'NCBIGene:6804'], 'p_value': 1.3315308325673068e-13, 'coalescence_method': 'graph_enrichment', 'enriched_nodes': ['HP:0004313']}, {'qg_id': 'extra_qn_0', 'kg_id': ['HP:0004313']}], 'edge_bindings': [{'qg_id': 'ab', 'kg_id': ['8ff819b0bf8041f7ffd624f954bd536a', 'a8c45616851f027d6d630b42f28b919d', 'a9eac7fa54140a5bafc6b9d471479d46', '3db0c85b8e74b8510fc6fc076d104648']}, {'qg_id': 'extra_qe_0', 'kg_id': ['-33992857485397000', '8541783076542763279', '-4194468150601643081', '4187070331858888333']}], 'score': 1.0000000000000002}, {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0009061']}, {'qg_id': 'b', 'kg_id': ['NCBIGene:51164', 'NCBIGene:22802', 'NCBIGene:1080', 'NCBIGene:6804'], 'p_value': 9.021708766190988e-13, 'coalescence_method': 'graph_enrichment', 'enriched_nodes': ['MONDO:0005388']}, {'qg_id': 'extra_qn_0', 'kg_id': ['MONDO:0005388']}], 'edge_bindings': [{'qg_id': 'ab', 'kg_id': ['8ff819b0bf8041f7ffd624f954bd536a', 'a8c456 ...

# %%
#phenotypes of Charcot Marie Tooth
message = one_hop_message('MONDO:0015626','disease','phenotypic_feature','has_phenotype')
results = striderandfriends(message)

# %%
print(results['results'])
# Out:
# [{'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0015626']}, {'qg_id': 'b', 'kg_id': ['HP:0003444', 'HP:0006460', 'HP:0003551', 'HP:0001155', 'HP:0003384', 'HP:0006915', 'HP:0002495', 'HP:0002936', 'HP:0003731', 'HP:0009046', 'HP:0003487', 'HP:0007010', 'HP:0003380', 'HP:0003383'], 'p_value': 5.436947985203358e-29, 'coalescence_method': 'graph_enrichment', 'enriched_nodes': ['MONDO:0012231']}, {'qg_id': 'extra_qn_0', 'kg_id': ['MONDO:0012231']}], 'edge_bindings': [{'qg_id': 'ab', 'kg_id': ['5378b4189d6899b577d8754d08402921', '858b4dcbe3ea4a09e2dc6ae3bdbf0b88', '2603d6380768d23bc9fa4e1374837a7d', 'a43ad0018340b3dfb7d6c0f628e82b58', 'c1097c284e40e2094880a7c0eb76a8c3', '7c23bc7b4e75213fbcae8366ff087b44', 'f7256a240e7bf4cbcf7b8272621a92e1', 'ef6e4453fba62ecfb7651c674a5b6063', 'bc1979f7b3f1cf82c08366002fab5801', '09a2583e853c3375160c0a47ef09216f', '021ff59cd842168b8bdc8a8a6712e1be', 'ed99bebc81071b73fe2b004542cbf4c9', '7edf9d6b836c239fb8fc034581773cc6', 'f41bc1ae7cdb3d334db67f47884e2aa1']}, {'qg_id': 'extra_qe_0', 'kg_id': ['-7674117556344988196', '-3279305737987691011', '-259919160688267400', '4786176313657768071', '4423644932711534585', '6553897980421678991', '-4757031425978496912', '5939289110295698498', '6943348747437247963', '-2682129670119060786', '4555800681857964147', '7979013025805758144', '-1916151139968630039', '2088124963197596277']}, {'qg_id': 's21', 'kg_id': ['4e18e194-9452-4949-b23d-ea9d5d829e60']}, {'qg_id': 's42', 'kg_id': ['6a321898-839c-44ee-bb1b-48adbaed1ce5']}, {'qg_id': 's45', 'kg_id': ['e78d579e-24d2-4a79-84c8-e54d0bd2d46f']}, {'qg_id': 's82', 'kg_id': ['121fad77-2b2a-4d72-845c-df0614765e97']}, {'qg_id': 's23', 'kg_id': ['77256f5c-055b-4541-b52f-90d027c269a5']}, {'qg_id': 's53', 'kg_id': ['771c3676-cebe-46be-8489-4f8e755bcb32']}, {'qg_id': 's57', 'kg_id': ['a361008d-59f8-4d20-bc9f-2fdb61f9b8f9']}, {'qg_id': 's50', 'kg_id': ['a8069441-908e-44f5-9b24-0fa2e6edb9e0']}], 'score': 0.5466242577432169}, {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0015626']}, {'qg_id': 'b', 'kg_id': ['HP:0003444', 'HP:0100490', 'HP:0002505', 'HP:0008954', 'HP:0030198', 'HP:0100288', 'HP:0002943', 'HP:0002936', 'HP:0007289', 'HP:0003710', 'HP:0003760', 'HP:0012899', 'HP:0002273'], 'p_value': 1.3102888379491228e-26, 'coalescence_method': 'graph_enrichment', 'enriched_nodes': ['MONDO:0007646']}, {'qg_id': 'extra_qn_0', 'kg_id': ['MONDO:0007646']}], 'edge_bindings': [{'qg_id': 'ab', 'kg_id': ['054b3867f64324305839e10ef777c10d', 'a76a277e5fc531aaae9c7810c56d64ea', '7c23bc7b4e75213fbcae8366ff087b44', '9f776e39f533cee4edd2912e6f293c87', '3ac76fdc4725921fb3a3a99cc7829f54', 'c3598639d9affaabc4d5e685c8ff2bdf', 'b74019eca7ec1d4f91378b5faf8c965f', '021ff59cd842168b8bdc8a8a6712e1be', '4a55fe71e64008c6abc8634d15d010a5', '5336f6b048021c79c02698bdbab12ef6', 'da59be4a663d39a0c20584fa1bf7cb7b', '254b5bf8d0efb5b7100ea197a8aeaff7', '8feb6a191d258291d960bf877ee0bdee']}, {'qg_id': 'extra_qe_0', 'kg_id': ['3907551298841958321', '4974100439759800540', '5400022026541579198', '2312309769559559148', '8174564172626284528', '2202092569141378467', '20802893734254384', '-1234628889897302854', '-5406310081002705765', '-8958915714565762512', '-3423958172454073321', '182022833712605352', '377417553384528777']}, {'qg_id': 's42', 'kg_id': ['6a321898-839c-44ee-bb1b-48adbaed1ce5']}, {'qg_id': 's96', 'kg_id': ['903cd894-7e7b-42cd-ab45-bb74e6c860e6']}, {'qg_id': 's49', 'kg_id': ['a931666e-e530-45cf-a107-059e94a2a729']}], 'score': 0.29676322771798347}, {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0015626']}, {'qg_id': 'b', 'kg_id': ['HP:0000823', 'HP:0003384', 'HP:0000020', 'HP:0000649', 'HP:0002079', 'HP:0003760', 'HP:0012899', 'HP:0003427', 'HP:0008962', 'HP:0000325', 'HP:0100490', 'HP:0006466', 'HP:0003009', 'HP:0006915', 'HP:0001218', 'HP:0000527', 'HP:0009623', 'HP:0006006', 'HP:0003798', 'HP:0002816', 'HP:0030051', 'HP:0001178', 'HP:0006460', 'HP:0003551', 'HP:0003448', 'HP:0003557', 'HP:0008734', 'HP:0002922', 'HP:0007289', 'HP:0003487', 'HP:0007010',  ...

# %%
#What cells are in the brain?
message = one_hop_message('UBERON:0000955','anatomical_entity','cell','part_of',reverse=True)
results = striderandfriends(message)

# %%
print(results['results'])
# Out:
# [{'node_bindings': [{'qg_id': 'a', 'kg_id': ['UBERON:0000955']}, {'qg_id': 'b', 'kg_id': ['CL:2000043', 'CL:2000047', 'CL:2000004', 'CL:1001474', 'CL:2000097', 'CL:0002614', 'CL:1001579', 'CL:1001503', 'CL:1000042', 'CL:2000044', 'CL:1001602', 'CL:1001581', 'CL:0002610', 'CL:0013000', 'CL:0012001', 'CL:0010012', 'CL:0000652', 'CL:1000001', 'CL:0000706', 'CL:0002590', 'CL:1001582', 'CL:2000030', 'CL:0000708', 'CL:2000005', 'CL:0002549', 'CL:1001611'], 'p_value': 2.0528992289900936e-73, 'coalescence_method': 'graph_enrichment', 'enriched_nodes': ['UBERON:0000955']}, {'qg_id': 'extra_qn_0', 'kg_id': ['UBERON:0000955']}], 'edge_bindings': [{'qg_id': 'ab', 'kg_id': ['6288c88f27391d2e3a7dea2ef3af5afc', 'c21173bb57754d0957b89ca38e343999', '1c398352690fc02a9a61af269da460c7', '0e745690f9054ffc070a2659f0785256', '7b2c4325e24b99a753ecb1cbdf62807e', 'e2a4fac6c7a041db120126665c8b5263', 'a4c94ed3ac416a38d8b1c34156e7d2ab', '2d9a7118b254de5e8886e7bcea95db5e', 'cbad7918112146ca186b9120c54153dc', '904b860b1931b9be63e2f6ed4961dcac', '1dd0664cfd63bc3cc04683af2d5c1f54', '4a2bb9e366553b52d6bba70560dd3386', 'e735040ce07b47c152eb44bc7106cdac', '41a28b61a970a3ba373b339730db3d5a', 'c88df257204cb7eb10e02775c4fd0178', '704f2eafa46ce9a9e647f2b594623b65', '7295c463318e1353f22e4b78a3e8047a', '5c674627803f72e987f2c8e907518ee0', '7ba3f2e3eed756d29b725b3192c7cc09', '5f65f71a2be30d489a8c286caf342ee1', '76f0690c908a706b07b786f0d5d86f33', 'c742f8ab53ea3edf4fe2beb5bbeea3bf', '21760e7f29b4657c622821ecf4db9e66', '276bf3500c1796b5af4db111afef8ada', 'f9217c23ce286ad426ce981b1ca7b32c', 'adfafd702bc33c8500e4dfbecc87383c']}, {'qg_id': 'extra_qe_0', 'kg_id': ['6288c88f27391d2e3a7dea2ef3af5afc', '0e745690f9054ffc070a2659f0785256', 'cbad7918112146ca186b9120c54153dc', '1dd0664cfd63bc3cc04683af2d5c1f54', '4a2bb9e366553b52d6bba70560dd3386', 'e735040ce07b47c152eb44bc7106cdac', 'c88df257204cb7eb10e02775c4fd0178', '704f2eafa46ce9a9e647f2b594623b65', '7295c463318e1353f22e4b78a3e8047a', '5c674627803f72e987f2c8e907518ee0', '76f0690c908a706b07b786f0d5d86f33', '5f65f71a2be30d489a8c286caf342ee1', 'c742f8ab53ea3edf4fe2beb5bbeea3bf', 'f9217c23ce286ad426ce981b1ca7b32c', 'adfafd702bc33c8500e4dfbecc87383c', 'c21173bb57754d0957b89ca38e343999', '1c398352690fc02a9a61af269da460c7', '7b2c4325e24b99a753ecb1cbdf62807e', 'e2a4fac6c7a041db120126665c8b5263', 'a4c94ed3ac416a38d8b1c34156e7d2ab', '2d9a7118b254de5e8886e7bcea95db5e', '904b860b1931b9be63e2f6ed4961dcac', '41a28b61a970a3ba373b339730db3d5a', '21760e7f29b4657c622821ecf4db9e66', '276bf3500c1796b5af4db111afef8ada', '7ba3f2e3eed756d29b725b3192c7cc09']}, {'qg_id': 's7', 'kg_id': ['50cc8ac9-af0a-450c-9665-d4557e3cb6fa']}, {'qg_id': 's5', 'kg_id': ['d988af21-866c-4419-8010-3ad0f9e23e93']}, {'qg_id': 's14', 'kg_id': ['b6dfaf1d-625b-4b50-b844-51358215cdc8']}, {'qg_id': 's23', 'kg_id': ['bed81e8d-2293-4e27-bf1c-9a177c4082ef']}, {'qg_id': 's10', 'kg_id': ['de2aa765-d2c4-45cb-80c7-f37cccb60bea']}, {'qg_id': 's21', 'kg_id': ['86df825d-df5f-49b4-9599-0cbc7e11ae52']}, {'qg_id': 's2', 'kg_id': ['d67d92ce-6e3a-4ae5-8fec-585433b24770']}, {'qg_id': 's4', 'kg_id': ['39fbc89e-d2b1-4b53-93d1-a9d272c081e7']}, {'qg_id': 's8', 'kg_id': ['02461265-8706-4499-b892-f5e4de03aa08']}, {'qg_id': 's11', 'kg_id': ['3da52e60-36bd-420b-83a1-976f4c973956']}, {'qg_id': 's24', 'kg_id': ['822207b7-44d0-4ce5-b4c2-78bfb7aa2e1f']}, {'qg_id': 's3', 'kg_id': ['17eb7f10-87aa-4f24-8671-22e18f225273']}, {'qg_id': 's15', 'kg_id': ['1d55731a-c0b4-4d9f-b05a-3e7490c51d69']}, {'qg_id': 's1', 'kg_id': ['08c71b55-f1a4-4b94-b891-76ad6de9fe39']}, {'qg_id': 's12', 'kg_id': ['1d5b694d-1fdb-4ca4-9445-84644bad1045']}, {'qg_id': 's9', 'kg_id': ['37297b5b-6381-4b02-aff5-c38f495be95d']}, {'qg_id': 's20', 'kg_id': ['567f89be-087f-4f07-9781-b2e1f292f65e']}, {'qg_id': 's17', 'kg_id': ['e9fe85a5-3f03-4df2-9937-64b25d24b40c']}, {'qg_id': 's18', 'kg_id': ['d1d08aab-9b22-4d40-b184-3d69771b6a1d']}, {'qg_id': 's22', 'kg_id': ['3d16bca1-1dfe-4e5c-a076-601f03625a9c']}], 'score': 0.9852555701657868}, {'node_bindings': ...

# %%
#which genes enable glycolipid binding?
message = one_hop_message('GO:0051861','molecular_activity','gene','enabled_by')
results = striderandfriends(message)

# %%
#what part of the body does vasculitis affect?
message = one_hop_message('MONDO:0018882','disease','anatomical_entity','biolink:affects')
results = automat('uberongraph',message)
#results = striderandfriends(message)
print(message)
print(results)
# Out:
# 500
# {'message': {'query_graph': {'nodes': [{'id': 'a', 'type': 'disease', 'curie': 'MONDO:0018882'}, {'id': 'b', 'type': 'anatomical_entity'}], 'edges': [{'id': 'ab', 'source_id': 'a', 'target_id': 'b', 'type': 'biolink:affects'}]}, 'knowledge_graph': {'nodes': [], 'edges': []}, 'results': []}}
# {'error': ''}

# %%
#what are the types of diabetes?
message = one_hop_message('MONDO:0005015','disease','disease','subclass_of',reverse=True)
results = striderandfriends(message)
# Out:
# no answers
# {'query_graph': {'nodes': [{'id': 'a', 'curie': 'MONDO:0005015', 'type': 'disease'}, {'id': 'b', 'curie': None, 'type': 'disease'}], 'edges': [{'id': 'ab', 'source_id': 'b', 'target_id': 'a', 'type': 'subclass_of'}]}, 'knowledge_graph': {'nodes': [], 'edges': []}, 'results': []}

# %%
#message= one_hop_message('DOID:0050427','biolink:Disease','biolink:PhenotypicFeature','biolink:has_phenotype',reverse=False)
message= one_hop_message('MONDO:0019600','biolink:Disease','biolink:PhenotypicFeature','biolink:related_to',reverse=False)

message
# Out:
# {'message': {'query_graph': {'nodes': {'a': {'category': 'biolink:Disease',
#      'id': 'MONDO:0019600'},
#     'b': {'category': 'biolink:PhenotypicFeature'}},
#    'edges': {'ab': {'subject': 'a',
#      'object': 'b',
#      'predicate': 'biolink:related_to'}}}}}

# %%
response = requests.post('http://robokop.renci.org:5781/query',json=message)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': {'query_graph': {'nodes': {'a': {'id': 'MONDO:0019600',
#      'category': 'biolink:Disease',
#      'is_set': False},
#     'b': {'id': None,
#      'category': 'biolink:PhenotypicFeature',
#      'is_set': False}},
#    'edges': {'ab': {'subject': 'a',
#      'object': 'b',
#      'predicate': 'biolink:related_to',
#      'relation': None}}},
#   'knowledge_graph': {'nodes': {}, 'edges': {}},
#   'results': []},
#  'logs': []}

# %%
def automat(db,message):
    automat_url = f'https://automat.renci.org/{db}/query'
    #response = requests.post(automat_url,json=message['message'])
    response = requests.post(automat_url,json=message)
    print(response.status_code)
    return response.json()

# %%
message= one_hop_message('MONDO:0019600','biolink:Disease','biolink:PhenotypicFeature','biolink:related_to',reverse=False)

aresponse = requests.post('https://automat.renci.org/biolink/query',json=message)

# %%
aresponse.status_code
# Out:
# 200

# %%
aresponse.json()
# Out:
# {'message': {'query_graph': {'nodes': {'a': {'id': 'MONDO:0019600',
#      'category': 'biolink:Disease',
#      'is_set': False},
#     'b': {'id': None,
#      'category': 'biolink:PhenotypicFeature',
#      'is_set': False}},
#    'edges': {'ab': {'subject': 'a',
#      'object': 'b',
#      'predicate': 'biolink:related_to',
#      'relation': None}}},
#   'knowledge_graph': {'nodes': {'HP:0007603': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Freckles in sun-exposed areas',
#      'attributes': [{'type': 'NA',
#        'value': ['Freckles in sun-exposed areas'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Freckles in sun-exposed areas',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C1859923', 'HP:0007603'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000252': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': '',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormally small cranium',
#         'Abnormally small skull',
#         'Decreased size of cranium',
#         'Decreased size of skull',
#         'Decreased circumference of cranium',
#         'Reduced head circumference',
#         'small calvarium',
#         'small cranium',
#         'Small head circumference'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA', 'value': '', 'name': 'name', 'url': None, 'source': None},
#       {'type': 'NA',
#        'value': ['HP:0000252', 'UMLS:C4551563'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0025033': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': '',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA', 'value': '', 'name': 'name', 'url': None, 'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4293691', 'HP:0025033'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0010978': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of immune system physiology',
#      'attributes': [{'type': 'NA',
#        'value': 'Abnormality of immune system physiology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0010978', 'UMLS:C4023616'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0025031': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of the digestive system',
#      'attributes': [{'type': 'NA',
#        'value': 'Abnormality of the digestive system',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0025031'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0012638': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of nervous system physiology',
#      'attributes': [{'type': 'NA',
#        'value': 'Abnormality of nervous system physiology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0012638', 'UMLS:C4022811'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0012759': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Neurodevelopmental abnormality',
#      'attributes': [{'type': 'NA',
#        'value': 'Neurodevelopmental abnormality',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4022737', 'HP:0012759'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0003241': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'External genital hypoplasia',
#      'attributes': [{'type': 'NA',
#        'value': ['Underdevelopment of external reproductive organs',
#         'Hypogenitalism',
#         'Small genitalia'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'External genital hypoplasia',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0003241', 'UMLS:C1855333'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0012639': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of nervous system morphology',
#      'attributes': [{'type': 'NA',
#        'value': 'Abnormality of nervous system morphology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4022810', 'HP:0012639'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000492': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal eyelid morphology',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormality of the eyelid', 'Abnormality of the eyelids'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormal eyelid morphology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0000492', 'UMLS:C4021803'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011389': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Functional abnormality of the inner ear',
#      'attributes': [{'type': 'NA',
#        'value': ['Functional abnormality of the inner ear'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Functional abnormality of the inner ear',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0011389', 'UMLS:C4023382'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011821': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of facial skeleton',
#      'attributes': [{'type': 'NA',
#        'value': ['Anomaly of facial skeleton',
#         'Abnormality of facial skeleton'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of facial skeleton',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C2315229', 'HP:0011821', 'SNOMEDCT:433096001'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0032245': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': '',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA', 'value': '', 'name': 'name', 'url': None, 'source': None},
#       {'type': 'NA',
#        'value': ['HP:0032245', 'UMLS:C5139220'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011025': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal cardiovascular system physiology',
#      'attributes': [{'type': 'NA',
#        'value': 'Abnormal cardiovascular system physiology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0011025', 'UMLS:C4023587'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0100533': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Inflammatory abnormality of the eye',
#      'attributes': [{'type': 'NA',
#        'value': 'Inflammatory abnormality of the eye',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0100533', 'UMLS:C4020969'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000927': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of skeletal maturation',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormality of skeletal maturation'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of skeletal maturation',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0000927', 'UMLS:C4025818'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0012243': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal reproductive system morphology',
#      'attributes': [{'type': 'NA',
#        'value': 'Abnormal reproductive system morphology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4021096', 'HP:0012243'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011792': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Neoplasm by histology',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Neoplasm by histology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0011792', 'UMLS:C4023186'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0012244': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal sex determination',
#      'attributes': [{'type': 'NA',
#        'value': 'Abnormal sex determination',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0012244', 'UMLS:C4022996'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000929': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': '',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormality of the skull'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA', 'value': '', 'name': 'name', 'url': None, 'source': None},
#       {'type': 'NA',
#        'value': ['HP:0000929', 'UMLS:C0235942'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011793': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Neoplasm by anatomical site',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Neoplasm by anatomical site',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0011793', 'UMLS:C4023185'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000924': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of the skeletal system',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormality of the skeletal system',
#         'Skeletal abnormalities',
#         'Skeletal anomalies'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of the skeletal system',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4021790', 'HP:0000924'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0010461': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of the male genitalia',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormal male genitals',
#         'Abnormality of the male genitalia'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of the male genitalia',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4023819', 'HP:0010461'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0200034': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Papule',
#      'attributes': [{'type': 'NA',
#        'value': 'Papule',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['SNOMEDCT:443871003',
#         'SNOMEDCT:25694009',
#         'UMLS:C0858697',
#         'HP:0200034',
#         'UMLS:C0858695',
#         'UMLS:C0858696',
#         'HP:0031289',
#         'MEDDRA:10033733',
#         'UMLS:C0332563'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0004329': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal posterior eye segment morphology',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormal morphology of the posterior segment of the globe',
#         'Abnormality of the posterior segment of the eye',
#         'Abnormality of the posterior segment of the eyeball',
#         'Abnormality of the posterior segment of the globe'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormal posterior eye segment morphology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4025354', 'HP:0004329'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000762': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Decreased nerve conduction velocity',
#      'attributes': [{'type': 'NA',
#        'value': ['Decreased NCV',
#         'Decreased nerve conduction velocities',
#         'Delayed nerve conduction velocity',
#         'Reduced nerve conduction velocities',
#         'Slow nerve conduction velocity',
#         'Slowed nerve conduction velocities'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Decreased nerve conduction velocity',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0000762', 'UMLS:C1857640'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0004328': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal anterior eye segment morphology',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormal anterior segment morphology',
#         'Abnormality of the anterior segment of the eye',
#         'Abnormality of the anterior segment of the eyeball',
#         'Abnormality of the anterior segment of the globe'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormal anterior eye segment morphology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4025355', 'HP:0004328'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000002': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of body height',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormality of body height'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of body height',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0000002', 'UMLS:C4025901'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0004325': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Decreased body weight',
#      'attributes': [{'type': 'NA',
#        'value': ['Thin body habitus',
#         'Thin build',
#         'Asthenic habitus',
#         'Slender build',
#         'Decreased body weight',
#         'Decreased weight',
#         'Low body weight',
#         'Low weight',
#         'Weight less than 3rd percentile'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Decreased body weight',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['SNOMEDCT:248342006',
#         'SNOMEDCT:389350008',
#         'SNOMEDCT:206919000',
#         'UMLS:C0041667',
#         'SNOMEDCT:267158006',
#         'UMLS:C1262477',
#         'SNOMEDCT:61294007',
#         'SNOMEDCT:161832001',
#         'UMLS:C2363736',
#         'MESH:D015431',
#         'HP:0004325',
#         'UMLS:C1542746',
#         'UMLS:C1112280',
#         'SNOMEDCT:161834000',
#         'UMLS:C1844806',
#         'SNOMEDCT:262285001',
#         'UMLS:C0936227',
#         'NCIT:C3445',
#         'SNOMEDCT:390083004',
#         'SNOMEDCT:267024001',
#         'MESH:D013851',
#         'SNOMEDCT:139091004',
#         'UMLS:C0039870',
#         'SNOMEDCT:139089007',
#         'SNOMEDCT:448765001',
#         'SNOMEDCT:23712001',
#         'SNOMEDCT:89362005',
#         'HP:0001533',
#         'MEDDRA:10047895',
#         'HP:0001824',
#         'MEDDRA:10048828',
#         'SNOMEDCT:699205002',
#         'SNOMEDCT:158271000',
#         'MEDDRA:10000159',
#         'UMLS:C1850573',
#         'SNOMEDCT:60861008'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0006887': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Intellectual disability, progressive',
#      'attributes': [{'type': 'NA',
#        'value': ['Intellectual disability, progressive',
#         'Mental retardation, progressive',
#         'Progressive mental retardation'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Intellectual disability, progressive',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0006887', 'UMLS:C1846149'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0025142': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': '',
#      'attributes': [{'type': 'NA',
#        'value': '',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['NCIT:C38469', 'HP:0025142', 'UMLS:C0009812'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0001596': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Alopecia',
#      'attributes': [{'type': 'NA',
#        'value': ['Hair loss'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Alopecia',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['SNOMEDCT:23323004',
#         'UMLS:C3267164',
#         'UMLS:C0029489',
#         'SNOMEDCT:225056006',
#         'SNOMEDCT:268288009',
#         'UMLS:C0858678',
#         'SNOMEDCT:201156007',
#         'HP:0001596',
#         'UMLS:C0574770',
#         'MEDDRA:10001760',
#         'SNOMEDCT:205593003',
#         'UMLS:C0002182',
#         'UMLS:C0474893',
#         'UMLS:C0856677',
#         'UMLS:C0702167',
#         'SNOMEDCT:67488005',
#         'UMLS:C0860449',
#         'UMLS:C1541673',
#         'SNOMEDCT:298001000'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0001992': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Organic aciduria',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Organic aciduria',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C0241775', 'HP:0001992'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000022': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of male internal genitalia',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of male internal genitalia',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0000022', 'UMLS:C4025899'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0002683': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of the calvaria',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormality of calvarium',
#         'Abnormality of cranial vault',
#         'Abnormality of the skull cap',
#         'Abnormality of the skullcap'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of the calvaria',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4025691', 'HP:0002683', 'UMLS:C4280561'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0003011': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of the musculature',
#      'attributes': [{'type': 'NA',
#        'value': ['Muscular abnormality'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of the musculature',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4021745', 'HP:0003011'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0031287': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Seborrheic keratosis',
#      'attributes': [{'type': 'NA',
#        'value': 'Seborrheic keratosis',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0031287'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011138': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of skin adnexa morphology',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormal skin appendage'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of skin adnexa morphology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4023518', 'HP:0011138'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011017': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal cellular physiology',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormality of cell physiology'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormal cellular physiology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0011017', 'UMLS:C4023595'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0040156': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Elevated urinary carboxylic acid',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Elevated urinary carboxylic acid',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4022413', 'HP:0040156'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0012072': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Aciduria',
#      'attributes': [{'type': 'NA',
#        'value': 'Aciduria',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['SNOMEDCT:21806007', 'UMLS:C0278026', 'HP:0012072'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0001507': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Growth abnormality',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormal growth', 'Growth abnormality', 'Growth issue'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Growth abnormality',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0001507', 'UMLS:C0262361'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0008373': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Puberty and gonadal disorders',
#      'attributes': [{'type': 'NA',
#        'value': ['Puberty and gonadal disorders'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Puberty and gonadal disorders',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0008373', 'UMLS:C4024685'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0003808': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal muscle tone',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormal muscle tone'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormal muscle tone',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['MEDDRA:10028342', 'UMLS:C0852413', 'HP:0003808'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0001508': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Failure to thrive',
#      'attributes': [{'type': 'NA',
#        'value': ['Faltering weight',
#         'Weight faltering',
#         'Postnatal failure to thrive',
#         'Poor weight gain'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Failure to thrive',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['SNOMEDCT:206926000',
#         'SNOMEDCT:36440009',
#         'NCIT:C111659',
#         'UMLS:C4531021',
#         'UMLS:C0231246',
#         'HP:0001508',
#         'UMLS:C2315100',
#         'MEDDRA:10047897',
#         'SNOMEDCT:432788009',
#         'NCIT:C113099'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0100547': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of forebrain morphology',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormal shape of forebrain',
#         'Abnormality of the forebrain'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of forebrain morphology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4020967', 'HP:0100547'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0002715': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of the immune system',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormality of the immune system',
#         'Immunological abnormality'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of the immune system',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4021753', 'HP:0002715'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000812': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal internal genitalia',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormal internal genitalia'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormal internal genitalia',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0000812', 'UMLS:C4025824'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000811': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal external genitalia',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormal external genitalia'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormal external genitalia',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4025825', 'HP:0000811'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0008897': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Postnatal growth retardation',
#      'attributes': [{'type': 'NA',
#        'value': ['Growth delay as children',
#         'Growth retardation as children',
#         'Postnatal growth deceleration',
#         'Postnatal growth deficiency',
#         'Postnatal growth failure'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Postnatal growth retardation',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C1859778', 'HP:0008897'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0004337': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of amino acid metabolism',
#      'attributes': [{'type': 'NA',
#        'value': ['Amino acid levels abnormal'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of amino acid metabolism',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C1167673',
#         'UMLS:C1328440',
#         'MEDDRA:10063262',
#         'UMLS:C1112269',
#         'HP:0004337'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0001347': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Hyperreflexia',
#      'attributes': [{'type': 'NA',
#        'value': ['Increased deep tendon reflexes', 'Increased reflexes'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Hyperreflexia',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['NCIT:C43248',
#         'MEDDRA:10020745',
#         'UMLS:C0858575',
#         'UMLS:C0858574',
#         'UMLS:C0858573',
#         'UMLS:C0858576',
#         'HP:0001347',
#         'UMLS:C0151889',
#         'SNOMEDCT:86854008'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0002376': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Developmental regression',
#      'attributes': [{'type': 'NA',
#        'value': ['Loss of developmental milestones',
#         'Mental deterioration in childhood',
#         'Neurodevelopmental regression',
#         'Psychomotor regression',
#         'Psychomotor regression beginning in infancy',
#         'Psychomotor regression in infants',
#         'Psychomotor regression, progressive'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Developmental regression',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0002376',
#         'UMLS:C1836550',
#         'SNOMEDCT:609225004',
#         'MEDDRA:10076709',
#         'UMLS:C1836830',
#         'NCIT:C118200',
#         'UMLS:C1859678',
#         'UMLS:C1855019',
#         'UMLS:C1855009',
#         'UMLS:C1850493',
#         'UMLS:C1855996',
#         'UMLS:C1857121'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0003224': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Increased cellular sensitivity to UV light',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Increased cellular sensitivity to UV light',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0003224', 'UMLS:C1857707'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0002135': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Basal ganglia calcification',
#      'attributes': [{'type': 'NA',
#        'value': ['Basal ganglia calcifications',
#         'Basal ganglion calcification',
#         'Calcification of the basal ganglia'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Basal ganglia calcification',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0002135', 'UMLS:C1389280'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000078': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of the genital system',
#      'attributes': [{'type': 'NA',
#        'value': ['Genital abnormalities',
#         'Genital abnormality',
#         'Genital anomalies',
#         'Genital defects',
#         'Abnormality of the reproductive system'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of the genital system',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0000078', 'UMLS:C0744356', 'UMLS:C0281966'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0025015': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': '',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA', 'value': '', 'name': 'name', 'url': None, 'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4293699', 'HP:0025015'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0002493': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Upper motor neuron dysfunction',
#      'attributes': [{'type': 'NA',
#        'value': ['Corticospinal tract dysfunction',
#         'Pyramidal tract dysfunction'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Upper motor neuron dysfunction',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C1839042',
#         'NCIT:C43245',
#         'UMLS:C1504405',
#         'UMLS:C0235835',
#         'MEDDRA:10063636',
#         'HP:0002493'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011804': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal muscle physiology',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormality of muscle physiology',
#         'Issue with muscle function'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormal muscle physiology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0011804', 'UMLS:C4023182'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0012733': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Macule',
#      'attributes': [{'type': 'NA',
#        'value': 'Macule',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C0859040',
#         'UMLS:C0332573',
#         'HP:0012733',
#         'UMLS:C2089446',
#         'MEDDRA:10025421',
#         'SNOMEDCT:112629002',
#         'NCIT:C43278',
#         'UMLS:C0859039'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011368': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Epidermal thickening',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormality of keratinization'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Epidermal thickening',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0011368', 'UMLS:C0494876', 'UMLS:C4020752'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0012337': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal homeostasis',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormal homeostasis',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4022950', 'HP:0012337', 'MP:0001764'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0040170': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of hair growth',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of hair growth',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0040170', 'UMLS:C4073136'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011400': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal CNS myelination',
#      'attributes': [{'type': 'NA',
#        'value': 'Abnormal CNS myelination',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4021152', 'HP:0011400'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011124': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of epidermal morphology',
#      'attributes': [{'type': 'NA',
#        'value': 'Abnormality of epidermal morphology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C4023526', 'HP:0011124'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0010831': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Impaired proprioception',
#      'attributes': [{'type': 'NA',
#        'value': 'Impaired proprioception',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['UMLS:C1856691', 'HP:0010831'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:3000030': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of bony orbit of skull',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormality of the bony eye socket',
#         'Abnormality of the orbital bones of skull',
#         'Abnormality of bones of the orbit of the skull'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of bony orbit of skull',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:3000030', 'UMLS:C4073239'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011492': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of corneal stroma',
#      'attributes': [{'type': 'NA',
#        'value': 'Abnormality of corneal stroma',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0011492', 'UMLS:C4023328'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0011495': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormal corneal epithelium morphology',
#      'attributes': [{'type': 'NA',
#        'value': ['Abnormality of corneal epithelium'],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormal corneal epithelium morphology',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0011495', 'UMLS:C4023326'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0045058': {'category': ['biolink:NamedThing',
#       'biolink:DiseaseOrPhenotypicFeature',
#       'biolink:PhenotypicFeature'],
#      'name': 'Abnormality of the testis size',
#      'attributes': [{'type': 'NA',
#        'value': [],
#        'name': 'synonyms',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': 'Abnormality of the testis size',
#        'name': 'name',
#        'url': None,
#        'source': None},
#       {'type': 'NA',
#        'value': ['HP:0045058', 'UMLS:C4073180'],
#        'name': 'equivalent_identifiers',
#        'url': None,
#        'source': None}]},
#     'HP:0000502': {'category': ['biolink:NamedThing',
#       'biolink:BiologicalEntity',
# ...
#      'b': [{'id': 'HP:0011389'}]},
#     'edge_bindings': {'ab': [{'id': '7e9ac5914bf93409ae5fa769d034a465'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000153'}]},
#     'edge_bindings': {'ab': [{'id': '0a39246f30954b00c99660e3ac1c3ec1'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0002597'}]},
#     'edge_bindings': {'ab': [{'id': '207bbc048a16bf5fea2cd727fc815b00'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0045058'}]},
#     'edge_bindings': {'ab': [{'id': '388945d5387ccef85356abe881017200'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000152'}]},
#     'edge_bindings': {'ab': [{'id': '9c283af1d6900b6fee1f6d2860769746'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011492'}]},
#     'edge_bindings': {'ab': [{'id': '8aacea1e2e049efd014f8ba048f4cf39'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0005328'}]},
#     'edge_bindings': {'ab': [{'id': 'c4b7e63526910d0ddf7db344503cb5c1'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011017'}]},
#     'edge_bindings': {'ab': [{'id': '94bfa980e921f7b09ff8bbcbc42dd627'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0010461'}]},
#     'edge_bindings': {'ab': [{'id': '7b978470863ae906835bf80c57ebfa2b'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0003079'}]},
#     'edge_bindings': {'ab': [{'id': '6af89d880c21eb48827c20784eca3a85'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0001508'}]},
#     'edge_bindings': {'ab': [{'id': 'ac62b850355b40ac90000d419330bba4'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0012733'}]},
#     'edge_bindings': {'ab': [{'id': '8080df73099d1343e429664299f10243'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0031703'}]},
#     'edge_bindings': {'ab': [{'id': '026ee925b34827bd04cc2dc66e48b23b'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011277'}]},
#     'edge_bindings': {'ab': [{'id': '9525f06ce0aa0c153847d7d28fd0f7ad'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011804'}]},
#     'edge_bindings': {'ab': [{'id': '4d55307574784b95f60d1e983256a43d'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0002120'}]},
#     'edge_bindings': {'ab': [{'id': 'cfbcb6cbfb68b62dfe638ab476b6012f'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000022'}]},
#     'edge_bindings': {'ab': [{'id': '8847e4cd1d922c61dafad451b93301d0'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0010468'}]},
#     'edge_bindings': {'ab': [{'id': '7710158f92118c1a0d7df8b39f6e9068'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0004354'}]},
#     'edge_bindings': {'ab': [{'id': '3520c4af7d1168df5cc943e0b1bea681'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0007364'}]},
#     'edge_bindings': {'ab': [{'id': 'a1f16c4dcdd826118eee5131d52f0f15'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011443'}]},
#     'edge_bindings': {'ab': [{'id': '1605b8ef5f63c773958891d483d460b4'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011442'}]},
#     'edge_bindings': {'ab': [{'id': '17d380c4f49c3511d05e8f2d957cd44c'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000050'}]},
#     'edge_bindings': {'ab': [{'id': '531cad4b4f89e43f7bcce9580530539e'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0001029'}]},
#     'edge_bindings': {'ab': [{'id': 'e698c23f1f6b2fc2132b45d65a324f3a'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000502'}]},
#     'edge_bindings': {'ab': [{'id': '9294718cf1bd297c960ad4e2bd3535e0'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0003808'}]},
#     'edge_bindings': {'ab': [{'id': 'be1c8bcf36794c93a3a83929cfd4b27d'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0012056'}]},
#     'edge_bindings': {'ab': [{'id': '008a1c016a024505999cf3ffb0e43979'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000078'}]},
#     'edge_bindings': {'ab': [{'id': '62e70634ae96ec89c5f0be47b054a260'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0004325'}]},
#     'edge_bindings': {'ab': [{'id': '047cc2dffc90881aa30d0a50443e52e5'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000079'}]},
#     'edge_bindings': {'ab': [{'id': 'a6f1300acbc83587095268bd7b3df192'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0001098'}]},
#     'edge_bindings': {'ab': [{'id': '60541029e3c26594fcbff920686a6489'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0006887'}]},
#     'edge_bindings': {'ab': [{'id': '1d8db23e9ce7375c8d7b45ca79f79ba5'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0004493'}]},
#     'edge_bindings': {'ab': [{'id': '0eac5bc9140b2d1923d93ec1b7ebaf60'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0001034'}]},
#     'edge_bindings': {'ab': [{'id': '0f7ebc8384b61392dbbabf2b8bf7ea71'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0002472'}]},
#     'edge_bindings': {'ab': [{'id': 'f21d2b85f9040f2e2bddefb49950ea46'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011122'}]},
#     'edge_bindings': {'ab': [{'id': 'f126aaa8572ad68274544fd8287b7ca2'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0002135'}]},
#     'edge_bindings': {'ab': [{'id': 'd0f605055b0498cd5d065399fa338bd2'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0410009'}]},
#     'edge_bindings': {'ab': [{'id': '0f842f859893b010a452206a82015dbc'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0002119'}]},
#     'edge_bindings': {'ab': [{'id': 'b39fcaa8d107f602e0c225728fa9ba5b'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0003241'}]},
#     'edge_bindings': {'ab': [{'id': '06346ae56afef74defb87c3e80a9c0ff'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000762'}]},
#     'edge_bindings': {'ab': [{'id': '83f52ff54971dd205cdb39a62fb31fed'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0100585'}]},
#     'edge_bindings': {'ab': [{'id': '5dc109a528ee056fd78fbb6a1b77048d'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000364'}]},
#     'edge_bindings': {'ab': [{'id': '64c96a6c6e78ad315632f9d4118538fb'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000118'}]},
#     'edge_bindings': {'ab': [{'id': 'ce89214443eafc8ff0854890dd893adf'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000032'}]},
#     'edge_bindings': {'ab': [{'id': 'aaa9bcbfcef2e252febea80012cea428'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0007400'}]},
#     'edge_bindings': {'ab': [{'id': '59ce901eb0bf744d89df2547aab2e457'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000549'}]},
#     'edge_bindings': {'ab': [{'id': '0d65d294da7ce46a05c39ee5db965cb8'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0012649'}]},
#     'edge_bindings': {'ab': [{'id': 'd19e0fda5807778eb604989657740080'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0002977'}]},
#     'edge_bindings': {'ab': [{'id': 'd23535c6b320ba07ec771ee7ce5ea7f7'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0004370'}]},
#     'edge_bindings': {'ab': [{'id': '3feaaba1159dd8082f264e58211921ef'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0040195'}]},
#     'edge_bindings': {'ab': [{'id': '10c8dc834d39e386fac8a57ca018f6a6'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0031826'}]},
#     'edge_bindings': {'ab': [{'id': 'd16e82abe06827c07616b9c2e0680e54'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0002538'}]},
#     'edge_bindings': {'ab': [{'id': 'a20c2164f1dd8bc73a328bcd46664ff0'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0001347'}]},
#     'edge_bindings': {'ab': [{'id': 'efeee8fee59fe7a422ef337c0f3b17d7'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0010649'}]},
#     'edge_bindings': {'ab': [{'id': 'e39b311df1c39cf0656f1db5a8377b98'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0004437'}]},
#     'edge_bindings': {'ab': [{'id': '05285178a9053fee64b11b985970a613'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011821'}]},
#     'edge_bindings': {'ab': [{'id': 'ec1e2df2bec35d065abb0f2b79ea14a2'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011793'}]},
#     'edge_bindings': {'ab': [{'id': '94aa1c07fa30923552ebac3c1b366436'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0002861'}]},
#     'edge_bindings': {'ab': [{'id': 'cf42132634dae6043d2993f094e15455'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000812'}]},
#     'edge_bindings': {'ab': [{'id': 'b9459e36fbfb118c0718044377f70324'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000234'}]},
#     'edge_bindings': {'ab': [{'id': '57629ed5f4e6b3e538fd4f964a80923b'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011025'}]},
#     'edge_bindings': {'ab': [{'id': 'c27153b1e56a3b7aea7700b98d6327ba'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0002683'}]},
#     'edge_bindings': {'ab': [{'id': 'ff536ac924191459771c8c79ad394777'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0012639'}]},
#     'edge_bindings': {'ab': [{'id': '3378972beaae1065fa558f771d95c7c2'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011792'}]},
#     'edge_bindings': {'ab': [{'id': 'd633ef3ec9fe415e5588b698c14df6f7'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011283'}]},
#     'edge_bindings': {'ab': [{'id': 'ba9ac4719ebcb1bd052d15780fda137b'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011368'}]},
#     'edge_bindings': {'ab': [{'id': '9eb8ca9122e940e6e3fa21d4b83b1293'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011400'}]},
#     'edge_bindings': {'ab': [{'id': 'a583a9af8f2341b13e6b03132a5338e8'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0001596'}]},
#     'edge_bindings': {'ab': [{'id': '14503bff35132c45b4ababfe9d2f2c9c'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000924'}]},
#     'edge_bindings': {'ab': [{'id': '71cf86a88f3dc585c51a2fa9b1c4966c'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011121'}]},
#     'edge_bindings': {'ab': [{'id': '9bf9f1d70222b160d489546ad9af542a'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000315'}]},
#     'edge_bindings': {'ab': [{'id': '334d4769096826c29028d20ffa0c46f7'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011356'}]},
#     'edge_bindings': {'ab': [{'id': 'b75a71080ecf6f82fbb729df149e9381'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0100579'}]},
#     'edge_bindings': {'ab': [{'id': 'f2e52ea83f63158cbb3c4793ea9ba103'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0025031'}]},
#     'edge_bindings': {'ab': [{'id': '255d8413955bb7eef877a65ebd835104'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000580'}]},
#     'edge_bindings': {'ab': [{'id': '5c192402093b30276da4b8f0f63fe1ae'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0001939'}]},
#     'edge_bindings': {'ab': [{'id': '5668e31393cc6e8ba30cd65a389f8dcf'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0025033'}]},
#     'edge_bindings': {'ab': [{'id': 'edc4bf2ab7ad1ad03ad78661790bacf6'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0004323'}]},
#     'edge_bindings': {'ab': [{'id': '6757b9479244a2fda2212fcefff726cf'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0008373'}]},
#     'edge_bindings': {'ab': [{'id': '3d86868b974f4f09af78ff9a05eb7bdc'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0008054'}]},
#     'edge_bindings': {'ab': [{'id': 'a9650e7fa4f37fd3257fc59d5acf5d4b'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0001992'}]},
#     'edge_bindings': {'ab': [{'id': 'ca2cc844dcecd2a4387173f5f8416aa5'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0100547'}]},
#     'edge_bindings': {'ab': [{'id': '22c4967094c24ce4b75fb808db54b3c9'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0200034'}]},
#     'edge_bindings': {'ab': [{'id': 'b8332fe8031906446c29af77497e8c25'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0011842'}]},
#     'edge_bindings': {'ab': [{'id': '51896828e7b46ed842892798f6c1120e'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0003011'}]},
#     'edge_bindings': {'ab': [{'id': '2146ff7b23eb5f28044ccc13565dc865'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0001093'}]},
#     'edge_bindings': {'ab': [{'id': 'ad483828a6031463ca5ca7a989cafab8'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0002750'}]},
#     'edge_bindings': {'ab': [{'id': 'aba80301acfed8fd53b30f47fe1aff01'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0004328'}]},
#     'edge_bindings': {'ab': [{'id': '8903e3eda346be7b732eaacd77f58a7a'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0001574'}]},
#     'edge_bindings': {'ab': [{'id': 'ecca89b9402087ff7c6a873868869172'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0012337'}]},
#     'edge_bindings': {'ab': [{'id': '04af8f339cbf1f4a7a9202a7ac217e5e'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0001510'}]},
#     'edge_bindings': {'ab': [{'id': 'a75ea3cdd389ee334d0a53e62c2d5057'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0010938'}]},
#     'edge_bindings': {'ab': [{'id': '593e07e8ddf9d4bd2bd417fef875be83'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0031816'}]},
#     'edge_bindings': {'ab': [{'id': 'a2f1fc9196dafc0d97f801e5496fc3df'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0002376'}]},
#     'edge_bindings': {'ab': [{'id': 'aec50d5bc85f7d2321dba668c41d9191'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0000927'}]},
#     'edge_bindings': {'ab': [{'id': '6a2d6eab5e73570c4840b080c87d0bb5'}]}},
#    {'node_bindings': {'a': [{'id': 'MONDO:0019600'}],
#      'b': [{'id': 'HP:0012372'}]},
#     'edge_bindings': {'ab': [{'id': '0d64458577b488717d4e8b3fd50963a7'}]}}]}}

# %%
from reasoner_validator import validate_Message, ValidationError
def v(m):
    try:
        validate_Message(m)
        print ('Valid!')
    except ValidationError:
        print('Invalid!')

# %%
message= one_hop_message('MONDO:0019600','biolink:Disease','biolink:PhenotypicFeature',None,reverse=False)

# %%
v(message)
# Out:
# Valid!
