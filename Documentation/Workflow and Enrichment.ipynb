# %%
import requests
import json

# %% [markdown]
# TRAPI Documentation: https://github.com/NCATSTranslator/ReasonerAPI
#
# Most TRAPI documents contain a `message` key.  Within that `message` are a `query_graph` denoting the user query,
# a `knowledge_graph` consisting of the union of all nodes and edges that match the `query_graph` pattern, and a list of `results` that bind `query_graph` elements to `knowledge_graph` elements.
#
# The following message contains only a `query_graph`.  This query graph consists of 2 nodes connected together in a line.
#
# This query asks "Find me a chemical that treats Alzheimer's Disease".

# %%
query={
    "message": {
      "query_graph": {
        "edges": {
          "e00": {
            "subject": "chemical",
              "object": "disease",
              "predicates":["biolink:treats"]
          }
        },
        "nodes": {
          "chemical": {
            "categories": ["biolink:ChemicalEntity"]
          },
          "disease": {
            "ids": ["MONDO:0004975"],
            #  "ids":["MONDO:0018956"]
          }
        }
      }
    },
    "workflow": [{"id":"lookup"}]
  }

# %% [markdown]
# This query can be sent to various components of Translator as needed.  We are going to send it to the renci-dev version of aragorn.

# %%
aragorn_url = "http://127.0.0.1:4868/aragorn/query"
response = requests.post(aragorn_url,json=query)

# %%
result = response.json()

# %%
result.keys()
# Out:
# dict_keys(['message', 'log_level', 'status', 'logs', 'pid'])

# %%
result['message'].keys()
# Out:
# dict_keys(['query_graph', 'knowledge_graph', 'results'])

# %%
len(result['message']['results'])
# Out:
# 2331

# %%
print(json.dumps(result['message']['results'][0],indent=2))
# Out:
# {
#   "node_bindings": {
#     "chemical": [
#       {
#         "id": "PUBCHEM.COMPOUND:5284607"
#       }
#     ],
#     "disease": [
#       {
#         "id": "MONDO:0004975"
#       }
#     ]
#   },
#   "edge_bindings": {
#     "e00": [
#       {
#         "id": "faf8510d2547",
#         "attributes": null
#       },
#       {
#         "id": "4c468e80ebbd",
#         "attributes": null
#       }
#     ]
#   },
#   "score": null
# }

# %%
result['message']['knowledge_graph']['nodes']['PUBCHEM.COMPOUND:5284607']
# Out:
# {'categories': ['biolink:SmallMolecule', 'biolink:ChemicalEntity'],
#  'name': 'Phytonadione',
#  'attributes': [{'attribute_type_id': 'biolink:full_name',
#    'value': 'VITAMIN K',
#    'value_type_id': None,
#    'original_attribute_name': 'pref_name',
#    'value_url': None,
#    'attribute_source': None,
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:id',
#    'value': '',
#    'value_type_id': None,
#    'original_attribute_name': 'inchi',
#    'value_url': None,
#    'attribute_source': None,
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:IriType',
#    'value': 'https://identifiers.org/chembl.compound:CHEMBL1201519',
#    'value_type_id': 'metatype:Uri',
#    'original_attribute_name': None,
#    'value_url': 'https://identifiers.org/chembl.compound:CHEMBL1201519',
#    'attribute_source': None,
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:highest_FDA_approval_status',
#    'value': 'regular approval',
#    'value_type_id': None,
#    'original_attribute_name': 'max_phase',
#    'value_url': None,
#    'attribute_source': None,
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:category',
#    'value': ['biolink:ChemicalEntity',
#     'biolink:SmallMolecule',
#     'biolink:MolecularEntity',
#     'biolink:Drug'],
#    'value_type_id': 'metatype:Uriorcurie',
#    'original_attribute_name': None,
#    'value_url': None,
#    'attribute_source': None,
#    'description': 'Categories of all nodes in this synonym set in RTX-KG2.',
#    'attributes': None},
#   {'attribute_type_id': 'biolink:synonym',
#    'value': ['Phytonadione',
#     'VITAMIN K',
#     'PHYTONADIONE',
#     'PHYTONADIONE, (E)-(+/-)-',
#     'PHYTONADIONE, (E)-',
#     'phylloquinone',
#     'Vitamin K 1',
#     'phytomenadione',
#     'Phylloquinol',
#     'Konakion',
#     'Aquamephyton',
#     'Phyllohydroquinone'],
#    'value_type_id': None,
#    'original_attribute_name': None,
#    'value_url': None,
#    'attribute_source': None,
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:xref',
#    'value': ['UMLS:C0140139',
#     'UMLS:C0740141',
#     'UMLS:C0591689',
#     'UMLS:C0113994',
#     'HMDB:HMDB0304722',
#     'ATC:B02BA01',
#     'VANDF:4018981',
#     'UMLS:C0042878',
#     'CHEBI:8784',
#     'LOINC:LP17945-4',
#     'UMLS:C0914046',
#     'UMLS:C0031862',
#     'RXNORM:8308',
#     'CHEBI:28433',
#     'MESH:D014812',
#     'LOINC:LP31699-9',
#     'LOINC:LP31700-5',
#     'NCIT:C943',
#     'VANDF:4017772',
#     'HMDB:HMDB0004198',
#     'CHEBI:28384',
#     'VANDF:4021719',
#     'KEGG.COMPOUND:C02059',
#     'CHEMBL.COMPOUND:CHEMBL520156',
#     'KEGG.COMPOUND:C01628',
#     'KEGG.COMPOUND:C05850',
#     'CHEMBL.COMPOUND:CHEMBL1201519',
#     'CHEBI:18067',
#     'PathWhiz.Compound:2089',
#     'MESH:D010837',
#     'KEGG.DRUG:D00148',
#     'VANDF:4021911',
#     'NCIT:C29365',
#     'MESH:C028843',
#     'LOINC:MTHU024798',
#     'PathWhiz.Compound:57915',
#     'PDQ:CDR0000786611',
#     'HMDB:HMDB0003555',
#     'DRUGBANK:DB01022',
#     'RXNORM:11258',
#     'UMLS:C0078378',
#     'KEGG.COMPOUND:C03313',
#     'PathWhiz.Compound:1924',
#     'DrugCentral:2843',
#     'CHEMBL.COMPOUND:CHEMBL1550',
#     'PDQ:CDR0000765353'],
#    'value_type_id': 'metatype:Nodeidentifier',
#    'original_attribute_name': None,
#    'value_url': None,
#    'attribute_source': None,
#    'description': 'Identifiers of all nodes in this synonym set in RTX-KG2.',
#    'attributes': None},
#   {'attribute_type_id': 'biolink:id',
#    'value': '',
#    'value_type_id': None,
#    'original_attribute_name': 'inchikey_prefix',
#    'value_url': None,
#    'attribute_source': None,
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:source',
#    'value': 'ChEMBL',
#    'value_type_id': None,
#    'original_attribute_name': 'source',
#    'value_url': None,
#    'attribute_source': None,
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:id',
#    'value': 'CHEMBL1201519',
#    'value_type_id': None,
#    'original_attribute_name': 'chembl_id',
#    'value_url': None,
#    'attribute_source': None,
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:id',
#    'value': '',
#    'value_type_id': None,
#    'original_attribute_name': 'canonical_smiles',
#    'value_url': None,
#    'attribute_source': None,
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:synonym',
#    'value': ['vitamin K1',
#     'Vitamin K1',
#     'Vitamin k',
#     'Phytonadione',
#     'SID29215362',
#     'Phytonadione (JP18/USP)',
#     'vitamin K',
#     'dihydroxyvitamin K',
#     'VITAMIN K',
#     'phytomenadione',
#     'Konakion',
#     'Reduced Vitamin K (phylloquinone)',
#     'Phylloquinone',
#     'Vitamin K 1',
#     'Phyllohydroquinone',
#     'phytonadione',
#     'reduced vitamin K',
#     'phyllohydroquinone',
#     'PHYTONADIONE',
#     'Phylloquinol',
#     'Aquamephyton',
#     'Vitamin K',
#     'phylloquinone',
#     'vitamin K1 hydroquinone',
#     'Reduced Vitamin K'],
#    'value_type_id': 'metatype:String',
#    'original_attribute_name': None,
#    'value_url': None,
#    'attribute_source': None,
#    'description': 'Names of all nodes in this synonym set in RTX-KG2.',
#    'attributes': None},
#   {'attribute_type_id': 'biolink:description',
#    'value': 'The term "vitamin K" refers to a group of chemically similar fat-soluble compounds called naphthoquinones: vitamin K1 (phytonadione) is found in plants and is the primary source of vitamin K for humans through dietary consumption, vitamin K2 compounds (menaquinones) are made by bacteria in the human gut, and vitamin K3 (menadione) is a water-soluble preparation available for adults only. Vitamin K is necessary for the liver to produce the coagulation factors II, VII, IX, and X, as well as the clotting factors protein C, protein S, and protein Z; vitamin K deficiency can result in deficiencies of these coagulation factors and excess bleeding. An injection of vitamin K is routinely given to newborn infants to prevent vitamin K deficiency bleeding, also known as hemorrhagic disease of the newborn. Vitamin K deficiency is rare in adults but may result from chronic malnutrition or an inability to absorb dietary vitamins. Check for "https://www.cancer.gov/about-cancer/treatment/clinical-trials/intervention/C943" active clinical trials using this agent. ("http://ncit.nci.nih.gov/ncitbrowser/ConceptReport.jsp?dictionary=NCI%20Thesaurus&code=C943" NCI Thesaurus); The term "vitamin K" refers to a group of chemically similar fat-soluble compounds called naphthoquinones: vitamin K1 (phytonadione) is found in plants and is the primary source of vitamin K for humans through dietary consumption, vitamin K2 compounds (menaquinones) are made by bacteria in the human gut, and vitamin K3 (menadione) is a water-soluble preparation available for adults only. Vitamin K is necessary for the liver to produce the coagulation factors II, VII, IX, and X, as well as the clotting factors protein C, protein S, and protein Z; vitamin K deficiency can result in deficiencies of these coagulation factors and excess bleeding. An injection of vitamin K is routinely given to newborn infants to prevent vitamin K deficiency bleeding, also known as hemorrhagic disease of the newborn. Vitamin K deficiency is rare in adults but may result from chronic malnutrition or an inability to absorb dietary vitamins.; A lipid cofactor that is required for normal blood clotting. Several forms of vitamin K have been identified: VITAMIN K 1 (phytomenadione) derived from plants, VITAMIN K 2 (menaquinone) from bacteria, and synthetic naphthoquinone provitamins, VITAMIN K 3 (menadione). Vitamin K 3 provitamins, after being alkylated in vivo, exhibit the antifibrinolytic activity of vitamin K. Green leafy vegetables, liver, cheese, butter, and egg yolk are good sources of vitamin K.; Vitamins are substances that your body needs to grow and develop normally. Vitamin K helps your body by making proteins for healthy bones and tissues. It also makes proteins for blood clotting. If you don\'t have enough vitamin K, you may bleed too much. Newborns have very little vitamin K. They usually get a shot of vitamin K soon after they are born. If you take blood thinners, you need to be careful about how much vitamin K you get. You also need to be careful about taking vitamin E supplements. Vitamin E can interfere with how vitamin K works in your body. Ask your health care provider for recommendations about these vitamins. There are different types of vitamin K. Most people get vitamin K from plants such as green vegetables, and dark berries. Bacteria in your intestines also produce small amounts of another type of vitamin K.; UMLS Semantic Type: STY:T121; UMLS Semantic Type: STY:T127; UMLS Semantic Type: STY:T109; UMLS Semantic Type: STY:T121; UMLS Semantic Type: STY:T127; UMLS Semantic Type: STY:T109',
#    'value_type_id': 'metatype:String',
#    'original_attribute_name': None,
#    'value_url': None,
#    'attribute_source': None,
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:xref',
#    'value': ['PUBCHEM.COMPOUND:5284607',
#     'CHEMBL.COMPOUND:CHEMBL1201519',
#     'CHEMBL.COMPOUND:CHEMBL1550',
#     'UNII:A034SE7857',
#     'UNII:MLF3D1712D',
#     'UNII:S5Z3U87QHF',
#     'CHEBI:18067',
#     'DRUGBANK:DB01022',
#     'MESH:D010837',
#     'CAS:10485-69-5',
#     'CAS:11104-38-4',
#     'CAS:79083-00-4',
#     'CAS:84-80-0',
#     'DrugCentral:2843',
#     'HMDB:HMDB0004198',
#     'HMDB:HMDB0015157',
#     'INCHIKEY:MBWXNTAXLNYFJB-NKFFZRIASA-N',
#     'UMLS:C0031862',
#     'UMLS:C0591689',
#     'UMLS:C0740141',
#     'UMLS:C0914046'],
#    'value_type_id': None,
#    'original_attribute_name': None,
#    'value_url': None,
#    'attribute_source': None,
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:publications',
#    'value': ['PMID:17629592',
#     'PMID:10893417',
#     'PMID:1009028',
#     'PMID:15646539',
#     'PMID:10701947',
#     'PMID:20185316',
#     'PMID:11413487',
#     'PMID:22194678',
#     'PMID:15773196',
#     'PMID:17374880'],
#    'value_type_id': 'biolink:Uriorcurie',
#    'original_attribute_name': None,
#    'value_url': None,
#    'attribute_source': None,
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:id',
#    'value': '',
#    'value_type_id': None,
#    'original_attribute_name': 'inchikey',
#    'value_url': None,
#    'attribute_source': None,
#    'description': None,
#    'attributes': None}]}

# %%
result['message']['knowledge_graph']['edges']['faf8510d2547']
# Out:
# {'subject': 'PUBCHEM.COMPOUND:5284607',
#  'object': 'MONDO:0004975',
#  'predicate': 'biolink:treats',
#  'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#    'value': 'infores:chembl',
#    'value_type_id': 'biolink:InformationResource',
#    'original_attribute_name': 'source',
#    'value_url': None,
#    'attribute_source': 'infores:spoke',
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:has_confidence_level',
#    'value': 1,
#    'value_type_id': None,
#    'original_attribute_name': 'phase',
#    'value_url': None,
#    'attribute_source': 'infores:chembl',
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#    'value': 'infores:spoke',
#    'value_type_id': 'biolink:InformationResource',
#    'original_attribute_name': None,
#    'value_url': None,
#    'attribute_source': 'infores:spoke',
#    'description': None,
#    'attributes': None},
#   {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#    'value': 'infores:aragorn',
#    'value_type_id': 'biolink:InformationResource',
#    'original_attribute_name': None,
#    'value_url': None,
#    'attribute_source': 'infores:aragorn',
#    'description': None,
#    'attributes': None}]}

# %%
result['workflow']=[{"id":"enrich_results"}]

# %%
aragorn_url = "http://127.0.0.1:4868/aragorn/query"
response2 = requests.post(aragorn_url,json=result)

# %%
result2 = response2.json()

# %%
len(result2['message']['results'])
# Out:
# 4623

# %%
for i in range(100):
    print(i,result2['message']['results'][i]['node_bindings'].keys())
# Out:
# 0 dict_keys(['chemical', 'disease'])
# 1 dict_keys(['chemical', 'disease'])
# 2 dict_keys(['chemical', 'disease'])
# 3 dict_keys(['chemical', 'disease'])
# 4 dict_keys(['chemical', 'disease'])
# 5 dict_keys(['chemical', 'disease'])
# 6 dict_keys(['chemical', 'disease'])
# 7 dict_keys(['chemical', 'disease'])
# 8 dict_keys(['chemical', 'disease'])
# 9 dict_keys(['chemical', 'disease'])
# 10 dict_keys(['chemical', 'disease'])
# 11 dict_keys(['chemical', 'disease'])
# 12 dict_keys(['chemical', 'disease'])
# 13 dict_keys(['chemical', 'disease'])
# 14 dict_keys(['chemical', 'disease'])
# 15 dict_keys(['chemical', 'disease'])
# 16 dict_keys(['chemical', 'disease'])
# 17 dict_keys(['disease', 'chemical'])
# 18 dict_keys(['chemical', 'disease'])
# 19 dict_keys(['chemical', 'disease'])
# 20 dict_keys(['chemical', 'disease'])
# 21 dict_keys(['chemical', 'disease'])
# 22 dict_keys(['chemical', 'disease'])
# 23 dict_keys(['chemical', 'disease'])
# 24 dict_keys(['chemical', 'disease'])
# 25 dict_keys(['chemical', 'disease'])
# 26 dict_keys(['chemical', 'disease'])
# 27 dict_keys(['chemical', 'disease'])
# 28 dict_keys(['chemical', 'disease'])
# 29 dict_keys(['chemical', 'disease'])
# 30 dict_keys(['chemical', 'disease'])
# 31 dict_keys(['chemical', 'disease'])
# 32 dict_keys(['chemical', 'disease'])
# 33 dict_keys(['chemical', 'disease'])
# 34 dict_keys(['chemical', 'disease'])
# 35 dict_keys(['chemical', 'disease'])
# 36 dict_keys(['chemical', 'disease'])
# 37 dict_keys(['chemical', 'disease'])
# 38 dict_keys(['chemical', 'disease'])
# 39 dict_keys(['chemical', 'disease'])
# 40 dict_keys(['chemical', 'disease'])
# 41 dict_keys(['chemical', 'disease'])
# 42 dict_keys(['chemical', 'disease'])
# 43 dict_keys(['chemical', 'disease'])
# 44 dict_keys(['chemical', 'disease'])
# 45 dict_keys(['chemical', 'disease'])
# 46 dict_keys(['chemical', 'disease'])
# 47 dict_keys(['chemical', 'disease'])
# 48 dict_keys(['chemical', 'disease'])
# 49 dict_keys(['chemical', 'disease', '_n_ac_51_0'])
# 50 dict_keys(['chemical', 'disease', '_n_ac_53_0'])
# 51 dict_keys(['chemical', 'disease', '_n_ac_54_0'])
# 52 dict_keys(['chemical', 'disease', '_n_ac_55_0'])
# 53 dict_keys(['chemical', 'disease', '_n_ac_56_0'])
# 54 dict_keys(['chemical', 'disease', '_n_ac_57_0'])
# 55 dict_keys(['chemical', 'disease', '_n_ac_58_0'])
# 56 dict_keys(['chemical', 'disease', '_n_ac_59_0'])
# 57 dict_keys(['chemical', 'disease', '_n_ac_60_0'])
# 58 dict_keys(['chemical', 'disease', '_n_ac_61_0'])
# 59 dict_keys(['chemical', 'disease', '_n_ac_62_0'])
# 60 dict_keys(['chemical', 'disease', '_n_ac_63_0'])
# 61 dict_keys(['chemical', 'disease', '_n_ac_64_0'])
# 62 dict_keys(['chemical', 'disease', '_n_ac_65_0'])
# 63 dict_keys(['chemical', 'disease', '_n_ac_66_0'])
# 64 dict_keys(['chemical', 'disease', '_n_ac_67_0'])
# 65 dict_keys(['chemical', 'disease', '_n_ac_68_0'])
# 66 dict_keys(['chemical', 'disease', '_n_ac_69_0'])
# 67 dict_keys(['chemical', 'disease', '_n_ac_70_0'])
# 68 dict_keys(['chemical', 'disease', '_n_ac_71_0'])
# 69 dict_keys(['chemical', 'disease', '_n_ac_72_0'])
# 70 dict_keys(['chemical', 'disease', '_n_ac_73_0'])
# 71 dict_keys(['chemical', 'disease', '_n_ac_74_0'])
# 72 dict_keys(['chemical', 'disease', '_n_ac_75_0'])
# 73 dict_keys(['chemical', 'disease', '_n_ac_76_0'])
# 74 dict_keys(['chemical', 'disease', '_n_ac_77_0'])
# 75 dict_keys(['chemical', 'disease', '_n_ac_78_0'])
# 76 dict_keys(['chemical', 'disease', '_n_ac_79_0'])
# 77 dict_keys(['chemical', 'disease', '_n_ac_80_0'])
# 78 dict_keys(['chemical', 'disease', '_n_ac_81_0'])
# 79 dict_keys(['chemical', 'disease', '_n_ac_82_0'])
# 80 dict_keys(['chemical', 'disease', '_n_ac_83_0'])
# 81 dict_keys(['chemical', 'disease', '_n_ac_84_0'])
# 82 dict_keys(['chemical', 'disease', '_n_ac_85_0'])
# 83 dict_keys(['chemical', 'disease', '_n_ac_86_0'])
# 84 dict_keys(['chemical', 'disease', '_n_ac_87_0'])
# 85 dict_keys(['chemical', 'disease', '_n_ac_88_0'])
# 86 dict_keys(['chemical', 'disease', '_n_ac_89_0'])
# 87 dict_keys(['chemical', 'disease', '_n_ac_90_0'])
# 88 dict_keys(['chemical', 'disease', '_n_ac_91_0'])
# 89 dict_keys(['chemical', 'disease', '_n_ac_92_0'])
# 90 dict_keys(['chemical', 'disease', '_n_ac_93_0'])
# 91 dict_keys(['chemical', 'disease', '_n_ac_94_0'])
# 92 dict_keys(['chemical', 'disease', '_n_ac_95_0'])
# 93 dict_keys(['chemical', 'disease', '_n_ac_96_0'])
# 94 dict_keys(['chemical', 'disease', '_n_ac_97_0'])
# 95 dict_keys(['chemical', 'disease', '_n_ac_98_0'])
# 96 dict_keys(['chemical', 'disease', '_n_ac_99_0'])
# 97 dict_keys(['chemical', 'disease', '_n_ac_100_0'])
# 98 dict_keys(['chemical', 'disease', '_n_ac_101_0'])
# 99 dict_keys(['chemical', 'disease', '_n_ac_102_0'])

# %%
print(json.dumps(result2['message']['results'][55],indent=2))
# Out:
# {
#   "node_bindings": {
#     "chemical": [
#       {
#         "id": "NCBIGene:3827",
#         "attributes": [
#           {
#             "original_attribute_name": "coalescence_method",
#             "attribute_type_id": "biolink:has_attribute",
#             "value": "graph_enrichment",
#             "value_type_id": "EDAM:operation_0004"
#           },
#           {
#             "original_attribute_name": "p_value",
#             "attribute_type_id": "biolink:has_numeric_value",
#             "value": 0.0,
#             "value_type_id": "EDAM:data_1669"
#           },
#           {
#             "original_attribute_name": "enriched_nodes",
#             "attribute_type_id": "biolink:has_attribute",
#             "value": [
#               "GO:0001775"
#             ],
#             "value_type_id": "EDAM:data_0006"
#           }
#         ]
#       },
#       {
#         "id": "NCBIGene:3952",
#         "attributes": [
#           {
#             "original_attribute_name": "coalescence_method",
#             "attribute_type_id": "biolink:has_attribute",
#             "value": "graph_enrichment",
#             "value_type_id": "EDAM:operation_0004"
#           },
#           {
#             "original_attribute_name": "p_value",
#             "attribute_type_id": "biolink:has_numeric_value",
#             "value": 0.0,
#             "value_type_id": "EDAM:data_1669"
#           },
#           {
#             "original_attribute_name": "enriched_nodes",
#             "attribute_type_id": "biolink:has_attribute",
#             "value": [
#               "GO:0001775"
#             ],
#             "value_type_id": "EDAM:data_0006"
#           }
#         ]
#       },
#       {
#         "id": "NCBIGene:5340",
#         "attributes": [
#           {
#             "original_attribute_name": "coalescence_method",
#             "attribute_type_id": "biolink:has_attribute",
#             "value": "graph_enrichment",
#             "value_type_id": "EDAM:operation_0004"
#           },
#           {
#             "original_attribute_name": "p_value",
#             "attribute_type_id": "biolink:has_numeric_value",
#             "value": 0.0,
#             "value_type_id": "EDAM:data_1669"
#           },
#           {
#             "original_attribute_name": "enriched_nodes",
#             "attribute_type_id": "biolink:has_attribute",
#             "value": [
#               "GO:0001775"
#             ],
#             "value_type_id": "EDAM:data_0006"
#           }
#         ]
#       },
#       {
#         "id": "NCBIGene:1950",
#         "attributes": [
#           {
#             "original_attribute_name": "coalescence_method",
#             "attribute_type_id": "biolink:has_attribute",
#             "value": "graph_enrichment",
#             "value_type_id": "EDAM:operation_0004"
#           },
#           {
#             "original_attribute_name": "p_value",
#             "attribute_type_id": "biolink:has_numeric_value",
#             "value": 0.0,
#             "value_type_id": "EDAM:data_1669"
#           },
#           {
#             "original_attribute_name": "enriched_nodes",
#             "attribute_type_id": "biolink:has_attribute",
#             "value": [
#               "GO:0001775"
#             ],
#             "value_type_id": "EDAM:data_0006"
#           }
#         ]
#       }
#     ],
#     "disease": [
#       {
#         "id": "MONDO:0004975"
#       }
#     ],
#     "_n_ac_58_0": [
#       {
#         "id": "GO:0001775"
#       }
#     ]
#   },
#   "edge_bindings": {
#     "e00": [
#       {
#         "id": "648360c28a2c"
#       },
#       {
#         "id": "ec1632d40b25"
#       },
#       {
#         "id": "fe320df07ad2"
#       },
#       {
#         "id": "7b310832aa83"
#       },
#       {
#         "id": "7e8352f2df93"
#       }
#     ],
#     "_e_ac_58_0": [
#       {
#         "id": "-2432539198192019996"
#       },
#       {
#         "id": "-3570758132883244731"
#       },
#       {
#         "id": "-1405990057711531048"
#       },
#       {
#         "id": "-7986338617325845844"
#       }
#     ]
#   },
#   "score": 0.0
# }

# %%
result2['message']['knowledge_graph']['edges']['-2432539198192019996']
# Out:
# {'subject': 'GO:0001775',
#  'object': 'NCBIGene:1950',
#  'predicate': 'biolink:has_part',
#  'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#    'value': 'infores:aragorn'},
#   {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#    'value': 'infores:automat-robokop'}]}

# %%
query={
    "message": {
      "query_graph": {
        "edges": {
          "e00": {
            "subject": "enrichment_node",
              "object": "drug",
              "predicates":["biolink:has_part"]
          }
        },
        "nodes": {
          "enrichment_node": {
            "ids": ["GO:0001775"]
          },
          "drug": {
            "categories": ['biolink:ChemicalEntity']
          }
        }
      }
    },
    "workflow": [{"id":"lookup"}]
  }

# %%
scores = [ r['score'] for r in response.json()['message']['results'] ]

# %%
print(scores)
# Out:
# [0.510846429686573, 0.5060871088749919, 0.5, 0.5, 0.5]

# %%
print(response.status_code)
# Out:
# 200

# %%
aragorn_url = "http://aragorn-dev.apps.renci.org/aragorn/query"
response = requests.post(aragorn_url,json=query)

# %%
scores = [ r['score'] for r in response.json()['message']['results'] ]
print(scores)
# Out:
# [0.5, 0.5, 0.5, 0.2267451154805472, 0.22628507638714038, 0.1983897196479663, 0.15590446820618298, 0.11825812938994941, 0.11598528805156579, 0.11524208508222455, 0.10924998064427234, 0.1065856482718269, 0.10336002959399013, 0.1010726066230609, 0.10079885437124532, 0.10023878492599814, 0.09930535041865343, 0.09924301094778931, 0.09924115856460845, 0.0992354800424769, 0.09917119544847097, 0.09909932891559504, 0.0990992813042587, 0.09909591558198803, 0.09902726872165873, 0.09895515756628528, 0.09895515756628528, 0.09895515756628528, 0.09895515756628528, 0.09895515756628528, 0.09895515756628528, 0.09895515756628528, 0.09895515756628528, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628524, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628523, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628522, 0.09895515756628516, 0.09895515756628516, 0.09895515756628516, 0.09895515756628516, 0.09895515756628516, 0.09895515756628516, 0.09895515756628516, 0.09895515756628516, 0.09895515756628516, 0.09895515756628516, 0.09152957324159736, 0.08946800299192506, 0.08884380810477689, 0.08817085800074344, 0.08802715873814108, 0.08802715873814108, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.0878798521739465, 0.08787985217394649, 0.08787985217394649, 0.08787985217394649, 0.08787985217394649, 0.08787985217394649, 0.08787985217394649, 0.08787985217394649, 0.08787985217394649, 0.08787985217394649, 0.08774287957663537, 0.08774269510304945, 0.08774251062905157, 0.08772479920700246, 0.08759642919462167, 0.08759642919462167, 0.08759642919462167, 0.08759642919462167, 0.08759642919462167, 0.08759642919462167, 0.08759642919462167, 0.08759642919462167, 0.08759642919462167, 0.08759642919462167, 0.08759642919462167, 0.08759642919462167, 0.08759642919462167, 0.0875964291946 ...

# %% [markdown]
# The ARS returned a 201 success code.  It also returned as part of the respone payload a key that we can use to monitor progress and look up results.

# %%
PK = response.json()['pk']
print(PK)
# Out:
# 99ca200b-6f74-4173-b874-2b1e5ed09a37

# %% [markdown]
# The ARAX UI provides a convenient way to view results by PK:

# %%
arax_url = f'https://arax.ncats.io/?source=ARS&id={PK}'
print(arax_url)
# Out:
# https://arax.ncats.io/?source=ARS&id=99ca200b-6f74-4173-b874-2b1e5ed09a37

# %% [markdown]
# You will have noticed that the specified nodes `n00` and `n02` are defined in terms of identifiers, not names.  All nodes and edges in Translator queries and results are defined by CURIES (Compact URIs).  There are two tools in Translator to help navigate identifiers and queries.
#
# The name-resolver: https://name-resolution-sri.renci.org/docs has a lookup function that can take a string and return potential identifiers.  Here, we look up the string "alzheimer"

# %%
results = requests.post('https://name-resolution-sri.renci.org/lookup?string=alzheimer&offset=0&limit=10')

# %%
print(json.dumps(results.json(),indent=4))
# Out:
# {
#     "MONDO:0004975": [
#         "Alzheimer",
#         "Alzheimers",
#         "Alzheimer's",
#         "ALZHEIMER DIS",
#         "ALZHEIMERS DIS",
#         "Alzheimer Disease",
#         "ALZHEIMER DISEASE",
#         "Alzheimer disease",
#         "Alzheimer Dementia",
#         "Alzheimers disease",
#         "DEMENTIA ALZHEIMER",
#         "Alzheimer syndrome",
#         "alzheimers disease",
#         "Disease, Alzheimer",
#         "Alzheimer Syndrome",
#         "alzheimer diseases",
#         "Disease;Alzheimers",
#         "Alzheimers Disease",
#         "Alzheimer dementia",
#         "Alzheimer's Disease",
#         "Alzheimer's disease",
#         "Alzheimers Dementia",
#         "Alzheimers dementia",
#         "ALZHEIMER'S DISEASE",
#         "alzheimer's disease",
#         "Alzheimer Sclerosis",
#         "Alzheimer Dementias",
#         "Alzheimer sclerosis",
#         "Dementia, Alzheimer",
#         "alzheimers dementia",
#         "dementia alzheimers",
#         "sclerosis; Alzheimer",
#         "Disease, Alzheimer's",
#         "Alzheimer's dementia",
#         "Dementias, Alzheimer",
#         "Alzheimer; sclerosis",
#         "alzheimer's diseases",
#         "Sclerosis, Alzheimer",
#         "Alzheimer's Dementia",
#         "Alzheimer disease (AD)",
#         "Alzheimer-type dementia",
#         "Alzheimer Type Dementia",
#         "Alzheimer dementia (AD)",
#         "Dementia, Alzheimer Type",
#         "AD - Alzheimer's disease",
#         "Alzheimer's disease, NOS",
#         "Dementia Alzheimer's type",
#         "Alzheimer disease, familial",
#         "Dementia in Alzheimer's dis",
#         "Dementia of Alzheimers Type",
#         "Presenile Alzheimer Dementia",
#         "sporadic Alzheimer's disease",
#         "Alzheimer-type dementia (ADT)",
#         "DAT - Dementia Alzheimer type",
#         "Alzheimer-Type Dementia (ATD)",
#         "Dementia, Presenile Alzheimer",
#         "Alzheimer Dementia, Presenile",
#         "Alzheimer Type Dementia (ATD)",
#         "Alzheimer; dementia (etiology)",
#         "Alzheimer Type Senile Dementia",
#         "DEMENTIA OF THE ALZHEIMER TYPE",
#         "Alzheimer's disease (disorder)",
#         "Dementia, Alzheimer-Type (ATD)",
#         "dementia of the Alzheimer type",
#         "dementia; Alzheimer (etiology)",
#         "DAT - Dementia Alzheimer's type",
#         "Senile Dementia, Alzheimer Type",
#         "Alzheimer's disease (diagnosis)",
#         "Dementia in Alzheimer's disease",
#         "Alzheimer's Disease Pathway KEGG",
#         "Dementia of the Alzheimer's type",
#         "Alzheimer's disease, unspecified",
#         "[X]Dementia in Alzheimer's disease",
#         "Progression of Alzheimer's disease",
#         "dementia; Alzheimer (manifestation)",
#         "Alzheimer; dementia (manifestation)",
#         "dementia of the Alzheimer type (DAT)",
#         "Dementia of the Alzheimer's type NOS",
#         "senile dementia of the Alzheimer type",
#         "SENILE DEMENTIA OF THE ALZHEIMER TYPE",
#         "Dementia in Alzheimer's disease (disorder)",
#         "senile dementia of the Alzheimer type (SDAT)",
#         "Late-onset form of familial Alzheimer disease",
#         "[X]Dementia in Alzheimer's disease (disorder)",
#         "Dementia in Alzheimer's disease, unspecified (disorder)",
#         "AD",
#         "DAT",
#         "SDAT",
#         "dats",
#         "senile dementia",
#         "Senile Dementia",
#         "Dementia, Senile",
#         "Dementia, Presenile",
#         "simple senile dementia",
#         "Primary Senile Degenerative Dementia",
#         "Dementia, Primary Senile Degenerative"
#     ],
#     "MESH:D023582": [
#         "Alzheimer Vaccines"
#     ],
#     "MONDO:0011743": [
#         "ALZHEIMER DISEASE 4",
#         "Alzheimer disease 4",
#         "Alzheimer's disease 4",
#         "Alzheimer disease type 4",
#         "Alzheimer's disease type 4",
#         "Alzheimer disease, familial4",
#         "Alzheimer disease, familial, 4",
#         "Alzheimer Disease, Familial, 4",
#         "ALZHEIMER DISEASE, FAMILIAL, 4",
#         "Alzheimer disease familial type 4",
#         "familial Alzheimer disease, type 4",
#         "Familial Alzheimer Disease, Type 4",
#         "Alzheimer disease, familial, type 4",
#         "Familial Alzheimer's Disease, Type 4",
#         "familial Alzheimer's disease, type 4",
#         "Ad4",
#         "AD4"
#     ],
#     "MONDO:0011561": [
#         "Alzheimer Disease 6",
#         "Alzheimer disease 6",
#         "Alzheimer's disease 6",
#         "Alzheimer disease type 6",
#         "Alzheimer's disease type 6",
#         "Alzheimer disease 6, late onset",
#         "Alzheimer disease 6, late-onset",
#         "AD6",
#         "AD6",
#         "plasma Beta-amyloid-42 level quantitative trait locus"
#     ],
#     "MONDO:0007088": [
#         "Alzheimer disease 1",
#         "Alzheimer disease 1",
#         "Alzheimer disease; AD",
#         "Alzheimer disease type 1",
#         "Alzheimer disease, familial, 1",
#         "Alzheimer disease, protection against",
#         "early-onset familial form of Alzheimer disease",
#         "Early-onset familial form of Alzheimer disease",
#         "Alzheimer disease, early-onset, with cerebral amyloid angiopathy",
#         "AD1",
#         "presenile and senile dementia"
#     ],
#     "MONDO:0011647": [
#         "Alzheimer disease 7",
#         "ALZHEIMER DISEASE 7",
#         "Alzheimer Disease 7",
#         "Alzheimer's disease 7",
#         "Alzheimer disease type 7",
#         "Alzheimer's disease type 7",
#         "Alzheimer disease, familial 7",
#         "ALZHEIMER DISEASE, FAMILIAL, 7",
#         "Alzheimer disease, familial, 7",
#         "Alzheimer Disease, Familial, 7",
#         "AD7",
#         "Ad7"
#     ],
#     "MONDO:0011777": [
#         "Alzheimer disease 8",
#         "ALZHEIMER DISEASE 8",
#         "Alzheimer Disease 8",
#         "Alzheimer's disease 8",
#         "Alzheimer disease type 8",
#         "Alzheimer's disease type 8",
#         "Alzheimer disease, familial 8",
#         "ALZHEIMER DISEASE, FAMILIAL, 8",
#         "Alzheimer disease, familial, 8",
#         "Alzheimer Disease, Familial, 8",
#         "AD8",
#         "Ad8"
#     ],
#     "MONDO:0011913": [
#         "Alzheimer disease 3",
#         "Alzheimer's disease 3",
#         "Alzheimer disease 3; AD",
#         "Alzheimer disease type 3",
#         "Alzheimer's disease type 3",
#         "Alzheimer disease familial 3",
#         "Alzheimer disease, familial, 3",
#         "Alzheimer disease 3, early onset",
#         "Alzheimer disease 3, early-onset",
#         "familial Alzheimer disease, type 3",
#         "Familial Alzheimer Disease, Type 3",
#         "Alzheimer disease, familial, type 3",
#         "familial Alzheimer's disease, type 3",
#         "Familial Alzheimer's Disease, Type 3",
#         "Alzheimer disease early onset type 3",
#         "PSEN1 early-onset autosomal dominant Alzheimer disease",
#         "Alzheimer disease, familial, 3, with spastic paraparesis and apraxia",
#         "Alzheimer disease, familial, 3, with spastic paraparesis and unusual plaques",
#         "early-onset autosomal dominant Alzheimer disease caused by mutation in PSEN1",
#         "AD3"
#     ],
#     "MONDO:0007089": [
#         "Alzheimer Disease 2",
#         "ALZHEIMER DISEASE 2",
#         "Alzheimer disease 2",
#         "Alzheimer disease-2",
#         "Alzheimer's disease 2",
#         "Alzheimer disease 2; AD2",
#         "Alzheimer disease type 2",
#         "Alzheimer's disease type 2",
#         "late onset Alzheimer disease",
#         "Fam Alzheimer dis of late onse",
#         "ALZHEIMER DISEASE 2, LATE-ONSET",
#         "Alzheimer disease 2, late-onset",
#         "Alzheimer disease 2, late onset",
#         "Alzheimer Disease 2, Late-Onset",
#         "late onset familial Alzheimer disease",
#         "Late onset familial Alzheimer disease",
#         "Alzheimer Disease Associated With Apoe4",
#         "ALZHEIMER DISEASE ASSOCIATED WITH APOE4",
#         "Alzheimer disease associated with Apoe4",
#         "Alzheimer disease associated with APOE4",
#         "Familial Alzheimer disease of late onset",
#         "Alzheimer disease associated with APOE E4",
#         "Alzheimer disease associated with APOE E4",
#         "Familial Alzheimer's disease of late onset",
#         "Late-onset form of familial Alzheimer disease",
#         "Familial Alzheimer's disease of late onset (disorder)",
#         "AD2",
#         "LOFAD"
#     ],
#     "MONDO:0011194": [
#         "Alzheimer Disease 5",
#         "Alzheimer disease 5",
#         "ALZHEIMER DISEASE 5",
#         "Alzheimer's disease 5",
#         "Alzheimer disease type 5",
#         "Alzheimer's disease type 5",
#         "Alzheimer disease, familial 5",
#         "Alzheimer Disease, Familial, 5",
#         "ALZHEIMER DISEASE, FAMILIAL, 5",
#         "Alzheimer disease, familial, 5",
#         "AD5",
#         "Ad5"
#     ]
# }

# %% [markdown]
# The node normalizer (https://nodenormalization-sri.renci.org/docs) takes CURIES and returns all other CURIES that are synonymous with the input. It also returns labels for the node, the biolink classes of the node, and often the information content of the node.

# %%
nn_query = {
  "curies": [
    "MONDO:0004975",
  ],
  "conflate": True
}
results = requests.post('https://nodenormalization-sri.renci.org/get_normalized_nodes',json=nn_query)

# %%
print(json.dumps(results.json(),indent=4))
# Out:
# {
#     "MONDO:0004975": {
#         "id": {
#             "identifier": "MONDO:0004975",
#             "label": "Alzheimer disease"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "MONDO:0004975",
#                 "label": "Alzheimer disease"
#             },
#             {
#                 "identifier": "DOID:10652",
#                 "label": "Alzheimer's disease"
#             },
#             {
#                 "identifier": "EFO:0000249",
#                 "label": "Alzheimer's disease"
#             },
#             {
#                 "identifier": "UMLS:C0002395",
#                 "label": "Alzheimer's Disease"
#             },
#             {
#                 "identifier": "UMLS:C0011265",
#                 "label": "Presenile dementia"
#             },
#             {
#                 "identifier": "UMLS:C0276496",
#                 "label": "Familial Alzheimer Disease (FAD)"
#             },
#             {
#                 "identifier": "UMLS:C0494463",
#                 "label": "Alzheimer Disease, Late Onset"
#             },
#             {
#                 "identifier": "UMLS:C0546126",
#                 "label": "Acute Confusional Senile Dementia"
#             },
#             {
#                 "identifier": "UMLS:C0750900",
#                 "label": "Alzheimer's Disease, Focal Onset"
#             },
#             {
#                 "identifier": "UMLS:C0750901",
#                 "label": "Alzheimer Disease, Early Onset"
#             },
#             {
#                 "identifier": "MESH:D000544",
#                 "label": "Alzheimer Disease"
#             },
#             {
#                 "identifier": "MEDDRA:10001896"
#             },
#             {
#                 "identifier": "MEDDRA:10012271"
#             },
#             {
#                 "identifier": "MEDDRA:10012292"
#             },
#             {
#                 "identifier": "MEDDRA:10012298"
#             },
#             {
#                 "identifier": "MEDDRA:10036506"
#             },
#             {
#                 "identifier": "MEDDRA:10036631"
#             },
#             {
#                 "identifier": "NCIT:C2866",
#                 "label": "Alzheimer's Disease"
#             },
#             {
#                 "identifier": "NCIT:C34523",
#                 "label": "Pre-Senile Dementia"
#             },
#             {
#                 "identifier": "NCIT:C38778",
#                 "label": "Alzheimer's Disease Pathway KEGG"
#             },
#             {
#                 "identifier": "SNOMEDCT:12348006"
#             },
#             {
#                 "identifier": "SNOMEDCT:142811000119104"
#             },
#             {
#                 "identifier": "SNOMEDCT:230267005"
#             },
#             {
#                 "identifier": "SNOMEDCT:26929004"
#             },
#             {
#                 "identifier": "SNOMEDCT:416780008"
#             },
#             {
#                 "identifier": "SNOMEDCT:416975007"
#             },
#             {
#                 "identifier": "ICD10:G30"
#             },
#             {
#                 "identifier": "ICD9:331.0"
#             },
#             {
#                 "identifier": "KEGG.DISEASE:05010"
#             },
#             {
#                 "identifier": "HP:0002511",
#                 "label": "Alzheimer disease"
#             }
#         ],
#         "type": [
#             "biolink:Disease",
#             "biolink:DiseaseOrPhenotypicFeature",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:ThingWithTaxon"
#         ],
#         "information_content": 100.0
#     }
# }
